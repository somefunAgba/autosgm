# %%
# !pip install watermark numpy pandas matplotlib torch torchvision torchaudio --yes

# %load_ext watermark
# %watermark -v -p watermark,numpy,pandas,matplotlib,torch

#
import math,random,os,copy,time,glob,itertools,shutil,re, json
from scipy.stats import wilcoxon

#
import numpy as np

#
import torch
import torch.nn as nn
import torch.nn.functional as tf
from torch.utils.data import Dataset,DataLoader
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor, Lambda

#
import matplotlib.pyplot as plt 
import matplotlib.ticker as ticker
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif", # sans-serif
    "font.sans-serif": "Helvetica", # Times, Palatino, Computer Modern Roman
})
from mpl_toolkits import mplot3d

#
import pandas as pd


#
from demofcns import *
from opts.asgm.torchlasgm import PID
from opts.elpf.fo import LPF
from opts.elpf.sfo import sLPF

worker_seed = 2023
def setseed(inc=0):
    # for redundancy
    # set seed for technical reproducibility
    myseed = worker_seed + inc
    random.seed(myseed)
    np.random.seed(myseed)
    np.random.default_rng(myseed)
    torch.manual_seed(myseed)    
    
    # torch.use_deterministic_algorithms(True)
    if torch.cuda.device_count() > 0:
      torch.cuda.manual_seed_all(myseed)
      torch.cuda.manual_seed(myseed)
      # torch.backends.cudnn.enabled = True
      # torch.backends.cuda.matmul.allow_tf32 = False
      # torch.backends.cudnn.benchmark = False
      # torch.backends.cudnn.deterministic = False
      # torch.backends.cudnn.allow_tf32 = True



class cseed_worker():
  def __init__(self,inc=0):
    self.inc = inc
    
  def seed_worker(self,workerid):
    np.random.seed(worker_seed+self.inc)
    random.seed(worker_seed+self.inc)

cseedwk = cseed_worker()

# python3 -m torch.utils.collect_env
# Out:
# Python implementation: CPython
# Python version       : 3.10.6
# IPython version      : 8.4.0
#
# watermark : 2.3.1
# numpy     : 1.23.2
# pandas    : 1.4.3
# matplotlib: 3.5.3
# torch     : 1.12.1+cu116

# %% [markdown]
# ##### Setup Configurations (Hyperparameters and so on)

# %%
# - is it being run remotely on OSU EECS server?
remotelyrun = 0 # 0 | 1

#----------------------
# Load setup config
#----------------------
with open('cfgs.json', 'r') as cfglist:
  cfgs = json.load(cfglist)
  
# setup
cfgs['storedir'] = "expstore"

# - pick data-set
cfgs["dataset"] = "fmnist"
# - set max. batchsize for each epoch, training runs, training epochs, 
cfgs["batch-size"] = 128 # 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, ...
cfgs['runs'] = 10
cfgs["epochs"] = 30

# -pick computation device
devcnt = torch.cuda.device_count()

# - setup multiprocessing, human signature
# random seed for python libraries
cfgs["seed"] = 2023
cfgs["var_seed"] = 1
worker_seed = cfgs["seed"] % (2**32)
cfgs["num-workers"] = 0 #3
cfgs["human_signature"] = "oas" # for signing experiments ran.


if devcnt > 1:
  cfgs["device"] = torch.device('cuda') # "cuda:1"
  torch.cuda.set_device(1)
elif devcnt == 1:
  cfgs["device"] = torch.device('cuda')
else:
  cfgs["device"] = torch.device('cpu')
#
if remotelyrun:
  cfgs["remote"] = True
else:
  cfgs["remote"] = False

# %% [markdown]
# ##### Construct Model (Differentiable Function) with  necessary methods.

# %%
''' LeNet
Image: 28x28

Conv: channels: 6 kernel: 5x5, pad=2 
=layer: 6x1x5x5, out: 6x28x28
Pool(Avg): 2x2, stride: 2
=layer: 2x2, out: 6x14x14

Conv: channels: 16 kernel: 5x5
=layer: 16x6x5x5, out: 16x10x10
Pool(Avg): 2x2, stride: 2
=layer: 2x2, out: 16x5x5

Flatten: 16x5x5=400
FC: 400 x 120: out width: 120
FC: 120 x 84: out width: 84
FC: 84 x 10: out width: 10

CNN: LeNet Class
'''
class LeNet(nn.Module):
  
  def __init__(self, cfgs=None):
    super(LeNet,self).__init__()
    
    self.lenet = nn.Sequential(
      nn.Conv2d(in_channels=1, out_channels=6, kernel_size=5, stride=1, padding=2),
      nn.AvgPool2d(kernel_size=2,stride=2),
      nn.ReLU(),
      nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, stride=1, padding=0),
      nn.AvgPool2d(kernel_size=2,stride=2),
      nn.ReLU(),
      nn.Flatten(),
      nn.Linear(in_features=16*5*5,out_features=120, bias=True),
      nn.ReLU(),
      nn.Linear(in_features=120,out_features=84, bias=True),
      nn.ReLU(),
      nn.Linear(in_features=84,out_features=10, bias=True),
    )
    
  def forward(self, X):
    Y = self.lenet(X)
    return Y


class thisNN(nn.Module):
  def __init__(self,num_heads=1,in_feats=1,out_feats=1, loss_type="mse", outs_class=False, mdl_name="nn1") -> None:
    """
    __init__ _summary_

    _extended_summary_

    Args:
        num_heads (int, req): net. output head. Defaults to 1.
        in_feats (int, req): net. input dimension. Defaults to 1.
        out_feats (int, req): net. output dimension per head. Defaults to 1.
        loss_type (str, req): type of loss function Defaults to "mse". ("mse","mce" for multi-class cross-entropy, "bce" binary-class cross-entropy)
        outs_class (bool, req): does model return class indices. Defaults to False, implying it outputs real-valued probabilities. This is also true for loss_type="mse" regardless of user-choice.
    """
    super().__init__()
    self.num_heads = num_heads
    
    # define mdl. params.
    self.cnn = nn.ModuleList()
    for hid in range(num_heads):
      h = LeNet()
      self.cnn.append(
        h
      )
    self.relu = nn.ReLU()
    self.flatten = nn.Flatten()
    
    # prob.fcn at last output or network head layer
    if loss_type == "bce" or loss_type == "mse":
      self.out = torch.nn.Sigmoid()
    else:
      self.out = torch.nn.Softmax()
    
    self.loss_type = loss_type
    self.outs_class = outs_class
    
    # optimizer
    self.sgm = None
    
    # saved trained model
    self.chkpt = None
    
    
    self.devcnt = torch.cuda.device_count()
    self.device = None
    self.name = mdl_name
    
    if not(loss_type == "mse" or loss_type =="mce" or loss_type == "bce"):
      raise ValueError(f"loss_type='{loss_type}' is not defined for this class")
    if (loss_type == "mse"):
      self.outs_class = False    
    
@clsmethod(thisNN)
def forward(self:thisNN, x):
  # pre-process
  # x = x.squeeze() # N x 1 x 28 x 28 -> N x 28 x 28
  logits = []
  for hid in range(self.num_heads):
    lenet = self.cnn[hid]
    y = lenet(x)  
    logits.append(y)
    
  return logits # List [Tensor]

@clsmethod(thisNN)
def outhead(self:thisNN, x):
  probs = []
  for hid in range(self.num_heads):
    y = self.out(x[hid])
    probs.append(y)  
  return probs # List [Tensor]

# Add necessary functions to train model
add_to_thisnn(thisNN,worker_seed,setseed,cseedwk)

# Use saved mdl as
# mdl <-- load model function
# prediction = mdl.infer(input)

# %% [markdown]
# ##### (Generate) or Load the Dataset

# %%
#----------------------
# Download/Load Dataset
#----------------------
if not cfgs["remote"]:
  # same dir. as source-code
  data_folder = "data"
else:
  # dalton's scratch on OSU's eecs server
  data_folder = "/scratch/data"


# FMNIST
if cfgs["dataset"] == "fmnist":
  train_data = datasets.FashionMNIST(
    root=data_folder,
    train=True,
    download=True,
    transform=ToTensor(),
  )
  test_data = datasets.FashionMNIST(
    root=data_folder,
    train=False,
    download= True,
    transform=ToTensor()
  )
  indim = [28,28]
  class_num = 10
  channels = 1
  val_data = None
  
# Tests 
trainloader = torch.utils.data.DataLoader(train_data, batch_size=cfgs['batch-size'],shuffle=True)
# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)
pass

# %% [markdown]
# ##### Run the Network Modeling (Training)

# %%
# Test.

torch.manual_seed(2023)
devcnt = torch.cuda.device_count()

cfgs['mdl_name_dir'] = "nnlenetfmnist"
isclassifier = True
cfgs["ss_init"] = 1e-3 # default 1e-3
cfgs["eps_ss"] = 5e-1 # default 5e-1
cfgs["weight_decay"] = 1e-5 # default 1e-5
mdl = thisNN(num_heads=1,in_feats=[28,28],out_feats=10,loss_type="mce",outs_class=isclassifier, mdl_name=cfgs['mdl_name_dir'])
if devcnt > 0:
    mdl.cuda()
cfgs['pathstr'] = str(mdl.name)+str(cfgs["batch-size"])+"_"+cfgs["dataset"]+"_"+str(cfgs["runs"])+"_"+str(cfgs["epochs"])

mdl.runs(train_data, test_data, cfgs=cfgs, eval_name="Test")
# Out:
# Seed: 2023
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9985],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.21-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.6410, Accuracy: 77.39% ] || Test: [ Avg Loss: 0.4926, Accuracy: 81.92% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4278, Accuracy: 84.64% ] || Test: [ Avg Loss: 0.4248, Accuracy: 84.39% ]
# Elapsed Inf. time: 0.01-mins.
#
# 3: Elapsed Train time: 0.15-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3791, Accuracy: 86.47% ] || Test: [ Avg Loss: 0.3869, Accuracy: 86.03% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3485, Accuracy: 87.60% ] || Test: [ Avg Loss: 0.3631, Accuracy: 86.81% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.15-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3279, Accuracy: 88.32% ] || Test: [ Avg Loss: 0.3633, Accuracy: 86.98% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3156, Accuracy: 88.55% ] || Test: [ Avg Loss: 0.3383, Accuracy: 88.07% ]
# Elapsed Inf. time: 0.01-mins.
#
# 7: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2981, Accuracy: 89.22% ] || Test: [ Avg Loss: 0.3327, Accuracy: 88.03% ]
# Elapsed Inf. time: 0.02-mins.
#
# 8: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2878, Accuracy: 89.52% ] || Test: [ Avg Loss: 0.3257, Accuracy: 88.34% ]
# Elapsed Inf. time: 0.03-mins.
#
# 9: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2772, Accuracy: 89.81% ] || Test: [ Avg Loss: 0.3176, Accuracy: 88.39% ]
# Elapsed Inf. time: 0.03-mins.
#
# 10: Elapsed Train time: 0.23-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2667, Accuracy: 90.22% ] || Test: [ Avg Loss: 0.3115, Accuracy: 88.61% ]
# Elapsed Inf. time: 0.02-mins.
#
# 11: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2589, Accuracy: 90.53% ] || Test: [ Avg Loss: 0.3102, Accuracy: 88.92% ]
# Elapsed Inf. time: 0.01-mins.
#
# 12: Elapsed Train time: 0.15-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2499, Accuracy: 90.73% ] || Test: [ Avg Loss: 0.3104, Accuracy: 88.77% ]
# Elapsed Inf. time: 0.01-mins.
#
# 13: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2423, Accuracy: 91.08% ] || Test: [ Avg Loss: 0.3088, Accuracy: 88.75% ]
# Elapsed Inf. time: 0.02-mins.
#
# 14: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2336, Accuracy: 91.33% ] || Test: [ Avg Loss: 0.3009, Accuracy: 89.12% ]
# Elapsed Inf. time: 0.01-mins.
#
# 15: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2298, Accuracy: 91.46% ] || Test: [ Avg Loss: 0.3067, Accuracy: 89.06% ]
# Elapsed Inf. time: 0.01-mins.
#
# 16: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2208, Accuracy: 91.82% ] || Test: [ Avg Loss: 0.2962, Accuracy: 89.41% ]
# Elapsed Inf. time: 0.02-mins.
#
# 17: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2147, Accuracy: 92.03% ] || Test: [ Avg Loss: 0.2968, Accuracy: 89.39% ]
# Elapsed Inf. time: 0.01-mins.
#
# 18: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2109, Accuracy: 92.17% ] || Test: [ Avg Loss: 0.2946, Accuracy: 89.62% ]
# Elapsed Inf. time: 0.01-mins.
#
# 19: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2053, Accuracy: 92.38% ] || Test: [ Avg Loss: 0.2935, Accuracy: 89.74% ]
# Elapsed Inf. time: 0.01-mins.
#
# 20: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1971, Accuracy: 92.64% ] || Test: [ Avg Loss: 0.2997, Accuracy: 89.53% ]
# Elapsed Inf. time: 0.01-mins.
#
# 21: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1937, Accuracy: 92.81% ] || Test: [ Avg Loss: 0.2991, Accuracy: 89.85% ]
# Elapsed Inf. time: 0.01-mins.
#
# 22: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1879, Accuracy: 93.00% ] || Test: [ Avg Loss: 0.2870, Accuracy: 90.01% ]
# Elapsed Inf. time: 0.01-mins.
#
# 23: Elapsed Train time: 0.15-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1845, Accuracy: 93.10% ] || Test: [ Avg Loss: 0.2976, Accuracy: 89.47% ]
# Elapsed Inf. time: 0.01-mins.
#
# 24: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1780, Accuracy: 93.25% ] || Test: [ Avg Loss: 0.2979, Accuracy: 89.90% ]
# Elapsed Inf. time: 0.02-mins.
#
# 25: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1734, Accuracy: 93.56% ] || Test: [ Avg Loss: 0.2953, Accuracy: 90.17% ]
# Elapsed Inf. time: 0.01-mins.
#
# 26: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1692, Accuracy: 93.68% ] || Test: [ Avg Loss: 0.2958, Accuracy: 90.04% ]
# Elapsed Inf. time: 0.01-mins.
#
# 27: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1655, Accuracy: 93.78% ] || Test: [ Avg Loss: 0.3000, Accuracy: 89.85% ]
# Elapsed Inf. time: 0.01-mins.
#
# 28: Elapsed Train time: 0.15-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1601, Accuracy: 94.07% ] || Test: [ Avg Loss: 0.3015, Accuracy: 90.07% ]
# Elapsed Inf. time: 0.01-mins.
#
# 29: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1550, Accuracy: 94.30% ] || Test: [ Avg Loss: 0.3045, Accuracy: 89.96% ]
# Elapsed Inf. time: 0.01-mins.
#
# 30: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1528, Accuracy: 94.19% ] || Test: [ Avg Loss: 0.2988, Accuracy: 89.94% ]
# Elapsed Inf. time: 0.01-mins.
#
# *********************************************************************************
# Done! Run: 1 : [Best Test @ epoch 25] || [ Avg loss: 0.295325, Accuracy: 90.17% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9985],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.6352, Accuracy: 76.94% ] || Test: [ Avg Loss: 0.4855, Accuracy: 82.60% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4369, Accuracy: 84.46% ] || Test: [ Avg Loss: 0.4228, Accuracy: 84.63% ]
# Elapsed Inf. time: 0.02-mins.
#
# 3: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3828, Accuracy: 86.19% ] || Test: [ Avg Loss: 0.3886, Accuracy: 85.95% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.15-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3541, Accuracy: 87.14% ] || Test: [ Avg Loss: 0.3691, Accuracy: 86.66% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.15-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3323, Accuracy: 87.83% ] || Test: [ Avg Loss: 0.3543, Accuracy: 87.26% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3163, Accuracy: 88.44% ] || Test: [ Avg Loss: 0.3368, Accuracy: 88.07% ]
# Elapsed Inf. time: 0.02-mins.
#
# 7: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3052, Accuracy: 88.72% ] || Test: [ Avg Loss: 0.3301, Accuracy: 88.15% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2926, Accuracy: 89.12% ] || Test: [ Avg Loss: 0.3263, Accuracy: 88.16% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2844, Accuracy: 89.56% ] || Test: [ Avg Loss: 0.3169, Accuracy: 88.76% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2746, Accuracy: 89.78% ] || Test: [ Avg Loss: 0.3099, Accuracy: 88.84% ]
# Elapsed Inf. time: 0.02-mins.
#
# 11: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2660, Accuracy: 90.15% ] || Test: [ Avg Loss: 0.3100, Accuracy: 88.90% ]
# Elapsed Inf. time: 0.01-mins.
#
# 12: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2591, Accuracy: 90.41% ] || Test: [ Avg Loss: 0.3066, Accuracy: 88.97% ]
# Elapsed Inf. time: 0.02-mins.
#
# 13: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2516, Accuracy: 90.69% ] || Test: [ Avg Loss: 0.3027, Accuracy: 89.26% ]
# Elapsed Inf. time: 0.01-mins.
#
# 14: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2472, Accuracy: 90.78% ] || Test: [ Avg Loss: 0.3027, Accuracy: 89.20% ]
# Elapsed Inf. time: 0.01-mins.
#
# 15: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2385, Accuracy: 91.12% ] || Test: [ Avg Loss: 0.2987, Accuracy: 89.47% ]
# Elapsed Inf. time: 0.01-mins.
#
# 16: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2312, Accuracy: 91.38% ] || Test: [ Avg Loss: 0.3026, Accuracy: 89.10% ]
# Elapsed Inf. time: 0.01-mins.
#
# 17: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2252, Accuracy: 91.54% ] || Test: [ Avg Loss: 0.2841, Accuracy: 90.00% ]
# Elapsed Inf. time: 0.01-mins.
#
# 18: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2209, Accuracy: 91.73% ] || Test: [ Avg Loss: 0.2946, Accuracy: 89.77% ]
# Elapsed Inf. time: 0.01-mins.
#
# 19: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2116, Accuracy: 92.12% ] || Test: [ Avg Loss: 0.2876, Accuracy: 89.98% ]
# Elapsed Inf. time: 0.01-mins.
#
# 20: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2072, Accuracy: 92.27% ] || Test: [ Avg Loss: 0.3020, Accuracy: 89.43% ]
# Elapsed Inf. time: 0.01-mins.
#
# 21: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2022, Accuracy: 92.47% ] || Test: [ Avg Loss: 0.3029, Accuracy: 89.66% ]
# Elapsed Inf. time: 0.01-mins.
#
# 22: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1972, Accuracy: 92.53% ] || Test: [ Avg Loss: 0.2883, Accuracy: 90.12% ]
# Elapsed Inf. time: 0.01-mins.
#
# 23: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1942, Accuracy: 92.72% ] || Test: [ Avg Loss: 0.2982, Accuracy: 89.83% ]
# Elapsed Inf. time: 0.01-mins.
#
# 24: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1871, Accuracy: 92.96% ] || Test: [ Avg Loss: 0.3034, Accuracy: 89.99% ]
# Elapsed Inf. time: 0.01-mins.
#
# 25: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1815, Accuracy: 93.22% ] || Test: [ Avg Loss: 0.3037, Accuracy: 90.07% ]
# Elapsed Inf. time: 0.01-mins.
#
# 26: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1794, Accuracy: 93.18% ] || Test: [ Avg Loss: 0.3026, Accuracy: 89.95% ]
# Elapsed Inf. time: 0.01-mins.
#
# 27: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1738, Accuracy: 93.44% ] || Test: [ Avg Loss: 0.2971, Accuracy: 89.89% ]
# Elapsed Inf. time: 0.02-mins.
#
# 28: Elapsed Train time: 0.21-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1680, Accuracy: 93.73% ] || Test: [ Avg Loss: 0.3078, Accuracy: 90.05% ]
# Elapsed Inf. time: 0.02-mins.
#
# 29: Elapsed Train time: 0.19-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1665, Accuracy: 93.86% ] || Test: [ Avg Loss: 0.3085, Accuracy: 89.92% ]
# Elapsed Inf. time: 0.01-mins.
#
# 30: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1608, Accuracy: 93.99% ] || Test: [ Avg Loss: 0.3140, Accuracy: 89.92% ]
# Elapsed Inf. time: 0.01-mins.
#
# *********************************************************************************
# Done! Run: 2 : [Best Test @ epoch 22] || [ Avg loss: 0.288325, Accuracy: 90.12% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9985],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.6041, Accuracy: 78.26% ] || Test: [ Avg Loss: 0.4642, Accuracy: 83.20% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4178, Accuracy: 84.83% ] || Test: [ Avg Loss: 0.3980, Accuracy: 85.70% ]
# Elapsed Inf. time: 0.01-mins.
#
# 3: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3680, Accuracy: 86.53% ] || Test: [ Avg Loss: 0.3733, Accuracy: 86.72% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3409, Accuracy: 87.66% ] || Test: [ Avg Loss: 0.3576, Accuracy: 86.81% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3204, Accuracy: 88.23% ] || Test: [ Avg Loss: 0.3419, Accuracy: 87.60% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3072, Accuracy: 88.57% ] || Test: [ Avg Loss: 0.3367, Accuracy: 87.95% ]
# Elapsed Inf. time: 0.02-mins.
#
# 7: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2905, Accuracy: 89.25% ] || Test: [ Avg Loss: 0.3203, Accuracy: 88.24% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2823, Accuracy: 89.64% ] || Test: [ Avg Loss: 0.3206, Accuracy: 88.59% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2697, Accuracy: 90.03% ] || Test: [ Avg Loss: 0.3149, Accuracy: 88.44% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2636, Accuracy: 90.31% ] || Test: [ Avg Loss: 0.3048, Accuracy: 89.00% ]
# Elapsed Inf. time: 0.01-mins.
#
# 11: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2550, Accuracy: 90.53% ] || Test: [ Avg Loss: 0.3112, Accuracy: 88.78% ]
# Elapsed Inf. time: 0.01-mins.
#
# 12: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2452, Accuracy: 90.94% ] || Test: [ Avg Loss: 0.2938, Accuracy: 89.60% ]
# Elapsed Inf. time: 0.01-mins.
#
# 13: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2379, Accuracy: 91.14% ] || Test: [ Avg Loss: 0.2917, Accuracy: 89.78% ]
# Elapsed Inf. time: 0.01-mins.
#
# 14: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2289, Accuracy: 91.65% ] || Test: [ Avg Loss: 0.2978, Accuracy: 88.98% ]
# Elapsed Inf. time: 0.01-mins.
#
# 15: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2236, Accuracy: 91.73% ] || Test: [ Avg Loss: 0.2913, Accuracy: 89.51% ]
# Elapsed Inf. time: 0.01-mins.
#
# 16: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2172, Accuracy: 91.82% ] || Test: [ Avg Loss: 0.2911, Accuracy: 89.84% ]
# Elapsed Inf. time: 0.01-mins.
#
# 17: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2123, Accuracy: 92.04% ] || Test: [ Avg Loss: 0.2963, Accuracy: 89.45% ]
# Elapsed Inf. time: 0.01-mins.
#
# 18: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2055, Accuracy: 92.23% ] || Test: [ Avg Loss: 0.2899, Accuracy: 89.54% ]
# Elapsed Inf. time: 0.01-mins.
#
# 19: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1988, Accuracy: 92.57% ] || Test: [ Avg Loss: 0.2973, Accuracy: 89.78% ]
# Elapsed Inf. time: 0.01-mins.
#
# 20: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1937, Accuracy: 92.76% ] || Test: [ Avg Loss: 0.2991, Accuracy: 89.93% ]
# Elapsed Inf. time: 0.01-mins.
#
# 21: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1887, Accuracy: 93.03% ] || Test: [ Avg Loss: 0.2875, Accuracy: 89.97% ]
# Elapsed Inf. time: 0.01-mins.
#
# 22: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1837, Accuracy: 93.10% ] || Test: [ Avg Loss: 0.3125, Accuracy: 89.10% ]
# Elapsed Inf. time: 0.01-mins.
#
# 23: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1797, Accuracy: 93.16% ] || Test: [ Avg Loss: 0.2976, Accuracy: 90.01% ]
# Elapsed Inf. time: 0.01-mins.
#
# 24: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1725, Accuracy: 93.56% ] || Test: [ Avg Loss: 0.2956, Accuracy: 89.85% ]
# Elapsed Inf. time: 0.01-mins.
#
# 25: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1703, Accuracy: 93.56% ] || Test: [ Avg Loss: 0.3109, Accuracy: 90.09% ]
# Elapsed Inf. time: 0.01-mins.
#
# 26: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1646, Accuracy: 93.87% ] || Test: [ Avg Loss: 0.2996, Accuracy: 90.00% ]
# Elapsed Inf. time: 0.01-mins.
#
# 27: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1572, Accuracy: 94.23% ] || Test: [ Avg Loss: 0.3143, Accuracy: 89.70% ]
# Elapsed Inf. time: 0.01-mins.
#
# 28: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1563, Accuracy: 94.07% ] || Test: [ Avg Loss: 0.3059, Accuracy: 90.21% ]
# Elapsed Inf. time: 0.01-mins.
#
# 29: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1495, Accuracy: 94.49% ] || Test: [ Avg Loss: 0.3112, Accuracy: 90.07% ]
# Elapsed Inf. time: 0.01-mins.
#
# 30: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1436, Accuracy: 94.64% ] || Test: [ Avg Loss: 0.3171, Accuracy: 90.17% ]
# Elapsed Inf. time: 0.01-mins.
#
# *********************************************************************************
# Done! Run: 3 : [Best Test @ epoch 28] || [ Avg loss: 0.305877, Accuracy: 90.21% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9985],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.6009, Accuracy: 78.62% ] || Test: [ Avg Loss: 0.4869, Accuracy: 82.39% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4239, Accuracy: 84.63% ] || Test: [ Avg Loss: 0.4235, Accuracy: 85.11% ]
# Elapsed Inf. time: 0.01-mins.
#
# 3: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3760, Accuracy: 86.44% ] || Test: [ Avg Loss: 0.3771, Accuracy: 86.55% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3502, Accuracy: 87.19% ] || Test: [ Avg Loss: 0.3701, Accuracy: 86.50% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3283, Accuracy: 88.00% ] || Test: [ Avg Loss: 0.3462, Accuracy: 87.42% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3146, Accuracy: 88.40% ] || Test: [ Avg Loss: 0.3405, Accuracy: 87.53% ]
# Elapsed Inf. time: 0.01-mins.
#
# 7: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3036, Accuracy: 88.79% ] || Test: [ Avg Loss: 0.3334, Accuracy: 87.85% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2917, Accuracy: 89.20% ] || Test: [ Avg Loss: 0.3185, Accuracy: 88.37% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2812, Accuracy: 89.67% ] || Test: [ Avg Loss: 0.3139, Accuracy: 88.54% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2716, Accuracy: 90.01% ] || Test: [ Avg Loss: 0.3242, Accuracy: 88.25% ]
# Elapsed Inf. time: 0.01-mins.
#
# 11: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2654, Accuracy: 90.11% ] || Test: [ Avg Loss: 0.3051, Accuracy: 88.97% ]
# Elapsed Inf. time: 0.01-mins.
#
# 12: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2568, Accuracy: 90.43% ] || Test: [ Avg Loss: 0.2926, Accuracy: 89.31% ]
# Elapsed Inf. time: 0.01-mins.
#
# 13: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2486, Accuracy: 90.67% ] || Test: [ Avg Loss: 0.3000, Accuracy: 88.82% ]
# Elapsed Inf. time: 0.01-mins.
#
# 14: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2436, Accuracy: 90.82% ] || Test: [ Avg Loss: 0.2916, Accuracy: 89.50% ]
# Elapsed Inf. time: 0.01-mins.
#
# 15: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2350, Accuracy: 91.16% ] || Test: [ Avg Loss: 0.2889, Accuracy: 89.59% ]
# Elapsed Inf. time: 0.01-mins.
#
# 16: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2291, Accuracy: 91.30% ] || Test: [ Avg Loss: 0.2937, Accuracy: 89.48% ]
# Elapsed Inf. time: 0.01-mins.
#
# 17: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2237, Accuracy: 91.58% ] || Test: [ Avg Loss: 0.2814, Accuracy: 89.80% ]
# Elapsed Inf. time: 0.01-mins.
#
# 18: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2168, Accuracy: 91.81% ] || Test: [ Avg Loss: 0.2868, Accuracy: 89.65% ]
# Elapsed Inf. time: 0.01-mins.
#
# 19: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2094, Accuracy: 92.16% ] || Test: [ Avg Loss: 0.2853, Accuracy: 89.84% ]
# Elapsed Inf. time: 0.01-mins.
#
# 20: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2043, Accuracy: 92.40% ] || Test: [ Avg Loss: 0.2835, Accuracy: 89.78% ]
# Elapsed Inf. time: 0.01-mins.
#
# 21: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1992, Accuracy: 92.50% ] || Test: [ Avg Loss: 0.2925, Accuracy: 89.94% ]
# Elapsed Inf. time: 0.02-mins.
#
# 22: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1938, Accuracy: 92.69% ] || Test: [ Avg Loss: 0.2837, Accuracy: 89.97% ]
# Elapsed Inf. time: 0.02-mins.
#
# 23: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1888, Accuracy: 92.92% ] || Test: [ Avg Loss: 0.2843, Accuracy: 90.03% ]
# Elapsed Inf. time: 0.01-mins.
#
# 24: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1859, Accuracy: 92.95% ] || Test: [ Avg Loss: 0.2807, Accuracy: 90.17% ]
# Elapsed Inf. time: 0.01-mins.
#
# 25: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1805, Accuracy: 93.16% ] || Test: [ Avg Loss: 0.2864, Accuracy: 90.15% ]
# Elapsed Inf. time: 0.02-mins.
#
# 26: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1769, Accuracy: 93.34% ] || Test: [ Avg Loss: 0.2876, Accuracy: 90.51% ]
# Elapsed Inf. time: 0.01-mins.
#
# 27: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1695, Accuracy: 93.61% ] || Test: [ Avg Loss: 0.2922, Accuracy: 89.81% ]
# Elapsed Inf. time: 0.01-mins.
#
# 28: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1661, Accuracy: 93.72% ] || Test: [ Avg Loss: 0.2870, Accuracy: 90.41% ]
# Elapsed Inf. time: 0.01-mins.
#
# 29: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1608, Accuracy: 93.98% ] || Test: [ Avg Loss: 0.3029, Accuracy: 90.13% ]
# Elapsed Inf. time: 0.01-mins.
#
# 30: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1585, Accuracy: 94.02% ] || Test: [ Avg Loss: 0.2944, Accuracy: 90.28% ]
# Elapsed Inf. time: 0.01-mins.
#
# *********************************************************************************
# Done! Run: 4 : [Best Test @ epoch 26] || [ Avg loss: 0.287576, Accuracy: 90.51% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9985],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.6502, Accuracy: 76.58% ] || Test: [ Avg Loss: 0.5243, Accuracy: 80.95% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4481, Accuracy: 83.67% ] || Test: [ Avg Loss: 0.4432, Accuracy: 83.68% ]
# Elapsed Inf. time: 0.02-mins.
#
# 3: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3979, Accuracy: 85.43% ] || Test: [ Avg Loss: 0.4112, Accuracy: 85.08% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3678, Accuracy: 86.64% ] || Test: [ Avg Loss: 0.3956, Accuracy: 85.70% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3456, Accuracy: 87.34% ] || Test: [ Avg Loss: 0.3641, Accuracy: 87.13% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3257, Accuracy: 88.03% ] || Test: [ Avg Loss: 0.3568, Accuracy: 86.88% ]
# Elapsed Inf. time: 0.01-mins.
#
# 7: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3125, Accuracy: 88.51% ] || Test: [ Avg Loss: 0.3405, Accuracy: 87.98% ]
# Elapsed Inf. time: 0.02-mins.
#
# 8: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2985, Accuracy: 88.94% ] || Test: [ Avg Loss: 0.3290, Accuracy: 88.18% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2859, Accuracy: 89.26% ] || Test: [ Avg Loss: 0.3227, Accuracy: 88.33% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2755, Accuracy: 89.80% ] || Test: [ Avg Loss: 0.3258, Accuracy: 88.13% ]
# Elapsed Inf. time: 0.01-mins.
#
# 11: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2682, Accuracy: 89.91% ] || Test: [ Avg Loss: 0.3115, Accuracy: 88.60% ]
# Elapsed Inf. time: 0.01-mins.
#
# 12: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2579, Accuracy: 90.36% ] || Test: [ Avg Loss: 0.3125, Accuracy: 88.76% ]
# Elapsed Inf. time: 0.01-mins.
#
# 13: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2508, Accuracy: 90.68% ] || Test: [ Avg Loss: 0.3177, Accuracy: 88.55% ]
# Elapsed Inf. time: 0.01-mins.
#
# 14: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2431, Accuracy: 90.97% ] || Test: [ Avg Loss: 0.3076, Accuracy: 88.70% ]
# Elapsed Inf. time: 0.01-mins.
#
# 15: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2361, Accuracy: 91.19% ] || Test: [ Avg Loss: 0.3085, Accuracy: 88.74% ]
# Elapsed Inf. time: 0.01-mins.
#
# 16: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2310, Accuracy: 91.38% ] || Test: [ Avg Loss: 0.3075, Accuracy: 89.05% ]
# Elapsed Inf. time: 0.01-mins.
#
# 17: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2230, Accuracy: 91.61% ] || Test: [ Avg Loss: 0.3069, Accuracy: 88.99% ]
# Elapsed Inf. time: 0.01-mins.
#
# 18: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2174, Accuracy: 91.89% ] || Test: [ Avg Loss: 0.3000, Accuracy: 89.35% ]
# Elapsed Inf. time: 0.02-mins.
#
# 19: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2125, Accuracy: 92.12% ] || Test: [ Avg Loss: 0.2964, Accuracy: 89.50% ]
# Elapsed Inf. time: 0.02-mins.
#
# 20: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2052, Accuracy: 92.29% ] || Test: [ Avg Loss: 0.3071, Accuracy: 89.36% ]
# Elapsed Inf. time: 0.01-mins.
#
# 21: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2017, Accuracy: 92.33% ] || Test: [ Avg Loss: 0.3026, Accuracy: 89.44% ]
# Elapsed Inf. time: 0.01-mins.
#
# 22: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1965, Accuracy: 92.54% ] || Test: [ Avg Loss: 0.3028, Accuracy: 89.53% ]
# Elapsed Inf. time: 0.01-mins.
#
# 23: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1908, Accuracy: 92.86% ] || Test: [ Avg Loss: 0.3210, Accuracy: 89.08% ]
# Elapsed Inf. time: 0.01-mins.
#
# 24: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1849, Accuracy: 93.03% ] || Test: [ Avg Loss: 0.3135, Accuracy: 89.42% ]
# Elapsed Inf. time: 0.01-mins.
#
# 25: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1804, Accuracy: 93.28% ] || Test: [ Avg Loss: 0.3024, Accuracy: 89.59% ]
# Elapsed Inf. time: 0.01-mins.
#
# 26: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1739, Accuracy: 93.44% ] || Test: [ Avg Loss: 0.3046, Accuracy: 89.86% ]
# Elapsed Inf. time: 0.01-mins.
#
# 27: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1707, Accuracy: 93.60% ] || Test: [ Avg Loss: 0.3149, Accuracy: 89.41% ]
# Elapsed Inf. time: 0.01-mins.
#
# 28: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1642, Accuracy: 93.87% ] || Test: [ Avg Loss: 0.3353, Accuracy: 88.77% ]
# Elapsed Inf. time: 0.01-mins.
#
# 29: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1623, Accuracy: 93.89% ] || Test: [ Avg Loss: 0.3167, Accuracy: 89.79% ]
# Elapsed Inf. time: 0.02-mins.
#
# 30: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1591, Accuracy: 94.01% ] || Test: [ Avg Loss: 0.3147, Accuracy: 89.68% ]
# Elapsed Inf. time: 0.01-mins.
#
# *********************************************************************************
# Done! Run: 5 : [Best Test @ epoch 26] || [ Avg loss: 0.304551, Accuracy: 89.86% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9985],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5970, Accuracy: 78.63% ] || Test: [ Avg Loss: 0.4617, Accuracy: 83.47% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4190, Accuracy: 85.00% ] || Test: [ Avg Loss: 0.4114, Accuracy: 85.31% ]
# Elapsed Inf. time: 0.01-mins.
#
# 3: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3723, Accuracy: 86.52% ] || Test: [ Avg Loss: 0.3826, Accuracy: 86.24% ]
# Elapsed Inf. time: 0.02-mins.
#
# 4: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3430, Accuracy: 87.55% ] || Test: [ Avg Loss: 0.3590, Accuracy: 87.12% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3208, Accuracy: 88.32% ] || Test: [ Avg Loss: 0.3556, Accuracy: 86.98% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3059, Accuracy: 88.83% ] || Test: [ Avg Loss: 0.3313, Accuracy: 87.66% ]
# Elapsed Inf. time: 0.01-mins.
#
# 7: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2907, Accuracy: 89.32% ] || Test: [ Avg Loss: 0.3202, Accuracy: 88.20% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2773, Accuracy: 89.81% ] || Test: [ Avg Loss: 0.3147, Accuracy: 88.46% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2702, Accuracy: 89.92% ] || Test: [ Avg Loss: 0.3075, Accuracy: 88.73% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2588, Accuracy: 90.35% ] || Test: [ Avg Loss: 0.3028, Accuracy: 89.00% ]
# Elapsed Inf. time: 0.02-mins.
#
# 11: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2505, Accuracy: 90.67% ] || Test: [ Avg Loss: 0.2957, Accuracy: 89.20% ]
# Elapsed Inf. time: 0.02-mins.
#
# 12: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2432, Accuracy: 90.89% ] || Test: [ Avg Loss: 0.2955, Accuracy: 89.00% ]
# Elapsed Inf. time: 0.01-mins.
#
# 13: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2382, Accuracy: 91.05% ] || Test: [ Avg Loss: 0.2913, Accuracy: 89.65% ]
# Elapsed Inf. time: 0.01-mins.
#
# 14: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2274, Accuracy: 91.51% ] || Test: [ Avg Loss: 0.2887, Accuracy: 89.40% ]
# Elapsed Inf. time: 0.01-mins.
#
# 15: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2223, Accuracy: 91.72% ] || Test: [ Avg Loss: 0.2858, Accuracy: 89.49% ]
# Elapsed Inf. time: 0.01-mins.
#
# 16: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2178, Accuracy: 91.83% ] || Test: [ Avg Loss: 0.2775, Accuracy: 90.09% ]
# Elapsed Inf. time: 0.01-mins.
#
# 17: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2102, Accuracy: 92.11% ] || Test: [ Avg Loss: 0.2903, Accuracy: 89.79% ]
# Elapsed Inf. time: 0.01-mins.
#
# 18: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2037, Accuracy: 92.40% ] || Test: [ Avg Loss: 0.2821, Accuracy: 89.94% ]
# Elapsed Inf. time: 0.01-mins.
#
# 19: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2005, Accuracy: 92.52% ] || Test: [ Avg Loss: 0.2825, Accuracy: 89.96% ]
# Elapsed Inf. time: 0.02-mins.
#
# 20: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1951, Accuracy: 92.71% ] || Test: [ Avg Loss: 0.2900, Accuracy: 90.08% ]
# Elapsed Inf. time: 0.02-mins.
#
# 21: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1900, Accuracy: 92.86% ] || Test: [ Avg Loss: 0.2933, Accuracy: 89.95% ]
# Elapsed Inf. time: 0.02-mins.
#
# 22: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1830, Accuracy: 93.11% ] || Test: [ Avg Loss: 0.2872, Accuracy: 90.56% ]
# Elapsed Inf. time: 0.01-mins.
#
# 23: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1775, Accuracy: 93.37% ] || Test: [ Avg Loss: 0.2834, Accuracy: 90.28% ]
# Elapsed Inf. time: 0.01-mins.
#
# 24: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1754, Accuracy: 93.39% ] || Test: [ Avg Loss: 0.2818, Accuracy: 90.65% ]
# Elapsed Inf. time: 0.02-mins.
#
# 25: Elapsed Train time: 0.19-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1673, Accuracy: 93.70% ] || Test: [ Avg Loss: 0.2885, Accuracy: 90.38% ]
# Elapsed Inf. time: 0.01-mins.
#
# 26: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1658, Accuracy: 93.82% ] || Test: [ Avg Loss: 0.2783, Accuracy: 90.54% ]
# Elapsed Inf. time: 0.01-mins.
#
# 27: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1605, Accuracy: 94.02% ] || Test: [ Avg Loss: 0.2867, Accuracy: 90.52% ]
# Elapsed Inf. time: 0.01-mins.
#
# 28: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1569, Accuracy: 94.08% ] || Test: [ Avg Loss: 0.2876, Accuracy: 90.57% ]
# Elapsed Inf. time: 0.01-mins.
#
# 29: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1505, Accuracy: 94.37% ] || Test: [ Avg Loss: 0.2914, Accuracy: 90.55% ]
# Elapsed Inf. time: 0.01-mins.
#
# 30: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1471, Accuracy: 94.48% ] || Test: [ Avg Loss: 0.2906, Accuracy: 90.35% ]
# Elapsed Inf. time: 0.01-mins.
#
# *********************************************************************************
# Done! Run: 6 : [Best Test @ epoch 24] || [ Avg loss: 0.281765, Accuracy: 90.65% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9985],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5889, Accuracy: 79.17% ] || Test: [ Avg Loss: 0.4461, Accuracy: 83.92% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4026, Accuracy: 85.36% ] || Test: [ Avg Loss: 0.3834, Accuracy: 85.89% ]
# Elapsed Inf. time: 0.01-mins.
#
# 3: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3623, Accuracy: 86.85% ] || Test: [ Avg Loss: 0.3589, Accuracy: 86.85% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3313, Accuracy: 88.00% ] || Test: [ Avg Loss: 0.3487, Accuracy: 87.12% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3114, Accuracy: 88.64% ] || Test: [ Avg Loss: 0.3312, Accuracy: 87.91% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2968, Accuracy: 89.12% ] || Test: [ Avg Loss: 0.3198, Accuracy: 88.40% ]
# Elapsed Inf. time: 0.01-mins.
#
# 7: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2852, Accuracy: 89.49% ] || Test: [ Avg Loss: 0.3224, Accuracy: 88.13% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2742, Accuracy: 89.83% ] || Test: [ Avg Loss: 0.3009, Accuracy: 89.19% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2631, Accuracy: 90.31% ] || Test: [ Avg Loss: 0.2897, Accuracy: 89.75% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2559, Accuracy: 90.47% ] || Test: [ Avg Loss: 0.2960, Accuracy: 89.39% ]
# Elapsed Inf. time: 0.01-mins.
#
# 11: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2467, Accuracy: 90.81% ] || Test: [ Avg Loss: 0.2886, Accuracy: 89.70% ]
# Elapsed Inf. time: 0.01-mins.
#
# 12: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2400, Accuracy: 91.03% ] || Test: [ Avg Loss: 0.2928, Accuracy: 89.61% ]
# Elapsed Inf. time: 0.01-mins.
#
# 13: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2335, Accuracy: 91.34% ] || Test: [ Avg Loss: 0.2756, Accuracy: 89.95% ]
# Elapsed Inf. time: 0.01-mins.
#
# 14: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2263, Accuracy: 91.62% ] || Test: [ Avg Loss: 0.2846, Accuracy: 89.99% ]
# Elapsed Inf. time: 0.01-mins.
#
# 15: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2207, Accuracy: 91.72% ] || Test: [ Avg Loss: 0.2829, Accuracy: 90.29% ]
# Elapsed Inf. time: 0.01-mins.
#
# 16: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2126, Accuracy: 92.08% ] || Test: [ Avg Loss: 0.2770, Accuracy: 90.14% ]
# Elapsed Inf. time: 0.01-mins.
#
# 17: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2067, Accuracy: 92.20% ] || Test: [ Avg Loss: 0.2790, Accuracy: 90.18% ]
# Elapsed Inf. time: 0.01-mins.
#
# 18: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2011, Accuracy: 92.40% ] || Test: [ Avg Loss: 0.3069, Accuracy: 89.42% ]
# Elapsed Inf. time: 0.01-mins.
#
# 19: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1953, Accuracy: 92.69% ] || Test: [ Avg Loss: 0.2694, Accuracy: 90.70% ]
# Elapsed Inf. time: 0.01-mins.
#
# 20: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1933, Accuracy: 92.61% ] || Test: [ Avg Loss: 0.2748, Accuracy: 90.48% ]
# Elapsed Inf. time: 0.01-mins.
#
# 21: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1866, Accuracy: 93.03% ] || Test: [ Avg Loss: 0.2713, Accuracy: 90.45% ]
# Elapsed Inf. time: 0.01-mins.
#
# 22: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1817, Accuracy: 93.11% ] || Test: [ Avg Loss: 0.2750, Accuracy: 90.53% ]
# Elapsed Inf. time: 0.01-mins.
#
# 23: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1741, Accuracy: 93.47% ] || Test: [ Avg Loss: 0.2745, Accuracy: 90.61% ]
# Elapsed Inf. time: 0.01-mins.
#
# 24: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1712, Accuracy: 93.54% ] || Test: [ Avg Loss: 0.2795, Accuracy: 90.53% ]
# Elapsed Inf. time: 0.01-mins.
#
# 25: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1687, Accuracy: 93.69% ] || Test: [ Avg Loss: 0.2804, Accuracy: 90.67% ]
# Elapsed Inf. time: 0.01-mins.
#
# 26: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1637, Accuracy: 93.83% ] || Test: [ Avg Loss: 0.2859, Accuracy: 90.70% ]
# Elapsed Inf. time: 0.01-mins.
#
# 27: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1597, Accuracy: 93.91% ] || Test: [ Avg Loss: 0.2813, Accuracy: 90.70% ]
# Elapsed Inf. time: 0.01-mins.
#
# 28: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1568, Accuracy: 94.06% ] || Test: [ Avg Loss: 0.3019, Accuracy: 89.90% ]
# Elapsed Inf. time: 0.01-mins.
#
# 29: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1516, Accuracy: 94.41% ] || Test: [ Avg Loss: 0.3069, Accuracy: 90.39% ]
# Elapsed Inf. time: 0.01-mins.
#
# 30: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1473, Accuracy: 94.48% ] || Test: [ Avg Loss: 0.2943, Accuracy: 90.38% ]
# Elapsed Inf. time: 0.01-mins.
#
# *********************************************************************************
# Done! Run: 7 : [Best Test @ epoch 19] || [ Avg loss: 0.269424, Accuracy: 90.70% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9985],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.16-mins.
# ...
# Elapsed Inf. time: 0.01-mins.
#
# 21: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1959, Accuracy: 92.61% ] || Test: [ Avg Loss: 0.2949, Accuracy: 90.01% ]
# Elapsed Inf. time: 0.01-mins.
#
# 22: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1918, Accuracy: 92.84% ] || Test: [ Avg Loss: 0.2946, Accuracy: 89.64% ]
# Elapsed Inf. time: 0.01-mins.
#
# 23: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1856, Accuracy: 93.09% ] || Test: [ Avg Loss: 0.2957, Accuracy: 89.92% ]
# Elapsed Inf. time: 0.01-mins.
#
# 24: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1809, Accuracy: 93.20% ] || Test: [ Avg Loss: 0.3004, Accuracy: 89.62% ]
# Elapsed Inf. time: 0.01-mins.
#
# 25: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1768, Accuracy: 93.42% ] || Test: [ Avg Loss: 0.3041, Accuracy: 89.94% ]
# Elapsed Inf. time: 0.01-mins.
#
# 26: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1728, Accuracy: 93.54% ] || Test: [ Avg Loss: 0.2923, Accuracy: 90.18% ]
# Elapsed Inf. time: 0.01-mins.
#
# 27: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1666, Accuracy: 93.66% ] || Test: [ Avg Loss: 0.3102, Accuracy: 89.83% ]
# Elapsed Inf. time: 0.01-mins.
#
# 28: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1647, Accuracy: 93.83% ] || Test: [ Avg Loss: 0.3007, Accuracy: 89.72% ]
# Elapsed Inf. time: 0.01-mins.
#
# 29: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1581, Accuracy: 94.18% ] || Test: [ Avg Loss: 0.3088, Accuracy: 89.75% ]
# Elapsed Inf. time: 0.01-mins.
#
# 30: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1542, Accuracy: 94.28% ] || Test: [ Avg Loss: 0.3039, Accuracy: 90.03% ]
# Elapsed Inf. time: 0.01-mins.
#
# *********************************************************************************
# Done! Run: 8 : [Best Test @ epoch 26] || [ Avg loss: 0.292287, Accuracy: 90.18% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9985],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.6246, Accuracy: 77.50% ] || Test: [ Avg Loss: 0.5023, Accuracy: 81.73% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4354, Accuracy: 84.31% ] || Test: [ Avg Loss: 0.4371, Accuracy: 84.43% ]
# Elapsed Inf. time: 0.01-mins.
#
# 3: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3886, Accuracy: 85.93% ] || Test: [ Avg Loss: 0.3961, Accuracy: 85.66% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3575, Accuracy: 87.00% ] || Test: [ Avg Loss: 0.3703, Accuracy: 86.69% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3402, Accuracy: 87.62% ] || Test: [ Avg Loss: 0.3658, Accuracy: 86.59% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3210, Accuracy: 88.24% ] || Test: [ Avg Loss: 0.3474, Accuracy: 87.81% ]
# Elapsed Inf. time: 0.01-mins.
#
# 7: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3097, Accuracy: 88.66% ] || Test: [ Avg Loss: 0.3417, Accuracy: 87.61% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2971, Accuracy: 89.04% ] || Test: [ Avg Loss: 0.3351, Accuracy: 88.20% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2845, Accuracy: 89.52% ] || Test: [ Avg Loss: 0.3256, Accuracy: 88.27% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2770, Accuracy: 89.79% ] || Test: [ Avg Loss: 0.3164, Accuracy: 88.66% ]
# Elapsed Inf. time: 0.01-mins.
#
# 11: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2656, Accuracy: 90.14% ] || Test: [ Avg Loss: 0.3161, Accuracy: 88.48% ]
# Elapsed Inf. time: 0.01-mins.
#
# 12: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2590, Accuracy: 90.46% ] || Test: [ Avg Loss: 0.3056, Accuracy: 89.05% ]
# Elapsed Inf. time: 0.01-mins.
#
# 13: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2515, Accuracy: 90.63% ] || Test: [ Avg Loss: 0.3050, Accuracy: 89.14% ]
# Elapsed Inf. time: 0.01-mins.
#
# 14: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2461, Accuracy: 90.92% ] || Test: [ Avg Loss: 0.3045, Accuracy: 89.15% ]
# Elapsed Inf. time: 0.01-mins.
#
# 15: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2379, Accuracy: 91.16% ] || Test: [ Avg Loss: 0.2977, Accuracy: 89.24% ]
# Elapsed Inf. time: 0.01-mins.
#
# 16: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2307, Accuracy: 91.44% ] || Test: [ Avg Loss: 0.2936, Accuracy: 89.55% ]
# Elapsed Inf. time: 0.01-mins.
#
# 17: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2257, Accuracy: 91.77% ] || Test: [ Avg Loss: 0.3011, Accuracy: 89.11% ]
# Elapsed Inf. time: 0.01-mins.
#
# 18: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2179, Accuracy: 91.89% ] || Test: [ Avg Loss: 0.2968, Accuracy: 89.78% ]
# Elapsed Inf. time: 0.01-mins.
#
# 19: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2139, Accuracy: 92.06% ] || Test: [ Avg Loss: 0.3000, Accuracy: 89.49% ]
# Elapsed Inf. time: 0.01-mins.
#
# 20: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2074, Accuracy: 92.26% ] || Test: [ Avg Loss: 0.2894, Accuracy: 89.78% ]
# Elapsed Inf. time: 0.01-mins.
#
# 21: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2044, Accuracy: 92.40% ] || Test: [ Avg Loss: 0.2947, Accuracy: 89.50% ]
# Elapsed Inf. time: 0.01-mins.
#
# 22: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1961, Accuracy: 92.70% ] || Test: [ Avg Loss: 0.2939, Accuracy: 89.94% ]
# Elapsed Inf. time: 0.01-mins.
#
# 23: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1918, Accuracy: 92.89% ] || Test: [ Avg Loss: 0.3076, Accuracy: 89.50% ]
# Elapsed Inf. time: 0.01-mins.
#
# 24: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1872, Accuracy: 92.98% ] || Test: [ Avg Loss: 0.3006, Accuracy: 89.84% ]
# Elapsed Inf. time: 0.01-mins.
#
# 25: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1819, Accuracy: 93.19% ] || Test: [ Avg Loss: 0.2906, Accuracy: 90.04% ]
# Elapsed Inf. time: 0.01-mins.
#
# 26: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1782, Accuracy: 93.40% ] || Test: [ Avg Loss: 0.2991, Accuracy: 90.02% ]
# Elapsed Inf. time: 0.01-mins.
#
# 27: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1739, Accuracy: 93.57% ] || Test: [ Avg Loss: 0.3041, Accuracy: 89.57% ]
# Elapsed Inf. time: 0.01-mins.
#
# 28: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1697, Accuracy: 93.72% ] || Test: [ Avg Loss: 0.2986, Accuracy: 90.01% ]
# Elapsed Inf. time: 0.01-mins.
#
# 29: Elapsed Train time: 0.15-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1646, Accuracy: 93.88% ] || Test: [ Avg Loss: 0.3125, Accuracy: 89.89% ]
# Elapsed Inf. time: 0.01-mins.
#
# 30: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1593, Accuracy: 94.03% ] || Test: [ Avg Loss: 0.3028, Accuracy: 89.89% ]
# Elapsed Inf. time: 0.01-mins.
#
# *********************************************************************************
# Done! Run: 9 : [Best Test @ epoch 25] || [ Avg loss: 0.290566, Accuracy: 90.04% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9985],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.6062, Accuracy: 78.24% ] || Test: [ Avg Loss: 0.5059, Accuracy: 81.05% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4278, Accuracy: 84.42% ] || Test: [ Avg Loss: 0.4172, Accuracy: 84.96% ]
# Elapsed Inf. time: 0.01-mins.
#
# 3: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3822, Accuracy: 86.03% ] || Test: [ Avg Loss: 0.3817, Accuracy: 86.21% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3513, Accuracy: 87.09% ] || Test: [ Avg Loss: 0.3700, Accuracy: 86.73% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3308, Accuracy: 87.93% ] || Test: [ Avg Loss: 0.3549, Accuracy: 87.49% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3121, Accuracy: 88.54% ] || Test: [ Avg Loss: 0.3393, Accuracy: 87.64% ]
# Elapsed Inf. time: 0.01-mins.
#
# 7: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3003, Accuracy: 89.03% ] || Test: [ Avg Loss: 0.3258, Accuracy: 88.30% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.18-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2893, Accuracy: 89.44% ] || Test: [ Avg Loss: 0.3300, Accuracy: 88.23% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.17-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2791, Accuracy: 89.79% ] || Test: [ Avg Loss: 0.3155, Accuracy: 88.67% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2689, Accuracy: 90.11% ] || Test: [ Avg Loss: 0.3122, Accuracy: 88.73% ]
# Elapsed Inf. time: 0.01-mins.
#
# 11: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2618, Accuracy: 90.35% ] || Test: [ Avg Loss: 0.3057, Accuracy: 89.07% ]
# Elapsed Inf. time: 0.01-mins.
#
# 12: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2534, Accuracy: 90.75% ] || Test: [ Avg Loss: 0.3103, Accuracy: 88.67% ]
# Elapsed Inf. time: 0.01-mins.
#
# 13: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2457, Accuracy: 90.85% ] || Test: [ Avg Loss: 0.3072, Accuracy: 88.91% ]
# Elapsed Inf. time: 0.01-mins.
#
# 14: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2410, Accuracy: 91.02% ] || Test: [ Avg Loss: 0.2972, Accuracy: 89.40% ]
# Elapsed Inf. time: 0.01-mins.
#
# 15: Elapsed Train time: 0.15-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2319, Accuracy: 91.41% ] || Test: [ Avg Loss: 0.2965, Accuracy: 89.48% ]
# Elapsed Inf. time: 0.01-mins.
#
# 16: Elapsed Train time: 0.15-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2277, Accuracy: 91.44% ] || Test: [ Avg Loss: 0.2985, Accuracy: 89.61% ]
# Elapsed Inf. time: 0.01-mins.
#
# 17: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2211, Accuracy: 91.72% ] || Test: [ Avg Loss: 0.3014, Accuracy: 89.13% ]
# Elapsed Inf. time: 0.01-mins.
#
# 18: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2139, Accuracy: 92.04% ] || Test: [ Avg Loss: 0.2865, Accuracy: 89.87% ]
# Elapsed Inf. time: 0.01-mins.
#
# 19: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2089, Accuracy: 92.21% ] || Test: [ Avg Loss: 0.2965, Accuracy: 89.93% ]
# Elapsed Inf. time: 0.01-mins.
#
# 20: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2046, Accuracy: 92.28% ] || Test: [ Avg Loss: 0.2912, Accuracy: 89.91% ]
# Elapsed Inf. time: 0.01-mins.
#
# 21: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1978, Accuracy: 92.67% ] || Test: [ Avg Loss: 0.2955, Accuracy: 89.83% ]
# Elapsed Inf. time: 0.01-mins.
#
# 22: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1931, Accuracy: 92.82% ] || Test: [ Avg Loss: 0.2972, Accuracy: 89.84% ]
# Elapsed Inf. time: 0.01-mins.
#
# 23: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1890, Accuracy: 92.94% ] || Test: [ Avg Loss: 0.2930, Accuracy: 90.04% ]
# Elapsed Inf. time: 0.01-mins.
#
# 24: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1852, Accuracy: 93.05% ] || Test: [ Avg Loss: 0.2989, Accuracy: 90.02% ]
# Elapsed Inf. time: 0.01-mins.
#
# 25: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1783, Accuracy: 93.28% ] || Test: [ Avg Loss: 0.2933, Accuracy: 90.05% ]
# Elapsed Inf. time: 0.01-mins.
#
# 26: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1767, Accuracy: 93.44% ] || Test: [ Avg Loss: 0.2986, Accuracy: 89.59% ]
# Elapsed Inf. time: 0.01-mins.
#
# 27: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1704, Accuracy: 93.61% ] || Test: [ Avg Loss: 0.3110, Accuracy: 89.54% ]
# Elapsed Inf. time: 0.01-mins.
#
# 28: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1647, Accuracy: 93.90% ] || Test: [ Avg Loss: 0.3055, Accuracy: 89.95% ]
# Elapsed Inf. time: 0.01-mins.
#
# 29: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1656, Accuracy: 93.76% ] || Test: [ Avg Loss: 0.3118, Accuracy: 89.92% ]
# Elapsed Inf. time: 0.01-mins.
#
# 30: Elapsed Train time: 0.16-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1587, Accuracy: 94.12% ] || Test: [ Avg Loss: 0.3022, Accuracy: 90.22% ]
# Elapsed Inf. time: 0.01-mins.
#
# **********************************************************************************
# Done! Run: 10 : [Best Test @ epoch 30] || [ Avg loss: 0.302219, Accuracy: 90.22% ]
# **********************************************************************************
#
# Effective Test Accuracy=90.19360888888887, pval=5.684341886080802e-14

# %%
# Plots
plotter_v1(cfgs,run_idx=1)
