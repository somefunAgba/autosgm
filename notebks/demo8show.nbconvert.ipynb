# %%
#!/scratch/nnenv/bin/python3

# %pip install watermark numpy pandas matplotlib torch torchvision torchaudio | grep -v 'already satisfied'
# %load_ext watermark
# %watermark -v -p watermark,numpy,pandas,matplotlib,torch

#
import math,random,os,sys,copy,time,glob,itertools,shutil,re, json
from scipy.stats import wilcoxon

#
import numpy as np

#
import torch, gc
torch.cuda.empty_cache()
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

import torch.nn as nn
import torch.nn.functional as tf
from torch.utils.data import Dataset,DataLoader
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor, Lambda

import pandas as pd

from pathlib import Path
sys.path[0] = str(Path(sys.path[0]).parent)

#
from demofcns import *
from opts.asgm.torchlasgm import PID
from opts.elpf.fo import LPF
from opts.elpf.esfo import esLPF

# from .. import arcs
from arcs.resnet import ResNetC

# python3 -m torch.utils.collect_env
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Python implementation: CPython
# Python version       : 3.10.6
# IPython version      : 8.7.0
#
# watermark : 2.3.1
# numpy     : 1.23.1
# pandas    : 1.4.3
# matplotlib: 3.5.3
# torch     : 1.12.0+cu116

# %% [markdown]
# ##### Setup Configurations (Hyperparameters and so on)

# %%
# - is it being run remotely on OSU EECS server?
remotelyrun = 1 # 0 | 1

#----------------------
# Load setup config
#----------------------
with open('cfgs.json', 'r') as cfglist:
  cfgs = json.load(cfglist)
  
# setup
cfgs['storedir'] = "../expstore"

# - pick data-set
cfgs["dataset"] = "svhn"
# - set max. batchsize for each epoch, training runs, training epochs, 
cfgs["batch-size"] = 128 # 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, ...
cfgs['runs'] = 10
cfgs["epochs"] = 30

# -pick computation device
devcnt = torch.cuda.device_count()

# - setup multiprocessing, human signature
# random seed for python libraries
cfgs["seed"] = 2023
cfgs["var_seed"] = 1
worker_seed = cfgs["seed"] % (2**32)
cfgs["num-workers"] = 0 #3
cfgs["human_signature"] = "oas" # for signing experiments ran.


if devcnt > 1:
  cfgs["device"] = torch.device('cuda') # "cuda:1"
  torch.cuda.set_device(1)
elif devcnt == 1:
  cfgs["device"] = torch.device('cuda')
else:
  cfgs["device"] = torch.device('cpu')
#
if remotelyrun:
  cfgs["remote"] = True
else:
  cfgs["remote"] = False

# %% [markdown]
# ##### (Generate) or Load the Dataset

# %%
#----------------------
# Download/Load Dataset
#----------------------
if not cfgs["remote"]:
  # same dir. as source-code
  data_folder = "../data"
else:
  # dalton's scratch on OSU's eecs server
  data_folder = "/scratch/data"


# SVHN
if cfgs["dataset"] == "svhn":
    train_data = datasets.SVHN(
      root=data_folder+"/SVHN",
      split="train",
      download=True,
      transform=ToTensor(),
    )
    test_data = datasets.SVHN(
      root=data_folder+"/SVHN",
      split="test",
      download= True,
      transform=ToTensor()
    )
    indim = [3,32,32]
    class_num = 10
    channels = indim[0]
    val_data = None
  
# Tests 
trainloader = torch.utils.data.DataLoader(train_data, batch_size=cfgs['batch-size'],shuffle=True)
# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)
pass
# Out:
# Using downloaded and verified file: /scratch/data/SVHN/train_32x32.mat
# Using downloaded and verified file: /scratch/data/SVHN/test_32x32.mat

# %% [markdown]
# ##### Construct Model (Differentiable Function) with  necessary methods.

# %%
'''
Uses ResNetC
'''

class thisNN(nn.Module):
  def __init__(self,num_heads=1,in_feats=[3,32,32],out_feats=10,layers=6, loss_type="mce", outs_class=True, mdl_name="nnresnet") -> None:
    """
    __init__ _summary_

    _extended_summary_

    Args:
        num_heads (int, req): net. output head. Defaults to 1.
        in_feats (int, req): net. input dimension. Defaults to 1.
        out_feats (int, req): net. output dimension per head. Defaults to 1.
        loss_type (str, req): type of loss function Defaults to "mse". ("mse","mce" for multi-class cross-entropy, "bce" binary-class cross-entropy)
        outs_class (bool, req): does model return class indices. Defaults to False, implying it outputs real-valued probabilities. This is also true for loss_type="mse" regardless of user-choice.
    """
    super().__init__()
    self.num_heads = num_heads
    
    # define mdl. params.
    self.cnn = nn.ModuleList()
    for hid in range(num_heads): 
      self.cnn.append(
        ResNetC(in_chans=in_feats[0],stem_chans=64,layers=str(layers),botneck=False,num_classes=out_feats,num_heads=num_heads) 
      )
    self.relu = nn.ReLU()
    self.flatten = nn.Flatten()
    
    # prob.fcn at last output or network head layer
    if loss_type == "bce" or loss_type == "mse":
      self.out = torch.nn.Sigmoid()
    else:
      self.out = torch.nn.Softmax()
    
    self.loss_type = loss_type
    self.outs_class = outs_class
    
    # optimizer
    self.sgm = None
    
    # saved trained model
    self.chkpt = None
    
    
    self.devcnt = torch.cuda.device_count()
    self.device = None
    self.name = mdl_name
    
    if not(loss_type == "mse" or loss_type =="mce" or loss_type == "bce"):
      raise ValueError(f"loss_type='{loss_type}' is not defined for this class")
    if (loss_type == "mse"):
      self.outs_class = False    
    
@clsmethod(thisNN)
def forward(self:thisNN, x):
  # pre-process
  logits = []
  for hid in range(self.num_heads):
    resnet = self.cnn[hid]
    y = resnet(x)  
    logits.append(y)
    
  return logits # List [Tensor]

@clsmethod(thisNN)
def outhead(self:thisNN, x):
  probs = []
  for hid in range(self.num_heads):
    y = self.out(x[hid])
    probs.append(y)  
  return probs # List [Tensor]

# Add necessary functions to train model
add_to_thisnn(thisNN,worker_seed,setseed,cseedwk)

# Use saved mdl as
# mdl <-- load model function
# prediction = mdl.infer(input)

# %% [markdown]
# ##### Run the Network Modeling (Training)

# %%
# Test.

torch.manual_seed(2023)
devcnt = torch.cuda.device_count()

cfgs['mdl_name_dir'] = "nndemo8_svhn_resnet6"
isclassifier = True
cfgs["ss_init"] = 1e-3 # default 1e-3
cfgs["eps_ss"] = 5e-1 # default 5e-1
cfgs["weight_decay"] = 1e-5 # default 1e-5
mdl = thisNN(mdl_name=cfgs['mdl_name_dir'])
if devcnt > 0:
    mdl.cuda()
cfgs['pathstr'] = str(mdl.name)+str(cfgs["batch-size"])+"_"+cfgs["dataset"]+"_"+str(cfgs["runs"])+"_"+str(cfgs["epochs"])

mdl.runs(train_data, test_data, cfgs=cfgs, eval_name="Test")
# Out:
# Seed: 2023
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9988],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# calc.: 0.000136, pvec2norm: 42.282299, gvec2norm: 20.010094
# ss_calc: 0.002716
# ss_used: 0.002716
# 1: Elapsed Train time: 1.47-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 1.3795, Accuracy: 54.85% ] || Test: [ Avg Loss: 0.6607, Accuracy: 81.48% ]
# Elapsed Inf. time: 0.13-mins.
#
# 2: Elapsed Train time: 1.57-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.4780, Accuracy: 85.89% ] || Test: [ Avg Loss: 0.4500, Accuracy: 86.27% ]
# Elapsed Inf. time: 0.13-mins.
#
# 3: Elapsed Train time: 1.63-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.3486, Accuracy: 89.71% ] || Test: [ Avg Loss: 0.3435, Accuracy: 90.08% ]
# Elapsed Inf. time: 0.13-mins.
#
# 4: Elapsed Train time: 1.66-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2892, Accuracy: 91.50% ] || Test: [ Avg Loss: 0.3504, Accuracy: 89.31% ]
# Elapsed Inf. time: 0.13-mins.
#
# 5: Elapsed Train time: 1.61-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2564, Accuracy: 92.49% ] || Test: [ Avg Loss: 0.3055, Accuracy: 90.83% ]
# Elapsed Inf. time: 0.13-mins.
#
# 6: Elapsed Train time: 1.61-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2290, Accuracy: 93.39% ] || Test: [ Avg Loss: 0.2500, Accuracy: 92.79% ]
# Elapsed Inf. time: 0.13-mins.
#
# 7: Elapsed Train time: 1.65-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2070, Accuracy: 94.01% ] || Test: [ Avg Loss: 0.2198, Accuracy: 93.83% ]
# Elapsed Inf. time: 0.13-mins.
#
# 8: Elapsed Train time: 1.65-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1905, Accuracy: 94.53% ] || Test: [ Avg Loss: 0.2344, Accuracy: 93.25% ]
# Elapsed Inf. time: 0.13-mins.
#
# 9: Elapsed Train time: 1.66-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1699, Accuracy: 95.19% ] || Test: [ Avg Loss: 0.2220, Accuracy: 93.73% ]
# Elapsed Inf. time: 0.13-mins.
#
# 10: Elapsed Train time: 1.65-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1580, Accuracy: 95.46% ] || Test: [ Avg Loss: 0.2299, Accuracy: 93.57% ]
# Elapsed Inf. time: 0.13-mins.
#
# 11: Elapsed Train time: 1.64-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1393, Accuracy: 96.08% ] || Test: [ Avg Loss: 0.2532, Accuracy: 92.64% ]
# Elapsed Inf. time: 0.13-mins.
#
# 12: Elapsed Train time: 1.57-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1267, Accuracy: 96.48% ] || Test: [ Avg Loss: 0.2256, Accuracy: 93.55% ]
# Elapsed Inf. time: 0.13-mins.
#
# 13: Elapsed Train time: 1.57-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1153, Accuracy: 96.69% ] || Test: [ Avg Loss: 0.2239, Accuracy: 93.71% ]
# Elapsed Inf. time: 0.13-mins.
#
# 14: Elapsed Train time: 1.56-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1037, Accuracy: 97.07% ] || Test: [ Avg Loss: 0.2331, Accuracy: 93.52% ]
# Elapsed Inf. time: 0.13-mins.
#
# 15: Elapsed Train time: 1.33-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0911, Accuracy: 97.42% ] || Test: [ Avg Loss: 0.2553, Accuracy: 92.88% ]
# Elapsed Inf. time: 0.13-mins.
#
# 16: Elapsed Train time: 1.40-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0815, Accuracy: 97.57% ] || Test: [ Avg Loss: 0.2619, Accuracy: 92.64% ]
# Elapsed Inf. time: 0.14-mins.
#
# 17: Elapsed Train time: 1.44-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0731, Accuracy: 97.97% ] || Test: [ Avg Loss: 0.2820, Accuracy: 92.15% ]
# Elapsed Inf. time: 0.14-mins.
#
# 18: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0691, Accuracy: 97.98% ] || Test: [ Avg Loss: 0.2713, Accuracy: 92.59% ]
# Elapsed Inf. time: 0.14-mins.
#
# 19: Elapsed Train time: 1.44-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0597, Accuracy: 98.22% ] || Test: [ Avg Loss: 0.2830, Accuracy: 92.59% ]
# Elapsed Inf. time: 0.13-mins.
#
# 20: Elapsed Train time: 1.41-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0550, Accuracy: 98.43% ] || Test: [ Avg Loss: 0.3117, Accuracy: 91.76% ]
# Elapsed Inf. time: 0.13-mins.
#
# 21: Elapsed Train time: 1.47-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0526, Accuracy: 98.46% ] || Test: [ Avg Loss: 0.2828, Accuracy: 92.46% ]
# Elapsed Inf. time: 0.13-mins.
#
# 22: Elapsed Train time: 1.51-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0479, Accuracy: 98.60% ] || Test: [ Avg Loss: 0.2979, Accuracy: 92.41% ]
# Elapsed Inf. time: 0.13-mins.
#
# 23: Elapsed Train time: 1.66-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0447, Accuracy: 98.62% ] || Test: [ Avg Loss: 0.2941, Accuracy: 92.44% ]
# Elapsed Inf. time: 0.13-mins.
#
# 24: Elapsed Train time: 1.65-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0419, Accuracy: 98.76% ] || Test: [ Avg Loss: 0.2854, Accuracy: 92.67% ]
# Elapsed Inf. time: 0.13-mins.
#
# 25: Elapsed Train time: 1.63-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0416, Accuracy: 98.79% ] || Test: [ Avg Loss: 0.2733, Accuracy: 93.19% ]
# Elapsed Inf. time: 0.13-mins.
#
# 26: Elapsed Train time: 1.62-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0418, Accuracy: 98.74% ] || Test: [ Avg Loss: 0.2913, Accuracy: 92.67% ]
# Elapsed Inf. time: 0.13-mins.
#
# 27: Elapsed Train time: 1.62-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0358, Accuracy: 98.94% ] || Test: [ Avg Loss: 0.3119, Accuracy: 92.68% ]
# Elapsed Inf. time: 0.13-mins.
#
# 28: Elapsed Train time: 1.65-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0373, Accuracy: 98.85% ] || Test: [ Avg Loss: 0.2837, Accuracy: 93.17% ]
# Elapsed Inf. time: 0.13-mins.
#
# 29: Elapsed Train time: 1.65-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0343, Accuracy: 98.96% ] || Test: [ Avg Loss: 0.2894, Accuracy: 93.02% ]
# Elapsed Inf. time: 0.13-mins.
#
# 30: Elapsed Train time: 1.66-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0388, Accuracy: 98.80% ] || Test: [ Avg Loss: 0.3024, Accuracy: 92.88% ]
# Elapsed Inf. time: 0.13-mins.
#
# ********************************************************************************
# Done! Run: 1 : [Best Test @ epoch 7] || [ Avg loss: 0.219850, Accuracy: 93.83% ]
# ********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9988],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# calc.: 0.000135, pvec2norm: 42.162495, gvec2norm: 13.463120
# ss_calc: 0.001822
# ss_used: 0.001822
# 1: Elapsed Train time: 1.65-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 1.3904, Accuracy: 54.80% ] || Test: [ Avg Loss: 0.6308, Accuracy: 82.25% ]
# Elapsed Inf. time: 0.13-mins.
#
# 2: Elapsed Train time: 1.65-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.4747, Accuracy: 86.02% ] || Test: [ Avg Loss: 0.4226, Accuracy: 87.93% ]
# Elapsed Inf. time: 0.13-mins.
#
# 3: Elapsed Train time: 1.65-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.3518, Accuracy: 89.66% ] || Test: [ Avg Loss: 0.3050, Accuracy: 91.44% ]
# Elapsed Inf. time: 0.13-mins.
#
# 4: Elapsed Train time: 1.63-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2964, Accuracy: 91.33% ] || Test: [ Avg Loss: 0.3372, Accuracy: 90.05% ]
# Elapsed Inf. time: 0.13-mins.
#
# 5: Elapsed Train time: 1.61-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2601, Accuracy: 92.49% ] || Test: [ Avg Loss: 0.2792, Accuracy: 92.25% ]
# Elapsed Inf. time: 0.13-mins.
#
# 6: Elapsed Train time: 1.53-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2335, Accuracy: 93.29% ] || Test: [ Avg Loss: 0.2430, Accuracy: 93.08% ]
# Elapsed Inf. time: 0.13-mins.
#
# 7: Elapsed Train time: 1.62-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2122, Accuracy: 93.93% ] || Test: [ Avg Loss: 0.2433, Accuracy: 93.14% ]
# Elapsed Inf. time: 0.13-mins.
#
# 8: Elapsed Train time: 1.60-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1962, Accuracy: 94.35% ] || Test: [ Avg Loss: 0.2628, Accuracy: 92.32% ]
# Elapsed Inf. time: 0.13-mins.
#
# 9: Elapsed Train time: 1.66-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1772, Accuracy: 95.01% ] || Test: [ Avg Loss: 0.3188, Accuracy: 90.40% ]
# Elapsed Inf. time: 0.13-mins.
#
# 10: Elapsed Train time: 1.66-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1623, Accuracy: 95.41% ] || Test: [ Avg Loss: 0.2265, Accuracy: 93.58% ]
# Elapsed Inf. time: 0.13-mins.
#
# 11: Elapsed Train time: 1.67-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1493, Accuracy: 95.80% ] || Test: [ Avg Loss: 0.2287, Accuracy: 93.42% ]
# Elapsed Inf. time: 0.13-mins.
#
# 12: Elapsed Train time: 1.66-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1343, Accuracy: 96.18% ] || Test: [ Avg Loss: 0.2227, Accuracy: 93.92% ]
# Elapsed Inf. time: 0.13-mins.
#
# 13: Elapsed Train time: 1.64-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1186, Accuracy: 96.68% ] || Test: [ Avg Loss: 0.2317, Accuracy: 93.27% ]
# Elapsed Inf. time: 0.13-mins.
#
# 14: Elapsed Train time: 1.63-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1093, Accuracy: 96.93% ] || Test: [ Avg Loss: 0.2279, Accuracy: 93.54% ]
# Elapsed Inf. time: 0.13-mins.
#
# 15: Elapsed Train time: 1.66-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0970, Accuracy: 97.31% ] || Test: [ Avg Loss: 0.2461, Accuracy: 92.91% ]
# Elapsed Inf. time: 0.13-mins.
#
# 16: Elapsed Train time: 1.66-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0871, Accuracy: 97.58% ] || Test: [ Avg Loss: 0.2469, Accuracy: 93.32% ]
# Elapsed Inf. time: 0.13-mins.
#
# 17: Elapsed Train time: 1.65-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0803, Accuracy: 97.75% ] || Test: [ Avg Loss: 0.2557, Accuracy: 93.18% ]
# Elapsed Inf. time: 0.13-mins.
#
# 18: Elapsed Train time: 1.66-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0716, Accuracy: 98.03% ] || Test: [ Avg Loss: 0.2415, Accuracy: 93.57% ]
# Elapsed Inf. time: 0.13-mins.
#
# 19: Elapsed Train time: 1.66-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0637, Accuracy: 98.20% ] || Test: [ Avg Loss: 0.2850, Accuracy: 92.22% ]
# Elapsed Inf. time: 0.13-mins.
#
# 20: Elapsed Train time: 1.65-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0561, Accuracy: 98.45% ] || Test: [ Avg Loss: 0.2970, Accuracy: 92.13% ]
# Elapsed Inf. time: 0.13-mins.
#
# 21: Elapsed Train time: 1.62-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0550, Accuracy: 98.39% ] || Test: [ Avg Loss: 0.2741, Accuracy: 92.81% ]
# Elapsed Inf. time: 0.13-mins.
#
# 22: Elapsed Train time: 1.65-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0447, Accuracy: 98.76% ] || Test: [ Avg Loss: 0.2631, Accuracy: 93.07% ]
# Elapsed Inf. time: 0.13-mins.
#
# 23: Elapsed Train time: 1.44-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0465, Accuracy: 98.67% ] || Test: [ Avg Loss: 0.2706, Accuracy: 92.99% ]
# Elapsed Inf. time: 0.13-mins.
#
# 24: Elapsed Train time: 1.07-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0446, Accuracy: 98.72% ] || Test: [ Avg Loss: 0.2704, Accuracy: 92.94% ]
# Elapsed Inf. time: 0.13-mins.
#
# 25: Elapsed Train time: 1.07-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0402, Accuracy: 98.81% ] || Test: [ Avg Loss: 0.2770, Accuracy: 92.87% ]
# Elapsed Inf. time: 0.13-mins.
#
# 26: Elapsed Train time: 1.07-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0307, Accuracy: 99.17% ] || Test: [ Avg Loss: 0.2842, Accuracy: 92.74% ]
# Elapsed Inf. time: 0.13-mins.
#
# 27: Elapsed Train time: 1.66-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0413, Accuracy: 98.84% ] || Test: [ Avg Loss: 0.2863, Accuracy: 92.77% ]
# Elapsed Inf. time: 0.13-mins.
#
# 28: Elapsed Train time: 1.67-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0281, Accuracy: 99.25% ] || Test: [ Avg Loss: 0.2721, Accuracy: 93.25% ]
# Elapsed Inf. time: 0.13-mins.
#
# 29: Elapsed Train time: 1.66-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0288, Accuracy: 99.21% ] || Test: [ Avg Loss: 0.3084, Accuracy: 92.42% ]
# Elapsed Inf. time: 0.13-mins.
#
# 30: Elapsed Train time: 1.64-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0375, Accuracy: 98.93% ] || Test: [ Avg Loss: 0.2918, Accuracy: 92.90% ]
# Elapsed Inf. time: 0.13-mins.
#
# *********************************************************************************
# Done! Run: 2 : [Best Test @ epoch 12] || [ Avg loss: 0.222742, Accuracy: 93.92% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9988],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# calc.: 0.000136, pvec2norm: 42.254745, gvec2norm: 18.688997
# ss_calc: 0.002535
# ss_used: 0.002535
# 1: Elapsed Train time: 1.64-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 1.4109, Accuracy: 54.18% ] || Test: [ Avg Loss: 0.7318, Accuracy: 76.86% ]
# Elapsed Inf. time: 0.13-mins.
#
# 2: Elapsed Train time: 1.65-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.4626, Accuracy: 86.16% ] || Test: [ Avg Loss: 0.4287, Accuracy: 87.80% ]
# Elapsed Inf. time: 0.13-mins.
#
# 3: Elapsed Train time: 1.60-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.3367, Accuracy: 90.13% ] || Test: [ Avg Loss: 0.3423, Accuracy: 90.20% ]
# Elapsed Inf. time: 0.13-mins.
#
# 4: Elapsed Train time: 1.67-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2851, Accuracy: 91.66% ] || Test: [ Avg Loss: 0.2898, Accuracy: 91.42% ]
# Elapsed Inf. time: 0.13-mins.
#
# 5: Elapsed Train time: 1.67-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2518, Accuracy: 92.71% ] || Test: [ Avg Loss: 0.2609, Accuracy: 92.95% ]
# Elapsed Inf. time: 0.13-mins.
#
# 6: Elapsed Train time: 1.67-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2273, Accuracy: 93.49% ] || Test: [ Avg Loss: 0.2343, Accuracy: 93.39% ]
# Elapsed Inf. time: 0.13-mins.
#
# 7: Elapsed Train time: 1.67-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2037, Accuracy: 94.13% ] || Test: [ Avg Loss: 0.2379, Accuracy: 93.16% ]
# Elapsed Inf. time: 0.13-mins.
#
# 8: Elapsed Train time: 1.66-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1875, Accuracy: 94.59% ] || Test: [ Avg Loss: 0.2358, Accuracy: 93.22% ]
# Elapsed Inf. time: 0.13-mins.
#
# 9: Elapsed Train time: 1.67-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1722, Accuracy: 95.09% ] || Test: [ Avg Loss: 0.2127, Accuracy: 94.15% ]
# Elapsed Inf. time: 0.13-mins.
#
# 10: Elapsed Train time: 1.65-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1516, Accuracy: 95.66% ] || Test: [ Avg Loss: 0.2454, Accuracy: 92.92% ]
# Elapsed Inf. time: 0.14-mins.
#
# 11: Elapsed Train time: 1.55-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1417, Accuracy: 95.97% ] || Test: [ Avg Loss: 0.2247, Accuracy: 93.58% ]
# Elapsed Inf. time: 0.13-mins.
#
# 12: Elapsed Train time: 1.62-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1254, Accuracy: 96.46% ] || Test: [ Avg Loss: 0.2719, Accuracy: 91.96% ]
# Elapsed Inf. time: 0.14-mins.
#
# 13: Elapsed Train time: 1.61-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1143, Accuracy: 96.77% ] || Test: [ Avg Loss: 0.2169, Accuracy: 93.87% ]
# Elapsed Inf. time: 0.13-mins.
#
# 14: Elapsed Train time: 1.64-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1029, Accuracy: 97.04% ] || Test: [ Avg Loss: 0.2730, Accuracy: 91.98% ]
# Elapsed Inf. time: 0.13-mins.
#
# 15: Elapsed Train time: 1.59-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0893, Accuracy: 97.46% ] || Test: [ Avg Loss: 0.2830, Accuracy: 92.18% ]
# Elapsed Inf. time: 0.13-mins.
#
# 16: Elapsed Train time: 1.62-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0814, Accuracy: 97.67% ] || Test: [ Avg Loss: 0.3044, Accuracy: 91.66% ]
# Elapsed Inf. time: 0.14-mins.
#
# 17: Elapsed Train time: 1.40-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0723, Accuracy: 97.93% ] || Test: [ Avg Loss: 0.2337, Accuracy: 93.65% ]
# Elapsed Inf. time: 0.13-mins.
#
# 18: Elapsed Train time: 1.53-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0674, Accuracy: 98.01% ] || Test: [ Avg Loss: 0.2746, Accuracy: 92.51% ]
# Elapsed Inf. time: 0.13-mins.
#
# 19: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0570, Accuracy: 98.32% ] || Test: [ Avg Loss: 0.2705, Accuracy: 92.72% ]
# Elapsed Inf. time: 0.13-mins.
#
# 20: Elapsed Train time: 1.44-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0558, Accuracy: 98.29% ] || Test: [ Avg Loss: 0.2504, Accuracy: 93.40% ]
# Elapsed Inf. time: 0.13-mins.
#
# 21: Elapsed Train time: 1.54-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0510, Accuracy: 98.44% ] || Test: [ Avg Loss: 0.2651, Accuracy: 92.95% ]
# Elapsed Inf. time: 0.13-mins.
#
# 22: Elapsed Train time: 1.66-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0454, Accuracy: 98.66% ] || Test: [ Avg Loss: 0.3345, Accuracy: 91.46% ]
# Elapsed Inf. time: 0.13-mins.
#
# 23: Elapsed Train time: 1.67-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0456, Accuracy: 98.61% ] || Test: [ Avg Loss: 0.2671, Accuracy: 93.33% ]
# Elapsed Inf. time: 0.13-mins.
#
# 24: Elapsed Train time: 1.64-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0402, Accuracy: 98.82% ] || Test: [ Avg Loss: 0.2896, Accuracy: 92.69% ]
# Elapsed Inf. time: 0.13-mins.
#
# 25: Elapsed Train time: 1.65-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0410, Accuracy: 98.75% ] || Test: [ Avg Loss: 0.2756, Accuracy: 93.39% ]
# Elapsed Inf. time: 0.13-mins.
#
# 26: Elapsed Train time: 1.60-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0346, Accuracy: 98.99% ] || Test: [ Avg Loss: 0.3325, Accuracy: 91.86% ]
# Elapsed Inf. time: 0.13-mins.
#
# 27: Elapsed Train time: 1.66-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0362, Accuracy: 98.88% ] || Test: [ Avg Loss: 0.2766, Accuracy: 93.12% ]
# Elapsed Inf. time: 0.13-mins.
#
# 28: Elapsed Train time: 1.58-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0386, Accuracy: 98.83% ] || Test: [ Avg Loss: 0.2974, Accuracy: 92.54% ]
# Elapsed Inf. time: 0.13-mins.
#
# 29: Elapsed Train time: 1.12-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0355, Accuracy: 98.96% ] || Test: [ Avg Loss: 0.2736, Accuracy: 93.41% ]
# Elapsed Inf. time: 0.13-mins.
#
# 30: Elapsed Train time: 1.07-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0237, Accuracy: 99.31% ] || Test: [ Avg Loss: 0.2915, Accuracy: 92.90% ]
# Elapsed Inf. time: 0.13-mins.
#
# ********************************************************************************
# Done! Run: 3 : [Best Test @ epoch 9] || [ Avg loss: 0.212734, Accuracy: 94.15% ]
# ********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9988],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# calc.: 0.000136, pvec2norm: 42.461296, gvec2norm: 20.590918
# ss_calc: 0.002807
# ss_used: 0.002807
# 1: Elapsed Train time: 1.31-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 1.4275, Accuracy: 53.29% ] || Test: [ Avg Loss: 0.6877, Accuracy: 78.72% ]
# Elapsed Inf. time: 0.13-mins.
#
# 2: Elapsed Train time: 1.48-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.4578, Accuracy: 86.45% ] || Test: [ Avg Loss: 0.5223, Accuracy: 83.15% ]
# Elapsed Inf. time: 0.13-mins.
#
# 3: Elapsed Train time: 1.32-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.3391, Accuracy: 89.99% ] || Test: [ Avg Loss: 0.3402, Accuracy: 89.86% ]
# Elapsed Inf. time: 0.13-mins.
#
# 4: Elapsed Train time: 1.63-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2863, Accuracy: 91.52% ] || Test: [ Avg Loss: 0.2658, Accuracy: 92.61% ]
# Elapsed Inf. time: 0.13-mins.
#
# 5: Elapsed Train time: 1.67-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2505, Accuracy: 92.73% ] || Test: [ Avg Loss: 0.2682, Accuracy: 92.27% ]
# Elapsed Inf. time: 0.13-mins.
#
# 6: Elapsed Train time: 1.67-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2261, Accuracy: 93.46% ] || Test: [ Avg Loss: 0.2257, Accuracy: 93.79% ]
# Elapsed Inf. time: 0.13-mins.
#
# 7: Elapsed Train time: 1.67-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2054, Accuracy: 94.07% ] || Test: [ Avg Loss: 0.2262, Accuracy: 93.58% ]
# Elapsed Inf. time: 0.13-mins.
#
# 8: Elapsed Train time: 1.64-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1846, Accuracy: 94.70% ] || Test: [ Avg Loss: 0.2515, Accuracy: 92.48% ]
# Elapsed Inf. time: 0.13-mins.
#
# 9: Elapsed Train time: 1.62-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1703, Accuracy: 95.15% ] || Test: [ Avg Loss: 0.2395, Accuracy: 92.95% ]
# Elapsed Inf. time: 0.13-mins.
#
# 10: Elapsed Train time: 1.67-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1542, Accuracy: 95.58% ] || Test: [ Avg Loss: 0.2381, Accuracy: 92.97% ]
# Elapsed Inf. time: 0.13-mins.
#
# 11: Elapsed Train time: 1.67-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1388, Accuracy: 96.01% ] || Test: [ Avg Loss: 0.2217, Accuracy: 93.64% ]
# Elapsed Inf. time: 0.13-mins.
#
# 12: Elapsed Train time: 1.66-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1268, Accuracy: 96.38% ] || Test: [ Avg Loss: 0.2172, Accuracy: 93.84% ]
# Elapsed Inf. time: 0.13-mins.
#
# 13: Elapsed Train time: 1.66-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1137, Accuracy: 96.81% ] || Test: [ Avg Loss: 0.2506, Accuracy: 92.71% ]
# Elapsed Inf. time: 0.13-mins.
#
# 14: Elapsed Train time: 1.66-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1017, Accuracy: 97.11% ] || Test: [ Avg Loss: 0.2644, Accuracy: 92.78% ]
# Elapsed Inf. time: 0.13-mins.
#
# 15: Elapsed Train time: 1.64-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0935, Accuracy: 97.31% ] || Test: [ Avg Loss: 0.2374, Accuracy: 93.38% ]
# Elapsed Inf. time: 0.14-mins.
#
# 16: Elapsed Train time: 1.54-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0838, Accuracy: 97.56% ] || Test: [ Avg Loss: 0.2446, Accuracy: 93.27% ]
# Elapsed Inf. time: 0.13-mins.
#
# 17: Elapsed Train time: 1.34-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0746, Accuracy: 97.90% ] || Test: [ Avg Loss: 0.2503, Accuracy: 93.05% ]
# Elapsed Inf. time: 0.13-mins.
#
# 18: Elapsed Train time: 1.32-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0660, Accuracy: 98.08% ] || Test: [ Avg Loss: 0.2521, Accuracy: 93.10% ]
# Elapsed Inf. time: 0.13-mins.
#
# 19: Elapsed Train time: 1.43-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0621, Accuracy: 98.09% ] || Test: [ Avg Loss: 0.2466, Accuracy: 93.73% ]
# Elapsed Inf. time: 0.13-mins.
#
# 20: Elapsed Train time: 1.54-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0546, Accuracy: 98.35% ] || Test: [ Avg Loss: 0.2688, Accuracy: 92.68% ]
# Elapsed Inf. time: 0.13-mins.
#
# 21: Elapsed Train time: 1.52-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0544, Accuracy: 98.39% ] || Test: [ Avg Loss: 0.2544, Accuracy: 92.90% ]
# Elapsed Inf. time: 0.13-mins.
#
# 22: Elapsed Train time: 1.50-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0460, Accuracy: 98.63% ] || Test: [ Avg Loss: 0.2517, Accuracy: 93.44% ]
# Elapsed Inf. time: 0.13-mins.
#
# 23: Elapsed Train time: 1.51-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0405, Accuracy: 98.85% ] || Test: [ Avg Loss: 0.2739, Accuracy: 93.03% ]
# Elapsed Inf. time: 0.13-mins.
#
# 24: Elapsed Train time: 1.48-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0478, Accuracy: 98.50% ] || Test: [ Avg Loss: 0.2549, Accuracy: 93.65% ]
# Elapsed Inf. time: 0.13-mins.
#
# 25: Elapsed Train time: 1.45-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0382, Accuracy: 98.91% ] || Test: [ Avg Loss: 0.3025, Accuracy: 92.48% ]
# Elapsed Inf. time: 0.13-mins.
#
# 26: Elapsed Train time: 1.08-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0421, Accuracy: 98.63% ] || Test: [ Avg Loss: 0.2800, Accuracy: 93.40% ]
# Elapsed Inf. time: 0.13-mins.
#
# 27: Elapsed Train time: 1.53-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0355, Accuracy: 98.91% ] || Test: [ Avg Loss: 0.2811, Accuracy: 92.94% ]
# Elapsed Inf. time: 0.13-mins.
#
# 28: Elapsed Train time: 1.53-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0372, Accuracy: 98.86% ] || Test: [ Avg Loss: 0.2681, Accuracy: 93.31% ]
# Elapsed Inf. time: 0.13-mins.
#
# 29: Elapsed Train time: 1.52-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0378, Accuracy: 98.83% ] || Test: [ Avg Loss: 0.2987, Accuracy: 92.92% ]
# Elapsed Inf. time: 0.13-mins.
#
# 30: Elapsed Train time: 1.52-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0306, Accuracy: 99.08% ] || Test: [ Avg Loss: 0.3250, Accuracy: 92.50% ]
# Elapsed Inf. time: 0.13-mins.
#
# *********************************************************************************
# Done! Run: 4 : [Best Test @ epoch 12] || [ Avg loss: 0.217161, Accuracy: 93.84% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9988],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# calc.: 0.000135, pvec2norm: 42.187302, gvec2norm: 18.777933
# ss_calc: 0.002543
# ss_used: 0.002543
# 1: Elapsed Train time: 1.49-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 1.3026, Accuracy: 58.53% ] || Test: [ Avg Loss: 0.6731, Accuracy: 77.73% ]
# Elapsed Inf. time: 0.13-mins.
#
# 2: Elapsed Train time: 1.48-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.4523, Accuracy: 86.55% ] || Test: [ Avg Loss: 0.3872, Accuracy: 88.51% ]
# Elapsed Inf. time: 0.13-mins.
#
# 3: Elapsed Train time: 1.49-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.3362, Accuracy: 90.07% ] || Test: [ Avg Loss: 0.3187, Accuracy: 90.68% ]
# Elapsed Inf. time: 0.13-mins.
#
# 4: Elapsed Train time: 1.55-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2827, Accuracy: 91.78% ] || Test: [ Avg Loss: 0.2693, Accuracy: 92.11% ]
# Elapsed Inf. time: 0.13-mins.
#
# 5: Elapsed Train time: 1.42-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2488, Accuracy: 92.79% ] || Test: [ Avg Loss: 0.2999, Accuracy: 91.25% ]
# Elapsed Inf. time: 0.13-mins.
#
# 6: Elapsed Train time: 1.48-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2225, Accuracy: 93.62% ] || Test: [ Avg Loss: 0.2691, Accuracy: 92.15% ]
# Elapsed Inf. time: 0.13-mins.
#
# 7: Elapsed Train time: 1.54-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2047, Accuracy: 94.17% ] || Test: [ Avg Loss: 0.2238, Accuracy: 93.61% ]
# Elapsed Inf. time: 0.13-mins.
#
# 8: Elapsed Train time: 1.48-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1845, Accuracy: 94.74% ] || Test: [ Avg Loss: 0.2238, Accuracy: 93.75% ]
# Elapsed Inf. time: 0.13-mins.
#
# 9: Elapsed Train time: 1.49-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1694, Accuracy: 95.16% ] || Test: [ Avg Loss: 0.2430, Accuracy: 93.01% ]
# Elapsed Inf. time: 0.13-mins.
#
# 10: Elapsed Train time: 1.54-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1535, Accuracy: 95.57% ] || Test: [ Avg Loss: 0.2065, Accuracy: 94.15% ]
# Elapsed Inf. time: 0.13-mins.
#
# 11: Elapsed Train time: 1.49-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1382, Accuracy: 96.07% ] || Test: [ Avg Loss: 0.2265, Accuracy: 93.49% ]
# Elapsed Inf. time: 0.13-mins.
#
# 12: Elapsed Train time: 1.48-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1274, Accuracy: 96.41% ] || Test: [ Avg Loss: 0.2307, Accuracy: 93.43% ]
# Elapsed Inf. time: 0.13-mins.
#
# 13: Elapsed Train time: 1.57-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1132, Accuracy: 96.83% ] || Test: [ Avg Loss: 0.2576, Accuracy: 92.47% ]
# Elapsed Inf. time: 0.13-mins.
#
# 14: Elapsed Train time: 1.53-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1025, Accuracy: 97.08% ] || Test: [ Avg Loss: 0.2791, Accuracy: 91.73% ]
# Elapsed Inf. time: 0.13-mins.
#
# 15: Elapsed Train time: 1.48-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0897, Accuracy: 97.48% ] || Test: [ Avg Loss: 0.2471, Accuracy: 93.03% ]
# Elapsed Inf. time: 0.13-mins.
#
# 16: Elapsed Train time: 1.47-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0821, Accuracy: 97.66% ] || Test: [ Avg Loss: 0.2527, Accuracy: 92.92% ]
# Elapsed Inf. time: 0.13-mins.
#
# 17: Elapsed Train time: 1.55-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0734, Accuracy: 97.89% ] || Test: [ Avg Loss: 0.2517, Accuracy: 93.02% ]
# Elapsed Inf. time: 0.13-mins.
#
# 18: Elapsed Train time: 1.39-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0650, Accuracy: 98.19% ] || Test: [ Avg Loss: 0.2554, Accuracy: 93.13% ]
# Elapsed Inf. time: 0.13-mins.
#
# 19: Elapsed Train time: 1.53-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0609, Accuracy: 98.21% ] || Test: [ Avg Loss: 0.2603, Accuracy: 92.77% ]
# Elapsed Inf. time: 0.13-mins.
#
# 20: Elapsed Train time: 1.54-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0567, Accuracy: 98.34% ] || Test: [ Avg Loss: 0.2706, Accuracy: 92.74% ]
# Elapsed Inf. time: 0.13-mins.
#
# 21: Elapsed Train time: 1.51-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0515, Accuracy: 98.52% ] || Test: [ Avg Loss: 0.2520, Accuracy: 93.31% ]
# Elapsed Inf. time: 0.13-mins.
#
# 22: Elapsed Train time: 1.50-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0480, Accuracy: 98.50% ] || Test: [ Avg Loss: 0.2578, Accuracy: 92.98% ]
# Elapsed Inf. time: 0.13-mins.
#
# 23: Elapsed Train time: 1.45-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0416, Accuracy: 98.81% ] || Test: [ Avg Loss: 0.2721, Accuracy: 92.96% ]
# Elapsed Inf. time: 0.13-mins.
#
# 24: Elapsed Train time: 1.51-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0402, Accuracy: 98.79% ] || Test: [ Avg Loss: 0.2700, Accuracy: 93.11% ]
# Elapsed Inf. time: 0.13-mins.
#
# 25: Elapsed Train time: 1.49-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0437, Accuracy: 98.65% ] || Test: [ Avg Loss: 0.2830, Accuracy: 92.78% ]
# Elapsed Inf. time: 0.13-mins.
#
# 26: Elapsed Train time: 1.51-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0372, Accuracy: 98.88% ] || Test: [ Avg Loss: 0.3060, Accuracy: 92.58% ]
# Elapsed Inf. time: 0.13-mins.
#
# 27: Elapsed Train time: 1.55-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0297, Accuracy: 99.16% ] || Test: [ Avg Loss: 0.3052, Accuracy: 92.66% ]
# Elapsed Inf. time: 0.13-mins.
#
# 28: Elapsed Train time: 1.57-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0389, Accuracy: 98.81% ] || Test: [ Avg Loss: 0.2850, Accuracy: 92.86% ]
# Elapsed Inf. time: 0.13-mins.
#
# 29: Elapsed Train time: 1.53-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0326, Accuracy: 99.05% ] || Test: [ Avg Loss: 0.2862, Accuracy: 93.10% ]
# Elapsed Inf. time: 0.13-mins.
#
# 30: Elapsed Train time: 1.54-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0328, Accuracy: 98.98% ] || Test: [ Avg Loss: 0.2816, Accuracy: 93.14% ]
# Elapsed Inf. time: 0.13-mins.
#
# *********************************************************************************
# Done! Run: 5 : [Best Test @ epoch 10] || [ Avg loss: 0.206510, Accuracy: 94.15% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9988],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# calc.: 0.000136, pvec2norm: 42.261230, gvec2norm: 22.933674
# ss_calc: 0.003111
# ss_used: 0.003111
# 1: Elapsed Train time: 1.59-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 1.4272, Accuracy: 53.21% ] || Test: [ Avg Loss: 0.7582, Accuracy: 77.62% ]
# Elapsed Inf. time: 0.13-mins.
#
# 2: Elapsed Train time: 1.57-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.4613, Accuracy: 86.31% ] || Test: [ Avg Loss: 0.3981, Accuracy: 88.65% ]
# Elapsed Inf. time: 0.13-mins.
#
# 3: Elapsed Train time: 1.53-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.3402, Accuracy: 89.97% ] || Test: [ Avg Loss: 0.3007, Accuracy: 91.63% ]
# Elapsed Inf. time: 0.13-mins.
#
# 4: Elapsed Train time: 1.50-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2858, Accuracy: 91.62% ] || Test: [ Avg Loss: 0.2871, Accuracy: 92.11% ]
# Elapsed Inf. time: 0.13-mins.
#
# 5: Elapsed Train time: 1.51-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2512, Accuracy: 92.72% ] || Test: [ Avg Loss: 0.2537, Accuracy: 92.85% ]
# Elapsed Inf. time: 0.13-mins.
#
# 6: Elapsed Train time: 1.46-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2269, Accuracy: 93.46% ] || Test: [ Avg Loss: 0.2607, Accuracy: 92.57% ]
# Elapsed Inf. time: 0.13-mins.
#
# 7: Elapsed Train time: 1.47-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2043, Accuracy: 94.13% ] || Test: [ Avg Loss: 0.2199, Accuracy: 93.83% ]
# Elapsed Inf. time: 0.13-mins.
#
# 8: Elapsed Train time: 1.53-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1849, Accuracy: 94.78% ] || Test: [ Avg Loss: 0.2254, Accuracy: 93.47% ]
# Elapsed Inf. time: 0.13-mins.
#
# 9: Elapsed Train time: 1.50-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1680, Accuracy: 95.26% ] || Test: [ Avg Loss: 0.2414, Accuracy: 92.90% ]
# Elapsed Inf. time: 0.13-mins.
#
# 10: Elapsed Train time: 1.48-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1568, Accuracy: 95.50% ] || Test: [ Avg Loss: 0.2197, Accuracy: 93.71% ]
# Elapsed Inf. time: 0.13-mins.
#
# 11: Elapsed Train time: 1.48-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1403, Accuracy: 96.00% ] || Test: [ Avg Loss: 0.2359, Accuracy: 93.21% ]
# Elapsed Inf. time: 0.13-mins.
#
# 12: Elapsed Train time: 1.41-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1269, Accuracy: 96.41% ] || Test: [ Avg Loss: 0.2309, Accuracy: 93.46% ]
# Elapsed Inf. time: 0.13-mins.
#
# 13: Elapsed Train time: 1.56-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1132, Accuracy: 96.83% ] || Test: [ Avg Loss: 0.2487, Accuracy: 93.07% ]
# Elapsed Inf. time: 0.14-mins.
#
# 14: Elapsed Train time: 1.50-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1036, Accuracy: 97.04% ] || Test: [ Avg Loss: 0.2315, Accuracy: 93.54% ]
# Elapsed Inf. time: 0.13-mins.
#
# 15: Elapsed Train time: 1.57-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0901, Accuracy: 97.45% ] || Test: [ Avg Loss: 0.2523, Accuracy: 92.93% ]
# Elapsed Inf. time: 0.13-mins.
#
# 16: Elapsed Train time: 1.57-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0834, Accuracy: 97.59% ] || Test: [ Avg Loss: 0.2427, Accuracy: 93.42% ]
# Elapsed Inf. time: 0.13-mins.
#
# 17: Elapsed Train time: 1.47-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0736, Accuracy: 97.90% ] || Test: [ Avg Loss: 0.2721, Accuracy: 92.64% ]
# Elapsed Inf. time: 0.13-mins.
#
# 18: Elapsed Train time: 1.55-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0680, Accuracy: 97.96% ] || Test: [ Avg Loss: 0.2445, Accuracy: 93.28% ]
# Elapsed Inf. time: 0.13-mins.
#
# 19: Elapsed Train time: 1.56-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0592, Accuracy: 98.31% ] || Test: [ Avg Loss: 0.2760, Accuracy: 92.37% ]
# Elapsed Inf. time: 0.13-mins.
#
# 20: Elapsed Train time: 1.52-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0586, Accuracy: 98.22% ] || Test: [ Avg Loss: 0.2563, Accuracy: 93.08% ]
# Elapsed Inf. time: 0.13-mins.
#
# 21: Elapsed Train time: 1.48-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0560, Accuracy: 98.34% ] || Test: [ Avg Loss: 0.2651, Accuracy: 93.10% ]
# Elapsed Inf. time: 0.13-mins.
#
# 22: Elapsed Train time: 1.55-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0439, Accuracy: 98.74% ] || Test: [ Avg Loss: 0.3158, Accuracy: 91.57% ]
# Elapsed Inf. time: 0.13-mins.
#
# 23: Elapsed Train time: 1.59-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0536, Accuracy: 98.39% ] || Test: [ Avg Loss: 0.2721, Accuracy: 93.09% ]
# Elapsed Inf. time: 0.13-mins.
#
# 24: Elapsed Train time: 1.56-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0421, Accuracy: 98.74% ] || Test: [ Avg Loss: 0.2763, Accuracy: 93.00% ]
# Elapsed Inf. time: 0.13-mins.
#
# 25: Elapsed Train time: 1.55-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0415, Accuracy: 98.67% ] || Test: [ Avg Loss: 0.2820, Accuracy: 93.19% ]
# Elapsed Inf. time: 0.13-mins.
#
# 26: Elapsed Train time: 1.55-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0419, Accuracy: 98.68% ] || Test: [ Avg Loss: 0.3204, Accuracy: 92.03% ]
# Elapsed Inf. time: 0.13-mins.
#
# 27: Elapsed Train time: 1.42-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0396, Accuracy: 98.78% ] || Test: [ Avg Loss: 0.2944, Accuracy: 92.97% ]
# Elapsed Inf. time: 0.13-mins.
#
# 28: Elapsed Train time: 1.42-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0321, Accuracy: 99.03% ] || Test: [ Avg Loss: 0.2933, Accuracy: 92.30% ]
# Elapsed Inf. time: 0.13-mins.
#
# 29: Elapsed Train time: 1.40-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0468, Accuracy: 98.51% ] || Test: [ Avg Loss: 0.3041, Accuracy: 92.77% ]
# Elapsed Inf. time: 0.13-mins.
#
# 30: Elapsed Train time: 1.42-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0320, Accuracy: 99.05% ] || Test: [ Avg Loss: 0.2970, Accuracy: 92.83% ]
# Elapsed Inf. time: 0.13-mins.
#
# ********************************************************************************
# Done! Run: 6 : [Best Test @ epoch 7] || [ Avg loss: 0.219855, Accuracy: 93.83% ]
# ********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9988],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# calc.: 0.000136, pvec2norm: 42.464172, gvec2norm: 15.955297
# ss_calc: 0.002175
# ss_used: 0.002175
# 1: Elapsed Train time: 1.16-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 1.4068, Accuracy: 54.19% ] || Test: [ Avg Loss: 0.7385, Accuracy: 78.12% ]
# Elapsed Inf. time: 0.13-mins.
#
# 2: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.4772, Accuracy: 85.88% ] || Test: [ Avg Loss: 0.3740, Accuracy: 89.47% ]
# Elapsed Inf. time: 0.13-mins.
#
# 3: Elapsed Train time: 1.52-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.3474, Accuracy: 89.67% ] || Test: [ Avg Loss: 0.3030, Accuracy: 91.25% ]
# Elapsed Inf. time: 0.13-mins.
#
# 4: Elapsed Train time: 1.53-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2892, Accuracy: 91.56% ] || Test: [ Avg Loss: 0.2989, Accuracy: 91.23% ]
# Elapsed Inf. time: 0.13-mins.
#
# 5: Elapsed Train time: 1.53-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2552, Accuracy: 92.60% ] || Test: [ Avg Loss: 0.2737, Accuracy: 92.20% ]
# Elapsed Inf. time: 0.13-mins.
#
# 6: Elapsed Train time: 1.55-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2303, Accuracy: 93.40% ] || Test: [ Avg Loss: 0.2713, Accuracy: 92.19% ]
# Elapsed Inf. time: 0.13-mins.
#
# 7: Elapsed Train time: 1.51-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2073, Accuracy: 94.09% ] || Test: [ Avg Loss: 0.2259, Accuracy: 93.51% ]
# Elapsed Inf. time: 0.13-mins.
#
# 8: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1885, Accuracy: 94.68% ] || Test: [ Avg Loss: 0.2477, Accuracy: 92.97% ]
# Elapsed Inf. time: 0.13-mins.
#
# 9: Elapsed Train time: 1.52-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1751, Accuracy: 95.03% ] || Test: [ Avg Loss: 0.2303, Accuracy: 93.46% ]
# Elapsed Inf. time: 0.14-mins.
#
# 10: Elapsed Train time: 1.51-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1574, Accuracy: 95.61% ] || Test: [ Avg Loss: 0.2275, Accuracy: 93.33% ]
# Elapsed Inf. time: 0.13-mins.
#
# 11: Elapsed Train time: 1.51-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1424, Accuracy: 95.94% ] || Test: [ Avg Loss: 0.2230, Accuracy: 93.57% ]
# Elapsed Inf. time: 0.13-mins.
#
# 12: Elapsed Train time: 1.55-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1289, Accuracy: 96.37% ] || Test: [ Avg Loss: 0.2294, Accuracy: 93.49% ]
# Elapsed Inf. time: 0.13-mins.
#
# 13: Elapsed Train time: 1.54-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1185, Accuracy: 96.69% ] || Test: [ Avg Loss: 0.2190, Accuracy: 93.76% ]
# Elapsed Inf. time: 0.13-mins.
#
# 14: Elapsed Train time: 1.08-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1054, Accuracy: 97.04% ] || Test: [ Avg Loss: 0.2336, Accuracy: 93.43% ]
# Elapsed Inf. time: 0.13-mins.
#
# 15: Elapsed Train time: 1.08-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0929, Accuracy: 97.43% ] || Test: [ Avg Loss: 0.2249, Accuracy: 93.62% ]
# Elapsed Inf. time: 0.13-mins.
#
# 16: Elapsed Train time: 1.09-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0842, Accuracy: 97.65% ] || Test: [ Avg Loss: 0.2361, Accuracy: 93.46% ]
# Elapsed Inf. time: 0.13-mins.
#
# 17: Elapsed Train time: 1.58-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0771, Accuracy: 97.79% ] || Test: [ Avg Loss: 0.2471, Accuracy: 93.23% ]
# Elapsed Inf. time: 0.13-mins.
#
# 18: Elapsed Train time: 1.58-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0682, Accuracy: 98.01% ] || Test: [ Avg Loss: 0.2619, Accuracy: 92.86% ]
# Elapsed Inf. time: 0.13-mins.
#
# 19: Elapsed Train time: 1.41-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0601, Accuracy: 98.29% ] || Test: [ Avg Loss: 0.3004, Accuracy: 91.50% ]
# Elapsed Inf. time: 0.14-mins.
#
# 20: Elapsed Train time: 1.47-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0548, Accuracy: 98.44% ] || Test: [ Avg Loss: 0.2600, Accuracy: 93.09% ]
# Elapsed Inf. time: 0.13-mins.
#
# 21: Elapsed Train time: 1.54-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0507, Accuracy: 98.51% ] || Test: [ Avg Loss: 0.2848, Accuracy: 92.43% ]
# Elapsed Inf. time: 0.13-mins.
#
# 22: Elapsed Train time: 1.54-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0481, Accuracy: 98.54% ] || Test: [ Avg Loss: 0.3022, Accuracy: 91.73% ]
# Elapsed Inf. time: 0.13-mins.
#
# 23: Elapsed Train time: 1.50-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0414, Accuracy: 98.87% ] || Test: [ Avg Loss: 0.2706, Accuracy: 93.18% ]
# Elapsed Inf. time: 0.13-mins.
#
# 24: Elapsed Train time: 1.52-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0441, Accuracy: 98.70% ] || Test: [ Avg Loss: 0.2939, Accuracy: 92.47% ]
# Elapsed Inf. time: 0.14-mins.
#
# 25: Elapsed Train time: 1.57-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0350, Accuracy: 99.03% ] || Test: [ Avg Loss: 0.2793, Accuracy: 92.95% ]
# Elapsed Inf. time: 0.13-mins.
#
# 26: Elapsed Train time: 1.51-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0364, Accuracy: 98.93% ] || Test: [ Avg Loss: 0.2903, Accuracy: 92.69% ]
# Elapsed Inf. time: 0.13-mins.
#
# 27: Elapsed Train time: 1.50-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0384, Accuracy: 98.90% ] || Test: [ Avg Loss: 0.2845, Accuracy: 93.01% ]
# Elapsed Inf. time: 0.14-mins.
#
# 28: Elapsed Train time: 1.47-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0255, Accuracy: 99.32% ] || Test: [ Avg Loss: 0.2973, Accuracy: 92.83% ]
# Elapsed Inf. time: 0.13-mins.
#
# 29: Elapsed Train time: 1.54-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0400, Accuracy: 98.74% ] || Test: [ Avg Loss: 0.2872, Accuracy: 92.91% ]
# Elapsed Inf. time: 0.13-mins.
#
# 30: Elapsed Train time: 1.52-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0254, Accuracy: 99.32% ] || Test: [ Avg Loss: 0.2922, Accuracy: 92.94% ]
# Elapsed Inf. time: 0.14-mins.
#
# ...
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0470, Accuracy: 98.71% ] || Test: [ Avg Loss: 0.2554, Accuracy: 93.27% ]
# Elapsed Inf. time: 0.13-mins.
#
# 23: Elapsed Train time: 1.28-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0382, Accuracy: 98.97% ] || Test: [ Avg Loss: 0.2843, Accuracy: 92.65% ]
# Elapsed Inf. time: 0.13-mins.
#
# 24: Elapsed Train time: 1.40-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0397, Accuracy: 98.85% ] || Test: [ Avg Loss: 0.2788, Accuracy: 92.71% ]
# Elapsed Inf. time: 0.13-mins.
#
# 25: Elapsed Train time: 1.49-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0351, Accuracy: 99.03% ] || Test: [ Avg Loss: 0.2732, Accuracy: 92.96% ]
# Elapsed Inf. time: 0.13-mins.
#
# 26: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0407, Accuracy: 98.75% ] || Test: [ Avg Loss: 0.2986, Accuracy: 92.32% ]
# Elapsed Inf. time: 0.13-mins.
#
# 27: Elapsed Train time: 1.59-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0307, Accuracy: 99.15% ] || Test: [ Avg Loss: 0.2991, Accuracy: 92.56% ]
# Elapsed Inf. time: 0.13-mins.
#
# 28: Elapsed Train time: 1.58-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0285, Accuracy: 99.19% ] || Test: [ Avg Loss: 0.2923, Accuracy: 92.73% ]
# Elapsed Inf. time: 0.13-mins.
#
# 29: Elapsed Train time: 1.42-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0294, Accuracy: 99.18% ] || Test: [ Avg Loss: 0.3004, Accuracy: 92.54% ]
# Elapsed Inf. time: 0.13-mins.
#
# 30: Elapsed Train time: 1.58-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0327, Accuracy: 99.06% ] || Test: [ Avg Loss: 0.2935, Accuracy: 92.96% ]
# Elapsed Inf. time: 0.13-mins.
#
# *********************************************************************************
# Done! Run: 8 : [Best Test @ epoch 11] || [ Avg loss: 0.222803, Accuracy: 93.73% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9988],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# calc.: 0.000136, pvec2norm: 42.312893, gvec2norm: 18.120262
# ss_calc: 0.002461
# ss_used: 0.002461
# 1: Elapsed Train time: 1.52-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 1.3447, Accuracy: 56.65% ] || Test: [ Avg Loss: 0.7591, Accuracy: 73.47% ]
# Elapsed Inf. time: 0.13-mins.
#
# 2: Elapsed Train time: 1.52-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.4515, Accuracy: 86.59% ] || Test: [ Avg Loss: 0.3656, Accuracy: 89.44% ]
# Elapsed Inf. time: 0.13-mins.
#
# 3: Elapsed Train time: 1.30-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.3368, Accuracy: 90.03% ] || Test: [ Avg Loss: 0.3413, Accuracy: 89.59% ]
# Elapsed Inf. time: 0.13-mins.
#
# 4: Elapsed Train time: 1.54-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2841, Accuracy: 91.72% ] || Test: [ Avg Loss: 0.3494, Accuracy: 89.52% ]
# Elapsed Inf. time: 0.13-mins.
#
# 5: Elapsed Train time: 1.41-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2492, Accuracy: 92.81% ] || Test: [ Avg Loss: 0.2936, Accuracy: 91.16% ]
# Elapsed Inf. time: 0.13-mins.
#
# 6: Elapsed Train time: 1.15-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2253, Accuracy: 93.41% ] || Test: [ Avg Loss: 0.2354, Accuracy: 93.31% ]
# Elapsed Inf. time: 0.13-mins.
#
# 7: Elapsed Train time: 1.60-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2055, Accuracy: 94.08% ] || Test: [ Avg Loss: 0.2326, Accuracy: 93.43% ]
# Elapsed Inf. time: 0.13-mins.
#
# 8: Elapsed Train time: 1.50-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1840, Accuracy: 94.79% ] || Test: [ Avg Loss: 0.2202, Accuracy: 93.82% ]
# Elapsed Inf. time: 0.13-mins.
#
# 9: Elapsed Train time: 1.60-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1689, Accuracy: 95.21% ] || Test: [ Avg Loss: 0.2593, Accuracy: 92.46% ]
# Elapsed Inf. time: 0.13-mins.
#
# 10: Elapsed Train time: 1.54-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1552, Accuracy: 95.54% ] || Test: [ Avg Loss: 0.2187, Accuracy: 93.94% ]
# Elapsed Inf. time: 0.13-mins.
#
# 11: Elapsed Train time: 1.54-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1418, Accuracy: 96.09% ] || Test: [ Avg Loss: 0.2371, Accuracy: 93.34% ]
# Elapsed Inf. time: 0.14-mins.
#
# 12: Elapsed Train time: 1.48-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1261, Accuracy: 96.43% ] || Test: [ Avg Loss: 0.2717, Accuracy: 92.16% ]
# Elapsed Inf. time: 0.13-mins.
#
# 13: Elapsed Train time: 1.53-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1131, Accuracy: 96.82% ] || Test: [ Avg Loss: 0.2190, Accuracy: 93.87% ]
# Elapsed Inf. time: 0.13-mins.
#
# 14: Elapsed Train time: 1.41-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1017, Accuracy: 97.18% ] || Test: [ Avg Loss: 0.2531, Accuracy: 92.95% ]
# Elapsed Inf. time: 0.13-mins.
#
# 15: Elapsed Train time: 1.23-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0915, Accuracy: 97.41% ] || Test: [ Avg Loss: 0.2397, Accuracy: 93.49% ]
# Elapsed Inf. time: 0.13-mins.
#
# 16: Elapsed Train time: 1.52-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0819, Accuracy: 97.69% ] || Test: [ Avg Loss: 0.2581, Accuracy: 92.97% ]
# Elapsed Inf. time: 0.14-mins.
#
# 17: Elapsed Train time: 1.50-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0698, Accuracy: 98.03% ] || Test: [ Avg Loss: 0.2727, Accuracy: 92.50% ]
# Elapsed Inf. time: 0.14-mins.
#
# 18: Elapsed Train time: 1.58-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0658, Accuracy: 98.07% ] || Test: [ Avg Loss: 0.2508, Accuracy: 93.09% ]
# Elapsed Inf. time: 0.13-mins.
#
# 19: Elapsed Train time: 1.55-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0623, Accuracy: 98.17% ] || Test: [ Avg Loss: 0.2598, Accuracy: 93.26% ]
# Elapsed Inf. time: 0.13-mins.
#
# 20: Elapsed Train time: 1.57-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0540, Accuracy: 98.41% ] || Test: [ Avg Loss: 0.2491, Accuracy: 93.76% ]
# Elapsed Inf. time: 0.13-mins.
#
# 21: Elapsed Train time: 1.51-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0476, Accuracy: 98.65% ] || Test: [ Avg Loss: 0.2872, Accuracy: 92.65% ]
# Elapsed Inf. time: 0.13-mins.
#
# 22: Elapsed Train time: 1.53-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0538, Accuracy: 98.36% ] || Test: [ Avg Loss: 0.2758, Accuracy: 93.24% ]
# Elapsed Inf. time: 0.13-mins.
#
# 23: Elapsed Train time: 1.55-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0387, Accuracy: 98.91% ] || Test: [ Avg Loss: 0.3034, Accuracy: 92.42% ]
# Elapsed Inf. time: 0.13-mins.
#
# 24: Elapsed Train time: 1.56-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0404, Accuracy: 98.83% ] || Test: [ Avg Loss: 0.2776, Accuracy: 92.91% ]
# Elapsed Inf. time: 0.14-mins.
#
# 25: Elapsed Train time: 1.54-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0407, Accuracy: 98.78% ] || Test: [ Avg Loss: 0.2980, Accuracy: 92.67% ]
# Elapsed Inf. time: 0.13-mins.
#
# 26: Elapsed Train time: 1.54-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0319, Accuracy: 99.09% ] || Test: [ Avg Loss: 0.2993, Accuracy: 92.85% ]
# Elapsed Inf. time: 0.13-mins.
#
# 27: Elapsed Train time: 1.51-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0379, Accuracy: 98.86% ] || Test: [ Avg Loss: 0.2798, Accuracy: 93.15% ]
# Elapsed Inf. time: 0.13-mins.
#
# 28: Elapsed Train time: 1.52-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0394, Accuracy: 98.79% ] || Test: [ Avg Loss: 0.2785, Accuracy: 93.51% ]
# Elapsed Inf. time: 0.13-mins.
#
# 29: Elapsed Train time: 1.56-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0291, Accuracy: 99.15% ] || Test: [ Avg Loss: 0.3216, Accuracy: 92.47% ]
# Elapsed Inf. time: 0.13-mins.
#
# 30: Elapsed Train time: 1.32-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0309, Accuracy: 99.08% ] || Test: [ Avg Loss: 0.3117, Accuracy: 92.97% ]
# Elapsed Inf. time: 0.13-mins.
#
# *********************************************************************************
# Done! Run: 9 : [Best Test @ epoch 10] || [ Avg loss: 0.218709, Accuracy: 93.94% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9988],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# calc.: 0.000136, pvec2norm: 42.489346, gvec2norm: 20.638247
# ss_calc: 0.002815
# ss_used: 0.002815
# 1: Elapsed Train time: 1.08-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 1.4197, Accuracy: 53.60% ] || Test: [ Avg Loss: 0.7976, Accuracy: 75.61% ]
# Elapsed Inf. time: 0.13-mins.
#
# 2: Elapsed Train time: 1.50-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.4656, Accuracy: 86.34% ] || Test: [ Avg Loss: 0.4023, Accuracy: 88.56% ]
# Elapsed Inf. time: 0.13-mins.
#
# 3: Elapsed Train time: 1.26-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.3417, Accuracy: 89.83% ] || Test: [ Avg Loss: 0.3026, Accuracy: 91.49% ]
# Elapsed Inf. time: 0.13-mins.
#
# 4: Elapsed Train time: 1.53-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2863, Accuracy: 91.64% ] || Test: [ Avg Loss: 0.3198, Accuracy: 90.73% ]
# Elapsed Inf. time: 0.13-mins.
#
# 5: Elapsed Train time: 1.54-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2523, Accuracy: 92.63% ] || Test: [ Avg Loss: 0.2508, Accuracy: 92.87% ]
# Elapsed Inf. time: 0.13-mins.
#
# 6: Elapsed Train time: 1.52-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2251, Accuracy: 93.49% ] || Test: [ Avg Loss: 0.2605, Accuracy: 92.47% ]
# Elapsed Inf. time: 0.13-mins.
#
# 7: Elapsed Train time: 1.54-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2049, Accuracy: 94.04% ] || Test: [ Avg Loss: 0.2224, Accuracy: 93.69% ]
# Elapsed Inf. time: 0.13-mins.
#
# 8: Elapsed Train time: 1.53-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1889, Accuracy: 94.60% ] || Test: [ Avg Loss: 0.2178, Accuracy: 93.98% ]
# Elapsed Inf. time: 0.13-mins.
#
# 9: Elapsed Train time: 1.49-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1723, Accuracy: 95.05% ] || Test: [ Avg Loss: 0.2245, Accuracy: 93.59% ]
# Elapsed Inf. time: 0.13-mins.
#
# 10: Elapsed Train time: 1.50-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1553, Accuracy: 95.58% ] || Test: [ Avg Loss: 0.2313, Accuracy: 93.17% ]
# Elapsed Inf. time: 0.13-mins.
#
# 11: Elapsed Train time: 1.50-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1405, Accuracy: 96.00% ] || Test: [ Avg Loss: 0.2339, Accuracy: 93.23% ]
# Elapsed Inf. time: 0.13-mins.
#
# 12: Elapsed Train time: 1.50-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1273, Accuracy: 96.39% ] || Test: [ Avg Loss: 0.2231, Accuracy: 93.78% ]
# Elapsed Inf. time: 0.13-mins.
#
# 13: Elapsed Train time: 1.57-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1167, Accuracy: 96.61% ] || Test: [ Avg Loss: 0.2235, Accuracy: 93.86% ]
# Elapsed Inf. time: 0.13-mins.
#
# 14: Elapsed Train time: 1.50-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1041, Accuracy: 97.08% ] || Test: [ Avg Loss: 0.2724, Accuracy: 92.39% ]
# Elapsed Inf. time: 0.13-mins.
#
# 15: Elapsed Train time: 1.53-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0921, Accuracy: 97.40% ] || Test: [ Avg Loss: 0.2409, Accuracy: 93.16% ]
# Elapsed Inf. time: 0.13-mins.
#
# 16: Elapsed Train time: 1.48-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0842, Accuracy: 97.55% ] || Test: [ Avg Loss: 0.2298, Accuracy: 93.79% ]
# Elapsed Inf. time: 0.13-mins.
#
# 17: Elapsed Train time: 1.50-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0736, Accuracy: 97.90% ] || Test: [ Avg Loss: 0.2438, Accuracy: 93.27% ]
# Elapsed Inf. time: 0.13-mins.
#
# 18: Elapsed Train time: 1.51-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0673, Accuracy: 98.01% ] || Test: [ Avg Loss: 0.2817, Accuracy: 92.46% ]
# Elapsed Inf. time: 0.13-mins.
#
# 19: Elapsed Train time: 1.48-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0638, Accuracy: 98.11% ] || Test: [ Avg Loss: 0.2730, Accuracy: 92.64% ]
# Elapsed Inf. time: 0.13-mins.
#
# 20: Elapsed Train time: 1.27-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0563, Accuracy: 98.33% ] || Test: [ Avg Loss: 0.2510, Accuracy: 93.30% ]
# Elapsed Inf. time: 0.13-mins.
#
# 21: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0507, Accuracy: 98.51% ] || Test: [ Avg Loss: 0.2480, Accuracy: 93.34% ]
# Elapsed Inf. time: 0.13-mins.
#
# 22: Elapsed Train time: 1.48-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0492, Accuracy: 98.48% ] || Test: [ Avg Loss: 0.2561, Accuracy: 93.62% ]
# Elapsed Inf. time: 0.13-mins.
#
# 23: Elapsed Train time: 1.54-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0485, Accuracy: 98.52% ] || Test: [ Avg Loss: 0.2627, Accuracy: 93.25% ]
# Elapsed Inf. time: 0.14-mins.
#
# 24: Elapsed Train time: 1.46-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0396, Accuracy: 98.82% ] || Test: [ Avg Loss: 0.2804, Accuracy: 92.90% ]
# Elapsed Inf. time: 0.13-mins.
#
# 25: Elapsed Train time: 1.44-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0411, Accuracy: 98.75% ] || Test: [ Avg Loss: 0.2742, Accuracy: 93.09% ]
# Elapsed Inf. time: 0.13-mins.
#
# 26: Elapsed Train time: 1.47-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0431, Accuracy: 98.67% ] || Test: [ Avg Loss: 0.2615, Accuracy: 93.16% ]
# Elapsed Inf. time: 0.13-mins.
#
# 27: Elapsed Train time: 1.48-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0381, Accuracy: 98.86% ] || Test: [ Avg Loss: 0.3067, Accuracy: 92.52% ]
# Elapsed Inf. time: 0.13-mins.
#
# 28: Elapsed Train time: 1.41-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0352, Accuracy: 98.92% ] || Test: [ Avg Loss: 0.2833, Accuracy: 93.47% ]
# Elapsed Inf. time: 0.13-mins.
#
# 29: Elapsed Train time: 1.44-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0373, Accuracy: 98.86% ] || Test: [ Avg Loss: 0.3019, Accuracy: 92.62% ]
# Elapsed Inf. time: 0.13-mins.
#
# 30: Elapsed Train time: 1.48-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0298, Accuracy: 99.14% ] || Test: [ Avg Loss: 0.3041, Accuracy: 92.66% ]
# Elapsed Inf. time: 0.13-mins.
#
# *********************************************************************************
# Done! Run: 10 : [Best Test @ epoch 8] || [ Avg loss: 0.217796, Accuracy: 93.98% ]
# *********************************************************************************
#
# *********************************************
# Average Prediction Difference = 0.06%
# Effective Test Accuracy = 93.85%, pval=0.0000
# *********************************************

# %%
# Plots
plotter_v1(cfgs,run_idx=1)
