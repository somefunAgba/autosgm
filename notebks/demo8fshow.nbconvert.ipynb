# %%
#!/scratch/nnenv/bin/python3

# %pip install watermark numpy pandas matplotlib torch torchvision torchaudio | grep -v 'already satisfied'
# %load_ext watermark
# %watermark -v -p watermark,numpy,pandas,matplotlib,torch

#
import math,random,os,sys,copy,time,glob,itertools,shutil,re, json
from scipy.stats import wilcoxon

#
import numpy as np

#
import torch, gc
torch.cuda.empty_cache()
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

import torch.nn as nn
import torch.nn.functional as tf
from torch.utils.data import Dataset,DataLoader
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor, Lambda

import pandas as pd

from pathlib import Path
sys.path[0] = str(Path(sys.path[0]).parent)

#
from demofcns import *
from opts.asgm.torchlasgm import PID
from opts.elpf.fo import LPF
from opts.elpf.esfo import esLPF

# from .. import arcs
from arcs.resnet import ResNetC

# python3 -m torch.utils.collect_env
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Python implementation: CPython
# Python version       : 3.10.6
# IPython version      : 8.7.0
#
# watermark : 2.3.1
# numpy     : 1.23.1
# pandas    : 1.4.3
# matplotlib: 3.5.3
# torch     : 1.12.0+cu116

# %% [markdown]
# ##### Setup Configurations (Hyperparameters and so on)

# %%
# - is it being run remotely on OSU EECS server?
remotelyrun = 1 # 0 | 1

#----------------------
# Load setup config
#----------------------
with open('cfgs.json', 'r') as cfglist:
  cfgs = json.load(cfglist)
  
# setup
cfgs['storedir'] = "../expstore"

# - pick data-set
cfgs["dataset"] = "svhn"
# - set max. batchsize for each epoch, training runs, training epochs, 
cfgs["batch-size"] = 128 # 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, ...
cfgs['runs'] = 10
cfgs["epochs"] = 30

# -pick computation device
devcnt = torch.cuda.device_count()

# - setup multiprocessing, human signature
# random seed for python libraries
cfgs["seed"] = 2023
cfgs["var_seed"] = 1
worker_seed = cfgs["seed"] % (2**32)
cfgs["num-workers"] = 0 #3
cfgs["human_signature"] = "oas" # for signing experiments ran.


if devcnt > 1:
  cfgs["device"] = torch.device('cuda') # "cuda:1"
  torch.cuda.set_device(1)
elif devcnt == 1:
  cfgs["device"] = torch.device('cuda')
else:
  cfgs["device"] = torch.device('cpu')
#
if remotelyrun:
  cfgs["remote"] = True
else:
  cfgs["remote"] = False

# %% [markdown]
# ##### (Generate) or Load the Dataset

# %%
#----------------------
# Download/Load Dataset
#----------------------
if not cfgs["remote"]:
  # same dir. as source-code
  data_folder = "../data"
else:
  # dalton's scratch on OSU's eecs server
  data_folder = "/scratch/data"


# SVHN
if cfgs["dataset"] == "svhn":
    train_data = datasets.SVHN(
      root=data_folder+"/SVHN",
      split="train",
      download=True,
      transform=ToTensor(),
    )
    test_data = datasets.SVHN(
      root=data_folder+"/SVHN",
      split="test",
      download= True,
      transform=ToTensor()
    )
    indim = [3,32,32]
    class_num = 10
    channels = indim[0]
    val_data = None
  
# Tests 
trainloader = torch.utils.data.DataLoader(train_data, batch_size=cfgs['batch-size'],shuffle=True)
# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)
pass
# Out:
# Using downloaded and verified file: /scratch/data/SVHN/train_32x32.mat
# Using downloaded and verified file: /scratch/data/SVHN/test_32x32.mat

# %% [markdown]
# ##### Construct Model (Differentiable Function) with  necessary methods.

# %%
'''
Uses ResNetC
'''

class thisNN(nn.Module):
  def __init__(self,num_heads=1,in_feats=[3,32,32],out_feats=10,layers=6, loss_type="mce", outs_class=True, mdl_name="nnresnet") -> None:
    """
    __init__ _summary_

    _extended_summary_

    Args:
        num_heads (int, req): net. output head. Defaults to 1.
        in_feats (int, req): net. input dimension. Defaults to 1.
        out_feats (int, req): net. output dimension per head. Defaults to 1.
        loss_type (str, req): type of loss function Defaults to "mse". ("mse","mce" for multi-class cross-entropy, "bce" binary-class cross-entropy)
        outs_class (bool, req): does model return class indices. Defaults to False, implying it outputs real-valued probabilities. This is also true for loss_type="mse" regardless of user-choice.
    """
    super().__init__()
    self.num_heads = num_heads
    
    # define mdl. params.
    self.cnn = nn.ModuleList()
    for hid in range(num_heads): 
      self.cnn.append(
        ResNetC(in_chans=in_feats[0],stem_chans=64,layers=str(layers),botneck=False,num_classes=out_feats,num_heads=num_heads) 
      )
    self.relu = nn.ReLU()
    self.flatten = nn.Flatten()
    
    # prob.fcn at last output or network head layer
    if loss_type == "bce" or loss_type == "mse":
      self.out = torch.nn.Sigmoid()
    else:
      self.out = torch.nn.Softmax()
    
    self.loss_type = loss_type
    self.outs_class = outs_class
    
    # optimizer
    self.sgm = None
    
    # saved trained model
    self.chkpt = None
    
    
    self.devcnt = torch.cuda.device_count()
    self.device = None
    self.name = mdl_name
    
    if not(loss_type == "mse" or loss_type =="mce" or loss_type == "bce"):
      raise ValueError(f"loss_type='{loss_type}' is not defined for this class")
    if (loss_type == "mse"):
      self.outs_class = False    
    
@clsmethod(thisNN)
def forward(self:thisNN, x):
  # pre-process
  logits = []
  for hid in range(self.num_heads):
    resnet = self.cnn[hid]
    y = resnet(x)  
    logits.append(y)
    
  return logits # List [Tensor]

@clsmethod(thisNN)
def outhead(self:thisNN, x):
  probs = []
  for hid in range(self.num_heads):
    y = self.out(x[hid])
    probs.append(y)  
  return probs # List [Tensor]

# Add necessary functions to train model
add_to_thisnn(thisNN,worker_seed,setseed,cseedwk)

# Use saved mdl as
# mdl <-- load model function
# prediction = mdl.infer(input)

# %% [markdown]
# ##### Run the Network Modeling (Training)

# %%
# Test.

torch.manual_seed(2023)
devcnt = torch.cuda.device_count()

cfgs['mdl_name_dir'] = "nndemo8f_svhn_resnet6"
isclassifier = True
cfgs["ss_init"] = 1e-3 # default 1e-3
cfgs["eps_ss"] = 1 # default 5e-1
cfgs["weight_decay"] = 1e-5 # default 1e-5
mdl = thisNN(mdl_name=cfgs['mdl_name_dir'])
if devcnt > 0:
    mdl.cuda()
cfgs['pathstr'] = str(mdl.name)+str(cfgs["batch-size"])+"_"+cfgs["dataset"]+"_"+str(cfgs["runs"])+"_"+str(cfgs["epochs"])

mdl.runs(train_data, test_data, cfgs=cfgs, eval_name="Test")
# Out:
# Seed: 2023
# **************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 1],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# **************************************************************************************************************************************************
#
# calc.: 0.002716 || calc2: 0.011793
# ss_calc: 0.005897
# ss_used: 0.005897
# 1: Elapsed Train time: 1.18-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 1.5609, Accuracy: 47.77% ] || Test: [ Avg Loss: 0.6529, Accuracy: 80.36% ]
# Elapsed Inf. time: 0.13-mins.
#
# 2: Elapsed Train time: 1.14-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.4277, Accuracy: 87.12% ] || Test: [ Avg Loss: 0.5197, Accuracy: 83.95% ]
# Elapsed Inf. time: 0.14-mins.
#
# 3: Elapsed Train time: 1.23-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.3146, Accuracy: 90.57% ] || Test: [ Avg Loss: 0.3503, Accuracy: 89.88% ]
# Elapsed Inf. time: 0.14-mins.
#
# 4: Elapsed Train time: 1.14-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2649, Accuracy: 92.23% ] || Test: [ Avg Loss: 0.5041, Accuracy: 83.77% ]
# Elapsed Inf. time: 0.13-mins.
#
# 5: Elapsed Train time: 1.11-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2388, Accuracy: 92.95% ] || Test: [ Avg Loss: 0.2838, Accuracy: 91.78% ]
# Elapsed Inf. time: 0.14-mins.
#
# 6: Elapsed Train time: 1.22-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2178, Accuracy: 93.66% ] || Test: [ Avg Loss: 0.2704, Accuracy: 92.25% ]
# Elapsed Inf. time: 0.14-mins.
#
# 7: Elapsed Train time: 1.16-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2013, Accuracy: 94.16% ] || Test: [ Avg Loss: 0.2279, Accuracy: 93.55% ]
# Elapsed Inf. time: 0.14-mins.
#
# 8: Elapsed Train time: 1.15-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1883, Accuracy: 94.49% ] || Test: [ Avg Loss: 0.3163, Accuracy: 90.19% ]
# Elapsed Inf. time: 0.14-mins.
#
# 9: Elapsed Train time: 1.27-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1767, Accuracy: 94.88% ] || Test: [ Avg Loss: 0.2381, Accuracy: 93.25% ]
# Elapsed Inf. time: 0.13-mins.
#
# 10: Elapsed Train time: 1.24-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1659, Accuracy: 95.07% ] || Test: [ Avg Loss: 0.2948, Accuracy: 91.23% ]
# Elapsed Inf. time: 0.14-mins.
#
# 11: Elapsed Train time: 1.40-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1551, Accuracy: 95.50% ] || Test: [ Avg Loss: 0.3228, Accuracy: 90.49% ]
# Elapsed Inf. time: 0.14-mins.
#
# 12: Elapsed Train time: 1.52-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1465, Accuracy: 95.76% ] || Test: [ Avg Loss: 0.2407, Accuracy: 92.92% ]
# Elapsed Inf. time: 0.13-mins.
#
# 13: Elapsed Train time: 1.12-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1400, Accuracy: 95.86% ] || Test: [ Avg Loss: 0.2705, Accuracy: 92.28% ]
# Elapsed Inf. time: 0.14-mins.
#
# 14: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1324, Accuracy: 96.12% ] || Test: [ Avg Loss: 0.2269, Accuracy: 93.68% ]
# Elapsed Inf. time: 0.14-mins.
#
# 15: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1264, Accuracy: 96.21% ] || Test: [ Avg Loss: 0.2746, Accuracy: 91.99% ]
# Elapsed Inf. time: 0.14-mins.
#
# 16: Elapsed Train time: 1.12-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1181, Accuracy: 96.44% ] || Test: [ Avg Loss: 0.2729, Accuracy: 92.08% ]
# Elapsed Inf. time: 0.13-mins.
#
# 17: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1131, Accuracy: 96.69% ] || Test: [ Avg Loss: 0.2797, Accuracy: 91.91% ]
# Elapsed Inf. time: 0.14-mins.
#
# 18: Elapsed Train time: 1.12-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1072, Accuracy: 96.76% ] || Test: [ Avg Loss: 0.2574, Accuracy: 92.70% ]
# Elapsed Inf. time: 0.14-mins.
#
# 19: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1028, Accuracy: 96.91% ] || Test: [ Avg Loss: 0.3395, Accuracy: 90.82% ]
# Elapsed Inf. time: 0.14-mins.
#
# 20: Elapsed Train time: 1.17-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0956, Accuracy: 97.06% ] || Test: [ Avg Loss: 0.2935, Accuracy: 91.90% ]
# Elapsed Inf. time: 0.14-mins.
#
# 21: Elapsed Train time: 1.12-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0975, Accuracy: 96.99% ] || Test: [ Avg Loss: 0.2412, Accuracy: 93.29% ]
# Elapsed Inf. time: 0.14-mins.
#
# 22: Elapsed Train time: 1.12-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0870, Accuracy: 97.32% ] || Test: [ Avg Loss: 0.2871, Accuracy: 92.17% ]
# Elapsed Inf. time: 0.14-mins.
#
# 23: Elapsed Train time: 1.13-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0897, Accuracy: 97.18% ] || Test: [ Avg Loss: 0.3386, Accuracy: 91.00% ]
# Elapsed Inf. time: 0.14-mins.
#
# 24: Elapsed Train time: 1.12-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0827, Accuracy: 97.34% ] || Test: [ Avg Loss: 0.4229, Accuracy: 89.45% ]
# Elapsed Inf. time: 0.14-mins.
#
# 25: Elapsed Train time: 1.14-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0807, Accuracy: 97.44% ] || Test: [ Avg Loss: 0.3122, Accuracy: 91.71% ]
# Elapsed Inf. time: 0.14-mins.
#
# 26: Elapsed Train time: 1.19-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0797, Accuracy: 97.48% ] || Test: [ Avg Loss: 0.3167, Accuracy: 91.48% ]
# Elapsed Inf. time: 0.14-mins.
#
# 27: Elapsed Train time: 1.11-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0763, Accuracy: 97.53% ] || Test: [ Avg Loss: 0.3021, Accuracy: 91.86% ]
# Elapsed Inf. time: 0.14-mins.
#
# 28: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0759, Accuracy: 97.54% ] || Test: [ Avg Loss: 0.3222, Accuracy: 91.48% ]
# Elapsed Inf. time: 0.14-mins.
#
# 29: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0706, Accuracy: 97.76% ] || Test: [ Avg Loss: 0.3168, Accuracy: 92.34% ]
# Elapsed Inf. time: 0.13-mins.
#
# 30: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0693, Accuracy: 97.71% ] || Test: [ Avg Loss: 0.2984, Accuracy: 92.24% ]
# Elapsed Inf. time: 0.14-mins.
#
# *********************************************************************************
# Done! Run: 1 : [Best Test @ epoch 14] || [ Avg loss: 0.226948, Accuracy: 93.68% ]
# *********************************************************************************
#
# **************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 1],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# **************************************************************************************************************************************************
#
# calc.: 0.001822 || calc2: 0.014333
# ss_calc: 0.007166
# ss_used: 0.007166
# 1: Elapsed Train time: 1.17-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 1.7070, Accuracy: 42.55% ] || Test: [ Avg Loss: 0.7362, Accuracy: 77.32% ]
# Elapsed Inf. time: 0.14-mins.
#
# 2: Elapsed Train time: 1.17-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.4357, Accuracy: 86.84% ] || Test: [ Avg Loss: 0.3975, Accuracy: 88.01% ]
# Elapsed Inf. time: 0.14-mins.
#
# 3: Elapsed Train time: 1.18-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.3121, Accuracy: 90.68% ] || Test: [ Avg Loss: 0.3218, Accuracy: 90.57% ]
# Elapsed Inf. time: 0.14-mins.
#
# 4: Elapsed Train time: 1.14-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2682, Accuracy: 92.07% ] || Test: [ Avg Loss: 0.2704, Accuracy: 92.19% ]
# Elapsed Inf. time: 0.14-mins.
#
# 5: Elapsed Train time: 1.20-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2396, Accuracy: 93.00% ] || Test: [ Avg Loss: 0.5068, Accuracy: 84.33% ]
# Elapsed Inf. time: 0.14-mins.
#
# 6: Elapsed Train time: 1.22-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2186, Accuracy: 93.71% ] || Test: [ Avg Loss: 0.3452, Accuracy: 89.22% ]
# Elapsed Inf. time: 0.13-mins.
#
# 7: Elapsed Train time: 1.15-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2049, Accuracy: 94.15% ] || Test: [ Avg Loss: 0.4101, Accuracy: 87.23% ]
# Elapsed Inf. time: 0.14-mins.
#
# 8: Elapsed Train time: 1.22-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1972, Accuracy: 94.28% ] || Test: [ Avg Loss: 0.2657, Accuracy: 92.28% ]
# Elapsed Inf. time: 0.14-mins.
#
# 9: Elapsed Train time: 1.19-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1802, Accuracy: 94.73% ] || Test: [ Avg Loss: 0.2608, Accuracy: 92.39% ]
# Elapsed Inf. time: 0.14-mins.
#
# 10: Elapsed Train time: 1.14-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1725, Accuracy: 95.03% ] || Test: [ Avg Loss: 0.2566, Accuracy: 92.47% ]
# Elapsed Inf. time: 0.14-mins.
#
# 11: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1667, Accuracy: 95.21% ] || Test: [ Avg Loss: 0.2562, Accuracy: 92.50% ]
# Elapsed Inf. time: 0.13-mins.
#
# 12: Elapsed Train time: 1.16-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1558, Accuracy: 95.43% ] || Test: [ Avg Loss: 0.2282, Accuracy: 93.61% ]
# Elapsed Inf. time: 0.13-mins.
#
# 13: Elapsed Train time: 1.14-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1481, Accuracy: 95.70% ] || Test: [ Avg Loss: 0.2279, Accuracy: 93.68% ]
# Elapsed Inf. time: 0.14-mins.
#
# 14: Elapsed Train time: 1.20-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1419, Accuracy: 95.90% ] || Test: [ Avg Loss: 0.3087, Accuracy: 91.15% ]
# Elapsed Inf. time: 0.14-mins.
#
# 15: Elapsed Train time: 1.18-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1356, Accuracy: 95.97% ] || Test: [ Avg Loss: 0.2427, Accuracy: 92.94% ]
# Elapsed Inf. time: 0.14-mins.
#
# 16: Elapsed Train time: 1.24-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1295, Accuracy: 96.10% ] || Test: [ Avg Loss: 0.2266, Accuracy: 93.61% ]
# Elapsed Inf. time: 0.14-mins.
#
# 17: Elapsed Train time: 1.24-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1230, Accuracy: 96.37% ] || Test: [ Avg Loss: 0.2495, Accuracy: 93.10% ]
# Elapsed Inf. time: 0.14-mins.
#
# 18: Elapsed Train time: 1.21-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1187, Accuracy: 96.48% ] || Test: [ Avg Loss: 0.3046, Accuracy: 91.47% ]
# Elapsed Inf. time: 0.14-mins.
#
# 19: Elapsed Train time: 1.17-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1159, Accuracy: 96.42% ] || Test: [ Avg Loss: 0.3019, Accuracy: 91.73% ]
# Elapsed Inf. time: 0.13-mins.
#
# 20: Elapsed Train time: 1.14-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1114, Accuracy: 96.63% ] || Test: [ Avg Loss: 0.2928, Accuracy: 91.66% ]
# Elapsed Inf. time: 0.14-mins.
#
# 21: Elapsed Train time: 1.23-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1087, Accuracy: 96.61% ] || Test: [ Avg Loss: 0.3328, Accuracy: 90.38% ]
# Elapsed Inf. time: 0.14-mins.
#
# 22: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1014, Accuracy: 96.92% ] || Test: [ Avg Loss: 0.2834, Accuracy: 92.36% ]
# Elapsed Inf. time: 0.14-mins.
#
# 23: Elapsed Train time: 1.18-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0974, Accuracy: 97.09% ] || Test: [ Avg Loss: 0.2697, Accuracy: 92.38% ]
# Elapsed Inf. time: 0.13-mins.
#
# 24: Elapsed Train time: 1.15-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0973, Accuracy: 96.96% ] || Test: [ Avg Loss: 0.3279, Accuracy: 91.37% ]
# Elapsed Inf. time: 0.14-mins.
#
# 25: Elapsed Train time: 1.16-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0942, Accuracy: 97.04% ] || Test: [ Avg Loss: 0.2501, Accuracy: 93.25% ]
# Elapsed Inf. time: 0.14-mins.
#
# 26: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0932, Accuracy: 97.10% ] || Test: [ Avg Loss: 0.2460, Accuracy: 93.35% ]
# Elapsed Inf. time: 0.14-mins.
#
# 27: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0863, Accuracy: 97.32% ] || Test: [ Avg Loss: 0.3403, Accuracy: 90.59% ]
# Elapsed Inf. time: 0.13-mins.
#
# 28: Elapsed Train time: 1.16-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0865, Accuracy: 97.31% ] || Test: [ Avg Loss: 0.2677, Accuracy: 92.84% ]
# Elapsed Inf. time: 0.14-mins.
#
# 29: Elapsed Train time: 1.22-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0831, Accuracy: 97.44% ] || Test: [ Avg Loss: 0.3695, Accuracy: 90.84% ]
# Elapsed Inf. time: 0.13-mins.
#
# 30: Elapsed Train time: 1.19-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0840, Accuracy: 97.30% ] || Test: [ Avg Loss: 0.3266, Accuracy: 91.58% ]
# Elapsed Inf. time: 0.13-mins.
#
# *********************************************************************************
# Done! Run: 2 : [Best Test @ epoch 13] || [ Avg loss: 0.227891, Accuracy: 93.68% ]
# *********************************************************************************
#
# **************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 1],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# **************************************************************************************************************************************************
#
# calc.: 0.002535 || calc2: 0.017771
# ss_calc: 0.008886
# ss_used: 0.008886
# 1: Elapsed Train time: 1.18-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 1.6750, Accuracy: 44.22% ] || Test: [ Avg Loss: 0.7157, Accuracy: 77.75% ]
# Elapsed Inf. time: 0.14-mins.
#
# 2: Elapsed Train time: 1.20-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.4262, Accuracy: 87.09% ] || Test: [ Avg Loss: 0.5293, Accuracy: 83.72% ]
# Elapsed Inf. time: 0.14-mins.
#
# 3: Elapsed Train time: 1.20-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.3109, Accuracy: 90.66% ] || Test: [ Avg Loss: 0.3211, Accuracy: 90.87% ]
# Elapsed Inf. time: 0.14-mins.
#
# 4: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2701, Accuracy: 92.08% ] || Test: [ Avg Loss: 0.4077, Accuracy: 87.68% ]
# Elapsed Inf. time: 0.14-mins.
#
# 5: Elapsed Train time: 1.16-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2432, Accuracy: 92.90% ] || Test: [ Avg Loss: 0.2729, Accuracy: 91.99% ]
# Elapsed Inf. time: 0.14-mins.
#
# 6: Elapsed Train time: 1.17-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2262, Accuracy: 93.41% ] || Test: [ Avg Loss: 0.3056, Accuracy: 90.88% ]
# Elapsed Inf. time: 0.14-mins.
#
# 7: Elapsed Train time: 1.14-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2130, Accuracy: 93.75% ] || Test: [ Avg Loss: 0.3286, Accuracy: 90.04% ]
# Elapsed Inf. time: 0.14-mins.
#
# 8: Elapsed Train time: 1.16-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2015, Accuracy: 94.06% ] || Test: [ Avg Loss: 0.2563, Accuracy: 92.62% ]
# Elapsed Inf. time: 0.14-mins.
#
# 9: Elapsed Train time: 1.21-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1911, Accuracy: 94.44% ] || Test: [ Avg Loss: 0.2369, Accuracy: 93.23% ]
# Elapsed Inf. time: 0.14-mins.
#
# 10: Elapsed Train time: 1.15-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1835, Accuracy: 94.69% ] || Test: [ Avg Loss: 0.2693, Accuracy: 91.99% ]
# Elapsed Inf. time: 0.13-mins.
#
# 11: Elapsed Train time: 1.17-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1755, Accuracy: 94.85% ] || Test: [ Avg Loss: 0.3544, Accuracy: 89.31% ]
# Elapsed Inf. time: 0.14-mins.
#
# 12: Elapsed Train time: 1.19-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1691, Accuracy: 95.11% ] || Test: [ Avg Loss: 0.2573, Accuracy: 92.38% ]
# Elapsed Inf. time: 0.13-mins.
#
# 13: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1638, Accuracy: 95.33% ] || Test: [ Avg Loss: 0.2424, Accuracy: 93.07% ]
# Elapsed Inf. time: 0.14-mins.
#
# 14: Elapsed Train time: 1.21-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1561, Accuracy: 95.46% ] || Test: [ Avg Loss: 0.2658, Accuracy: 92.41% ]
# Elapsed Inf. time: 0.14-mins.
#
# 15: Elapsed Train time: 1.17-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1520, Accuracy: 95.51% ] || Test: [ Avg Loss: 0.2401, Accuracy: 93.14% ]
# Elapsed Inf. time: 0.14-mins.
#
# 16: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1479, Accuracy: 95.66% ] || Test: [ Avg Loss: 0.2547, Accuracy: 92.81% ]
# Elapsed Inf. time: 0.13-mins.
#
# 17: Elapsed Train time: 1.19-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1417, Accuracy: 95.86% ] || Test: [ Avg Loss: 0.2306, Accuracy: 93.58% ]
# Elapsed Inf. time: 0.14-mins.
#
# 18: Elapsed Train time: 1.22-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1360, Accuracy: 95.99% ] || Test: [ Avg Loss: 0.2622, Accuracy: 92.64% ]
# Elapsed Inf. time: 0.14-mins.
#
# 19: Elapsed Train time: 1.23-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1335, Accuracy: 96.02% ] || Test: [ Avg Loss: 0.2746, Accuracy: 92.13% ]
# Elapsed Inf. time: 0.14-mins.
#
# 20: Elapsed Train time: 1.20-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1287, Accuracy: 96.19% ] || Test: [ Avg Loss: 0.2334, Accuracy: 93.27% ]
# Elapsed Inf. time: 0.14-mins.
#
# 21: Elapsed Train time: 1.14-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1270, Accuracy: 96.13% ] || Test: [ Avg Loss: 0.2569, Accuracy: 92.70% ]
# Elapsed Inf. time: 0.14-mins.
#
# 22: Elapsed Train time: 1.25-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1236, Accuracy: 96.36% ] || Test: [ Avg Loss: 0.2784, Accuracy: 92.08% ]
# Elapsed Inf. time: 0.14-mins.
#
# 23: Elapsed Train time: 1.12-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1209, Accuracy: 96.43% ] || Test: [ Avg Loss: 0.2726, Accuracy: 92.36% ]
# Elapsed Inf. time: 0.14-mins.
#
# 24: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1175, Accuracy: 96.46% ] || Test: [ Avg Loss: 0.2897, Accuracy: 91.91% ]
# Elapsed Inf. time: 0.13-mins.
#
# 25: Elapsed Train time: 1.23-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1128, Accuracy: 96.66% ] || Test: [ Avg Loss: 0.2890, Accuracy: 92.28% ]
# Elapsed Inf. time: 0.14-mins.
#
# 26: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1151, Accuracy: 96.49% ] || Test: [ Avg Loss: 0.2709, Accuracy: 92.60% ]
# Elapsed Inf. time: 0.13-mins.
#
# 27: Elapsed Train time: 1.13-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1073, Accuracy: 96.71% ] || Test: [ Avg Loss: 0.2468, Accuracy: 93.40% ]
# Elapsed Inf. time: 0.13-mins.
#
# 28: Elapsed Train time: 1.20-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1079, Accuracy: 96.65% ] || Test: [ Avg Loss: 0.2770, Accuracy: 92.40% ]
# Elapsed Inf. time: 0.14-mins.
#
# 29: Elapsed Train time: 1.16-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1061, Accuracy: 96.67% ] || Test: [ Avg Loss: 0.2565, Accuracy: 92.92% ]
# Elapsed Inf. time: 0.14-mins.
#
# 30: Elapsed Train time: 1.20-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1031, Accuracy: 96.83% ] || Test: [ Avg Loss: 0.2599, Accuracy: 92.86% ]
# Elapsed Inf. time: 0.14-mins.
#
# *********************************************************************************
# Done! Run: 3 : [Best Test @ epoch 17] || [ Avg loss: 0.230566, Accuracy: 93.58% ]
# *********************************************************************************
#
# **************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 1],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# **************************************************************************************************************************************************
#
# calc.: 0.002807 || calc2: 0.010434
# ss_calc: 0.005217
# ss_used: 0.005217
# 1: Elapsed Train time: 1.22-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 1.4803, Accuracy: 51.52% ] || Test: [ Avg Loss: 0.8361, Accuracy: 74.49% ]
# Elapsed Inf. time: 0.14-mins.
#
# 2: Elapsed Train time: 1.17-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.4207, Accuracy: 87.37% ] || Test: [ Avg Loss: 0.4098, Accuracy: 87.41% ]
# Elapsed Inf. time: 0.14-mins.
#
# 3: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.3076, Accuracy: 90.88% ] || Test: [ Avg Loss: 0.3471, Accuracy: 89.90% ]
# Elapsed Inf. time: 0.14-mins.
#
# 4: Elapsed Train time: 1.23-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2635, Accuracy: 92.17% ] || Test: [ Avg Loss: 0.2590, Accuracy: 92.55% ]
# Elapsed Inf. time: 0.14-mins.
#
# 5: Elapsed Train time: 1.23-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2346, Accuracy: 93.17% ] || Test: [ Avg Loss: 0.3104, Accuracy: 90.75% ]
# Elapsed Inf. time: 0.14-mins.
#
# 6: Elapsed Train time: 1.12-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2131, Accuracy: 93.79% ] || Test: [ Avg Loss: 0.2781, Accuracy: 92.27% ]
# Elapsed Inf. time: 0.14-mins.
#
# 7: Elapsed Train time: 1.16-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1959, Accuracy: 94.37% ] || Test: [ Avg Loss: 0.2725, Accuracy: 92.08% ]
# Elapsed Inf. time: 0.14-mins.
#
# 8: Elapsed Train time: 1.13-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1817, Accuracy: 94.80% ] || Test: [ Avg Loss: 0.2698, Accuracy: 92.11% ]
# Elapsed Inf. time: 0.14-mins.
#
# 9: Elapsed Train time: 1.20-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1689, Accuracy: 95.09% ] || Test: [ Avg Loss: 0.2664, Accuracy: 92.28% ]
# Elapsed Inf. time: 0.14-mins.
#
# 10: Elapsed Train time: 1.17-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1558, Accuracy: 95.49% ] || Test: [ Avg Loss: 0.3249, Accuracy: 90.25% ]
# Elapsed Inf. time: 0.14-mins.
#
# 11: Elapsed Train time: 1.11-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1464, Accuracy: 95.70% ] || Test: [ Avg Loss: 0.2996, Accuracy: 91.19% ]
# Elapsed Inf. time: 0.14-mins.
#
# 12: Elapsed Train time: 1.15-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1373, Accuracy: 95.94% ] || Test: [ Avg Loss: 0.2770, Accuracy: 92.19% ]
# Elapsed Inf. time: 0.14-mins.
#
# 13: Elapsed Train time: 1.23-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1291, Accuracy: 96.17% ] || Test: [ Avg Loss: 0.2645, Accuracy: 92.55% ]
# Elapsed Inf. time: 0.14-mins.
#
# 14: Elapsed Train time: 1.12-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1213, Accuracy: 96.47% ] || Test: [ Avg Loss: 0.3066, Accuracy: 91.37% ]
# Elapsed Inf. time: 0.14-mins.
#
# 15: Elapsed Train time: 1.18-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1136, Accuracy: 96.59% ] || Test: [ Avg Loss: 0.2619, Accuracy: 92.59% ]
# Elapsed Inf. time: 0.14-mins.
#
# 16: Elapsed Train time: 1.14-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1068, Accuracy: 96.72% ] || Test: [ Avg Loss: 0.2964, Accuracy: 91.48% ]
# Elapsed Inf. time: 0.14-mins.
#
# 17: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0991, Accuracy: 97.04% ] || Test: [ Avg Loss: 0.3834, Accuracy: 88.52% ]
# Elapsed Inf. time: 0.14-mins.
#
# 18: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0932, Accuracy: 97.09% ] || Test: [ Avg Loss: 0.2981, Accuracy: 91.74% ]
# Elapsed Inf. time: 0.14-mins.
#
# 19: Elapsed Train time: 1.19-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0870, Accuracy: 97.31% ] || Test: [ Avg Loss: 0.3652, Accuracy: 90.13% ]
# Elapsed Inf. time: 0.14-mins.
#
# 20: Elapsed Train time: 1.17-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0858, Accuracy: 97.37% ] || Test: [ Avg Loss: 0.3495, Accuracy: 90.07% ]
# Elapsed Inf. time: 0.14-mins.
#
# 21: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0826, Accuracy: 97.41% ] || Test: [ Avg Loss: 0.2656, Accuracy: 92.91% ]
# Elapsed Inf. time: 0.14-mins.
#
# 22: Elapsed Train time: 1.16-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0787, Accuracy: 97.56% ] || Test: [ Avg Loss: 0.2811, Accuracy: 92.64% ]
# Elapsed Inf. time: 0.14-mins.
#
# 23: Elapsed Train time: 1.15-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0746, Accuracy: 97.69% ] || Test: [ Avg Loss: 0.2922, Accuracy: 91.86% ]
# Elapsed Inf. time: 0.14-mins.
#
# 24: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0714, Accuracy: 97.77% ] || Test: [ Avg Loss: 0.3180, Accuracy: 91.40% ]
# Elapsed Inf. time: 0.14-mins.
#
# 25: Elapsed Train time: 1.12-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0690, Accuracy: 97.80% ] || Test: [ Avg Loss: 0.3336, Accuracy: 91.28% ]
# Elapsed Inf. time: 0.14-mins.
#
# 26: Elapsed Train time: 1.15-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0698, Accuracy: 97.83% ] || Test: [ Avg Loss: 0.3355, Accuracy: 91.25% ]
# Elapsed Inf. time: 0.14-mins.
#
# 27: Elapsed Train time: 1.21-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0682, Accuracy: 97.80% ] || Test: [ Avg Loss: 0.2782, Accuracy: 93.03% ]
# Elapsed Inf. time: 0.14-mins.
#
# 28: Elapsed Train time: 1.25-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0654, Accuracy: 97.88% ] || Test: [ Avg Loss: 0.2745, Accuracy: 93.29% ]
# Elapsed Inf. time: 0.14-mins.
#
# 29: Elapsed Train time: 1.15-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0633, Accuracy: 98.00% ] || Test: [ Avg Loss: 0.3166, Accuracy: 92.29% ]
# Elapsed Inf. time: 0.14-mins.
#
# 30: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0602, Accuracy: 98.09% ] || Test: [ Avg Loss: 0.3185, Accuracy: 91.74% ]
# Elapsed Inf. time: 0.14-mins.
#
# *********************************************************************************
# Done! Run: 4 : [Best Test @ epoch 28] || [ Avg loss: 0.274468, Accuracy: 93.29% ]
# *********************************************************************************
#
# **************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 1],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# **************************************************************************************************************************************************
#
# calc.: 0.002543 || calc2: 0.011900
# ss_calc: 0.005950
# ss_used: 0.005950
# 1: Elapsed Train time: 1.17-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 1.4418, Accuracy: 53.00% ] || Test: [ Avg Loss: 0.7509, Accuracy: 75.15% ]
# Elapsed Inf. time: 0.14-mins.
#
# 2: Elapsed Train time: 1.26-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.4130, Accuracy: 87.46% ] || Test: [ Avg Loss: 0.4298, Accuracy: 86.52% ]
# Elapsed Inf. time: 0.14-mins.
#
# 3: Elapsed Train time: 1.20-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.3101, Accuracy: 90.78% ] || Test: [ Avg Loss: 0.3180, Accuracy: 90.49% ]
# Elapsed Inf. time: 0.14-mins.
#
# 4: Elapsed Train time: 1.22-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2641, Accuracy: 92.24% ] || Test: [ Avg Loss: 0.2920, Accuracy: 91.43% ]
# Elapsed Inf. time: 0.14-mins.
#
# 5: Elapsed Train time: 1.16-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2363, Accuracy: 93.05% ] || Test: [ Avg Loss: 0.2605, Accuracy: 92.52% ]
# Elapsed Inf. time: 0.14-mins.
#
# 6: Elapsed Train time: 1.23-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2157, Accuracy: 93.62% ] || Test: [ Avg Loss: 0.2947, Accuracy: 91.17% ]
# Elapsed Inf. time: 0.14-mins.
#
# 7: Elapsed Train time: 1.24-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2007, Accuracy: 94.29% ] || Test: [ Avg Loss: 0.3416, Accuracy: 89.69% ]
# Elapsed Inf. time: 0.14-mins.
#
# 8: Elapsed Train time: 1.22-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1882, Accuracy: 94.47% ] || Test: [ Avg Loss: 0.3055, Accuracy: 91.05% ]
# Elapsed Inf. time: 0.14-mins.
#
# 9: Elapsed Train time: 1.21-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1755, Accuracy: 94.90% ] || Test: [ Avg Loss: 0.2608, Accuracy: 92.41% ]
# Elapsed Inf. time: 0.14-mins.
#
# 10: Elapsed Train time: 1.16-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1623, Accuracy: 95.29% ] || Test: [ Avg Loss: 0.2414, Accuracy: 93.00% ]
# Elapsed Inf. time: 0.14-mins.
#
# 11: Elapsed Train time: 1.24-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1559, Accuracy: 95.45% ] || Test: [ Avg Loss: 0.2539, Accuracy: 92.42% ]
# Elapsed Inf. time: 0.14-mins.
#
# 12: Elapsed Train time: 1.23-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1497, Accuracy: 95.60% ] || Test: [ Avg Loss: 0.4146, Accuracy: 87.90% ]
# Elapsed Inf. time: 0.14-mins.
#
# 13: Elapsed Train time: 1.21-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1386, Accuracy: 95.91% ] || Test: [ Avg Loss: 0.2489, Accuracy: 92.86% ]
# Elapsed Inf. time: 0.14-mins.
#
# 14: Elapsed Train time: 1.19-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1292, Accuracy: 96.16% ] || Test: [ Avg Loss: 0.2605, Accuracy: 92.49% ]
# Elapsed Inf. time: 0.14-mins.
#
# 15: Elapsed Train time: 1.15-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1221, Accuracy: 96.40% ] || Test: [ Avg Loss: 0.2783, Accuracy: 92.34% ]
# Elapsed Inf. time: 0.14-mins.
#
# 16: Elapsed Train time: 1.14-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1181, Accuracy: 96.44% ] || Test: [ Avg Loss: 0.2537, Accuracy: 93.01% ]
# Elapsed Inf. time: 0.14-mins.
#
# 17: Elapsed Train time: 1.21-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1089, Accuracy: 96.68% ] || Test: [ Avg Loss: 0.3640, Accuracy: 89.68% ]
# Elapsed Inf. time: 0.14-mins.
#
# 18: Elapsed Train time: 1.19-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1058, Accuracy: 96.77% ] || Test: [ Avg Loss: 0.3267, Accuracy: 91.17% ]
# Elapsed Inf. time: 0.14-mins.
#
# 19: Elapsed Train time: 1.16-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1017, Accuracy: 96.82% ] || Test: [ Avg Loss: 0.3581, Accuracy: 90.04% ]
# Elapsed Inf. time: 0.14-mins.
#
# 20: Elapsed Train time: 1.21-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0954, Accuracy: 97.05% ] || Test: [ Avg Loss: 0.2654, Accuracy: 92.85% ]
# Elapsed Inf. time: 0.14-mins.
#
# 21: Elapsed Train time: 1.17-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0911, Accuracy: 97.16% ] || Test: [ Avg Loss: 0.2454, Accuracy: 93.35% ]
# Elapsed Inf. time: 0.14-mins.
#
# 22: Elapsed Train time: 1.16-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0929, Accuracy: 97.10% ] || Test: [ Avg Loss: 0.2997, Accuracy: 92.10% ]
# Elapsed Inf. time: 0.14-mins.
#
# 23: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0823, Accuracy: 97.44% ] || Test: [ Avg Loss: 0.3850, Accuracy: 90.05% ]
# Elapsed Inf. time: 0.14-mins.
#
# 24: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0850, Accuracy: 97.34% ] || Test: [ Avg Loss: 0.2863, Accuracy: 92.14% ]
# Elapsed Inf. time: 0.14-mins.
#
# 25: Elapsed Train time: 1.17-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0794, Accuracy: 97.47% ] || Test: [ Avg Loss: 0.2745, Accuracy: 92.39% ]
# Elapsed Inf. time: 0.14-mins.
#
# 26: Elapsed Train time: 1.12-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0742, Accuracy: 97.65% ] || Test: [ Avg Loss: 0.3261, Accuracy: 91.51% ]
# Elapsed Inf. time: 0.14-mins.
#
# 27: Elapsed Train time: 1.20-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0768, Accuracy: 97.53% ] || Test: [ Avg Loss: 0.2618, Accuracy: 93.09% ]
# Elapsed Inf. time: 0.14-mins.
#
# 28: Elapsed Train time: 1.24-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0747, Accuracy: 97.60% ] || Test: [ Avg Loss: 0.3098, Accuracy: 91.32% ]
# Elapsed Inf. time: 0.14-mins.
#
# 29: Elapsed Train time: 1.20-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0694, Accuracy: 97.83% ] || Test: [ Avg Loss: 0.2928, Accuracy: 92.71% ]
# Elapsed Inf. time: 0.14-mins.
#
# 30: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0701, Accuracy: 97.77% ] || Test: [ Avg Loss: 0.3327, Accuracy: 91.37% ]
# Elapsed Inf. time: 0.14-mins.
#
# *********************************************************************************
# Done! Run: 5 : [Best Test @ epoch 21] || [ Avg loss: 0.245405, Accuracy: 93.35% ]
# *********************************************************************************
#
# **************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 1],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# **************************************************************************************************************************************************
#
# calc.: 0.003111 || calc2: 0.010920
# ss_calc: 0.005460
# ss_used: 0.005460
# 1: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 1.5561, Accuracy: 48.31% ] || Test: [ Avg Loss: 0.6722, Accuracy: 79.63% ]
# Elapsed Inf. time: 0.14-mins.
#
# 2: Elapsed Train time: 1.16-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.4310, Accuracy: 87.12% ] || Test: [ Avg Loss: 0.4464, Accuracy: 86.20% ]
# Elapsed Inf. time: 0.14-mins.
#
# 3: Elapsed Train time: 1.22-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.3120, Accuracy: 90.69% ] || Test: [ Avg Loss: 0.2834, Accuracy: 92.07% ]
# Elapsed Inf. time: 0.14-mins.
#
# 4: Elapsed Train time: 1.17-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2670, Accuracy: 92.09% ] || Test: [ Avg Loss: 0.2890, Accuracy: 91.97% ]
# Elapsed Inf. time: 0.14-mins.
#
# 5: Elapsed Train time: 1.23-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2344, Accuracy: 93.13% ] || Test: [ Avg Loss: 0.2540, Accuracy: 92.52% ]
# Elapsed Inf. time: 0.14-mins.
#
# 6: Elapsed Train time: 1.21-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2167, Accuracy: 93.69% ] || Test: [ Avg Loss: 0.3630, Accuracy: 88.88% ]
# Elapsed Inf. time: 0.14-mins.
#
# 7: Elapsed Train time: 1.18-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1995, Accuracy: 94.12% ] || Test: [ Avg Loss: 0.2220, Accuracy: 93.84% ]
# Elapsed Inf. time: 0.14-mins.
#
# 8: Elapsed Train time: 1.17-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1849, Accuracy: 94.65% ] || Test: [ Avg Loss: 0.3336, Accuracy: 89.61% ]
# Elapsed Inf. time: 0.14-mins.
#
# 9: Elapsed Train time: 1.16-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1703, Accuracy: 94.96% ] || Test: [ Avg Loss: 0.3419, Accuracy: 89.68% ]
# Elapsed Inf. time: 0.14-mins.
#
# 10: Elapsed Train time: 1.12-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1624, Accuracy: 95.25% ] || Test: [ Avg Loss: 0.3299, Accuracy: 90.00% ]
# Elapsed Inf. time: 0.14-mins.
#
# 11: Elapsed Train time: 1.11-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1502, Accuracy: 95.71% ] || Test: [ Avg Loss: 0.2694, Accuracy: 92.19% ]
# Elapsed Inf. time: 0.14-mins.
#
# 12: Elapsed Train time: 1.16-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1406, Accuracy: 95.89% ] || Test: [ Avg Loss: 0.2280, Accuracy: 93.59% ]
# Elapsed Inf. time: 0.14-mins.
#
# 13: Elapsed Train time: 1.21-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1349, Accuracy: 95.99% ] || Test: [ Avg Loss: 0.2666, Accuracy: 92.48% ]
# Elapsed Inf. time: 0.14-mins.
#
# 14: Elapsed Train time: 1.19-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1260, Accuracy: 96.20% ] || Test: [ Avg Loss: 0.2718, Accuracy: 92.47% ]
# Elapsed Inf. time: 0.14-mins.
#
# 15: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1151, Accuracy: 96.58% ] || Test: [ Avg Loss: 0.3018, Accuracy: 91.56% ]
# Elapsed Inf. time: 0.14-mins.
#
# 16: Elapsed Train time: 1.12-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1109, Accuracy: 96.57% ] || Test: [ Avg Loss: 0.2765, Accuracy: 92.44% ]
# Elapsed Inf. time: 0.14-mins.
#
# 17: Elapsed Train time: 1.15-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1044, Accuracy: 96.84% ] || Test: [ Avg Loss: 0.2918, Accuracy: 91.58% ]
# Elapsed Inf. time: 0.14-mins.
#
# 18: Elapsed Train time: 1.14-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0995, Accuracy: 96.94% ] || Test: [ Avg Loss: 0.2868, Accuracy: 92.12% ]
# Elapsed Inf. time: 0.14-mins.
#
# 19: Elapsed Train time: 1.12-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0952, Accuracy: 97.06% ] || Test: [ Avg Loss: 0.2657, Accuracy: 92.65% ]
# Elapsed Inf. time: 0.14-mins.
#
# 20: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0908, Accuracy: 97.18% ] || Test: [ Avg Loss: 0.2793, Accuracy: 92.18% ]
# Elapsed Inf. time: 0.14-mins.
#
# 21: Elapsed Train time: 1.15-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0873, Accuracy: 97.26% ] || Test: [ Avg Loss: 0.2881, Accuracy: 91.89% ]
# Elapsed Inf. time: 0.14-mins.
#
# 22: Elapsed Train time: 1.12-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0818, Accuracy: 97.41% ] || Test: [ Avg Loss: 0.3162, Accuracy: 91.15% ]
# Elapsed Inf. time: 0.14-mins.
#
# 23: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0784, Accuracy: 97.54% ] || Test: [ Avg Loss: 0.2873, Accuracy: 91.99% ]
# Elapsed Inf. time: 0.14-mins.
#
# 24: Elapsed Train time: 1.18-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0775, Accuracy: 97.54% ] || Test: [ Avg Loss: 0.3722, Accuracy: 89.76% ]
# Elapsed Inf. time: 0.14-mins.
#
# 25: Elapsed Train time: 1.23-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0799, Accuracy: 97.47% ] || Test: [ Avg Loss: 0.2887, Accuracy: 92.31% ]
# Elapsed Inf. time: 0.14-mins.
#
# 26: Elapsed Train time: 1.21-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0720, Accuracy: 97.74% ] || Test: [ Avg Loss: 0.2928, Accuracy: 92.36% ]
# Elapsed Inf. time: 0.14-mins.
#
# 27: Elapsed Train time: 1.23-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0680, Accuracy: 97.86% ] || Test: [ Avg Loss: 0.2816, Accuracy: 92.72% ]
# Elapsed Inf. time: 0.14-mins.
#
# 28: Elapsed Train time: 1.12-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0687, Accuracy: 97.81% ] || Test: [ Avg Loss: 0.3395, Accuracy: 91.08% ]
# Elapsed Inf. time: 0.14-mins.
#
# 29: Elapsed Train time: 1.22-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0669, Accuracy: 97.85% ] || Test: [ Avg Loss: 0.3201, Accuracy: 91.68% ]
# Elapsed Inf. time: 0.14-mins.
#
# 30: Elapsed Train time: 1.21-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0683, Accuracy: 97.76% ] || Test: [ Avg Loss: 0.2574, Accuracy: 93.13% ]
# Elapsed Inf. time: 0.14-mins.
#
# ********************************************************************************
# Done! Run: 6 : [Best Test @ epoch 7] || [ Avg loss: 0.221998, Accuracy: 93.84% ]
# ********************************************************************************
#
# **************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 1],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# **************************************************************************************************************************************************
#
# calc.: 0.002175 || calc2: 0.018145
# ss_calc: 0.009072
# ss_used: 0.009072
# 1: Elapsed Train time: 1.11-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 1.5328, Accuracy: 49.68% ] || Test: [ Avg Loss: 0.7887, Accuracy: 74.74% ]
# Elapsed Inf. time: 0.14-mins.
#
# 2: Elapsed Train time: 1.20-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.4227, Accuracy: 87.19% ] || Test: [ Avg Loss: 0.4124, Accuracy: 87.22% ]
# Elapsed Inf. time: 0.14-mins.
#
# 3: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.3155, Accuracy: 90.54% ] || Test: [ Avg Loss: 0.3234, Accuracy: 90.34% ]
# Elapsed Inf. time: 0.14-mins.
#
# 4: Elapsed Train time: 1.19-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2716, Accuracy: 91.91% ] || Test: [ Avg Loss: 0.3226, Accuracy: 90.62% ]
# Elapsed Inf. time: 0.14-mins.
#
# 5: Elapsed Train time: 1.21-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2485, Accuracy: 92.70% ] || Test: [ Avg Loss: 0.2876, Accuracy: 91.79% ]
# Elapsed Inf. time: 0.14-mins.
#
# 6: Elapsed Train time: 1.15-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2298, Accuracy: 93.26% ] || Test: [ Avg Loss: 0.2428, Accuracy: 93.07% ]
# Elapsed Inf. time: 0.14-mins.
#
# 7: Elapsed Train time: 1.17-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2148, Accuracy: 93.71% ] || Test: [ Avg Loss: 0.2502, Accuracy: 92.81% ]
# Elapsed Inf. time: 0.14-mins.
#
# 8: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2047, Accuracy: 94.06% ] || Test: [ Avg Loss: 0.2953, Accuracy: 91.29% ]
# Elapsed Inf. time: 0.14-mins.
#
# 9: Elapsed Train time: 1.11-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1953, Accuracy: 94.28% ] || Test: [ Avg Loss: 0.3448, Accuracy: 90.05% ]
# Elapsed Inf. time: 0.14-mins.
#
# 10: Elapsed Train time: 1.24-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1874, Accuracy: 94.59% ] || Test: [ Avg Loss: 0.2300, Accuracy: 93.44% ]
# Elapsed Inf. time: 0.14-mins.
#
# 11: Elapsed Train time: 1.14-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1790, Accuracy: 94.85% ] || Test: [ Avg Loss: 0.2210, Accuracy: 93.88% ]
# Elapsed Inf. time: 0.14-mins.
#
# 12: Elapsed Train time: 1.24-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1708, Accuracy: 95.04% ] || Test: [ Avg Loss: 0.2232, Accuracy: 93.71% ]
# Elapsed Inf. time: 0.14-mins.
#
# 13: Elapsed Train time: 1.17-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1680, Accuracy: 95.06% ] || Test: [ Avg Loss: 0.3040, Accuracy: 91.46% ]
# Elapsed Inf. time: 0.14-mins.
#
# 14: Elapsed Train time: 1.14-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1620, Accuracy: 95.19% ] || Test: [ Avg Loss: 0.2430, Accuracy: 93.05% ]
# Elapsed Inf. time: 0.14-mins.
#
# 15: Elapsed Train time: 1.16-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1560, Accuracy: 95.47% ] || Test: [ Avg Loss: 0.2298, Accuracy: 93.52% ]
# Elapsed Inf. time: 0.14-mins.
#
# 16: Elapsed Train time: 1.15-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1482, Accuracy: 95.60% ] || Test: [ Avg Loss: 0.2949, Accuracy: 91.38% ]
# Elapsed Inf. time: 0.14-mins.
#
# 17: Elapsed Train time: 1.18-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1475, Accuracy: 95.66% ] || Test: [ Avg Loss: 0.2878, Accuracy: 91.79% ]
# Elapsed Inf. time: 0.14-mins.
#
# 18: Elapsed Train time: 1.24-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1426, Accuracy: 95.78% ] || Test: [ Avg Loss: 0.2834, Accuracy: 91.58% ]
# Elapsed Inf. time: 0.14-mins.
#
# 19: Elapsed Train time: 1.23-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1365, Accuracy: 96.00% ] || Test: [ Avg Loss: 0.2504, Accuracy: 92.91% ]
# Elapsed Inf. time: 0.14-mins.
#
# 20: Elapsed Train time: 1.11-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1338, Accuracy: 96.05% ] || Test: [ Avg Loss: 0.2746, Accuracy: 92.53% ]
# Elapsed Inf. time: 0.14-mins.
#
# 21: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1296, Accuracy: 96.18% ] || Test: [ Avg Loss: 0.2407, Accuracy: 93.12% ]
# Elapsed Inf. time: 0.14-mins.
#
# 22: Elapsed Train time: 1.19-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1286, Accuracy: 96.16% ] || Test: [ Avg Loss: 0.2707, Accuracy: 92.24% ]
# Elapsed Inf. time: 0.14-mins.
#
# 23: Elapsed Train time: 1.17-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1228, Accuracy: 96.27% ] || Test: [ Avg Loss: 0.2527, Accuracy: 93.08% ]
# Elapsed Inf. time: 0.14-mins.
#
# 24: Elapsed Train time: 1.15-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1210, Accuracy: 96.35% ] || Test: [ Avg Loss: 0.2476, Accuracy: 93.06% ]
# Elapsed Inf. time: 0.14-mins.
#
# 25: Elapsed Train time: 1.18-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1185, Accuracy: 96.43% ] || Test: [ Avg Loss: 0.2903, Accuracy: 91.94% ]
# Elapsed Inf. time: 0.14-mins.
#
# 26: Elapsed Train time: 1.25-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1152, Accuracy: 96.55% ] || Test: [ Avg Loss: 0.2465, Accuracy: 93.20% ]
# Elapsed Inf. time: 0.14-mins.
#
# 27: Elapsed Train time: 1.29-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1143, Accuracy: 96.48% ] || Test: [ Avg Loss: 0.2343, Accuracy: 93.79% ]
# Elapsed Inf. time: 0.14-mins.
#
# 28: Elapsed Train time: 1.39-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1106, Accuracy: 96.68% ] || Test: [ Avg Loss: 0.2713, Accuracy: 92.74% ]
# Elapsed Inf. time: 0.13-mins.
#
# 29: Elapsed Train time: 1.28-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1087, Accuracy: 96.72% ] || Test: [ Avg Loss: 0.2609, Accuracy: 92.89% ]
# Elapsed Inf. time: 0.14-mins.
#
# 30: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1080, Accuracy: 96.70% ] || Test: [ Avg Loss: 0.2410, Accuracy: 93.40% ]
# Elapsed Inf. time: 0.14-mins.
#
# *********************************************************************************
# Done! Run: 7 : [Best Test @ epoch 11] || [ Avg loss: 0.221041, Accuracy: 93.88% ]
# *********************************************************************************
#
# ...
# Elapsed Inf. time: 0.13-mins.
#
# 22: Elapsed Train time: 1.20-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0802, Accuracy: 97.43% ] || Test: [ Avg Loss: 0.3185, Accuracy: 91.12% ]
# Elapsed Inf. time: 0.14-mins.
#
# 23: Elapsed Train time: 1.15-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0771, Accuracy: 97.56% ] || Test: [ Avg Loss: 0.2580, Accuracy: 93.17% ]
# Elapsed Inf. time: 0.14-mins.
#
# 24: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0675, Accuracy: 97.87% ] || Test: [ Avg Loss: 0.2593, Accuracy: 92.94% ]
# Elapsed Inf. time: 0.14-mins.
#
# 25: Elapsed Train time: 1.33-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0735, Accuracy: 97.65% ] || Test: [ Avg Loss: 0.2629, Accuracy: 93.09% ]
# Elapsed Inf. time: 0.13-mins.
#
# 26: Elapsed Train time: 1.29-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0678, Accuracy: 97.77% ] || Test: [ Avg Loss: 0.2798, Accuracy: 92.60% ]
# Elapsed Inf. time: 0.14-mins.
#
# 27: Elapsed Train time: 1.34-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0685, Accuracy: 97.74% ] || Test: [ Avg Loss: 0.2861, Accuracy: 92.99% ]
# Elapsed Inf. time: 0.14-mins.
#
# 28: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0587, Accuracy: 98.13% ] || Test: [ Avg Loss: 0.3517, Accuracy: 91.18% ]
# Elapsed Inf. time: 0.14-mins.
#
# 29: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0702, Accuracy: 97.65% ] || Test: [ Avg Loss: 0.3598, Accuracy: 91.18% ]
# Elapsed Inf. time: 0.14-mins.
#
# 30: Elapsed Train time: 1.25-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0611, Accuracy: 98.02% ] || Test: [ Avg Loss: 2.0155, Accuracy: 63.96% ]
# Elapsed Inf. time: 0.14-mins.
#
# *********************************************************************************
# Done! Run: 8 : [Best Test @ epoch 17] || [ Avg loss: 0.234435, Accuracy: 93.74% ]
# *********************************************************************************
#
# **************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 1],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# **************************************************************************************************************************************************
#
# calc.: 0.002461 || calc2: 0.018672
# ss_calc: 0.009336
# ss_used: 0.009336
# 1: Elapsed Train time: 1.09-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 1.7675, Accuracy: 41.38% ] || Test: [ Avg Loss: 0.9755, Accuracy: 66.12% ]
# Elapsed Inf. time: 0.13-mins.
#
# 2: Elapsed Train time: 1.26-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.4251, Accuracy: 87.15% ] || Test: [ Avg Loss: 0.3668, Accuracy: 88.99% ]
# Elapsed Inf. time: 0.13-mins.
#
# 3: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.3042, Accuracy: 90.91% ] || Test: [ Avg Loss: 0.2983, Accuracy: 91.08% ]
# Elapsed Inf. time: 0.14-mins.
#
# 4: Elapsed Train time: 1.41-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2629, Accuracy: 92.32% ] || Test: [ Avg Loss: 0.3337, Accuracy: 89.90% ]
# Elapsed Inf. time: 0.14-mins.
#
# 5: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2406, Accuracy: 92.88% ] || Test: [ Avg Loss: 0.2774, Accuracy: 92.47% ]
# Elapsed Inf. time: 0.13-mins.
#
# 6: Elapsed Train time: 1.19-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2280, Accuracy: 93.26% ] || Test: [ Avg Loss: 0.3429, Accuracy: 89.93% ]
# Elapsed Inf. time: 0.14-mins.
#
# 7: Elapsed Train time: 1.30-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2123, Accuracy: 93.85% ] || Test: [ Avg Loss: 0.2296, Accuracy: 93.45% ]
# Elapsed Inf. time: 0.13-mins.
#
# 8: Elapsed Train time: 1.29-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2014, Accuracy: 94.18% ] || Test: [ Avg Loss: 0.3105, Accuracy: 90.56% ]
# Elapsed Inf. time: 0.14-mins.
#
# 9: Elapsed Train time: 1.34-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1890, Accuracy: 94.53% ] || Test: [ Avg Loss: 0.2850, Accuracy: 91.59% ]
# Elapsed Inf. time: 0.13-mins.
#
# 10: Elapsed Train time: 1.31-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1847, Accuracy: 94.66% ] || Test: [ Avg Loss: 0.2775, Accuracy: 92.01% ]
# Elapsed Inf. time: 0.14-mins.
#
# 11: Elapsed Train time: 1.24-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1799, Accuracy: 94.74% ] || Test: [ Avg Loss: 0.2773, Accuracy: 92.19% ]
# Elapsed Inf. time: 0.13-mins.
#
# 12: Elapsed Train time: 1.09-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1707, Accuracy: 95.00% ] || Test: [ Avg Loss: 0.2354, Accuracy: 93.20% ]
# Elapsed Inf. time: 0.13-mins.
#
# 13: Elapsed Train time: 1.28-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1663, Accuracy: 95.12% ] || Test: [ Avg Loss: 0.2453, Accuracy: 92.90% ]
# Elapsed Inf. time: 0.14-mins.
#
# 14: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1598, Accuracy: 95.30% ] || Test: [ Avg Loss: 0.2395, Accuracy: 93.16% ]
# Elapsed Inf. time: 0.13-mins.
#
# 15: Elapsed Train time: 1.21-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1537, Accuracy: 95.54% ] || Test: [ Avg Loss: 0.2930, Accuracy: 91.21% ]
# Elapsed Inf. time: 0.14-mins.
#
# 16: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1503, Accuracy: 95.61% ] || Test: [ Avg Loss: 0.2403, Accuracy: 93.34% ]
# Elapsed Inf. time: 0.13-mins.
#
# 17: Elapsed Train time: 1.24-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1431, Accuracy: 95.74% ] || Test: [ Avg Loss: 0.2335, Accuracy: 93.59% ]
# Elapsed Inf. time: 0.13-mins.
#
# 18: Elapsed Train time: 1.13-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1432, Accuracy: 95.74% ] || Test: [ Avg Loss: 0.2920, Accuracy: 91.51% ]
# Elapsed Inf. time: 0.13-mins.
#
# 19: Elapsed Train time: 1.28-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1374, Accuracy: 95.95% ] || Test: [ Avg Loss: 0.2368, Accuracy: 93.18% ]
# Elapsed Inf. time: 0.13-mins.
#
# 20: Elapsed Train time: 1.20-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1314, Accuracy: 96.03% ] || Test: [ Avg Loss: 0.2511, Accuracy: 92.77% ]
# Elapsed Inf. time: 0.13-mins.
#
# 21: Elapsed Train time: 1.09-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1307, Accuracy: 96.20% ] || Test: [ Avg Loss: 0.2417, Accuracy: 93.27% ]
# Elapsed Inf. time: 0.13-mins.
#
# 22: Elapsed Train time: 1.11-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1283, Accuracy: 96.14% ] || Test: [ Avg Loss: 0.2549, Accuracy: 92.96% ]
# Elapsed Inf. time: 0.14-mins.
#
# 23: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1252, Accuracy: 96.27% ] || Test: [ Avg Loss: 0.2762, Accuracy: 92.00% ]
# Elapsed Inf. time: 0.14-mins.
#
# 24: Elapsed Train time: 1.26-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1230, Accuracy: 96.26% ] || Test: [ Avg Loss: 0.2936, Accuracy: 91.79% ]
# Elapsed Inf. time: 0.13-mins.
#
# 25: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1201, Accuracy: 96.33% ] || Test: [ Avg Loss: 0.2533, Accuracy: 92.96% ]
# Elapsed Inf. time: 0.14-mins.
#
# 26: Elapsed Train time: 1.22-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1148, Accuracy: 96.48% ] || Test: [ Avg Loss: 0.2858, Accuracy: 92.16% ]
# Elapsed Inf. time: 0.14-mins.
#
# 27: Elapsed Train time: 1.34-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1149, Accuracy: 96.45% ] || Test: [ Avg Loss: 0.2815, Accuracy: 91.96% ]
# Elapsed Inf. time: 0.13-mins.
#
# 28: Elapsed Train time: 1.14-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1109, Accuracy: 96.67% ] || Test: [ Avg Loss: 0.2525, Accuracy: 92.95% ]
# Elapsed Inf. time: 0.13-mins.
#
# 29: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1087, Accuracy: 96.60% ] || Test: [ Avg Loss: 0.2577, Accuracy: 93.00% ]
# Elapsed Inf. time: 0.13-mins.
#
# 30: Elapsed Train time: 1.09-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1081, Accuracy: 96.64% ] || Test: [ Avg Loss: 0.3100, Accuracy: 91.04% ]
# Elapsed Inf. time: 0.13-mins.
#
# *********************************************************************************
# Done! Run: 9 : [Best Test @ epoch 17] || [ Avg loss: 0.233461, Accuracy: 93.59% ]
# *********************************************************************************
#
# **************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 1],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# **************************************************************************************************************************************************
#
# calc.: 0.002815 || calc2: 0.012171
# ss_calc: 0.006086
# ss_used: 0.006086
# 1: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 1.6980, Accuracy: 43.34% ] || Test: [ Avg Loss: 0.8092, Accuracy: 75.91% ]
# Elapsed Inf. time: 0.13-mins.
#
# 2: Elapsed Train time: 1.33-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.4400, Accuracy: 86.71% ] || Test: [ Avg Loss: 0.5191, Accuracy: 82.96% ]
# Elapsed Inf. time: 0.14-mins.
#
# 3: Elapsed Train time: 1.27-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.3105, Accuracy: 90.82% ] || Test: [ Avg Loss: 0.2725, Accuracy: 92.06% ]
# Elapsed Inf. time: 0.14-mins.
#
# 4: Elapsed Train time: 1.32-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2681, Accuracy: 92.13% ] || Test: [ Avg Loss: 0.2739, Accuracy: 92.24% ]
# Elapsed Inf. time: 0.14-mins.
#
# 5: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2369, Accuracy: 93.13% ] || Test: [ Avg Loss: 0.2705, Accuracy: 91.98% ]
# Elapsed Inf. time: 0.13-mins.
#
# 6: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2167, Accuracy: 93.70% ] || Test: [ Avg Loss: 0.2839, Accuracy: 91.51% ]
# Elapsed Inf. time: 0.14-mins.
#
# 7: Elapsed Train time: 1.33-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.2001, Accuracy: 94.12% ] || Test: [ Avg Loss: 0.2767, Accuracy: 91.77% ]
# Elapsed Inf. time: 0.14-mins.
#
# 8: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1884, Accuracy: 94.54% ] || Test: [ Avg Loss: 0.2356, Accuracy: 93.24% ]
# Elapsed Inf. time: 0.14-mins.
#
# 9: Elapsed Train time: 1.33-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1784, Accuracy: 94.77% ] || Test: [ Avg Loss: 0.2798, Accuracy: 92.11% ]
# Elapsed Inf. time: 0.14-mins.
#
# 10: Elapsed Train time: 1.34-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1631, Accuracy: 95.35% ] || Test: [ Avg Loss: 0.2242, Accuracy: 93.68% ]
# Elapsed Inf. time: 0.14-mins.
#
# 11: Elapsed Train time: 1.16-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1527, Accuracy: 95.57% ] || Test: [ Avg Loss: 0.3061, Accuracy: 91.14% ]
# Elapsed Inf. time: 0.14-mins.
#
# 12: Elapsed Train time: 1.20-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1459, Accuracy: 95.75% ] || Test: [ Avg Loss: 0.2577, Accuracy: 92.69% ]
# Elapsed Inf. time: 0.13-mins.
#
# 13: Elapsed Train time: 1.18-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1393, Accuracy: 95.81% ] || Test: [ Avg Loss: 0.2690, Accuracy: 92.39% ]
# Elapsed Inf. time: 0.13-mins.
#
# 14: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1303, Accuracy: 96.17% ] || Test: [ Avg Loss: 0.3948, Accuracy: 89.69% ]
# Elapsed Inf. time: 0.13-mins.
#
# 15: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1238, Accuracy: 96.30% ] || Test: [ Avg Loss: 0.2604, Accuracy: 92.37% ]
# Elapsed Inf. time: 0.13-mins.
#
# 16: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1185, Accuracy: 96.47% ] || Test: [ Avg Loss: 0.2739, Accuracy: 92.14% ]
# Elapsed Inf. time: 0.13-mins.
#
# 17: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1126, Accuracy: 96.64% ] || Test: [ Avg Loss: 0.2361, Accuracy: 93.47% ]
# Elapsed Inf. time: 0.13-mins.
#
# 18: Elapsed Train time: 1.16-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1049, Accuracy: 96.78% ] || Test: [ Avg Loss: 0.3011, Accuracy: 91.59% ]
# Elapsed Inf. time: 0.13-mins.
#
# 19: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.1037, Accuracy: 96.85% ] || Test: [ Avg Loss: 0.2544, Accuracy: 93.07% ]
# Elapsed Inf. time: 0.14-mins.
#
# 20: Elapsed Train time: 1.22-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0986, Accuracy: 97.02% ] || Test: [ Avg Loss: 0.2725, Accuracy: 92.33% ]
# Elapsed Inf. time: 0.13-mins.
#
# 21: Elapsed Train time: 1.23-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0926, Accuracy: 97.16% ] || Test: [ Avg Loss: 0.2507, Accuracy: 93.26% ]
# Elapsed Inf. time: 0.13-mins.
#
# 22: Elapsed Train time: 1.30-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0887, Accuracy: 97.27% ] || Test: [ Avg Loss: 0.2431, Accuracy: 93.22% ]
# Elapsed Inf. time: 0.14-mins.
#
# 23: Elapsed Train time: 1.23-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0892, Accuracy: 97.24% ] || Test: [ Avg Loss: 0.3129, Accuracy: 91.66% ]
# Elapsed Inf. time: 0.14-mins.
#
# 24: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0858, Accuracy: 97.34% ] || Test: [ Avg Loss: 0.2982, Accuracy: 92.58% ]
# Elapsed Inf. time: 0.13-mins.
#
# 25: Elapsed Train time: 1.13-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0794, Accuracy: 97.51% ] || Test: [ Avg Loss: 0.2794, Accuracy: 92.55% ]
# Elapsed Inf. time: 0.14-mins.
#
# 26: Elapsed Train time: 1.10-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0774, Accuracy: 97.55% ] || Test: [ Avg Loss: 0.3085, Accuracy: 91.29% ]
# Elapsed Inf. time: 0.13-mins.
#
# 27: Elapsed Train time: 1.17-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0752, Accuracy: 97.65% ] || Test: [ Avg Loss: 0.2588, Accuracy: 92.96% ]
# Elapsed Inf. time: 0.14-mins.
#
# 28: Elapsed Train time: 1.34-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0778, Accuracy: 97.50% ] || Test: [ Avg Loss: 0.2676, Accuracy: 93.00% ]
# Elapsed Inf. time: 0.14-mins.
#
# 29: Elapsed Train time: 1.22-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0732, Accuracy: 97.68% ] || Test: [ Avg Loss: 0.2987, Accuracy: 92.33% ]
# Elapsed Inf. time: 0.14-mins.
#
# 30: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   573
# Train:	[ Avg Loss: 0.0720, Accuracy: 97.70% ] || Test: [ Avg Loss: 0.2749, Accuracy: 93.00% ]
# Elapsed Inf. time: 0.14-mins.
#
# **********************************************************************************
# Done! Run: 10 : [Best Test @ epoch 10] || [ Avg loss: 0.224155, Accuracy: 93.68% ]
# **********************************************************************************
#
# *********************************************
# Average Prediction Difference = 0.07%
# Effective Test Accuracy = 93.56%, pval=0.0000
# *********************************************

# %%
# Plots
plotter_v1(cfgs,run_idx=1)
