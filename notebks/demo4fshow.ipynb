# %%
#!/scratch/nnenv/bin/python3

# %pip install watermark numpy pandas matplotlib torch torchvision torchaudio | grep -v 'already satisfied'
# %load_ext watermark
# %watermark -v -p watermark,numpy,pandas,matplotlib,torch

#
import math,random,os,sys,copy,time,glob,itertools,shutil,re, json
from scipy.stats import wilcoxon

#
import numpy as np

#
import torch, gc
torch.cuda.empty_cache()
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

import torch.nn as nn
import torch.nn.functional as tf
from torch.utils.data import Dataset,DataLoader
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor, Lambda

import pandas as pd

from pathlib import Path
sys.path[0] = str(Path(sys.path[0]).parent)

#
from demofcns import *
from opts.asgm.torchlasgm import PID
from opts.elpf.fo import LPF
from opts.elpf.esfo import esLPF

# from .. import arcs
from arcs.resnet import ResNetC

# python3 -m torch.utils.collect_env
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Python implementation: CPython
# Python version       : 3.10.6
# IPython version      : 8.7.0
#
# watermark : 2.3.1
# numpy     : 1.23.1
# pandas    : 1.4.3
# matplotlib: 3.5.3
# torch     : 1.12.0+cu116

# %% [markdown]
# ##### Setup Configurations (Hyperparameters and so on)

# %%
# - is it being run remotely on OSU EECS server?
remotelyrun = 0 # 0 | 1

#----------------------
# Load setup config
#----------------------
with open('cfgs.json', 'r') as cfglist:
  cfgs = json.load(cfglist)
  
# setup
cfgs['storedir'] = "../expstore"

# - pick data-set
cfgs["dataset"] = "fmnist"
# - set max. batchsize for each epoch, training runs, training epochs, 
cfgs["batch-size"] = 128 # 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, ...
cfgs['runs'] = 10
cfgs["epochs"] = 30

# -pick computation device
devcnt = torch.cuda.device_count()

# - setup multiprocessing, human signature
# random seed for python libraries
cfgs["seed"] = 2023
cfgs["var_seed"] = 1
worker_seed = cfgs["seed"] % (2**32)
cfgs["num-workers"] = 0 #3
cfgs["human_signature"] = "oas" # for signing experiments ran.


if devcnt > 1:
  cfgs["device"] = torch.device('cuda') # "cuda:1"
  torch.cuda.set_device(1)
elif devcnt == 1:
  cfgs["device"] = torch.device('cuda')
else:
  cfgs["device"] = torch.device('cpu')
#
if remotelyrun:
  cfgs["remote"] = True
else:
  cfgs["remote"] = False

# %% [markdown]
# ##### (Generate) or Load the Dataset

# %%
#----------------------
# Download/Load Dataset
#----------------------
if not cfgs["remote"]:
  # same dir. as source-code
  data_folder = "../data"
else:
  # dalton's scratch on OSU's eecs server
  data_folder = "/scratch/data"


# FMNIST
if cfgs["dataset"] == "fmnist":
  train_data = datasets.FashionMNIST(
    root=data_folder,
    train=True,
    download=True,
    transform=ToTensor(),
  )
  test_data = datasets.FashionMNIST(
    root=data_folder,
    train=False,
    download= True,
    transform=ToTensor()
  )
  indim = [28,28]
  class_num = 10
  channels = 1
  val_data = None
  
# Tests 
trainloader = torch.utils.data.DataLoader(train_data, batch_size=cfgs['batch-size'],shuffle=True)
# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)
pass

# %% [markdown]
# ##### Construct Model (Differentiable Function) with  necessary methods.

# %%
''' LeNet
Image: 28x28

Conv: channels: 6 kernel: 5x5, pad=2 
=layer: 6x1x5x5, out: 6x28x28
Pool(Avg): 2x2, stride: 2
=layer: 2x2, out: 6x14x14

Conv: channels: 16 kernel: 5x5
=layer: 16x6x5x5, out: 16x10x10
Pool(Avg): 2x2, stride: 2
=layer: 2x2, out: 16x5x5

Flatten: 16x5x5=400
FC: 400 x 120: out width: 120
FC: 120 x 84: out width: 84
FC: 84 x 10: out width: 10

CNN: LeNet Class
'''
class LeNet(nn.Module):
  
  def __init__(self, cfgs=None):
    super(LeNet,self).__init__()
    
    self.lenet = nn.Sequential(
      nn.Conv2d(in_channels=1, out_channels=6, kernel_size=5, stride=1, padding=2),
      nn.AvgPool2d(kernel_size=2,stride=2),
      nn.ReLU(),
      nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, stride=1, padding=0),
      nn.AvgPool2d(kernel_size=2,stride=2),
      nn.ReLU(),
      nn.Flatten(),
      nn.Linear(in_features=16*5*5,out_features=120, bias=True),
      nn.ReLU(),
      nn.Linear(in_features=120,out_features=84, bias=True),
      nn.ReLU(),
      nn.Linear(in_features=84,out_features=10, bias=True),
    )
    
  def forward(self, X):
    Y = self.lenet(X)
    return Y


class thisNN(nn.Module):
  def __init__(self,num_heads=1,in_feats=1,out_feats=1, loss_type="mse", outs_class=False, mdl_name="nn1") -> None:
    """
    __init__ _summary_

    _extended_summary_

    Args:
        num_heads (int, req): net. output head. Defaults to 1.
        in_feats (int, req): net. input dimension. Defaults to 1.
        out_feats (int, req): net. output dimension per head. Defaults to 1.
        loss_type (str, req): type of loss function Defaults to "mse". ("mse","mce" for multi-class cross-entropy, "bce" binary-class cross-entropy)
        outs_class (bool, req): does model return class indices. Defaults to False, implying it outputs real-valued probabilities. This is also true for loss_type="mse" regardless of user-choice.
    """
    super().__init__()
    self.num_heads = num_heads
    
    # define mdl. params.
    self.cnn = nn.ModuleList()
    for hid in range(num_heads):
      h = LeNet()
      self.cnn.append(
        h
      )
    self.relu = nn.ReLU()
    self.flatten = nn.Flatten()
    
    # prob.fcn at last output or network head layer
    if loss_type == "bce" or loss_type == "mse":
      self.out = torch.nn.Sigmoid()
    else:
      self.out = torch.nn.Softmax()
    
    self.loss_type = loss_type
    self.outs_class = outs_class
    
    # optimizer
    self.sgm = None
    
    # saved trained model
    self.chkpt = None
    
    
    self.devcnt = torch.cuda.device_count()
    self.device = None
    self.name = mdl_name
    
    if not(loss_type == "mse" or loss_type =="mce" or loss_type == "bce"):
      raise ValueError(f"loss_type='{loss_type}' is not defined for this class")
    if (loss_type == "mse"):
      self.outs_class = False    
    
@clsmethod(thisNN)
def forward(self:thisNN, x):
  # pre-process
  # x = x.squeeze() # N x 1 x 28 x 28 -> N x 28 x 28
  logits = []
  for hid in range(self.num_heads):
    lenet = self.cnn[hid]
    y = lenet(x)  
    logits.append(y)
    
  return logits # List [Tensor]

@clsmethod(thisNN)
def outhead(self:thisNN, x):
  probs = []
  for hid in range(self.num_heads):
    y = self.out(x[hid])
    probs.append(y)  
  return probs # List [Tensor]

# Add necessary functions to train model
add_to_thisnn(thisNN,worker_seed,setseed,cseedwk)

# Use saved mdl as
# mdl <-- load model function
# prediction = mdl.infer(input)

# %% [markdown]
# ##### Run the Network Modeling (Training)

# %%
# Test.

torch.manual_seed(2023)
devcnt = torch.cuda.device_count()

cfgs['mdl_name_dir'] = "nndemo4f_fmnist_lenet"
isclassifier = True
cfgs["ss_init"] = 1e-3 # default 1e-3
cfgs["eps_ss"] = 1 # default 5e-1
cfgs["weight_decay"] = 1e-5 # default 1e-5
mdl = thisNN(num_heads=1,in_feats=[28,28],out_feats=10,loss_type="mce",outs_class=isclassifier, mdl_name=cfgs['mdl_name_dir'])
if devcnt > 0:
    mdl.cuda()
cfgs['pathstr'] = str(mdl.name)+str(cfgs["batch-size"])+"_"+cfgs["dataset"]+"_"+str(cfgs["runs"])+"_"+str(cfgs["epochs"])

mdl.runs(train_data, test_data, cfgs=cfgs, eval_name="Test")
# Out:
# Seed: 2023
# **************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 1],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# **************************************************************************************************************************************************
#
# [ ss_raw: 0.022746 => 0.007506, ss_init: 0.007506 ]
# 1: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.6243, Accuracy: 77.18% ] || Test: [ Avg Loss: 0.4800, Accuracy: 82.18% ]
# Elapsed Inf. time: 0.02-mins.
#
# 2: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4072, Accuracy: 84.91% ] || Test: [ Avg Loss: 0.3992, Accuracy: 85.06% ]
# Elapsed Inf. time: 0.02-mins.
#
# 3: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3683, Accuracy: 86.31% ] || Test: [ Avg Loss: 0.3948, Accuracy: 85.08% ]
# Elapsed Inf. time: 0.02-mins.
#
# 4: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3445, Accuracy: 87.09% ] || Test: [ Avg Loss: 0.3696, Accuracy: 86.15% ]
# Elapsed Inf. time: 0.02-mins.
#
# 5: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3280, Accuracy: 87.69% ] || Test: [ Avg Loss: 0.3717, Accuracy: 86.00% ]
# Elapsed Inf. time: 0.02-mins.
#
# 6: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3218, Accuracy: 87.82% ] || Test: [ Avg Loss: 0.3727, Accuracy: 85.91% ]
# Elapsed Inf. time: 0.02-mins.
#
# 7: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3129, Accuracy: 88.23% ] || Test: [ Avg Loss: 0.3500, Accuracy: 86.71% ]
# Elapsed Inf. time: 0.02-mins.
#
# 8: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3091, Accuracy: 88.22% ] || Test: [ Avg Loss: 0.3539, Accuracy: 86.92% ]
# Elapsed Inf. time: 0.02-mins.
#
# 9: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2988, Accuracy: 88.60% ] || Test: [ Avg Loss: 0.3821, Accuracy: 86.04% ]
# Elapsed Inf. time: 0.02-mins.
#
# 10: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2937, Accuracy: 88.83% ] || Test: [ Avg Loss: 0.3410, Accuracy: 87.02% ]
# Elapsed Inf. time: 0.02-mins.
#
# 11: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2905, Accuracy: 88.98% ] || Test: [ Avg Loss: 0.3538, Accuracy: 86.94% ]
# Elapsed Inf. time: 0.02-mins.
#
# 12: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2862, Accuracy: 89.08% ] || Test: [ Avg Loss: 0.3476, Accuracy: 87.18% ]
# Elapsed Inf. time: 0.02-mins.
#
# 13: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2840, Accuracy: 89.15% ] || Test: [ Avg Loss: 0.3515, Accuracy: 86.98% ]
# Elapsed Inf. time: 0.02-mins.
#
# 14: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2800, Accuracy: 89.35% ] || Test: [ Avg Loss: 0.3496, Accuracy: 87.48% ]
# Elapsed Inf. time: 0.02-mins.
#
# 15: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2778, Accuracy: 89.40% ] || Test: [ Avg Loss: 0.3511, Accuracy: 86.99% ]
# Elapsed Inf. time: 0.02-mins.
#
# 16: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2724, Accuracy: 89.68% ] || Test: [ Avg Loss: 0.3456, Accuracy: 87.42% ]
# Elapsed Inf. time: 0.02-mins.
#
# 17: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2675, Accuracy: 89.86% ] || Test: [ Avg Loss: 0.3482, Accuracy: 87.61% ]
# Elapsed Inf. time: 0.02-mins.
#
# 18: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2674, Accuracy: 89.79% ] || Test: [ Avg Loss: 0.3444, Accuracy: 87.17% ]
# Elapsed Inf. time: 0.02-mins.
#
# 19: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2669, Accuracy: 89.77% ] || Test: [ Avg Loss: 0.3599, Accuracy: 87.06% ]
# Elapsed Inf. time: 0.02-mins.
#
# 20: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2646, Accuracy: 89.88% ] || Test: [ Avg Loss: 0.3347, Accuracy: 87.93% ]
# Elapsed Inf. time: 0.02-mins.
#
# 21: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2598, Accuracy: 90.24% ] || Test: [ Avg Loss: 0.3392, Accuracy: 87.69% ]
# Elapsed Inf. time: 0.02-mins.
#
# 22: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2584, Accuracy: 90.07% ] || Test: [ Avg Loss: 0.3359, Accuracy: 87.50% ]
# Elapsed Inf. time: 0.02-mins.
#
# 23: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2541, Accuracy: 90.27% ] || Test: [ Avg Loss: 0.3470, Accuracy: 87.76% ]
# Elapsed Inf. time: 0.02-mins.
#
# 24: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2542, Accuracy: 90.31% ] || Test: [ Avg Loss: 0.3942, Accuracy: 86.71% ]
# Elapsed Inf. time: 0.02-mins.
#
# 25: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2527, Accuracy: 90.40% ] || Test: [ Avg Loss: 0.3593, Accuracy: 87.17% ]
# Elapsed Inf. time: 0.02-mins.
#
# 26: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2576, Accuracy: 90.20% ] || Test: [ Avg Loss: 0.3470, Accuracy: 87.92% ]
# Elapsed Inf. time: 0.02-mins.
#
# 27: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2495, Accuracy: 90.41% ] || Test: [ Avg Loss: 0.3606, Accuracy: 87.68% ]
# Elapsed Inf. time: 0.02-mins.
#
# 28: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2510, Accuracy: 90.47% ] || Test: [ Avg Loss: 0.3472, Accuracy: 87.90% ]
# Elapsed Inf. time: 0.02-mins.
#
# 29: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2455, Accuracy: 90.52% ] || Test: [ Avg Loss: 0.3406, Accuracy: 87.75% ]
# Elapsed Inf. time: 0.02-mins.
#
# 30: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2464, Accuracy: 90.54% ] || Test: [ Avg Loss: 0.3448, Accuracy: 88.16% ]
# Elapsed Inf. time: 0.02-mins.
#
# *********************************************************************************
# Done! Run: 1 : [Best Test @ epoch 30] || [ Avg loss: 0.344796, Accuracy: 88.16% ]
# *********************************************************************************
#
# **************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 1],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# **************************************************************************************************************************************************
#
# [ ss_raw: 0.015597 => 0.005147, ss_init: 0.005147 ]
# 1: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5307, Accuracy: 80.46% ] || Test: [ Avg Loss: 0.4075, Accuracy: 84.73% ]
# Elapsed Inf. time: 0.02-mins.
#
# 2: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3694, Accuracy: 86.20% ] || Test: [ Avg Loss: 0.3741, Accuracy: 86.07% ]
# Elapsed Inf. time: 0.02-mins.
#
# 3: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3228, Accuracy: 87.92% ] || Test: [ Avg Loss: 0.3538, Accuracy: 86.52% ]
# Elapsed Inf. time: 0.02-mins.
#
# 4: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2991, Accuracy: 88.71% ] || Test: [ Avg Loss: 0.3160, Accuracy: 88.51% ]
# Elapsed Inf. time: 0.02-mins.
#
# 5: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2840, Accuracy: 89.30% ] || Test: [ Avg Loss: 0.3212, Accuracy: 88.40% ]
# Elapsed Inf. time: 0.02-mins.
#
# 6: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2691, Accuracy: 89.92% ] || Test: [ Avg Loss: 0.3057, Accuracy: 88.72% ]
# Elapsed Inf. time: 0.02-mins.
#
# 7: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2590, Accuracy: 90.12% ] || Test: [ Avg Loss: 0.3020, Accuracy: 88.81% ]
# Elapsed Inf. time: 0.02-mins.
#
# 8: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2476, Accuracy: 90.75% ] || Test: [ Avg Loss: 0.3208, Accuracy: 88.46% ]
# Elapsed Inf. time: 0.02-mins.
#
# 9: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2398, Accuracy: 91.08% ] || Test: [ Avg Loss: 0.3033, Accuracy: 89.21% ]
# Elapsed Inf. time: 0.02-mins.
#
# 10: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2357, Accuracy: 91.14% ] || Test: [ Avg Loss: 0.3107, Accuracy: 88.60% ]
# Elapsed Inf. time: 0.02-mins.
#
# 11: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2283, Accuracy: 91.39% ] || Test: [ Avg Loss: 0.3077, Accuracy: 89.33% ]
# Elapsed Inf. time: 0.02-mins.
#
# 12: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2187, Accuracy: 91.61% ] || Test: [ Avg Loss: 0.2991, Accuracy: 89.55% ]
# Elapsed Inf. time: 0.02-mins.
#
# 13: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2124, Accuracy: 91.92% ] || Test: [ Avg Loss: 0.3276, Accuracy: 88.64% ]
# Elapsed Inf. time: 0.02-mins.
#
# 14: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2117, Accuracy: 91.89% ] || Test: [ Avg Loss: 0.3119, Accuracy: 89.37% ]
# Elapsed Inf. time: 0.02-mins.
#
# 15: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2004, Accuracy: 92.39% ] || Test: [ Avg Loss: 0.3236, Accuracy: 89.17% ]
# Elapsed Inf. time: 0.02-mins.
#
# 16: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1999, Accuracy: 92.28% ] || Test: [ Avg Loss: 0.3237, Accuracy: 88.97% ]
# Elapsed Inf. time: 0.02-mins.
#
# 17: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1965, Accuracy: 92.57% ] || Test: [ Avg Loss: 0.3427, Accuracy: 89.57% ]
# Elapsed Inf. time: 0.02-mins.
#
# 18: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1878, Accuracy: 92.78% ] || Test: [ Avg Loss: 0.3405, Accuracy: 88.93% ]
# Elapsed Inf. time: 0.02-mins.
#
# 19: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1849, Accuracy: 92.93% ] || Test: [ Avg Loss: 0.3355, Accuracy: 88.79% ]
# Elapsed Inf. time: 0.02-mins.
#
# 20: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1777, Accuracy: 93.07% ] || Test: [ Avg Loss: 0.3339, Accuracy: 88.91% ]
# Elapsed Inf. time: 0.02-mins.
#
# 21: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1835, Accuracy: 92.95% ] || Test: [ Avg Loss: 0.3314, Accuracy: 88.90% ]
# Elapsed Inf. time: 0.02-mins.
#
# 22: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1780, Accuracy: 93.17% ] || Test: [ Avg Loss: 0.3394, Accuracy: 89.54% ]
# Elapsed Inf. time: 0.02-mins.
#
# 23: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1699, Accuracy: 93.61% ] || Test: [ Avg Loss: 0.3585, Accuracy: 89.17% ]
# Elapsed Inf. time: 0.02-mins.
#
# 24: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1709, Accuracy: 93.41% ] || Test: [ Avg Loss: 0.3706, Accuracy: 89.34% ]
# Elapsed Inf. time: 0.02-mins.
#
# 25: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1678, Accuracy: 93.62% ] || Test: [ Avg Loss: 0.3687, Accuracy: 89.10% ]
# Elapsed Inf. time: 0.02-mins.
#
# 26: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1581, Accuracy: 93.90% ] || Test: [ Avg Loss: 0.3723, Accuracy: 89.13% ]
# Elapsed Inf. time: 0.02-mins.
#
# 27: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1573, Accuracy: 93.89% ] || Test: [ Avg Loss: 0.3551, Accuracy: 89.36% ]
# Elapsed Inf. time: 0.02-mins.
#
# 28: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1562, Accuracy: 93.94% ] || Test: [ Avg Loss: 0.3780, Accuracy: 88.76% ]
# Elapsed Inf. time: 0.02-mins.
#
# 29: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1540, Accuracy: 94.09% ] || Test: [ Avg Loss: 0.4100, Accuracy: 88.51% ]
# Elapsed Inf. time: 0.02-mins.
#
# 30: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1524, Accuracy: 94.12% ] || Test: [ Avg Loss: 0.3956, Accuracy: 88.74% ]
# Elapsed Inf. time: 0.02-mins.
#
# *********************************************************************************
# Done! Run: 2 : [Best Test @ epoch 17] || [ Avg loss: 0.342740, Accuracy: 89.57% ]
# *********************************************************************************
#
# **************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 1],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# **************************************************************************************************************************************************
#
# [ ss_raw: 0.011935 => 0.003938, ss_init: 0.003938 ]
# 1: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5350, Accuracy: 80.56% ] || Test: [ Avg Loss: 0.4071, Accuracy: 85.15% ]
# Elapsed Inf. time: 0.02-mins.
#
# 2: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3528, Accuracy: 86.98% ] || Test: [ Avg Loss: 0.3579, Accuracy: 86.69% ]
# Elapsed Inf. time: 0.02-mins.
#
# 3: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3145, Accuracy: 88.25% ] || Test: [ Avg Loss: 0.3418, Accuracy: 87.24% ]
# Elapsed Inf. time: 0.02-mins.
#
# 4: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2887, Accuracy: 89.19% ] || Test: [ Avg Loss: 0.3336, Accuracy: 87.71% ]
# Elapsed Inf. time: 0.02-mins.
#
# 5: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2733, Accuracy: 89.77% ] || Test: [ Avg Loss: 0.3153, Accuracy: 88.52% ]
# Elapsed Inf. time: 0.02-mins.
#
# 6: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2619, Accuracy: 90.22% ] || Test: [ Avg Loss: 0.3046, Accuracy: 88.62% ]
# Elapsed Inf. time: 0.02-mins.
#
# 7: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2495, Accuracy: 90.52% ] || Test: [ Avg Loss: 0.2964, Accuracy: 89.13% ]
# Elapsed Inf. time: 0.02-mins.
#
# 8: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2416, Accuracy: 90.85% ] || Test: [ Avg Loss: 0.3204, Accuracy: 88.56% ]
# Elapsed Inf. time: 0.02-mins.
#
# 9: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2276, Accuracy: 91.44% ] || Test: [ Avg Loss: 0.3068, Accuracy: 88.80% ]
# Elapsed Inf. time: 0.02-mins.
#
# 10: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2237, Accuracy: 91.42% ] || Test: [ Avg Loss: 0.2947, Accuracy: 89.25% ]
# Elapsed Inf. time: 0.02-mins.
#
# 11: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2154, Accuracy: 91.84% ] || Test: [ Avg Loss: 0.3051, Accuracy: 89.24% ]
# Elapsed Inf. time: 0.02-mins.
#
# 12: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2076, Accuracy: 92.09% ] || Test: [ Avg Loss: 0.3019, Accuracy: 89.19% ]
# Elapsed Inf. time: 0.02-mins.
#
# 13: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2012, Accuracy: 92.28% ] || Test: [ Avg Loss: 0.3150, Accuracy: 89.22% ]
# Elapsed Inf. time: 0.02-mins.
#
# 14: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1905, Accuracy: 92.70% ] || Test: [ Avg Loss: 0.3114, Accuracy: 89.22% ]
# Elapsed Inf. time: 0.02-mins.
#
# 15: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1895, Accuracy: 92.78% ] || Test: [ Avg Loss: 0.3235, Accuracy: 89.10% ]
# Elapsed Inf. time: 0.02-mins.
#
# 16: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1808, Accuracy: 93.09% ] || Test: [ Avg Loss: 0.3372, Accuracy: 88.89% ]
# Elapsed Inf. time: 0.02-mins.
#
# 17: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1774, Accuracy: 93.12% ] || Test: [ Avg Loss: 0.3128, Accuracy: 89.31% ]
# Elapsed Inf. time: 0.02-mins.
#
# 18: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1732, Accuracy: 93.49% ] || Test: [ Avg Loss: 0.3100, Accuracy: 89.91% ]
# Elapsed Inf. time: 0.02-mins.
#
# 19: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1627, Accuracy: 93.73% ] || Test: [ Avg Loss: 0.3345, Accuracy: 89.19% ]
# Elapsed Inf. time: 0.02-mins.
#
# 20: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1646, Accuracy: 93.69% ] || Test: [ Avg Loss: 0.3624, Accuracy: 89.27% ]
# Elapsed Inf. time: 0.02-mins.
#
# 21: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1614, Accuracy: 93.83% ] || Test: [ Avg Loss: 0.3354, Accuracy: 89.36% ]
# Elapsed Inf. time: 0.02-mins.
#
# 22: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1522, Accuracy: 94.15% ] || Test: [ Avg Loss: 0.3715, Accuracy: 89.03% ]
# Elapsed Inf. time: 0.02-mins.
#
# 23: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1537, Accuracy: 94.10% ] || Test: [ Avg Loss: 0.3596, Accuracy: 89.57% ]
# Elapsed Inf. time: 0.02-mins.
#
# 24: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1477, Accuracy: 94.31% ] || Test: [ Avg Loss: 0.3726, Accuracy: 88.67% ]
# Elapsed Inf. time: 0.02-mins.
#
# 25: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1430, Accuracy: 94.54% ] || Test: [ Avg Loss: 0.3825, Accuracy: 88.33% ]
# Elapsed Inf. time: 0.02-mins.
#
# 26: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1400, Accuracy: 94.65% ] || Test: [ Avg Loss: 0.3613, Accuracy: 89.45% ]
# Elapsed Inf. time: 0.02-mins.
#
# 27: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1342, Accuracy: 94.93% ] || Test: [ Avg Loss: 0.3853, Accuracy: 89.72% ]
# Elapsed Inf. time: 0.02-mins.
#
# 28: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1343, Accuracy: 94.81% ] || Test: [ Avg Loss: 0.3988, Accuracy: 89.34% ]
# Elapsed Inf. time: 0.02-mins.
#
# 29: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1291, Accuracy: 94.98% ] || Test: [ Avg Loss: 0.3783, Accuracy: 89.73% ]
# Elapsed Inf. time: 0.02-mins.
#
# 30: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1258, Accuracy: 95.15% ] || Test: [ Avg Loss: 0.3990, Accuracy: 89.78% ]
# Elapsed Inf. time: 0.02-mins.
#
# *********************************************************************************
# Done! Run: 3 : [Best Test @ epoch 18] || [ Avg loss: 0.309981, Accuracy: 89.91% ]
# *********************************************************************************
#
# **************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 1],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# **************************************************************************************************************************************************
#
# [ ss_raw: 0.011517 => 0.003800, ss_init: 0.003800 ]
# 1: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5027, Accuracy: 81.58% ] || Test: [ Avg Loss: 0.4123, Accuracy: 84.78% ]
# Elapsed Inf. time: 0.02-mins.
#
# 2: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3515, Accuracy: 86.90% ] || Test: [ Avg Loss: 0.3661, Accuracy: 86.35% ]
# Elapsed Inf. time: 0.02-mins.
#
# 3: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3158, Accuracy: 88.19% ] || Test: [ Avg Loss: 0.3444, Accuracy: 87.36% ]
# Elapsed Inf. time: 0.02-mins.
#
# 4: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2948, Accuracy: 88.80% ] || Test: [ Avg Loss: 0.3334, Accuracy: 87.31% ]
# Elapsed Inf. time: 0.02-mins.
#
# 5: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2776, Accuracy: 89.58% ] || Test: [ Avg Loss: 0.3016, Accuracy: 88.98% ]
# Elapsed Inf. time: 0.02-mins.
#
# 6: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2621, Accuracy: 90.12% ] || Test: [ Avg Loss: 0.3103, Accuracy: 88.50% ]
# Elapsed Inf. time: 0.02-mins.
#
# 7: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2495, Accuracy: 90.50% ] || Test: [ Avg Loss: 0.2976, Accuracy: 89.35% ]
# Elapsed Inf. time: 0.02-mins.
#
# 8: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2398, Accuracy: 90.82% ] || Test: [ Avg Loss: 0.2978, Accuracy: 89.36% ]
# Elapsed Inf. time: 0.02-mins.
#
# 9: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2313, Accuracy: 91.27% ] || Test: [ Avg Loss: 0.3089, Accuracy: 89.01% ]
# Elapsed Inf. time: 0.02-mins.
#
# 10: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2211, Accuracy: 91.59% ] || Test: [ Avg Loss: 0.2973, Accuracy: 89.35% ]
# Elapsed Inf. time: 0.02-mins.
#
# 11: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2168, Accuracy: 91.78% ] || Test: [ Avg Loss: 0.2879, Accuracy: 89.88% ]
# Elapsed Inf. time: 0.02-mins.
#
# 12: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2040, Accuracy: 92.18% ] || Test: [ Avg Loss: 0.3142, Accuracy: 89.42% ]
# Elapsed Inf. time: 0.02-mins.
#
# 13: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1972, Accuracy: 92.50% ] || Test: [ Avg Loss: 0.2953, Accuracy: 89.49% ]
# Elapsed Inf. time: 0.02-mins.
#
# 14: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1910, Accuracy: 92.68% ] || Test: [ Avg Loss: 0.3035, Accuracy: 89.50% ]
# Elapsed Inf. time: 0.02-mins.
#
# 15: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1854, Accuracy: 92.93% ] || Test: [ Avg Loss: 0.3131, Accuracy: 89.28% ]
# Elapsed Inf. time: 0.02-mins.
#
# 16: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1764, Accuracy: 93.18% ] || Test: [ Avg Loss: 0.3246, Accuracy: 89.59% ]
# Elapsed Inf. time: 0.02-mins.
#
# 17: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1753, Accuracy: 93.21% ] || Test: [ Avg Loss: 0.3046, Accuracy: 89.67% ]
# Elapsed Inf. time: 0.02-mins.
#
# 18: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1667, Accuracy: 93.56% ] || Test: [ Avg Loss: 0.3369, Accuracy: 89.14% ]
# Elapsed Inf. time: 0.02-mins.
#
# 19: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1631, Accuracy: 93.80% ] || Test: [ Avg Loss: 0.3255, Accuracy: 89.44% ]
# Elapsed Inf. time: 0.02-mins.
#
# 20: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1554, Accuracy: 94.12% ] || Test: [ Avg Loss: 0.3302, Accuracy: 89.57% ]
# Elapsed Inf. time: 0.02-mins.
#
# 21: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1540, Accuracy: 94.11% ] || Test: [ Avg Loss: 0.3265, Accuracy: 89.96% ]
# Elapsed Inf. time: 0.02-mins.
#
# 22: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1511, Accuracy: 94.21% ] || Test: [ Avg Loss: 0.3393, Accuracy: 89.65% ]
# Elapsed Inf. time: 0.02-mins.
#
# 23: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1398, Accuracy: 94.66% ] || Test: [ Avg Loss: 0.3557, Accuracy: 89.64% ]
# Elapsed Inf. time: 0.02-mins.
#
# 24: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1390, Accuracy: 94.70% ] || Test: [ Avg Loss: 0.3619, Accuracy: 89.70% ]
# Elapsed Inf. time: 0.02-mins.
#
# 25: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1358, Accuracy: 94.80% ] || Test: [ Avg Loss: 0.3540, Accuracy: 89.72% ]
# Elapsed Inf. time: 0.02-mins.
#
# 26: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1298, Accuracy: 95.02% ] || Test: [ Avg Loss: 0.3674, Accuracy: 89.51% ]
# Elapsed Inf. time: 0.02-mins.
#
# 27: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1332, Accuracy: 94.88% ] || Test: [ Avg Loss: 0.3763, Accuracy: 89.48% ]
# Elapsed Inf. time: 0.02-mins.
#
# 28: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1242, Accuracy: 95.24% ] || Test: [ Avg Loss: 0.3761, Accuracy: 89.89% ]
# Elapsed Inf. time: 0.02-mins.
#
# 29: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1234, Accuracy: 95.21% ] || Test: [ Avg Loss: 0.3910, Accuracy: 88.98% ]
# Elapsed Inf. time: 0.02-mins.
#
# 30: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1204, Accuracy: 95.35% ] || Test: [ Avg Loss: 0.4124, Accuracy: 89.65% ]
# Elapsed Inf. time: 0.02-mins.
#
# *********************************************************************************
# Done! Run: 4 : [Best Test @ epoch 21] || [ Avg loss: 0.326463, Accuracy: 89.96% ]
# *********************************************************************************
#
# **************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 1],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# **************************************************************************************************************************************************
#
# [ ss_raw: 0.017681 => 0.005835, ss_init: 0.005835 ]
# 1: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5833, Accuracy: 78.77% ] || Test: [ Avg Loss: 0.4362, Accuracy: 83.53% ]
# Elapsed Inf. time: 0.02-mins.
#
# 2: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3796, Accuracy: 86.02% ] || Test: [ Avg Loss: 0.3696, Accuracy: 86.29% ]
# Elapsed Inf. time: 0.02-mins.
#
# 3: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3430, Accuracy: 87.19% ] || Test: [ Avg Loss: 0.3673, Accuracy: 86.74% ]
# Elapsed Inf. time: 0.02-mins.
#
# 4: Elapsed Train time: 0.28-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3228, Accuracy: 87.91% ] || Test: [ Avg Loss: 0.3754, Accuracy: 86.35% ]
# Elapsed Inf. time: 0.02-mins.
#
# 5: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3049, Accuracy: 88.59% ] || Test: [ Avg Loss: 0.3451, Accuracy: 87.15% ]
# Elapsed Inf. time: 0.02-mins.
#
# 6: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2923, Accuracy: 89.06% ] || Test: [ Avg Loss: 0.3371, Accuracy: 87.61% ]
# Elapsed Inf. time: 0.02-mins.
#
# 7: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2828, Accuracy: 89.38% ] || Test: [ Avg Loss: 0.3415, Accuracy: 87.76% ]
# Elapsed Inf. time: 0.02-mins.
#
# 8: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2717, Accuracy: 89.74% ] || Test: [ Avg Loss: 0.3200, Accuracy: 88.15% ]
# Elapsed Inf. time: 0.02-mins.
#
# 9: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2611, Accuracy: 90.20% ] || Test: [ Avg Loss: 0.3177, Accuracy: 88.73% ]
# Elapsed Inf. time: 0.02-mins.
#
# 10: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2590, Accuracy: 90.23% ] || Test: [ Avg Loss: 0.3214, Accuracy: 88.12% ]
# Elapsed Inf. time: 0.02-mins.
#
# 11: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2516, Accuracy: 90.56% ] || Test: [ Avg Loss: 0.3057, Accuracy: 88.97% ]
# Elapsed Inf. time: 0.02-mins.
#
# 12: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2472, Accuracy: 90.59% ] || Test: [ Avg Loss: 0.3068, Accuracy: 89.32% ]
# Elapsed Inf. time: 0.02-mins.
#
# 13: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2400, Accuracy: 90.85% ] || Test: [ Avg Loss: 0.3302, Accuracy: 88.48% ]
# Elapsed Inf. time: 0.02-mins.
#
# 14: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2362, Accuracy: 91.03% ] || Test: [ Avg Loss: 0.3238, Accuracy: 88.43% ]
# Elapsed Inf. time: 0.02-mins.
#
# 15: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2319, Accuracy: 91.12% ] || Test: [ Avg Loss: 0.3205, Accuracy: 88.63% ]
# Elapsed Inf. time: 0.02-mins.
#
# 16: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2278, Accuracy: 91.34% ] || Test: [ Avg Loss: 0.3197, Accuracy: 89.03% ]
# Elapsed Inf. time: 0.02-mins.
#
# 17: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2241, Accuracy: 91.47% ] || Test: [ Avg Loss: 0.3162, Accuracy: 88.58% ]
# Elapsed Inf. time: 0.02-mins.
#
# 18: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2219, Accuracy: 91.54% ] || Test: [ Avg Loss: 0.3313, Accuracy: 88.84% ]
# Elapsed Inf. time: 0.02-mins.
#
# 19: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2163, Accuracy: 91.73% ] || Test: [ Avg Loss: 0.3275, Accuracy: 88.74% ]
# Elapsed Inf. time: 0.02-mins.
#
# 20: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2174, Accuracy: 91.76% ] || Test: [ Avg Loss: 0.3572, Accuracy: 88.41% ]
# Elapsed Inf. time: 0.02-mins.
#
# 21: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2093, Accuracy: 92.04% ] || Test: [ Avg Loss: 0.3386, Accuracy: 88.24% ]
# Elapsed Inf. time: 0.02-mins.
#
# 22: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2058, Accuracy: 92.04% ] || Test: [ Avg Loss: 0.3453, Accuracy: 89.26% ]
# Elapsed Inf. time: 0.02-mins.
#
# 23: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2085, Accuracy: 92.03% ] || Test: [ Avg Loss: 0.3506, Accuracy: 88.60% ]
# Elapsed Inf. time: 0.02-mins.
#
# 24: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2002, Accuracy: 92.29% ] || Test: [ Avg Loss: 0.3458, Accuracy: 89.02% ]
# Elapsed Inf. time: 0.02-mins.
#
# 25: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2013, Accuracy: 92.23% ] || Test: [ Avg Loss: 0.3380, Accuracy: 89.41% ]
# Elapsed Inf. time: 0.02-mins.
#
# 26: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1971, Accuracy: 92.38% ] || Test: [ Avg Loss: 0.3710, Accuracy: 88.22% ]
# Elapsed Inf. time: 0.02-mins.
#
# 27: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1986, Accuracy: 92.34% ] || Test: [ Avg Loss: 0.3450, Accuracy: 89.21% ]
# Elapsed Inf. time: 0.02-mins.
#
# 28: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1933, Accuracy: 92.60% ] || Test: [ Avg Loss: 0.3890, Accuracy: 87.96% ]
# Elapsed Inf. time: 0.02-mins.
#
# 29: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1936, Accuracy: 92.61% ] || Test: [ Avg Loss: 0.3532, Accuracy: 88.88% ]
# Elapsed Inf. time: 0.02-mins.
#
# 30: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1866, Accuracy: 92.84% ] || Test: [ Avg Loss: 0.3651, Accuracy: 88.48% ]
# Elapsed Inf. time: 0.02-mins.
#
# *********************************************************************************
# Done! Run: 5 : [Best Test @ epoch 25] || [ Avg loss: 0.338049, Accuracy: 89.41% ]
# *********************************************************************************
#
# **************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 1],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# **************************************************************************************************************************************************
#
# [ ss_raw: 0.015881 => 0.005241, ss_init: 0.005241 ]
# 1: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4900, Accuracy: 82.06% ] || Test: [ Avg Loss: 0.3901, Accuracy: 85.64% ]
# Elapsed Inf. time: 0.02-mins.
#
# 2: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3397, Accuracy: 87.31% ] || Test: [ Avg Loss: 0.3439, Accuracy: 87.06% ]
# Elapsed Inf. time: 0.02-mins.
#
# 3: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3061, Accuracy: 88.63% ] || Test: [ Avg Loss: 0.3146, Accuracy: 88.18% ]
# Elapsed Inf. time: 0.02-mins.
#
# 4: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2876, Accuracy: 89.23% ] || Test: [ Avg Loss: 0.3272, Accuracy: 87.64% ]
# Elapsed Inf. time: 0.02-mins.
#
# 5: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2700, Accuracy: 89.91% ] || Test: [ Avg Loss: 0.3253, Accuracy: 88.50% ]
# Elapsed Inf. time: 0.02-mins.
#
# 6: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2577, Accuracy: 90.25% ] || Test: [ Avg Loss: 0.3063, Accuracy: 89.34% ]
# Elapsed Inf. time: 0.02-mins.
#
# 7: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2463, Accuracy: 90.74% ] || Test: [ Avg Loss: 0.3219, Accuracy: 88.31% ]
# Elapsed Inf. time: 0.02-mins.
#
# 8: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2358, Accuracy: 91.01% ] || Test: [ Avg Loss: 0.3049, Accuracy: 88.79% ]
# Elapsed Inf. time: 0.02-mins.
#
# 9: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2258, Accuracy: 91.44% ] || Test: [ Avg Loss: 0.3136, Accuracy: 89.48% ]
# Elapsed Inf. time: 0.02-mins.
#
# 10: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2214, Accuracy: 91.66% ] || Test: [ Avg Loss: 0.3248, Accuracy: 89.02% ]
# Elapsed Inf. time: 0.02-mins.
#
# 11: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2106, Accuracy: 91.98% ] || Test: [ Avg Loss: 0.3103, Accuracy: 89.50% ]
# Elapsed Inf. time: 0.02-mins.
#
# 12: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2078, Accuracy: 92.03% ] || Test: [ Avg Loss: 0.3090, Accuracy: 89.49% ]
# Elapsed Inf. time: 0.02-mins.
#
# 13: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2007, Accuracy: 92.30% ] || Test: [ Avg Loss: 0.3164, Accuracy: 89.31% ]
# Elapsed Inf. time: 0.02-mins.
#
# 14: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1896, Accuracy: 92.82% ] || Test: [ Avg Loss: 0.3145, Accuracy: 89.99% ]
# Elapsed Inf. time: 0.02-mins.
#
# 15: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1883, Accuracy: 92.84% ] || Test: [ Avg Loss: 0.3591, Accuracy: 88.37% ]
# Elapsed Inf. time: 0.02-mins.
#
# 16: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1887, Accuracy: 92.72% ] || Test: [ Avg Loss: 0.3409, Accuracy: 88.61% ]
# Elapsed Inf. time: 0.02-mins.
#
# 17: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1818, Accuracy: 93.11% ] || Test: [ Avg Loss: 0.3371, Accuracy: 89.18% ]
# Elapsed Inf. time: 0.02-mins.
#
# 18: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1768, Accuracy: 93.30% ] || Test: [ Avg Loss: 0.3635, Accuracy: 88.72% ]
# Elapsed Inf. time: 0.02-mins.
#
# 19: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1692, Accuracy: 93.52% ] || Test: [ Avg Loss: 0.3604, Accuracy: 89.06% ]
# Elapsed Inf. time: 0.02-mins.
#
# 20: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1658, Accuracy: 93.72% ] || Test: [ Avg Loss: 0.3428, Accuracy: 89.56% ]
# Elapsed Inf. time: 0.02-mins.
#
# 21: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1663, Accuracy: 93.61% ] || Test: [ Avg Loss: 0.3523, Accuracy: 89.73% ]
# Elapsed Inf. time: 0.02-mins.
#
# 22: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1606, Accuracy: 93.90% ] || Test: [ Avg Loss: 0.3721, Accuracy: 89.53% ]
# Elapsed Inf. time: 0.02-mins.
#
# 23: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1579, Accuracy: 93.97% ] || Test: [ Avg Loss: 0.3850, Accuracy: 89.54% ]
# Elapsed Inf. time: 0.02-mins.
#
# 24: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1536, Accuracy: 94.08% ] || Test: [ Avg Loss: 0.4100, Accuracy: 89.68% ]
# Elapsed Inf. time: 0.02-mins.
#
# 25: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1507, Accuracy: 94.37% ] || Test: [ Avg Loss: 0.3781, Accuracy: 90.17% ]
# Elapsed Inf. time: 0.02-mins.
#
# 26: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1463, Accuracy: 94.46% ] || Test: [ Avg Loss: 0.3725, Accuracy: 89.51% ]
# Elapsed Inf. time: 0.02-mins.
#
# 27: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1529, Accuracy: 94.16% ] || Test: [ Avg Loss: 0.3779, Accuracy: 89.51% ]
# Elapsed Inf. time: 0.02-mins.
#
# 28: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1418, Accuracy: 94.56% ] || Test: [ Avg Loss: 0.4184, Accuracy: 89.28% ]
# Elapsed Inf. time: 0.02-mins.
#
# 29: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1462, Accuracy: 94.34% ] || Test: [ Avg Loss: 0.4050, Accuracy: 88.97% ]
# Elapsed Inf. time: 0.02-mins.
#
# 30: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1416, Accuracy: 94.55% ] || Test: [ Avg Loss: 0.3769, Accuracy: 89.75% ]
# Elapsed Inf. time: 0.02-mins.
#
# *********************************************************************************
# Done! Run: 6 : [Best Test @ epoch 25] || [ Avg loss: 0.378126, Accuracy: 90.17% ]
# *********************************************************************************
#
# **************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 1],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# **************************************************************************************************************************************************
#
# [ ss_raw: 0.003601 => 0.001188, ss_init: 0.001188 ]
# 1: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5663, Accuracy: 79.76% ] || Test: [ Avg Loss: 0.4373, Accuracy: 83.75% ]
# Elapsed Inf. time: 0.02-mins.
#
# 2: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3767, Accuracy: 86.24% ] || Test: [ Avg Loss: 0.3694, Accuracy: 86.62% ]
# Elapsed Inf. time: 0.02-mins.
#
# 3: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3378, Accuracy: 87.56% ] || Test: [ Avg Loss: 0.3406, Accuracy: 87.31% ]
# Elapsed Inf. time: 0.02-mins.
#
# 4: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3086, Accuracy: 88.71% ] || Test: [ Avg Loss: 0.3288, Accuracy: 87.86% ]
# Elapsed Inf. time: 0.02-mins.
#
# 5: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2888, Accuracy: 89.19% ] || Test: [ Avg Loss: 0.3173, Accuracy: 88.12% ]
# Elapsed Inf. time: 0.02-mins.
#
# 6: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2761, Accuracy: 89.73% ] || Test: [ Avg Loss: 0.3162, Accuracy: 88.52% ]
# Elapsed Inf. time: 0.02-mins.
#
# 7: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2665, Accuracy: 90.07% ] || Test: [ Avg Loss: 0.3399, Accuracy: 87.45% ]
# Elapsed Inf. time: 0.02-mins.
#
# 8: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2536, Accuracy: 90.49% ] || Test: [ Avg Loss: 0.2853, Accuracy: 89.78% ]
# Elapsed Inf. time: 0.02-mins.
#
# 9: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2423, Accuracy: 90.86% ] || Test: [ Avg Loss: 0.2812, Accuracy: 89.59% ]
# Elapsed Inf. time: 0.02-mins.
#
# 10: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2347, Accuracy: 91.08% ] || Test: [ Avg Loss: 0.2864, Accuracy: 89.62% ]
# Elapsed Inf. time: 0.02-mins.
#
# 11: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2250, Accuracy: 91.44% ] || Test: [ Avg Loss: 0.2869, Accuracy: 89.34% ]
# Elapsed Inf. time: 0.02-mins.
#
# 12: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2180, Accuracy: 91.77% ] || Test: [ Avg Loss: 0.2793, Accuracy: 89.92% ]
# Elapsed Inf. time: 0.02-mins.
#
# 13: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2098, Accuracy: 91.99% ] || Test: [ Avg Loss: 0.2751, Accuracy: 90.05% ]
# Elapsed Inf. time: 0.02-mins.
#
# 14: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2013, Accuracy: 92.35% ] || Test: [ Avg Loss: 0.2744, Accuracy: 90.06% ]
# Elapsed Inf. time: 0.02-mins.
#
# 15: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1925, Accuracy: 92.67% ] || Test: [ Avg Loss: 0.2797, Accuracy: 89.93% ]
# Elapsed Inf. time: 0.02-mins.
#
# 16: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1864, Accuracy: 92.98% ] || Test: [ Avg Loss: 0.2813, Accuracy: 90.20% ]
# Elapsed Inf. time: 0.02-mins.
#
# 17: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1787, Accuracy: 93.24% ] || Test: [ Avg Loss: 0.2859, Accuracy: 90.06% ]
# Elapsed Inf. time: 0.02-mins.
#
# 18: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1743, Accuracy: 93.46% ] || Test: [ Avg Loss: 0.3036, Accuracy: 89.63% ]
# Elapsed Inf. time: 0.02-mins.
#
# 19: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1655, Accuracy: 93.75% ] || Test: [ Avg Loss: 0.2828, Accuracy: 90.36% ]
# Elapsed Inf. time: 0.02-mins.
#
# 20: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1592, Accuracy: 93.96% ] || Test: [ Avg Loss: 0.2918, Accuracy: 90.10% ]
# Elapsed Inf. time: 0.02-mins.
#
# 21: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1532, Accuracy: 94.22% ] || Test: [ Avg Loss: 0.2892, Accuracy: 90.32% ]
# Elapsed Inf. time: 0.02-mins.
#
# 22: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1475, Accuracy: 94.42% ] || Test: [ Avg Loss: 0.3014, Accuracy: 90.66% ]
# Elapsed Inf. time: 0.02-mins.
#
# 23: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1408, Accuracy: 94.71% ] || Test: [ Avg Loss: 0.3067, Accuracy: 89.68% ]
# Elapsed Inf. time: 0.02-mins.
#
# 24: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1350, Accuracy: 94.83% ] || Test: [ Avg Loss: 0.3061, Accuracy: 90.18% ]
# Elapsed Inf. time: 0.02-mins.
#
# 25: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1320, Accuracy: 94.99% ] || Test: [ Avg Loss: 0.3092, Accuracy: 90.41% ]
# Elapsed Inf. time: 0.02-mins.
#
# 26: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1247, Accuracy: 95.26% ] || Test: [ Avg Loss: 0.3250, Accuracy: 89.97% ]
# Elapsed Inf. time: 0.02-mins.
#
# 27: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1191, Accuracy: 95.53% ] || Test: [ Avg Loss: 0.3252, Accuracy: 90.53% ]
# Elapsed Inf. time: 0.02-mins.
#
# 28: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1185, Accuracy: 95.49% ] || Test: [ Avg Loss: 0.3353, Accuracy: 90.04% ]
# Elapsed Inf. time: 0.02-mins.
#
# 29: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1111, Accuracy: 95.78% ] || Test: [ Avg Loss: 0.3438, Accuracy: 90.07% ]
# Elapsed Inf. time: 0.02-mins.
#
# 30: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1089, Accuracy: 95.84% ] || Test: [ Avg Loss: 0.3382, Accuracy: 90.24% ]
# Elapsed Inf. time: 0.02-mins.
#
# *********************************************************************************
# Done! Run: 7 : [Best Test @ epoch 22] || [ Avg loss: 0.301380, Accuracy: 90.66% ]
# *********************************************************************************
#
# **************************************************************************************************************************************************
# aSGM info:
# ...
# Elapsed Inf. time: 0.02-mins.
#
# 22: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1676, Accuracy: 93.56% ] || Test: [ Avg Loss: 0.3764, Accuracy: 89.00% ]
# Elapsed Inf. time: 0.02-mins.
#
# 23: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1681, Accuracy: 93.55% ] || Test: [ Avg Loss: 0.3622, Accuracy: 88.78% ]
# Elapsed Inf. time: 0.02-mins.
#
# 24: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1612, Accuracy: 93.83% ] || Test: [ Avg Loss: 0.3514, Accuracy: 88.92% ]
# Elapsed Inf. time: 0.02-mins.
#
# 25: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1648, Accuracy: 93.77% ] || Test: [ Avg Loss: 0.3811, Accuracy: 88.81% ]
# Elapsed Inf. time: 0.02-mins.
#
# 26: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1598, Accuracy: 93.86% ] || Test: [ Avg Loss: 0.3930, Accuracy: 88.74% ]
# Elapsed Inf. time: 0.02-mins.
#
# 27: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1589, Accuracy: 93.97% ] || Test: [ Avg Loss: 0.3812, Accuracy: 89.11% ]
# Elapsed Inf. time: 0.02-mins.
#
# 28: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1538, Accuracy: 94.16% ] || Test: [ Avg Loss: 0.3868, Accuracy: 89.02% ]
# Elapsed Inf. time: 0.02-mins.
#
# 29: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1475, Accuracy: 94.30% ] || Test: [ Avg Loss: 0.3995, Accuracy: 88.63% ]
# Elapsed Inf. time: 0.02-mins.
#
# 30: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1454, Accuracy: 94.43% ] || Test: [ Avg Loss: 0.3984, Accuracy: 89.12% ]
# Elapsed Inf. time: 0.02-mins.
#
# *********************************************************************************
# Done! Run: 8 : [Best Test @ epoch 15] || [ Avg loss: 0.318254, Accuracy: 89.32% ]
# *********************************************************************************
#
# **************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 1],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# **************************************************************************************************************************************************
#
# [ ss_raw: 0.012948 => 0.004273, ss_init: 0.004273 ]
# 1: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5482, Accuracy: 80.03% ] || Test: [ Avg Loss: 0.4378, Accuracy: 83.75% ]
# Elapsed Inf. time: 0.02-mins.
#
# 2: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3747, Accuracy: 86.16% ] || Test: [ Avg Loss: 0.3794, Accuracy: 85.57% ]
# Elapsed Inf. time: 0.02-mins.
#
# 3: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3325, Accuracy: 87.60% ] || Test: [ Avg Loss: 0.3530, Accuracy: 87.43% ]
# Elapsed Inf. time: 0.02-mins.
#
# 4: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3066, Accuracy: 88.55% ] || Test: [ Avg Loss: 0.3370, Accuracy: 87.64% ]
# Elapsed Inf. time: 0.02-mins.
#
# 5: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2852, Accuracy: 89.16% ] || Test: [ Avg Loss: 0.3337, Accuracy: 87.90% ]
# Elapsed Inf. time: 0.02-mins.
#
# 6: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2759, Accuracy: 89.69% ] || Test: [ Avg Loss: 0.3192, Accuracy: 88.37% ]
# Elapsed Inf. time: 0.02-mins.
#
# 7: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2643, Accuracy: 90.12% ] || Test: [ Avg Loss: 0.3143, Accuracy: 88.82% ]
# Elapsed Inf. time: 0.02-mins.
#
# 8: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2521, Accuracy: 90.53% ] || Test: [ Avg Loss: 0.3197, Accuracy: 89.12% ]
# Elapsed Inf. time: 0.02-mins.
#
# 9: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2461, Accuracy: 90.64% ] || Test: [ Avg Loss: 0.3058, Accuracy: 88.87% ]
# Elapsed Inf. time: 0.02-mins.
#
# 10: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2347, Accuracy: 90.97% ] || Test: [ Avg Loss: 0.3176, Accuracy: 88.64% ]
# Elapsed Inf. time: 0.02-mins.
#
# 11: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2262, Accuracy: 91.30% ] || Test: [ Avg Loss: 0.3188, Accuracy: 88.64% ]
# Elapsed Inf. time: 0.02-mins.
#
# 12: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2165, Accuracy: 91.77% ] || Test: [ Avg Loss: 0.3187, Accuracy: 89.11% ]
# Elapsed Inf. time: 0.02-mins.
#
# 13: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2103, Accuracy: 92.00% ] || Test: [ Avg Loss: 0.3204, Accuracy: 89.00% ]
# Elapsed Inf. time: 0.02-mins.
#
# 14: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2070, Accuracy: 92.10% ] || Test: [ Avg Loss: 0.3318, Accuracy: 88.85% ]
# Elapsed Inf. time: 0.02-mins.
#
# 15: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1994, Accuracy: 92.41% ] || Test: [ Avg Loss: 0.3201, Accuracy: 89.12% ]
# Elapsed Inf. time: 0.02-mins.
#
# 16: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1945, Accuracy: 92.55% ] || Test: [ Avg Loss: 0.3291, Accuracy: 89.11% ]
# Elapsed Inf. time: 0.02-mins.
#
# 17: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1874, Accuracy: 92.77% ] || Test: [ Avg Loss: 0.3343, Accuracy: 89.15% ]
# Elapsed Inf. time: 0.02-mins.
#
# 18: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1829, Accuracy: 92.94% ] || Test: [ Avg Loss: 0.3359, Accuracy: 89.20% ]
# Elapsed Inf. time: 0.02-mins.
#
# 19: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1793, Accuracy: 93.17% ] || Test: [ Avg Loss: 0.3525, Accuracy: 87.87% ]
# Elapsed Inf. time: 0.02-mins.
#
# 20: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1725, Accuracy: 93.32% ] || Test: [ Avg Loss: 0.3449, Accuracy: 89.44% ]
# Elapsed Inf. time: 0.02-mins.
#
# 21: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1647, Accuracy: 93.75% ] || Test: [ Avg Loss: 0.3328, Accuracy: 89.22% ]
# Elapsed Inf. time: 0.02-mins.
#
# 22: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1627, Accuracy: 93.74% ] || Test: [ Avg Loss: 0.3696, Accuracy: 89.31% ]
# Elapsed Inf. time: 0.02-mins.
#
# 23: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1591, Accuracy: 93.91% ] || Test: [ Avg Loss: 0.3536, Accuracy: 89.11% ]
# Elapsed Inf. time: 0.02-mins.
#
# 24: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1522, Accuracy: 94.09% ] || Test: [ Avg Loss: 0.3713, Accuracy: 89.66% ]
# Elapsed Inf. time: 0.02-mins.
#
# 25: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1524, Accuracy: 94.28% ] || Test: [ Avg Loss: 0.3640, Accuracy: 89.68% ]
# Elapsed Inf. time: 0.02-mins.
#
# 26: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1475, Accuracy: 94.32% ] || Test: [ Avg Loss: 0.3848, Accuracy: 89.28% ]
# Elapsed Inf. time: 0.02-mins.
#
# 27: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1475, Accuracy: 94.36% ] || Test: [ Avg Loss: 0.3787, Accuracy: 89.37% ]
# Elapsed Inf. time: 0.02-mins.
#
# 28: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1393, Accuracy: 94.66% ] || Test: [ Avg Loss: 0.3652, Accuracy: 89.40% ]
# Elapsed Inf. time: 0.02-mins.
#
# 29: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1354, Accuracy: 94.79% ] || Test: [ Avg Loss: 0.4135, Accuracy: 89.05% ]
# Elapsed Inf. time: 0.02-mins.
#
# 30: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1406, Accuracy: 94.67% ] || Test: [ Avg Loss: 0.4110, Accuracy: 88.56% ]
# Elapsed Inf. time: 0.02-mins.
#
# *********************************************************************************
# Done! Run: 9 : [Best Test @ epoch 25] || [ Avg loss: 0.363999, Accuracy: 89.68% ]
# *********************************************************************************
#
# **************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 1],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# **************************************************************************************************************************************************
#
# [ ss_raw: 0.015172 => 0.005007, ss_init: 0.005007 ]
# 1: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5378, Accuracy: 80.44% ] || Test: [ Avg Loss: 0.4217, Accuracy: 84.48% ]
# Elapsed Inf. time: 0.02-mins.
#
# 2: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3591, Accuracy: 86.91% ] || Test: [ Avg Loss: 0.3576, Accuracy: 86.74% ]
# Elapsed Inf. time: 0.02-mins.
#
# 3: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3225, Accuracy: 88.11% ] || Test: [ Avg Loss: 0.3408, Accuracy: 87.62% ]
# Elapsed Inf. time: 0.02-mins.
#
# 4: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2964, Accuracy: 88.94% ] || Test: [ Avg Loss: 0.3139, Accuracy: 88.42% ]
# Elapsed Inf. time: 0.02-mins.
#
# 5: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2765, Accuracy: 89.58% ] || Test: [ Avg Loss: 0.3225, Accuracy: 88.37% ]
# Elapsed Inf. time: 0.02-mins.
#
# 6: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2675, Accuracy: 89.93% ] || Test: [ Avg Loss: 0.3012, Accuracy: 88.88% ]
# Elapsed Inf. time: 0.02-mins.
#
# 7: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2548, Accuracy: 90.61% ] || Test: [ Avg Loss: 0.3106, Accuracy: 88.73% ]
# Elapsed Inf. time: 0.02-mins.
#
# 8: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2512, Accuracy: 90.44% ] || Test: [ Avg Loss: 0.3071, Accuracy: 89.24% ]
# Elapsed Inf. time: 0.02-mins.
#
# 9: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2381, Accuracy: 91.00% ] || Test: [ Avg Loss: 0.3073, Accuracy: 89.41% ]
# Elapsed Inf. time: 0.02-mins.
#
# 10: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2317, Accuracy: 91.24% ] || Test: [ Avg Loss: 0.3276, Accuracy: 87.98% ]
# Elapsed Inf. time: 0.02-mins.
#
# 11: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2244, Accuracy: 91.51% ] || Test: [ Avg Loss: 0.3055, Accuracy: 89.36% ]
# Elapsed Inf. time: 0.02-mins.
#
# 12: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2173, Accuracy: 91.75% ] || Test: [ Avg Loss: 0.3294, Accuracy: 88.77% ]
# Elapsed Inf. time: 0.02-mins.
#
# 13: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2099, Accuracy: 92.20% ] || Test: [ Avg Loss: 0.3237, Accuracy: 88.94% ]
# Elapsed Inf. time: 0.02-mins.
#
# 14: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2051, Accuracy: 92.18% ] || Test: [ Avg Loss: 0.3278, Accuracy: 89.20% ]
# Elapsed Inf. time: 0.02-mins.
#
# 15: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1989, Accuracy: 92.42% ] || Test: [ Avg Loss: 0.3279, Accuracy: 88.68% ]
# Elapsed Inf. time: 0.02-mins.
#
# 16: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1984, Accuracy: 92.41% ] || Test: [ Avg Loss: 0.3227, Accuracy: 89.21% ]
# Elapsed Inf. time: 0.02-mins.
#
# 17: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1916, Accuracy: 92.61% ] || Test: [ Avg Loss: 0.3267, Accuracy: 89.03% ]
# Elapsed Inf. time: 0.02-mins.
#
# 18: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1859, Accuracy: 92.99% ] || Test: [ Avg Loss: 0.3400, Accuracy: 89.18% ]
# Elapsed Inf. time: 0.02-mins.
#
# 19: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1819, Accuracy: 93.04% ] || Test: [ Avg Loss: 0.3383, Accuracy: 89.06% ]
# Elapsed Inf. time: 0.02-mins.
#
# 20: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1772, Accuracy: 93.36% ] || Test: [ Avg Loss: 0.3744, Accuracy: 89.10% ]
# Elapsed Inf. time: 0.02-mins.
#
# 21: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1739, Accuracy: 93.36% ] || Test: [ Avg Loss: 0.3377, Accuracy: 89.20% ]
# Elapsed Inf. time: 0.02-mins.
#
# 22: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1687, Accuracy: 93.58% ] || Test: [ Avg Loss: 0.3887, Accuracy: 88.63% ]
# Elapsed Inf. time: 0.02-mins.
#
# 23: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1664, Accuracy: 93.55% ] || Test: [ Avg Loss: 0.3564, Accuracy: 88.65% ]
# Elapsed Inf. time: 0.02-mins.
#
# 24: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1643, Accuracy: 93.78% ] || Test: [ Avg Loss: 0.3608, Accuracy: 88.96% ]
# Elapsed Inf. time: 0.02-mins.
#
# 25: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1628, Accuracy: 93.85% ] || Test: [ Avg Loss: 0.3722, Accuracy: 89.15% ]
# Elapsed Inf. time: 0.02-mins.
#
# 26: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1621, Accuracy: 93.89% ] || Test: [ Avg Loss: 0.3726, Accuracy: 88.86% ]
# Elapsed Inf. time: 0.02-mins.
#
# 27: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1579, Accuracy: 94.00% ] || Test: [ Avg Loss: 0.3866, Accuracy: 88.85% ]
# Elapsed Inf. time: 0.02-mins.
#
# 28: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1488, Accuracy: 94.23% ] || Test: [ Avg Loss: 0.3778, Accuracy: 89.02% ]
# Elapsed Inf. time: 0.02-mins.
#
# 29: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1534, Accuracy: 94.11% ] || Test: [ Avg Loss: 0.3887, Accuracy: 89.41% ]
# Elapsed Inf. time: 0.02-mins.
#
# 30: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1531, Accuracy: 94.17% ] || Test: [ Avg Loss: 0.3950, Accuracy: 88.74% ]
# Elapsed Inf. time: 0.02-mins.
#
# *********************************************************************************
# Done! Run: 10 : [Best Test @ epoch 9] || [ Avg loss: 0.307303, Accuracy: 89.41% ]
# *********************************************************************************
#
# *********************************************
# Average Prediction Difference = 0.10%
# Effective Test Accuracy = 89.53%, pval=0.0000
# *********************************************

# %%
# Plots
plotter_v1(cfgs,run_idx=1)
