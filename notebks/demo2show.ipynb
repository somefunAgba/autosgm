# %% [markdown]
# ##### Load Required Libraries

# %%
#!/scratch/nnenv/bin/python3
#!~/hpc-share/nnenv/bin/python3

# %pip install watermark numpy pandas matplotlib torch torchvision torchaudio | grep -v 'already satisfied'
# %load_ext watermark
# %watermark -v -p watermark,numpy,pandas,matplotlib,torch

#
import math,random,os,sys,copy,time,glob,itertools,shutil,re, json
from scipy.stats import wilcoxon

#
import numpy as np

#
import torch, gc
torch.cuda.empty_cache()
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

import torch.nn as nn
import torch.nn.functional as tf
from torch.utils.data import Dataset,DataLoader
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor, Lambda

import pandas as pd

from pathlib import Path
sys.path[0] = str(Path(sys.path[0]).parent)

#
from demofcns import *
from opts.asgm.torchlasgm import PID
from opts.elpf.fo import LPF
from opts.elpf.esfo import esLPF

# from .. import arcs
from arcs.resnet import ResNetC

print("Is cuda available?", torch.cuda.is_available())
# python3 -m torch.utils.collect_env
# Out:
# 'grep' is not recognized as an internal or external command,
# operable program or batch file.
# Note: you may need to restart the kernel to use updated packages.
# Python implementation: CPython
# Python version       : 3.10.6
# IPython version      : 8.4.0
#
# watermark : 2.3.1
# numpy     : 1.24.2
# pandas    : 1.4.3
# matplotlib: 3.5.3
# torch     : 2.0.0.dev20230220+cu117
#
# Is cuda available? True

# %% [markdown]
# ##### Setup Configurations (Hyperparameters and so on)

# %%
#----------------------
# Load setup config
#----------------------
with open('cfgs.json', 'r') as cfglist:
  cfgs = json.load(cfglist)
  
# - is it being run remotely on OSU EECS server?
remotelyrun = cfgs['remote'] 
# set in cfgs.json
# remote = 0 [local computer] | 1 [dalton gpu] | 2 [hpc cluster]


# - pick data-set
cfgs["dataset"] = "fmnist"
# - set std. batchsize for each epoch, runs, epochs, multiprocessing, human
cfgs["batch-size"] = 128 # 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, ...
cfgs['runs'] = 1
cfgs["epochs"] = 50

# -pick computation device
devcnt = torch.cuda.device_count()

# random seed for python libraries
cfgs["seed"] = 2023
cfgs["var_seed"] = 1
worker_seed = cfgs["seed"] % (2**32)
cfgs["num-workers"] = 2 #3
cfgs["human_signature"] = "oas" # for signing experiments ran.



if devcnt > 1:
  cfgs["device"] = torch.device('cuda')
  torch.cuda.set_device(0)
elif devcnt == 1:
  cfgs["device"] = torch.device('cuda')
else:
  cfgs["device"] = torch.device('cpu')
#
if remotelyrun:
  cfgs["remote"] = True
else:
  cfgs["remote"] = False

# %% [markdown]
# ##### (Generate) or Load the Dataset

# %%
#----------------------
# Download/Load Dataset
#----------------------
if not cfgs["remote"]:
  # same dir. as source-code
  data_folder = "../data"
  # setup
  cfgs['storedir'] = "../expstore"
else:
  if remotelyrun == 1:
    # dalton's scratch on OSU's eecs server
    data_folder = "/scratch/data"
    # result. storage dir
    cfgs['storedir'] = "/scratch/expstore"
  else:
    data_folder = "/nfs/stak/users/somefuno/hpc-share/data"    
    # result. storage dir
    cfgs['storedir'] = "/nfs/stak/users/somefuno/hpc-share/expstore"


# FMNIST
if cfgs["dataset"] == "fmnist":
  train_data = datasets.FashionMNIST(
    root=data_folder,
    train=True,
    download=True,
    transform=ToTensor(),
  )
  test_data = datasets.FashionMNIST(
    root=data_folder,
    train=False,
    download= True,
    transform=ToTensor()
  )
  indim = [28,28]
  class_num = 10
  channels = 1
  val_data = None
  
# Tests 
trainloader = torch.utils.data.DataLoader(train_data, batch_size=cfgs['batch-size'],shuffle=True)
# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)
pass

# %% [markdown]
# ##### Construct Model (Differentiable Function) with  necessary methods.

# %%
class thisNN(nn.Module):
  def __init__(self,num_heads=1,in_feats=1,out_feats=1, loss_type="mse", outs_class=False, mdl_name="nn1") -> None:
    """
    __init__ _summary_

    _extended_summary_

    Args:
        num_heads (int, req): net. output head. Defaults to 1.
        in_feats (int, req): net. input dimension. Defaults to 1.
        out_feats (int, req): net. output dimension per head. Defaults to 1.
        loss_type (str, req): type of loss function Defaults to "mse". ("mse","mce" for multi-class cross-entropy, "bce" binary-class cross-entropy)
        outs_class (bool, req): does model return class indices. Defaults to False, implying it outputs real-valued probabilities. This is also true for loss_type="mse" regardless of user-choice.
    """
    super().__init__()
    self.num_heads = num_heads
    
    # define mdl. params.
    self.linearfcn = nn.ModuleList()
    
    self.keylinear = nn.ModuleList()
    self.valuelinear = nn.ModuleList()
    self.multiheadattn  = nn.ModuleList()
    self.ma_norm  = nn.ModuleList()
    for _ in range(num_heads):
      self.keylinear.append(
        nn.Sequential(
          torch.nn.Linear(in_features=in_feats[0],out_features=in_feats[0], bias=False),
          torch.nn.LayerNorm(normalized_shape=in_feats[0])
          )
      )
      self.valuelinear.append(
        nn.Sequential(
          torch.nn.Linear(in_features=in_feats[0],out_features=in_feats[0], bias=False),
          torch.nn.LayerNorm(normalized_shape=in_feats[0])
          )
      )
      self.multiheadattn.append(
            torch.nn.MultiheadAttention(in_feats[0],1,batch_first=True,)
      )
      
      self.ma_norm.append(
        torch.nn.LayerNorm(normalized_shape=in_feats[0])
      )
            
      self.linearfcn.append(
        torch.nn.Linear(in_features=in_feats[0]*in_feats[1],out_features=out_feats, bias=True)
      )

    self.relu = nn.ReLU()
    self.flatten = nn.Flatten()
    
    # prob.fcn at last output or network head layer
    if loss_type == "bce" or loss_type == "mse":
      self.out = torch.nn.Sigmoid()
    else:
      self.out = torch.nn.Softmax()
    
    self.loss_type = loss_type
    self.outs_class = outs_class
    
    # optimizer
    self.sgm = None
    
    # saved trained model
    self.chkpt = None
    
    
    self.devcnt = torch.cuda.device_count()
    self.device = None
    self.name = mdl_name
    
    if not(loss_type == "mse" or loss_type =="mce" or loss_type == "bce"):
      raise ValueError(f"loss_type='{loss_type}' is not defined for this class")
    if (loss_type == "mse"):
      self.outs_class = False    
    
@clsmethod(thisNN)
def forward(self:thisNN, x):
  # pre-process
  x = x.squeeze() # N x 1 x 28 x 28 -> N x 28 x 28
  logits = []
  for hid in range(self.num_heads):
    # xq = x.permute(0,2,1)
    xq = x
    keylinear = self.keylinear[hid]
    valuelinear = self.valuelinear[hid]
    xk = xq + self.relu(keylinear(xq))
    xv = xq + self.relu(valuelinear(xq))
    
    multiheadattn = self.multiheadattn[hid]
    manorm = self.ma_norm[hid]
    y,_ = multiheadattn(xq,xk,xv)
    y = y + self.relu(manorm(y))
    
    
    # y = y.permute(0,2,1)
    y = self.flatten(y)
    linearfcn = self.linearfcn[hid]
    y = linearfcn(y)  
    logits.append(y)
    
  return logits # List [Tensor]

@clsmethod(thisNN)
def outhead(self:thisNN, x):
  probs = []
  for hid in range(self.num_heads):
    y = self.out(x[hid])
    probs.append(y)  
  return probs # List [Tensor]

# Add necessary functions to train model
add_to_thisnn(thisNN,worker_seed,setseed,cseedwk)

# Use saved mdl as
# mdl <-- load model function
# prediction = mdl.infer(input)

# %% [markdown]
# ##### Run the Network Modeling (Training)

# %%
# Test.

torch.manual_seed(2023)
devcnt = torch.cuda.device_count()

cfgs['mdl_name_dir'] = "nndemo2_fmnist_customatt"
isclassifier = True
cfgs['p'] = 1, #optional
cfgs["ss_init"] = 1e-3 # default 1e-3, optionaL
cfgs["eps_ss"] = 5e-1 # default 5e-1, optional
cfgs["weight_decay"] = 1e-5 # default 1e-5
mdl = thisNN(num_heads=1,in_feats=[28,28],out_feats=10,loss_type="mce",outs_class=isclassifier, mdl_name=cfgs['mdl_name_dir'])
if devcnt > 0:
    mdl.cuda()
cfgs['pathstr'] = str(mdl.name)+str(cfgs["batch-size"])+"_"+cfgs["dataset"]+"_"+str(cfgs["runs"])+"_"+str(cfgs["epochs"])

mdl.runs(train_data, test_data, cfgs=cfgs, eval_name="Test")
# Out:
# Seed: 2023
# ********************************************************************************************
# total params, d=12834
# [p=1, eff. step-size [linear correlation est. (starting := 0.000802358)]
# aSGM info: (step-size ending := 0), step-size pole : 0.9985],
# [LPF Poles [i,o] : 0.9, 1e-05]
# ********************************************************************************************
#
# 1: Elapsed Train time: 0.42-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 1.4670, Accuracy: 60.43% ] || Test: [ Avg Loss: 0.8374, Accuracy: 69.71% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.000283797)]...
# 2: Elapsed Train time: 0.43-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.7594, Accuracy: 72.60% ] || Test: [ Avg Loss: 0.7516, Accuracy: 73.13% ]
# Elapsed Inf. time: 0.09-mins.
#
# ...[eff. step-size (starting := 9.99437e-05)]...
# 3: Elapsed Train time: 0.48-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.7111, Accuracy: 74.45% ] || Test: [ Avg Loss: 0.7300, Accuracy: 73.61% ]
# Elapsed Inf. time: 0.09-mins.
#
# ...[eff. step-size (starting := 0.00101398)]...
# 4: Elapsed Train time: 0.45-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.6578, Accuracy: 76.68% ] || Test: [ Avg Loss: 0.6434, Accuracy: 77.41% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.00151362)]...
# 5: Elapsed Train time: 0.39-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5878, Accuracy: 79.40% ] || Test: [ Avg Loss: 0.5658, Accuracy: 79.96% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.000492682)]...
# 6: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5146, Accuracy: 81.89% ] || Test: [ Avg Loss: 0.5357, Accuracy: 81.02% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.000532682)]...
# 7: Elapsed Train time: 0.39-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5029, Accuracy: 82.22% ] || Test: [ Avg Loss: 0.5291, Accuracy: 81.33% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.00297414)]...
# 8: Elapsed Train time: 0.41-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5505, Accuracy: 80.90% ] || Test: [ Avg Loss: 0.5073, Accuracy: 82.01% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.00353924)]...
# 9: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5054, Accuracy: 82.27% ] || Test: [ Avg Loss: 0.4862, Accuracy: 83.02% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.00379565)]...
# 10: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4735, Accuracy: 83.20% ] || Test: [ Avg Loss: 0.4567, Accuracy: 83.79% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.00189868)]...
# 11: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4202, Accuracy: 85.02% ] || Test: [ Avg Loss: 0.4394, Accuracy: 84.07% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.000719869)]...
# 12: Elapsed Train time: 0.39-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3901, Accuracy: 86.08% ] || Test: [ Avg Loss: 0.4226, Accuracy: 84.86% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.000853782)]...
# 13: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3875, Accuracy: 86.12% ] || Test: [ Avg Loss: 0.4150, Accuracy: 85.20% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.00111709)]...
# 14: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3884, Accuracy: 86.10% ] || Test: [ Avg Loss: 0.4210, Accuracy: 84.44% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.00254995)]...
# 15: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4144, Accuracy: 85.11% ] || Test: [ Avg Loss: 0.4155, Accuracy: 84.95% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.00499698)]...
# 16: Elapsed Train time: 0.41-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4347, Accuracy: 84.50% ] || Test: [ Avg Loss: 0.4492, Accuracy: 83.96% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.00293866)]...
# 17: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3876, Accuracy: 86.06% ] || Test: [ Avg Loss: 0.4165, Accuracy: 85.25% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.0026299)]...
# 18: Elapsed Train time: 0.43-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3788, Accuracy: 86.33% ] || Test: [ Avg Loss: 0.4055, Accuracy: 85.64% ]
# Elapsed Inf. time: 0.20-mins.
#
# ...[eff. step-size (starting := 0.0020915)]...
# 19: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3671, Accuracy: 86.82% ] || Test: [ Avg Loss: 0.3978, Accuracy: 85.79% ]
# Elapsed Inf. time: 0.07-mins.
#
# ...[eff. step-size (starting := 0.0045333)]...
# 20: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3980, Accuracy: 85.59% ] || Test: [ Avg Loss: 0.4353, Accuracy: 84.42% ]
# Elapsed Inf. time: 0.07-mins.
#
# ...[eff. step-size (starting := 0.0019092)]...
# 21: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3522, Accuracy: 87.31% ] || Test: [ Avg Loss: 0.3856, Accuracy: 86.21% ]
# Elapsed Inf. time: 0.07-mins.
#
# ...[eff. step-size (starting := 0.00138229)]...
# 22: Elapsed Train time: 0.36-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3420, Accuracy: 87.58% ] || Test: [ Avg Loss: 0.3769, Accuracy: 86.25% ]
# Elapsed Inf. time: 0.07-mins.
#
# ...[eff. step-size (starting := 0.0021234)]...
# 23: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3508, Accuracy: 87.23% ] || Test: [ Avg Loss: 0.3824, Accuracy: 86.41% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.00306234)]...
# 24: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3577, Accuracy: 87.02% ] || Test: [ Avg Loss: 0.3845, Accuracy: 86.44% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.00334881)]...
# 25: Elapsed Train time: 0.41-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3608, Accuracy: 86.95% ] || Test: [ Avg Loss: 0.3873, Accuracy: 85.95% ]
# Elapsed Inf. time: 0.09-mins.
#
# ...[eff. step-size (starting := 0.0129722)]...
# 26: Elapsed Train time: 0.44-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4572, Accuracy: 83.89% ] || Test: [ Avg Loss: 0.4363, Accuracy: 84.78% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.010606)]...
# 27: Elapsed Train time: 0.43-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4156, Accuracy: 85.02% ] || Test: [ Avg Loss: 0.4091, Accuracy: 85.48% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.00611612)]...
# 28: Elapsed Train time: 0.43-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3740, Accuracy: 86.55% ] || Test: [ Avg Loss: 0.3944, Accuracy: 86.24% ]
# Elapsed Inf. time: 0.09-mins.
#
# ...[eff. step-size (starting := 0.0083402)]...
# 29: Elapsed Train time: 0.44-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3857, Accuracy: 86.14% ] || Test: [ Avg Loss: 0.4022, Accuracy: 85.85% ]
# Elapsed Inf. time: 0.09-mins.
#
# ...[eff. step-size (starting := 0.0156794)]...
# 30: Elapsed Train time: 0.43-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4279, Accuracy: 84.67% ] || Test: [ Avg Loss: 0.4345, Accuracy: 84.98% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.0048586)]...
# 31: Elapsed Train time: 0.44-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3473, Accuracy: 87.34% ] || Test: [ Avg Loss: 0.3745, Accuracy: 86.83% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.00578494)]...
# 32: Elapsed Train time: 0.43-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3509, Accuracy: 87.12% ] || Test: [ Avg Loss: 0.3804, Accuracy: 86.52% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.0029103)]...
# 33: Elapsed Train time: 0.43-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3224, Accuracy: 88.24% ] || Test: [ Avg Loss: 0.3591, Accuracy: 87.28% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.0118438)]...
# 34: Elapsed Train time: 0.53-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3935, Accuracy: 85.75% ] || Test: [ Avg Loss: 0.3938, Accuracy: 85.93% ]
# Elapsed Inf. time: 0.09-mins.
#
# ...[eff. step-size (starting := 0.0065453)]...
# 35: Elapsed Train time: 0.45-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3457, Accuracy: 87.47% ] || Test: [ Avg Loss: 0.3847, Accuracy: 86.07% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.00625871)]...
# 36: Elapsed Train time: 0.43-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3415, Accuracy: 87.50% ] || Test: [ Avg Loss: 0.3823, Accuracy: 86.61% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.00317052)]...
# 37: Elapsed Train time: 0.44-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3129, Accuracy: 88.64% ] || Test: [ Avg Loss: 0.3591, Accuracy: 87.02% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.00455893)]...
# 38: Elapsed Train time: 0.43-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3212, Accuracy: 88.16% ] || Test: [ Avg Loss: 0.3599, Accuracy: 87.23% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.00151917)]...
# 39: Elapsed Train time: 0.43-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2930, Accuracy: 89.29% ] || Test: [ Avg Loss: 0.3465, Accuracy: 87.69% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.00262024)]...
# 40: Elapsed Train time: 0.44-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2994, Accuracy: 88.97% ] || Test: [ Avg Loss: 0.3591, Accuracy: 86.67% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.00196632)]...
# 41: Elapsed Train time: 0.43-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2931, Accuracy: 89.26% ] || Test: [ Avg Loss: 0.3490, Accuracy: 87.63% ]
# Elapsed Inf. time: 0.09-mins.
#
# ...[eff. step-size (starting := 0.00406056)]...
# 42: Elapsed Train time: 0.58-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3124, Accuracy: 88.53% ] || Test: [ Avg Loss: 0.3632, Accuracy: 86.94% ]
# Elapsed Inf. time: 0.09-mins.
#
# ...[eff. step-size (starting := 0.00282224)]...
# 43: Elapsed Train time: 0.56-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2970, Accuracy: 89.08% ] || Test: [ Avg Loss: 0.3535, Accuracy: 87.32% ]
# Elapsed Inf. time: 0.09-mins.
#
# ...[eff. step-size (starting := 0.00584935)]...
# 44: Elapsed Train time: 0.53-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3233, Accuracy: 88.24% ] || Test: [ Avg Loss: 0.3736, Accuracy: 86.94% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.00319778)]...
# 45: Elapsed Train time: 0.51-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2963, Accuracy: 89.08% ] || Test: [ Avg Loss: 0.3551, Accuracy: 87.52% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.00708649)]...
# 46: Elapsed Train time: 0.52-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3328, Accuracy: 87.84% ] || Test: [ Avg Loss: 0.3691, Accuracy: 86.91% ]
# Elapsed Inf. time: 0.08-mins.
#
# ...[eff. step-size (starting := 0.00430747)]...
# 47: Elapsed Train time: 0.53-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3068, Accuracy: 88.75% ] || Test: [ Avg Loss: 0.3586, Accuracy: 87.46% ]
# Elapsed Inf. time: 0.09-mins.
#
# ...[eff. step-size (starting := 0.00800228)]...
# 48: Elapsed Train time: 0.52-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3391, Accuracy: 87.53% ] || Test: [ Avg Loss: 0.3714, Accuracy: 86.84% ]
# Elapsed Inf. time: 0.09-mins.
#
# ...[eff. step-size (starting := 0.0171569)]...
# 49: Elapsed Train time: 0.50-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4154, Accuracy: 85.31% ] || Test: [ Avg Loss: 0.4157, Accuracy: 85.08% ]
# Elapsed Inf. time: 0.09-mins.
#
# ...[eff. step-size (starting := 0.0109685)]...
# 50: Elapsed Train time: 0.48-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3602, Accuracy: 86.88% ] || Test: [ Avg Loss: 0.3817, Accuracy: 86.29% ]
# Elapsed Inf. time: 0.10-mins.
#
# *********************************************************************************
# Done! Run: 1 : [Best Test @ epoch 39] || [ Avg loss: 0.346518, Accuracy: 87.69% ]
# *********************************************************************************

# %%
# Plots
plotter_v1(cfgs,run_idx=1)
