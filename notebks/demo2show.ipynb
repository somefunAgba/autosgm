# %% [markdown]
# ##### Load Required Libraries

# %%
#!/scratch/nnenv/bin/python3

# %pip install watermark numpy pandas matplotlib torch torchvision torchaudio | grep -v 'already satisfied'
# %load_ext watermark
# %watermark -v -p watermark,numpy,pandas,matplotlib,torch

#
import math,random,os,sys,copy,time,glob,itertools,shutil,re, json
from scipy.stats import wilcoxon

#
import numpy as np

#
import torch, gc
torch.cuda.empty_cache()
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

import torch.nn as nn
import torch.nn.functional as tf
from torch.utils.data import Dataset,DataLoader
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor, Lambda

import pandas as pd

from pathlib import Path
sys.path[0] = str(Path(sys.path[0]).parent)

#
from demofcns import *
from opts.asgm.torchlasgm import PID
from opts.elpf.fo import LPF
from opts.elpf.esfo import esLPF

# from .. import arcs
from arcs.resnet import ResNetC

# python3 -m torch.utils.collect_env
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Python implementation: CPython
# Python version       : 3.10.6
# IPython version      : 8.7.0
#
# watermark : 2.3.1
# numpy     : 1.23.1
# pandas    : 1.4.3
# matplotlib: 3.5.3
# torch     : 1.12.0+cu116

# %% [markdown]
# ##### Setup Configurations (Hyperparameters and so on)

# %%
# - is it being run remotely on OSU EECS server?
remotelyrun = 0 # 0 | 1

#----------------------
# Load setup config
#----------------------
with open('cfgs.json', 'r') as cfglist:
  cfgs = json.load(cfglist)
  
# setup
cfgs['storedir'] = "../expstore"

# - pick data-set
cfgs["dataset"] = "fmnist"
# - set std. batchsize for each epoch, runs, epochs, multiprocessing, human
cfgs["batch-size"] = 128 # 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, ...
cfgs['runs'] = 10
cfgs["epochs"] = 30

# -pick computation device
devcnt = torch.cuda.device_count()

# random seed for python libraries
cfgs["seed"] = 2023
cfgs["var_seed"] = 1
worker_seed = cfgs["seed"] % (2**32)
cfgs["num-workers"] = 0 #3
cfgs["human_signature"] = "oas" # for signing experiments ran.



if devcnt > 1:
  cfgs["device"] = torch.device('cuda') # "cuda:1"
  torch.cuda.set_device(1)
elif devcnt == 1:
  cfgs["device"] = torch.device('cuda')
else:
  cfgs["device"] = torch.device('cpu')
#
if remotelyrun:
  cfgs["remote"] = True
else:
  cfgs["remote"] = False

# %% [markdown]
# ##### (Generate) or Load the Dataset

# %%
#----------------------
# Download/Load Dataset
#----------------------
if not cfgs["remote"]:
  # same dir. as source-code
  data_folder = "../data"
else:
  # dalton's scratch on OSU's eecs server
  data_folder = "/scratch/data"


# FMNIST
if cfgs["dataset"] == "fmnist":
  train_data = datasets.FashionMNIST(
    root=data_folder,
    train=True,
    download=True,
    transform=ToTensor(),
  )
  test_data = datasets.FashionMNIST(
    root=data_folder,
    train=False,
    download= True,
    transform=ToTensor()
  )
  indim = [28,28]
  class_num = 10
  channels = 1
  val_data = None
  
# Tests 
trainloader = torch.utils.data.DataLoader(train_data, batch_size=cfgs['batch-size'],shuffle=True)
# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)
pass

# %% [markdown]
# ##### Construct Model (Differentiable Function) with  necessary methods.

# %%
class thisNN(nn.Module):
  def __init__(self,num_heads=1,in_feats=1,out_feats=1, loss_type="mse", outs_class=False, mdl_name="nn1") -> None:
    """
    __init__ _summary_

    _extended_summary_

    Args:
        num_heads (int, req): net. output head. Defaults to 1.
        in_feats (int, req): net. input dimension. Defaults to 1.
        out_feats (int, req): net. output dimension per head. Defaults to 1.
        loss_type (str, req): type of loss function Defaults to "mse". ("mse","mce" for multi-class cross-entropy, "bce" binary-class cross-entropy)
        outs_class (bool, req): does model return class indices. Defaults to False, implying it outputs real-valued probabilities. This is also true for loss_type="mse" regardless of user-choice.
    """
    super().__init__()
    self.num_heads = num_heads
    
    # define mdl. params.
    self.linearfcn = nn.ModuleList()
    
    self.keylinear = nn.ModuleList()
    self.valuelinear = nn.ModuleList()
    self.multiheadattn  = nn.ModuleList()
    self.ma_norm  = nn.ModuleList()
    for _ in range(num_heads):
      self.keylinear.append(
        nn.Sequential(
          torch.nn.Linear(in_features=in_feats[0],out_features=in_feats[0], bias=False),
          torch.nn.LayerNorm(normalized_shape=in_feats[0])
          )
      )
      self.valuelinear.append(
        nn.Sequential(
          torch.nn.Linear(in_features=in_feats[0],out_features=in_feats[0], bias=False),
          torch.nn.LayerNorm(normalized_shape=in_feats[0])
          )
      )
      self.multiheadattn.append(
            torch.nn.MultiheadAttention(in_feats[0],1,batch_first=True,)
      )
      
      self.ma_norm.append(
        torch.nn.LayerNorm(normalized_shape=in_feats[0])
      )
            
      self.linearfcn.append(
        torch.nn.Linear(in_features=in_feats[0]*in_feats[1],out_features=out_feats, bias=True)
      )

    self.relu = nn.ReLU()
    self.flatten = nn.Flatten()
    
    # prob.fcn at last output or network head layer
    if loss_type == "bce" or loss_type == "mse":
      self.out = torch.nn.Sigmoid()
    else:
      self.out = torch.nn.Softmax()
    
    self.loss_type = loss_type
    self.outs_class = outs_class
    
    # optimizer
    self.sgm = None
    
    # saved trained model
    self.chkpt = None
    
    
    self.devcnt = torch.cuda.device_count()
    self.device = None
    self.name = mdl_name
    
    if not(loss_type == "mse" or loss_type =="mce" or loss_type == "bce"):
      raise ValueError(f"loss_type='{loss_type}' is not defined for this class")
    if (loss_type == "mse"):
      self.outs_class = False    
    
@clsmethod(thisNN)
def forward(self:thisNN, x):
  # pre-process
  x = x.squeeze() # N x 1 x 28 x 28 -> N x 28 x 28
  logits = []
  for hid in range(self.num_heads):
    # xq = x.permute(0,2,1)
    xq = x
    keylinear = self.keylinear[hid]
    valuelinear = self.valuelinear[hid]
    xk = xq + self.relu(keylinear(xq))
    xv = xq + self.relu(valuelinear(xq))
    
    multiheadattn = self.multiheadattn[hid]
    manorm = self.ma_norm[hid]
    y,_ = multiheadattn(xq,xk,xv)
    y = y + self.relu(manorm(y))
    
    
    # y = y.permute(0,2,1)
    y = self.flatten(y)
    linearfcn = self.linearfcn[hid]
    y = linearfcn(y)  
    logits.append(y)
    
  return logits # List [Tensor]

@clsmethod(thisNN)
def outhead(self:thisNN, x):
  probs = []
  for hid in range(self.num_heads):
    y = self.out(x[hid])
    probs.append(y)  
  return probs # List [Tensor]

# Add necessary functions to train model
add_to_thisnn(thisNN,worker_seed,setseed,cseedwk)

# Use saved mdl as
# mdl <-- load model function
# prediction = mdl.infer(input)

# %% [markdown]
# ##### Run the Network Modeling (Training)

# %%
# Test.

torch.manual_seed(2023)
devcnt = torch.cuda.device_count()

cfgs['mdl_name_dir'] = "nndemo2_fmnist_customatt"
isclassifier = True
cfgs["ss_init"] = 1e-3 # default 1e-3
cfgs["eps_ss"] = 5e-1 # default 5e-1
cfgs["weight_decay"] = 1e-5 # default 1e-5
mdl = thisNN(num_heads=1,in_feats=[28,28],out_feats=10,loss_type="mce",outs_class=isclassifier, mdl_name=cfgs['mdl_name_dir'])
if devcnt > 0:
    mdl.cuda()
cfgs['pathstr'] = str(mdl.name)+str(cfgs["batch-size"])+"_"+cfgs["dataset"]+"_"+str(cfgs["runs"])+"_"+str(cfgs["epochs"])

mdl.runs(train_data, test_data, cfgs=cfgs, eval_name="Test")
# Out:
# Seed: 2023
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9985],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# [ss_init: 0.004103, 0.010698 => 0.002675 ]
# 1: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 1.0948, Accuracy: 69.39% ] || Test: [ Avg Loss: 0.6195, Accuracy: 78.20% ]
# Elapsed Inf. time: 0.02-mins.
#
# 2: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5849, Accuracy: 79.44% ] || Test: [ Avg Loss: 0.5398, Accuracy: 80.71% ]
# Elapsed Inf. time: 0.02-mins.
#
# 3: Elapsed Train time: 0.32-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5191, Accuracy: 81.64% ] || Test: [ Avg Loss: 0.5126, Accuracy: 82.40% ]
# Elapsed Inf. time: 0.02-mins.
#
# 4: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4888, Accuracy: 82.80% ] || Test: [ Avg Loss: 0.4960, Accuracy: 82.28% ]
# Elapsed Inf. time: 0.02-mins.
#
# 5: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4579, Accuracy: 83.69% ] || Test: [ Avg Loss: 0.4777, Accuracy: 83.44% ]
# Elapsed Inf. time: 0.02-mins.
#
# 6: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4426, Accuracy: 84.07% ] || Test: [ Avg Loss: 0.4431, Accuracy: 83.87% ]
# Elapsed Inf. time: 0.02-mins.
#
# 7: Elapsed Train time: 0.30-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4267, Accuracy: 84.80% ] || Test: [ Avg Loss: 0.4282, Accuracy: 84.51% ]
# Elapsed Inf. time: 0.02-mins.
#
# 8: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4197, Accuracy: 84.96% ] || Test: [ Avg Loss: 0.4249, Accuracy: 84.59% ]
# Elapsed Inf. time: 0.02-mins.
#
# 9: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4022, Accuracy: 85.67% ] || Test: [ Avg Loss: 0.4330, Accuracy: 84.56% ]
# Elapsed Inf. time: 0.02-mins.
#
# 10: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4001, Accuracy: 85.73% ] || Test: [ Avg Loss: 0.4094, Accuracy: 85.13% ]
# Elapsed Inf. time: 0.02-mins.
#
# 11: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3915, Accuracy: 86.00% ] || Test: [ Avg Loss: 0.4062, Accuracy: 85.56% ]
# Elapsed Inf. time: 0.02-mins.
#
# 12: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3828, Accuracy: 86.22% ] || Test: [ Avg Loss: 0.4009, Accuracy: 85.65% ]
# Elapsed Inf. time: 0.02-mins.
#
# 13: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3814, Accuracy: 86.22% ] || Test: [ Avg Loss: 0.3904, Accuracy: 85.90% ]
# Elapsed Inf. time: 0.02-mins.
#
# 14: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3725, Accuracy: 86.49% ] || Test: [ Avg Loss: 0.4029, Accuracy: 85.51% ]
# Elapsed Inf. time: 0.02-mins.
#
# 15: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3717, Accuracy: 86.68% ] || Test: [ Avg Loss: 0.3826, Accuracy: 86.29% ]
# Elapsed Inf. time: 0.02-mins.
#
# 16: Elapsed Train time: 0.30-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3610, Accuracy: 86.98% ] || Test: [ Avg Loss: 0.3953, Accuracy: 85.93% ]
# Elapsed Inf. time: 0.02-mins.
#
# 17: Elapsed Train time: 0.30-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3569, Accuracy: 87.02% ] || Test: [ Avg Loss: 0.3787, Accuracy: 86.55% ]
# Elapsed Inf. time: 0.02-mins.
#
# 18: Elapsed Train time: 0.33-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3551, Accuracy: 86.97% ] || Test: [ Avg Loss: 0.3851, Accuracy: 86.43% ]
# Elapsed Inf. time: 0.02-mins.
#
# 19: Elapsed Train time: 0.30-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3514, Accuracy: 87.17% ] || Test: [ Avg Loss: 0.3785, Accuracy: 86.41% ]
# Elapsed Inf. time: 0.02-mins.
#
# 20: Elapsed Train time: 0.32-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3462, Accuracy: 87.43% ] || Test: [ Avg Loss: 0.3755, Accuracy: 86.44% ]
# Elapsed Inf. time: 0.02-mins.
#
# 21: Elapsed Train time: 0.30-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3468, Accuracy: 87.34% ] || Test: [ Avg Loss: 0.3726, Accuracy: 86.67% ]
# Elapsed Inf. time: 0.02-mins.
#
# 22: Elapsed Train time: 0.30-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3439, Accuracy: 87.35% ] || Test: [ Avg Loss: 0.3645, Accuracy: 86.80% ]
# Elapsed Inf. time: 0.02-mins.
#
# 23: Elapsed Train time: 0.32-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3421, Accuracy: 87.55% ] || Test: [ Avg Loss: 0.3775, Accuracy: 86.45% ]
# Elapsed Inf. time: 0.02-mins.
#
# 24: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3347, Accuracy: 87.78% ] || Test: [ Avg Loss: 0.3692, Accuracy: 86.92% ]
# Elapsed Inf. time: 0.02-mins.
#
# 25: Elapsed Train time: 0.32-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3356, Accuracy: 87.72% ] || Test: [ Avg Loss: 0.3665, Accuracy: 86.83% ]
# Elapsed Inf. time: 0.02-mins.
#
# 26: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3324, Accuracy: 87.97% ] || Test: [ Avg Loss: 0.3668, Accuracy: 87.08% ]
# Elapsed Inf. time: 0.02-mins.
#
# 27: Elapsed Train time: 0.30-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3302, Accuracy: 87.89% ] || Test: [ Avg Loss: 0.3593, Accuracy: 87.16% ]
# Elapsed Inf. time: 0.02-mins.
#
# 28: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3297, Accuracy: 87.90% ] || Test: [ Avg Loss: 0.3692, Accuracy: 87.27% ]
# Elapsed Inf. time: 0.02-mins.
#
# 29: Elapsed Train time: 0.30-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.