# %% [markdown]
# ##### Load Required Libraries

# %%
##!/scratch/nnenv/bin/python3

# %pip install watermark numpy pandas matplotlib torch torchvision torchaudio | grep -v 'already satisfied'
# %load_ext watermark
# %watermark -v -p watermark,numpy,pandas,matplotlib,torch

#
import math,random,os,sys,copy,time,glob,itertools,shutil,re, json
from scipy.stats import wilcoxon

#
import numpy as np

#
import torch, gc
torch.cuda.empty_cache()
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

import torch.nn as nn
import torch.nn.functional as tf
from torch.utils.data import Dataset,DataLoader
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor, Lambda

import pandas as pd

from pathlib import Path
sys.path[0] = str(Path(sys.path[0]).parent)

#
from demofcns import *
from opts.asgm.torchlasgm import PID
from opts.elpf.fo import LPF
from opts.elpf.esfo import esLPF


# python3 -m torch.utils.collect_env
# Out:
# 'grep' is not recognized as an internal or external command,
# operable program or batch file.
# Note: you may need to restart the kernel to use updated packages.
# Python implementation: CPython
# Python version       : 3.10.6
# IPython version      : 8.4.0
#
# watermark : 2.3.1
# numpy     : 1.23.2
# pandas    : 1.4.3
# matplotlib: 3.5.3
# torch     : 1.12.1+cu116

# %% [markdown]
# ##### Setup Configurations (Hyperparameters and so on)

# %%
# - is it being run remotely on OSU EECS server?
remotelyrun = 0 # 0 | 1

#----------------------
# Load setup config
#----------------------
with open('cfgs.json', 'r') as cfglist:
  cfgs = json.load(cfglist)
  
# setup
cfgs['storedir'] = "../expstore"

# - pick data-set
cfgs["dataset"] = "atoy"
# - set std. batchsize for each epoch, runs, epochs, multiprocessing, human
cfgs["batch-size"] = 128 # 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, ...
cfgs['runs'] = 10
cfgs["epochs"] = 10

# -pick computation device
devcnt = torch.cuda.device_count()

# random seed for python libraries
cfgs["seed"] = 2023
cfgs["var_seed"] = 1
worker_seed = cfgs["seed"] % (2**32)
cfgs["num-workers"] = 0 #3
cfgs["human_signature"] = "oas" # for signing experiments ran.

if devcnt > 1:
  cfgs["device"] = torch.device('cuda') # "cuda:1"
  torch.cuda.set_device(0)
elif devcnt == 1:
  cfgs["device"] = torch.device('cuda')
else:
  cfgs["device"] = torch.device('cpu')
#
if remotelyrun:
  cfgs["remote"] = True
else:
  cfgs["remote"] = False

# %% [markdown]
# ##### (Generate) or Load the Dataset

# %%
#----------------------
# Download/Load Dataset
#----------------------
if not cfgs["remote"]:
  # same dir. as source-code
  data_folder = "../data"
else:
  # dalton's scratch on OSU's eecs server
  data_folder = "/scratch/data"


# aToy
class aToy(Dataset):
    def __init__(self, data, split="", transform=None, target_transform=None):
      if split=="train": 
        self.data = data['train']
      elif split=="val" or split=="test":
        self.data = data['dev']
      #
      self.transform = transform
      self.target_transform = target_transform
      
      self.input = self.data['in']      
      self.labels = self.data['out']
        
            
    def __len__(self):
      return self.labels.shape[0]
    
    def __getitem__(self, idx):
        
      x = self.input[idx,:]
      y = self.labels[idx,]

      # transforms ...
      if self.transform:
        x = self.transform(x)
      if self.target_transform:
        y = self.target_transform(y)
          
        
      return x,y
    
def aToyGenerator(data_dir=f"{data_folder}/toydata_twofeatures_two_class.txt"):
  
  # Dataset with input: dim = 2 and ouput: class = binary, dim = 1 
  df = pd.read_csv(data_dir, sep="\t")
  # print(df.head())
  data_in = torch.tensor(df[["x1", "x2"]].values, dtype=torch.float)
  data_out = torch.tensor(df["label"].values, dtype=torch.int64)
  
  #
  torch.Generator().manual_seed(0)
  for i in range(10):
    data_in = torch.cat([data_in, data_in+torch.normal(0,0.1,size=(data_in.shape[0],1))])
    data_out = torch.cat([data_out,data_out])
    
  #
  intrain, inval = torch.utils.data.random_split(data_in, [int(0.6*data_in.shape[0]), int(0.4*data_in.shape[0])], generator=torch.Generator().manual_seed(0))
  # print(len(intrain.indices))
  
  atoy_data_train = {"in":data_in[intrain.indices,:], "out":data_out[intrain.indices,]}
  atoy_data_dev = {"in":data_in[inval.indices,:], "out":data_out[inval.indices,]}
  return {"train":atoy_data_train, "dev":atoy_data_dev}

if cfgs["dataset"] == "atoy":
  atoy_data = aToyGenerator()
  train_data = aToy(atoy_data,split="train")   
  test_data = aToy(atoy_data,split="test")

# %% [markdown]
# ##### Construct Model (Differentiable Function) with  necessary methods.

# %%
class thisNN(nn.Module):
  def __init__(self,num_heads=1,in_feats=1,out_feats=1, loss_type="mse", outs_class=False, mdl_name="nn1") -> None:
    """
    __init__ _summary_

    _extended_summary_

    Args:
        num_heads (int, req): net. output head. Defaults to 1.
        in_feats (int, req): net. input dimension. Defaults to 1.
        out_feats (int, req): net. output dimension per head. Defaults to 1.
        loss_type (str, req): type of loss function Defaults to "mse". ("mse","mce" for multi-class cross-entropy, "bce" binary-class cross-entropy)
        outs_class (bool, req): does model return class indices. Defaults to False, implying it outputs real-valued probabilities. This is also true for loss_type="mse" regardless of user-choice.
    """
    super().__init__()
    self.num_heads = num_heads
    
    # define mdl. params.
    self.linearfcn = nn.ModuleList()
    
    self.keylinear = nn.ModuleList()
    self.valuelinear = nn.ModuleList()
    self.multiheadattn  = nn.ModuleList()
    for _ in range(num_heads):
      self.keylinear.append(
        torch.nn.Linear(in_features=in_feats,out_features=in_feats, bias=True)
      )
      self.valuelinear.append(
        torch.nn.Linear(in_features=in_feats,out_features=in_feats, bias=True)
      )
      self.multiheadattn.append(
        torch.nn.MultiheadAttention(in_feats,1,batch_first=True,)
      )      
      self.linearfcn.append(
        torch.nn.Linear(in_features=in_feats,out_features=out_feats, bias=True)
      )

    self.relu = nn.ReLU()
    
    # prob.fcn at last output or network head layer
    if loss_type == "bce" or loss_type == "mse":
      self.out = torch.nn.Sigmoid()
    else:
      self.out = torch.nn.Softmax()
    
    self.loss_type = loss_type
    self.outs_class = outs_class
    
    # optimizer
    self.sgm = None
    
    # saved trained model
    self.chkpt = None
    
    
    self.devcnt = torch.cuda.device_count()
    self.device = None
    self.name = mdl_name
    
    if not(loss_type == "mse" or loss_type =="mce" or loss_type == "bce"):
      raise ValueError(f"loss_type='{loss_type}' is not defined for this class")
    if (loss_type == "mse"):
      self.outs_class = False    
    
@clsmethod(thisNN)
def forward(self:thisNN, x):
  # pre-process
  # x= x.unsqueeze(-1)
  # x = x.permute(0,2,1)
  logits = []
  for hid in range(self.num_heads):
    xq = x.unsqueeze(-1)
    xq = xq.permute(0,2,1)
    keylinear = self.keylinear[hid]
    valuelinear = self.valuelinear[hid]
    xk = xq + self.relu(keylinear(xq))
    xv = xq + self.relu(valuelinear(xq))
    
    multiheadattn = self.multiheadattn[hid]
    y,_ = multiheadattn(xq,xk,xv)
    y = y + self.relu(y)
    
    
    y = y.permute(0,2,1)
    y = y.squeeze(-1)
    linearfcn = self.linearfcn[hid]
    y = linearfcn(y)  
    logits.append(y)
    
  return logits # List [Tensor]

@clsmethod(thisNN)
def outhead(self:thisNN, x):
  probs = []
  for hid in range(self.num_heads):
    y = self.out(x[hid])
    probs.append(y)  
  return probs # List [Tensor]

# Add necessary functions to train model
add_to_thisnn(thisNN,worker_seed,setseed,cseedwk)

# %% [markdown]
# ##### Run the Network Modeling (Training)

# %%
# Test.

torch.manual_seed(2023)
devcnt = torch.cuda.device_count()

cfgs['mdl_name_dir'] = "nndemo1_toydata_customatt"
isclassifier = True
cfgs["ss_init"] = 1e-3
cfgs["eps_ss"] = 5e-1 # default 5e-1
cfgs["weight_decay"] = 1e-5 # default 1e-5
mdl = thisNN(num_heads=1,in_feats=2,out_feats=1,loss_type="bce",outs_class=isclassifier, mdl_name=cfgs['mdl_name_dir'])
if devcnt > 0:
    mdl.cuda()
cfgs['pathstr'] = str(mdl.name)+str(cfgs["batch-size"])+"_"+cfgs["dataset"]+"_"+str(cfgs["runs"])+"_"+str(cfgs["epochs"])

mdl.runs(train_data, test_data, cfgs=cfgs, eval_name="Test")
# Out:
# Seed: 2023
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# [ss_init: 0.061207 <= 0.244828 ]
# 1: Elapsed Train time: 0.06-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0585, Accuracy: 97.84%, FA = 3.613297% ]  || Test: [ Avg Loss: 0.0023, Accuracy: 99.91%,  FA = 0.149514% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0024, Accuracy: 99.90%, FA = 0.112414% ]  || Test: [ Avg Loss: 0.0025, Accuracy: 99.89%,  FA = 0.124595% ]
# Elapsed Inf. time: 0.01-mins.
#
# 3: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0026, Accuracy: 99.91%, FA = 0.096355% ]  || Test: [ Avg Loss: 0.0025, Accuracy: 99.91%,  FA = 0.024919% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0018, Accuracy: 99.94%, FA = 0.048177% ]  || Test: [ Avg Loss: 0.0024, Accuracy: 99.91%,  FA = 0.149514% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0017, Accuracy: 99.95%, FA = 0.048177% ]  || Test: [ Avg Loss: 0.0019, Accuracy: 99.91%,  FA = 0.074757% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0016, Accuracy: 99.95%, FA = 0.048177% ]  || Test: [ Avg Loss: 0.0011, Accuracy: 99.98%,  FA = 0.024919% ]
# Elapsed Inf. time: 0.01-mins.
#
# 7: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0016, Accuracy: 99.95%, FA = 0.048177% ]  || Test: [ Avg Loss: 0.0037, Accuracy: 99.88%,  FA = 0.224271% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0018, Accuracy: 99.95%, FA = 0.064236% ]  || Test: [ Avg Loss: 0.0014, Accuracy: 99.95%,  FA = 0.074757% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0021, Accuracy: 99.92%, FA = 0.096355% ]  || Test: [ Avg Loss: 0.0017, Accuracy: 99.93%,  FA = 0.049838% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0023, Accuracy: 99.90%, FA = 0.080295% ]  || Test: [ Avg Loss: 0.0026, Accuracy: 99.93%,  FA = 0.124595% ]
# Elapsed Inf. time: 0.01-mins.
#
# ********************************************************************************
# Done! Run: 1 : [Best Test @ epoch 6] || [ Avg loss: 0.001057, Accuracy: 99.98% ]
# ********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# [ss_init: 0.095965 <= -0.383860 ]
# 1: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.3444, Accuracy: 89.40%, FA = 10.807773% ]  || Test: [ Avg Loss: 0.0254, Accuracy: 99.41%,  FA = 0.373785% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0158, Accuracy: 99.40%, FA = 0.706600% ]  || Test: [ Avg Loss: 0.0124, Accuracy: 99.61%,  FA = 0.598056% ]
# Elapsed Inf. time: 0.01-mins.
#
# 3: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0133, Accuracy: 99.45%, FA = 0.562068% ]  || Test: [ Avg Loss: 0.0096, Accuracy: 99.67%,  FA = 0.224271% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0093, Accuracy: 99.65%, FA = 0.353300% ]  || Test: [ Avg Loss: 0.0084, Accuracy: 99.76%,  FA = 0.274109% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0085, Accuracy: 99.67%, FA = 0.353300% ]  || Test: [ Avg Loss: 0.0069, Accuracy: 99.79%,  FA = 0.224271% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0078, Accuracy: 99.67%, FA = 0.337241% ]  || Test: [ Avg Loss: 0.0058, Accuracy: 99.83%,  FA = 0.174433% ]
# Elapsed Inf. time: 0.01-mins.
#
# 7: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0064, Accuracy: 99.76%, FA = 0.224827% ]  || Test: [ Avg Loss: 0.0051, Accuracy: 99.87%,  FA = 0.149514% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0059, Accuracy: 99.82%, FA = 0.224827% ]  || Test: [ Avg Loss: 0.0048, Accuracy: 99.87%,  FA = 0.124595% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0293, Accuracy: 99.34%, FA = 0.658423% ]  || Test: [ Avg Loss: 0.0109, Accuracy: 99.69%,  FA = 0.448542% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0117, Accuracy: 99.63%, FA = 0.353300% ]  || Test: [ Avg Loss: 0.0098, Accuracy: 99.74%,  FA = 0.323947% ]
# Elapsed Inf. time: 0.01-mins.
#
# ********************************************************************************
# Done! Run: 2 : [Best Test @ epoch 7] || [ Avg loss: 0.005104, Accuracy: 99.87% ]
# ********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# [ss_init: 0.047771 <= -0.191083 ]
# 1: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.3059, Accuracy: 91.29%, FA = 8.158021% ]  || Test: [ Avg Loss: 0.0040, Accuracy: 99.87%,  FA = 0.124595% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0034, Accuracy: 99.90%, FA = 0.080295% ]  || Test: [ Avg Loss: 0.0033, Accuracy: 99.88%,  FA = 0.049838% ]
# Elapsed Inf. time: 0.01-mins.
#
# 3: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0031, Accuracy: 99.89%, FA = 0.080295% ]  || Test: [ Avg Loss: 0.0029, Accuracy: 99.89%,  FA = 0.049838% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0028, Accuracy: 99.91%, FA = 0.096355% ]  || Test: [ Avg Loss: 0.0028, Accuracy: 99.89%,  FA = 0.049838% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0032, Accuracy: 99.90%, FA = 0.064236% ]  || Test: [ Avg Loss: 0.0024, Accuracy: 99.90%,  FA = 0.099676% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0027, Accuracy: 99.92%, FA = 0.064236% ]  || Test: [ Avg Loss: 0.0023, Accuracy: 99.90%,  FA = 0.049838% ]
# Elapsed Inf. time: 0.01-mins.
#
# 7: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0029, Accuracy: 99.87%, FA = 0.112414% ]  || Test: [ Avg Loss: 0.0024, Accuracy: 99.90%,  FA = 0.024919% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0024, Accuracy: 99.93%, FA = 0.048177% ]  || Test: [ Avg Loss: 0.0022, Accuracy: 99.93%,  FA = 0.099676% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0024, Accuracy: 99.91%, FA = 0.064236% ]  || Test: [ Avg Loss: 0.0026, Accuracy: 99.94%,  FA = 0.099676% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0032, Accuracy: 99.92%, FA = 0.032118% ]  || Test: [ Avg Loss: 0.0022, Accuracy: 99.94%,  FA = 0.099676% ]
# Elapsed Inf. time: 0.01-mins.
#
# ********************************************************************************
# Done! Run: 3 : [Best Test @ epoch 9] || [ Avg loss: 0.002603, Accuracy: 99.94% ]
# ********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# [ss_init: 0.062504 <= -0.250016 ]
# 1: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.1529, Accuracy: 96.15%, FA = 7.194476% ]  || Test: [ Avg Loss: 0.0025, Accuracy: 99.90%,  FA = 0.049838% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0031, Accuracy: 99.88%, FA = 0.096355% ]  || Test: [ Avg Loss: 0.0023, Accuracy: 99.94%,  FA = 0.099676% ]
# Elapsed Inf. time: 0.01-mins.
#
# 3: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0027, Accuracy: 99.91%, FA = 0.080295% ]  || Test: [ Avg Loss: 0.0032, Accuracy: 99.89%,  FA = 0.024919% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0030, Accuracy: 99.89%, FA = 0.080295% ]  || Test: [ Avg Loss: 0.0020, Accuracy: 99.93%,  FA = 0.049838% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0027, Accuracy: 99.91%, FA = 0.080295% ]  || Test: [ Avg Loss: 0.0043, Accuracy: 99.90%,  FA = 0.174433% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0039, Accuracy: 99.86%, FA = 0.128473% ]  || Test: [ Avg Loss: 0.0024, Accuracy: 99.91%,  FA = 0.024919% ]
# Elapsed Inf. time: 0.01-mins.
#
# 7: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0037, Accuracy: 99.88%, FA = 0.128473% ]  || Test: [ Avg Loss: 0.0024, Accuracy: 99.91%,  FA = 0.024919% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0017, Accuracy: 99.94%, FA = 0.064236% ]  || Test: [ Avg Loss: 0.0031, Accuracy: 99.89%,  FA = 0.024919% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0035, Accuracy: 99.89%, FA = 0.096355% ]  || Test: [ Avg Loss: 0.0019, Accuracy: 99.95%,  FA = 0.074757% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0029, Accuracy: 99.90%, FA = 0.064236% ]  || Test: [ Avg Loss: 0.0019, Accuracy: 99.94%,  FA = 0.024919% ]
# Elapsed Inf. time: 0.01-mins.
#
# ********************************************************************************
# Done! Run: 4 : [Best Test @ epoch 9] || [ Avg loss: 0.001887, Accuracy: 99.95% ]
# ********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# [ss_init: 0.065275 <= -0.261100 ]
# 1: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.5537, Accuracy: 87.35%, FA = 12.558214% ]  || Test: [ Avg Loss: 0.0240, Accuracy: 99.93%,  FA = 0.124595% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0085, Accuracy: 99.93%, FA = 0.096355% ]  || Test: [ Avg Loss: 0.0049, Accuracy: 99.91%,  FA = 0.074757% ]
# Elapsed Inf. time: 0.01-mins.
#
# 3: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0033, Accuracy: 99.96%, FA = 0.048177% ]  || Test: [ Avg Loss: 0.0029, Accuracy: 99.93%,  FA = 0.124595% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0025, Accuracy: 99.93%, FA = 0.064236% ]  || Test: [ Avg Loss: 0.0025, Accuracy: 99.91%,  FA = 0.149514% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0021, Accuracy: 99.94%, FA = 0.080295% ]  || Test: [ Avg Loss: 0.0026, Accuracy: 99.93%,  FA = 0.024919% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0022, Accuracy: 99.93%, FA = 0.064236% ]  || Test: [ Avg Loss: 0.0023, Accuracy: 99.93%,  FA = 0.124595% ]
# Elapsed Inf. time: 0.01-mins.
#
# 7: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0019, Accuracy: 99.93%, FA = 0.064236% ]  || Test: [ Avg Loss: 0.0024, Accuracy: 99.90%,  FA = 0.174433% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0029, Accuracy: 99.90%, FA = 0.112414% ]  || Test: [ Avg Loss: 0.0022, Accuracy: 99.93%,  FA = 0.049838% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0017, Accuracy: 99.94%, FA = 0.064236% ]  || Test: [ Avg Loss: 0.0031, Accuracy: 99.90%,  FA = 0.174433% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0017, Accuracy: 99.94%, FA = 0.064236% ]  || Test: [ Avg Loss: 0.0021, Accuracy: 99.94%,  FA = 0.024919% ]
# Elapsed Inf. time: 0.01-mins.
#
# *********************************************************************************
# Done! Run: 5 : [Best Test @ epoch 10] || [ Avg loss: 0.002076, Accuracy: 99.94% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# [ss_init: 0.041704 <= -0.166816 ]
# 1: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0586, Accuracy: 97.84%, FA = 4.255661% ]  || Test: [ Avg Loss: 0.0024, Accuracy: 99.91%,  FA = 0.149514% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0018, Accuracy: 99.98%, FA = 0.032118% ]  || Test: [ Avg Loss: 0.0016, Accuracy: 99.96%,  FA = 0.049838% ]
# Elapsed Inf. time: 0.01-mins.
#
# 3: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0018, Accuracy: 99.93%, FA = 0.064236% ]  || Test: [ Avg Loss: 0.0019, Accuracy: 99.93%,  FA = 0.049838% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0016, Accuracy: 99.95%, FA = 0.048177% ]  || Test: [ Avg Loss: 0.0014, Accuracy: 99.96%,  FA = 0.024919% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0021, Accuracy: 99.93%, FA = 0.096355% ]  || Test: [ Avg Loss: 0.0018, Accuracy: 99.94%,  FA = 0.049838% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0012, Accuracy: 99.96%, FA = 0.048177% ]  || Test: [ Avg Loss: 0.0019, Accuracy: 99.93%,  FA = 0.024919% ]
# Elapsed Inf. time: 0.01-mins.
#
# 7: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0017, Accuracy: 99.93%, FA = 0.064236% ]  || Test: [ Avg Loss: 0.0017, Accuracy: 99.94%,  FA = 0.074757% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0015, Accuracy: 99.96%, FA = 0.032118% ]  || Test: [ Avg Loss: 0.0024, Accuracy: 99.91%,  FA = 0.149514% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0014, Accuracy: 99.96%, FA = 0.032118% ]  || Test: [ Avg Loss: 0.0024, Accuracy: 99.91%,  FA = 0.149514% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0020, Accuracy: 99.94%, FA = 0.048177% ]  || Test: [ Avg Loss: 0.0021, Accuracy: 99.94%,  FA = 0.099676% ]
# Elapsed Inf. time: 0.01-mins.
#
# ********************************************************************************
# Done! Run: 6 : [Best Test @ epoch 2] || [ Avg loss: 0.001633, Accuracy: 99.96% ]
# ********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# [ss_init: 0.094245 <= -0.376978 ]
# 1: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.4046, Accuracy: 88.92%, FA = 10.133291% ]  || Test: [ Avg Loss: 0.0040, Accuracy: 99.89%,  FA = 0.199352% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0024, Accuracy: 99.94%, FA = 0.096355% ]  || Test: [ Avg Loss: 0.0027, Accuracy: 99.93%,  FA = 0.124595% ]
# Elapsed Inf. time: 0.01-mins.
#
# 3: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0019, Accuracy: 99.95%, FA = 0.080295% ]  || Test: [ Avg Loss: 0.0023, Accuracy: 99.93%,  FA = 0.124595% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0019, Accuracy: 99.94%, FA = 0.096355% ]  || Test: [ Avg Loss: 0.0023, Accuracy: 99.90%,  FA = 0.174433% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0020, Accuracy: 99.93%, FA = 0.096355% ]  || Test: [ Avg Loss: 0.0023, Accuracy: 99.94%,  FA = 0.099676% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0016, Accuracy: 99.93%, FA = 0.080295% ]  || Test: [ Avg Loss: 0.0026, Accuracy: 99.90%,  FA = 0.124595% ]
# Elapsed Inf. time: 0.01-mins.
#
# 7: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0023, Accuracy: 99.93%, FA = 0.096355% ]  || Test: [ Avg Loss: 0.0029, Accuracy: 99.89%,  FA = 0.124595% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0027, Accuracy: 99.91%, FA = 0.128473% ]  || Test: [ Avg Loss: 0.0044, Accuracy: 99.87%,  FA = 0.174433% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0023, Accuracy: 99.92%, FA = 0.112414% ]  || Test: [ Avg Loss: 0.0015, Accuracy: 99.95%,  FA = 0.074757% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0020, Accuracy: 99.94%, FA = 0.096355% ]  || Test: [ Avg Loss: 0.0024, Accuracy: 99.91%,  FA = 0.000000% ]
# Elapsed Inf. time: 0.01-mins.
#
# ********************************************************************************
# Done! Run: 7 : [Best Test @ epoch 9] || [ Avg loss: 0.001487, Accuracy: 99.95% ]
# ********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# [ss_init: 0.115928 <= -0.463711 ]
# 1: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.5908, Accuracy: 91.67%, FA = 10.534768% ]  || Test: [ Avg Loss: 0.0031, Accuracy: 99.88%,  FA = 0.224271% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0023, Accuracy: 99.93%, FA = 0.096355% ]  || Test: [ Avg Loss: 0.0025, Accuracy: 99.90%,  FA = 0.174433% ]
# Elapsed Inf. time: 0.01-mins.
#
# 3: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0018, Accuracy: 99.95%, FA = 0.064236% ]  || Test: [ Avg Loss: 0.0023, Accuracy: 99.91%,  FA = 0.124595% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0019, Accuracy: 99.94%, FA = 0.080295% ]  || Test: [ Avg Loss: 0.0021, Accuracy: 99.91%,  FA = 0.149514% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0020, Accuracy: 99.93%, FA = 0.064236% ]  || Test: [ Avg Loss: 0.0024, Accuracy: 99.89%,  FA = 0.199352% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0021, Accuracy: 99.92%, FA = 0.112414% ]  || Test: [ Avg Loss: 0.0023, Accuracy: 99.90%,  FA = 0.174433% ]
# Elapsed Inf. time: 0.01-mins.
#
# 7: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0020, Accuracy: 99.92%, FA = 0.144532% ]  || Test: [ Avg Loss: 0.0023, Accuracy: 99.93%,  FA = 0.049838% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0021, Accuracy: 99.93%, FA = 0.080295% ]  || Test: [ Avg Loss: 0.0029, Accuracy: 99.91%,  FA = 0.049838% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0016, Accuracy: 99.95%, FA = 0.064236% ]  || Test: [ Avg Loss: 0.0023, Accuracy: 99.94%,  FA = 0.024919% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0027, Accuracy: 99.93%, FA = 0.096355% ]  || Test: [ Avg Loss: 0.0021, Accuracy: 99.91%,  FA = 0.149514% ]
# Elapsed Inf. time: 0.01-mins.
#
# ********************************************************************************
# Done! Run: 8 : [Best Test @ epoch 9] || [ Avg loss: 0.002339, Accuracy: 99.94% ]
# ********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# [ss_init: 0.125163 <= -0.500653 ]
# 1: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.8996, Accuracy: 85.12%, FA = 16.283925% ]  || Test: [ Avg Loss: 0.0588, Accuracy: 98.27%,  FA = 3.114877% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0109, Accuracy: 99.60%, FA = 0.594187% ]  || Test: [ Avg Loss: 0.0037, Accuracy: 99.89%,  FA = 0.099676% ]
# Elapsed Inf. time: 0.01-mins.
#
# 3: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0024, Accuracy: 99.92%, FA = 0.096355% ]  || Test: [ Avg Loss: 0.0026, Accuracy: 99.93%,  FA = 0.024919% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0019, Accuracy: 99.95%, FA = 0.064236% ]  || Test: [ Avg Loss: 0.0016, Accuracy: 99.95%,  FA = 0.074757% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0021, Accuracy: 99.92%, FA = 0.096355% ]  || Test: [ Avg Loss: 0.0018, Accuracy: 99.94%,  FA = 0.049838% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0019, Accuracy: 99.92%, FA = 0.112414% ]  || Test: [ Avg Loss: 0.0031, Accuracy: 99.90%,  FA = 0.024919% ]
# Elapsed Inf. time: 0.01-mins.
#
# 7: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0023, Accuracy: 99.91%, FA = 0.112414% ]  || Test: [ Avg Loss: 0.0017, Accuracy: 99.95%,  FA = 0.074757% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0023, Accuracy: 99.89%, FA = 0.144532% ]  || Test: [ Avg Loss: 0.0019, Accuracy: 99.94%,  FA = 0.099676% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0019, Accuracy: 99.93%, FA = 0.080295% ]  || Test: [ Avg Loss: 0.0030, Accuracy: 99.93%,  FA = 0.024919% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0018, Accuracy: 99.93%, FA = 0.080295% ]  || Test: [ Avg Loss: 0.0033, Accuracy: 99.91%,  FA = 0.024919% ]
# Elapsed Inf. time: 0.01-mins.
#
# ********************************************************************************
# Done! Run: 9 : [Best Test @ epoch 4] || [ Avg loss: 0.001632, Accuracy: 99.95% ]
# ********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# [ss_init: 0.156328 <= -0.625313 ]
# 1: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 3.3687, Accuracy: 95.35%, FA = 6.744821% ]  || Test: [ Avg Loss: 0.0046, Accuracy: 99.89%,  FA = 0.099676% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0045, Accuracy: 99.93%, FA = 0.064236% ]  || Test: [ Avg Loss: 0.0015, Accuracy: 99.96%,  FA = 0.049838% ]
# Elapsed Inf. time: 0.01-mins.
#
# 3: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0024, Accuracy: 99.96%, FA = 0.016059% ]  || Test: [ Avg Loss: 0.0023, Accuracy: 99.96%,  FA = 0.074757% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0019, Accuracy: 99.97%, FA = 0.032118% ]  || Test: [ Avg Loss: 0.0008, Accuracy: 99.98%,  FA = 0.024919% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0017, Accuracy: 99.97%, FA = 0.032118% ]  || Test: [ Avg Loss: 0.0016, Accuracy: 99.93%,  FA = 0.000000% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0024, Accuracy: 99.93%, FA = 0.048177% ]  || Test: [ Avg Loss: 0.0036, Accuracy: 99.94%,  FA = 0.124595% ]
# Elapsed Inf. time: 0.01-mins.
#
# 7: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0016, Accuracy: 99.98%, FA = 0.032118% ]  || Test: [ Avg Loss: 0.0019, Accuracy: 99.96%,  FA = 0.049838% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0011, Accuracy: 99.96%, FA = 0.048177% ]  || Test: [ Avg Loss: 0.0032, Accuracy: 99.90%,  FA = 0.000000% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0019, Accuracy: 99.97%, FA = 0.032118% ]  || Test: [ Avg Loss: 0.0021, Accuracy: 99.95%,  FA = 0.074757% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0019, Accuracy: 99.95%, FA = 0.032118% ]  || Test: [ Avg Loss: 0.0021, Accuracy: 99.91%,  FA = 0.074757% ]
# Elapsed Inf. time: 0.01-mins.
#
# *********************************************************************************
# Done! Run: 10 : [Best Test @ epoch 4] || [ Avg loss: 0.000828, Accuracy: 99.98% ]
# *********************************************************************************
#
# *********************************************
# Average Prediction Difference = 0.00%
# Effective Test Accuracy = 99.94%, pval=0.0000
# *********************************************
# r:\Programs\Python\Python310\lib\site-packages\scipy\stats\_morestats.py:3255: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "

# %%
# Plots
plotter_v1(cfgs,run_idx=1)

# %% [markdown]
# Using the test (or development) dataset, the average prediction difference gives the average percent of the test (or development) dataset on which the trained network flips its decision.
#
# Subtracting the average prediction difference from the average test-accuracy,
# recallibrates the expected test-accuracy from the trained model, we call this the effective test-accuracy.
#
# Here, 10 statistical training runs leads to a combined 45 prediction comparisons, on which the prediction difference is computed.
