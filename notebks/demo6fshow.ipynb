# %%
#!/scratch/nnenv/bin/python3

# %pip install watermark numpy pandas matplotlib torch torchvision torchaudio | grep -v 'already satisfied'
# %load_ext watermark
# %watermark -v -p watermark,numpy,pandas,matplotlib,torch

#
import math,random,os,sys,copy,time,glob,itertools,shutil,re, json
from scipy.stats import wilcoxon

#
import numpy as np

#
import torch, gc
torch.cuda.empty_cache()
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

import torch.nn as nn
import torch.nn.functional as tf
from torch.utils.data import Dataset,DataLoader
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor, Lambda

import pandas as pd

from pathlib import Path
sys.path[0] = str(Path(sys.path[0]).parent)

#
from demofcns import *
from opts.asgm.torchlasgm import PID
from opts.elpf.fo import LPF
from opts.elpf.esfo import esLPF

# from .. import arcs
from arcs.resnet import ResNetC

print("Is cuda available?", torch.cuda.is_available())
# python3 -m torch.utils.collect_env
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Python implementation: CPython
# Python version       : 3.10.6
# IPython version      : 8.9.0
#
# watermark : 2.3.1
# numpy     : 1.24.1
# pandas    : 1.5.3
# matplotlib: 3.6.3
# torch     : 1.13.1+cu116
#
# Is cuda available? True

# %% [markdown]
# ##### Setup Configurations (Hyperparameters and so on)

# %%
# - is it being run remotely on OSU EECS server?
remotelyrun = 2 # 0 [local computer] | 1 [dalton gpu] | 2 [hpc cluster]

#----------------------
# Load setup config
#----------------------
with open('cfgs.json', 'r') as cfglist:
  cfgs = json.load(cfglist)
  
# setup
cfgs['storedir'] = "../expstore"

# - pick data-set
cfgs["dataset"] = "fmnist"
# - set max. batchsize for each epoch, training runs, training epochs, 
cfgs["batch-size"] = 128 # 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, ...
cfgs['runs'] = 10
cfgs["epochs"] = 30

# -pick computation device
devcnt = torch.cuda.device_count()

# - setup multiprocessing, human signature
# random seed for python libraries
cfgs["seed"] = 2023
cfgs["var_seed"] = 1
worker_seed = cfgs["seed"] % (2**32)
cfgs["num-workers"] = 0 #3
cfgs["human_signature"] = "oas" # for signing experiments ran.


if devcnt > 1:
  cfgs["device"] = torch.device('cuda')
  torch.cuda.set_device(2)
elif devcnt == 1:
  cfgs["device"] = torch.device('cuda')
else:
  cfgs["device"] = torch.device('cpu')
#
if remotelyrun:
  cfgs["remote"] = True
else:
  cfgs["remote"] = False

# %% [markdown]
# ##### (Generate) or Load the Dataset

# %%
#----------------------
# Download/Load Dataset
#----------------------
#----------------------
if not cfgs["remote"]:
  # same dir. as source-code
  data_folder = "../data"
  # result. storage dir
  cfgs['storedir'] = "../expstore"
else:
  if remotelyrun == 1:
    # dalton's scratch on OSU's eecs server
    data_folder = "/scratch/data"
    # result. storage dir
    cfgs['storedir'] = "/scratch/expstore"
  else:
    data_folder = "/nfs/stak/users/somefuno/hpc-share/data"    
    # result. storage dir
    cfgs['storedir'] = "/nfs/stak/users/somefuno/hpc-share/expstore"


# FMNIST
if cfgs["dataset"] == "fmnist":
  train_data = datasets.FashionMNIST(
    root=data_folder,
    train=True,
    download=True,
    transform=ToTensor(),
  )
  test_data = datasets.FashionMNIST(
    root=data_folder,
    train=False,
    download= True,
    transform=ToTensor()
  )
  indim = [28,28]
  class_num = 10
  channels = 1
  val_data = None
  
# Tests 
trainloader = torch.utils.data.DataLoader(train_data, batch_size=cfgs['batch-size'],shuffle=True)
# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)
pass

# %% [markdown]
# ##### Construct Model (Differentiable Function) with  necessary methods.

# %%
'''
Uses ResNetC
'''

class thisNN(nn.Module):
  def __init__(self,num_heads=1,in_feats=[1,28,28],out_feats=10,layers=6, loss_type="mce", outs_class=True, mdl_name="nnresnet") -> None:
    """
    __init__ _summary_

    _extended_summary_

    Args:
        num_heads (int, req): net. output head. Defaults to 1.
        in_feats (int, req): net. input dimension. Defaults to 1.
        out_feats (int, req): net. output dimension per head. Defaults to 1.
        loss_type (str, req): type of loss function Defaults to "mse". ("mse","mce" for multi-class cross-entropy, "bce" binary-class cross-entropy)
        outs_class (bool, req): does model return class indices. Defaults to False, implying it outputs real-valued probabilities. This is also true for loss_type="mse" regardless of user-choice.
    """
    super().__init__()
    self.num_heads = num_heads
    
    # define mdl. params.
    self.cnn = nn.ModuleList()
    for hid in range(num_heads): 
      self.cnn.append(
        ResNetC(in_chans=in_feats[0],stem_chans=64,layers=str(layers),botneck=False,num_classes=out_feats,num_heads=num_heads) 
      )
    self.relu = nn.ReLU()
    self.flatten = nn.Flatten()
    
    # prob.fcn at last output or network head layer
    if loss_type == "bce" or loss_type == "mse":
      self.out = torch.nn.Sigmoid()
    else:
      self.out = torch.nn.Softmax()
    
    self.loss_type = loss_type
    self.outs_class = outs_class
    
    # optimizer
    self.sgm = None
    
    # saved trained model
    self.chkpt = None
    
    
    self.devcnt = torch.cuda.device_count()
    self.device = None
    self.name = mdl_name
    
    if not(loss_type == "mse" or loss_type =="mce" or loss_type == "bce"):
      raise ValueError(f"loss_type='{loss_type}' is not defined for this class")
    if (loss_type == "mse"):
      self.outs_class = False    
    
@clsmethod(thisNN)
def forward(self:thisNN, x):
  # pre-process
  logits = []
  for hid in range(self.num_heads):
    resnet = self.cnn[hid]
    y = resnet(x)  
    logits.append(y)
    
  return logits # List [Tensor]

@clsmethod(thisNN)
def outhead(self:thisNN, x):
  probs = []
  for hid in range(self.num_heads):
    y = self.out(x[hid])
    probs.append(y)  
  return probs # List [Tensor]

# Add necessary functions to train model
add_to_thisnn(thisNN,worker_seed,setseed,cseedwk)

# Use saved mdl as
# mdl <-- load model function
# prediction = mdl.infer(input)

# %% [markdown]
# ##### Run the Network Modeling (Training)

# %%
# Test.

torch.manual_seed(2023)
devcnt = torch.cuda.device_count()

cfgs['mdl_name_dir'] = "nndemo6f_fmnist_resnet6"
isclassifier = True
cfgs["p"] = 1
cfgs["ss_init"] = 1e-3 # default 1e-3
cfgs["eps_ss"] = 1. # default 5e-1
cfgs["weight_decay"] = 1e-5 # default 1e-5
mdl = thisNN(mdl_name=cfgs['mdl_name_dir'])
if devcnt > 0:
    mdl.cuda()
cfgs['pathstr'] = str(mdl.name)+str(cfgs["batch-size"])+"_"+cfgs["dataset"]+"_"+str(cfgs["runs"])+"_"+str(cfgs["epochs"])

mdl.runs(train_data, test_data, cfgs=cfgs, eval_name="Test")
# Out:
# Seed: 2023
# ****************************************************************************************************************
# total params, d=61706
# [p=2, eff. step-size [linear correlation est. (starting := 0.00717572) <= 0.0287029 ]
# aSGM info: (step-size ending := 0), step-size pole : 0.9985],
# [LPF Poles [i
]
# Elapsed Inf. time: 0.03-mins.
#
# [eff. step-size [(starting := 0.00500526)]
# 15: Elapsed Train time: 0.36-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2042, Accuracy: 92.20% ] || Test: [ Avg Loss: 0.3202, Accuracy: 89.55% ]
# Elapsed Inf. time: 0.03-mins.
#
# [eff. step-size [(starting := 0.00492029)]
# 16: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2000, Accuracy: 92.34% ] || Test: [ Avg Loss: 0.3133, Accuracy: 89.63% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.00483526)]
# 17: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1931, Accuracy: 92.62% ] || Test: [ Avg Loss: 0.3307, Accuracy: 89.63% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.00476351)]
# 18: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1910, Accuracy: 92.62% ] || Test: [ Avg Loss: 0.3223, Accuracy: 89.86% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.00468401)]
# 19: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1830, Accuracy: 92.98% ] || Test: [ Avg Loss: 0.3182, Accuracy: 89.63% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.00461367)]
# 20: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1798, Accuracy: 93.06% ] || Test: [ Avg Loss: 0.3219, Accuracy: 89.80% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.00454165)]
# 21: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1738, Accuracy: 93.30% ] || Test: [ Avg Loss: 0.3283, Accuracy: 89.64% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.00448479)]
# 22: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1688, Accuracy: 93.45% ] || Test: [ Avg Loss: 0.3455, Accuracy: 89.76% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.00442786)]
# 23: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1632, Accuracy: 93.65% ] || Test: [ Avg Loss: 0.3491, Accuracy: 89.84% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.00437449)]
# 24: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1605, Accuracy: 93.86% ] || Test: [ Avg Loss: 0.3486, Accuracy: 90.01% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.00431577)]
# 25: Elapsed Train time: 0.36-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1537, Accuracy: 94.08% ] || Test: [ Avg Loss: 0.3550, Accuracy: 89.90% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.0042816)]
# 26: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1544, Accuracy: 94.11% ] || Test: [ Avg Loss: 0.3725, Accuracy: 89.93% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.00423837)]
# 27: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1501, Accuracy: 94.19% ] || Test: [ Avg Loss: 0.3758, Accuracy: 89.78% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.00418955)]
# 28: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1436, Accuracy: 94.52% ] || Test: [ Avg Loss: 0.3778, Accuracy: 89.56% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.00415581)]
# 29: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1431, Accuracy: 94.43% ] || Test: [ Avg Loss: 0.3962, Accuracy: 90.15% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.00412092)]
# 30: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1377, Accuracy: 94.71% ] || Test: [ Avg Loss: 0.3874, Accuracy: 89.58% ]
# Elapsed Inf. time: 0.02-mins.
#
# *********************************************************************************
# Done! Run: 9 : [Best Test @ epoch 29] || [ Avg loss: 0.396151, Accuracy: 90.15% ]
# *********************************************************************************
#
# ****************************************************************************************************************
# total params, d=61706
# [p=2, eff. step-size [linear correlation est. (starting := 0.00712388) <= 0.0284955 ]
# aSGM info: (step-size ending := 0), step-size pole : 0.9985],
# [LPF Poles [i,o] : 0.9, 1e-05]
# ****************************************************************************************************************
#
# 1: Elapsed Train time: 0.30-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5629, Accuracy: 79.79% ] || Test: [ Avg Loss: 0.4188, Accuracy: 84.83% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.00694507)]
# 2: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3686, Accuracy: 86.40% ] || Test: [ Avg Loss: 0.3545, Accuracy: 86.91% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.00661316)]
# 3: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3293, Accuracy: 87.84% ] || Test: [ Avg Loss: 0.3279, Accuracy: 87.83% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.0063359)]
# 4: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3026, Accuracy: 88.85% ] || Test: [ Avg Loss: 0.3244, Accuracy: 88.24% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.00610535)]
# 5: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2827, Accuracy: 89.41% ] || Test: [ Avg Loss: 0.3098, Accuracy: 88.88% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.00585785)]
# 6: Elapsed Train time: 0.32-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2668, Accuracy: 90.02% ] || Test: [ Avg Loss: 0.3162, Accuracy: 88.90% ]
# Elapsed Inf. time: 0.03-mins.
#
# [eff. step-size [(starting := 0.0056111)]
# 7: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2525, Accuracy: 90.53% ] || Test: [ Avg Loss: 0.3101, Accuracy: 88.91% ]
# Elapsed Inf. time: 0.03-mins.
#
# [eff. step-size [(starting := 0.0054058)]
# 8: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2434, Accuracy: 90.81% ] || Test: [ Avg Loss: 0.3016, Accuracy: 89.43% ]
# Elapsed Inf. time: 0.03-mins.
#
# [eff. step-size [(starting := 0.00521792)]
# 9: Elapsed Train time: 0.36-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2293, Accuracy: 91.31% ] || Test: [ Avg Loss: 0.2902, Accuracy: 89.98% ]
# Elapsed Inf. time: 0.03-mins.
#
# [eff. step-size [(starting := 0.00507146)]
# 10: Elapsed Train time: 0.36-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2198, Accuracy: 91.69% ] || Test: [ Avg Loss: 0.3283, Accuracy: 88.37% ]
# Elapsed Inf. time: 0.03-mins.
#
# [eff. step-size [(starting := 0.00493748)]
# 11: Elapsed Train time: 0.36-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2105, Accuracy: 91.95% ] || Test: [ Avg Loss: 0.2983, Accuracy: 90.11% ]
# Elapsed Inf. time: 0.03-mins.
#
# [eff. step-size [(starting := 0.00482014)]
# 12: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.2046, Accuracy: 92.20% ] || Test: [ Avg Loss: 0.3062, Accuracy: 89.73% ]
# Elapsed Inf. time: 0.03-mins.
#
# [eff. step-size [(starting := 0.00470112)]
# 13: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1959, Accuracy: 92.40% ] || Test: [ Avg Loss: 0.3073, Accuracy: 90.06% ]
# Elapsed Inf. time: 0.03-mins.
#
# [eff. step-size [(starting := 0.00460323)]
# 14: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1853, Accuracy: 92.80% ] || Test: [ Avg Loss: 0.3136, Accuracy: 90.05% ]
# Elapsed Inf. time: 0.03-mins.
#
# [eff. step-size [(starting := 0.00450918)]
# 15: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1834, Accuracy: 92.99% ] || Test: [ Avg Loss: 0.3321, Accuracy: 89.72% ]
# Elapsed Inf. time: 0.03-mins.
#
# [eff. step-size [(starting := 0.00443783)]
# 16: Elapsed Train time: 0.36-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1757, Accuracy: 93.20% ] || Test: [ Avg Loss: 0.3320, Accuracy: 90.11% ]
# Elapsed Inf. time: 0.03-mins.
#
# [eff. step-size [(starting := 0.00436463)]
# 17: Elapsed Train time: 0.36-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1707, Accuracy: 93.44% ] || Test: [ Avg Loss: 0.3422, Accuracy: 89.86% ]
# Elapsed Inf. time: 0.03-mins.
#
# [eff. step-size [(starting := 0.00429324)]
# 18: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1622, Accuracy: 93.78% ] || Test: [ Avg Loss: 0.3367, Accuracy: 90.23% ]
# Elapsed Inf. time: 0.03-mins.
#
# [eff. step-size [(starting := 0.00423438)]
# 19: Elapsed Train time: 0.36-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1561, Accuracy: 93.97% ] || Test: [ Avg Loss: 0.3327, Accuracy: 90.02% ]
# Elapsed Inf. time: 0.03-mins.
#
# [eff. step-size [(starting := 0.0041807)]
# 20: Elapsed Train time: 0.36-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1510, Accuracy: 94.13% ] || Test: [ Avg Loss: 0.3496, Accuracy: 90.05% ]
# Elapsed Inf. time: 0.03-mins.
#
# [eff. step-size [(starting := 0.00412983)]
# 21: Elapsed Train time: 0.36-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1456, Accuracy: 94.32% ] || Test: [ Avg Loss: 0.3564, Accuracy: 89.65% ]
# Elapsed Inf. time: 0.03-mins.
#
# [eff. step-size [(starting := 0.00407387)]
# 22: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1399, Accuracy: 94.65% ] || Test: [ Avg Loss: 0.3653, Accuracy: 89.98% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.00402341)]
# 23: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1358, Accuracy: 94.67% ] || Test: [ Avg Loss: 0.3733, Accuracy: 89.91% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.00398146)]
# 24: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1351, Accuracy: 94.70% ] || Test: [ Avg Loss: 0.3956, Accuracy: 89.52% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.0039404)]
# 25: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1283, Accuracy: 95.05% ] || Test: [ Avg Loss: 0.3836, Accuracy: 89.90% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.00390093)]
# 26: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1257, Accuracy: 95.11% ] || Test: [ Avg Loss: 0.3928, Accuracy: 89.68% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.00386679)]
# 27: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1219, Accuracy: 95.33% ] || Test: [ Avg Loss: 0.4051, Accuracy: 89.84% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.00383169)]
# 28: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1176, Accuracy: 95.48% ] || Test: [ Avg Loss: 0.4083, Accuracy: 89.20% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.00379037)]
# 29: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1144, Accuracy: 95.60% ] || Test: [ Avg Loss: 0.4388, Accuracy: 89.90% ]
# Elapsed Inf. time: 0.02-mins.
#
# [eff. step-size [(starting := 0.00375822)]
# 30: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.1085, Accuracy: 95.78% ] || Test: [ Avg Loss: 0.4371, Accuracy: 89.73% ]
# Elapsed Inf. time: 0.02-mins.
#
# **********************************************************************************
# Done! Run: 10 : [Best Test @ epoch 18] || [ Avg loss: 0.336662, Accuracy: 90.23% ]
# **********************************************************************************
#
# *********************************************
# Average Prediction Difference = 0.09%
# Effective Test Accuracy = 89.91%, pval=0.0000
# *********************************************

# %%
# Plots
plotter_v1(cfgs,run_idx=1)
