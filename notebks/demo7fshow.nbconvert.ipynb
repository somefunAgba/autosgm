# %%
#!/scratch/nnenv/bin/python3

# %pip install watermark numpy pandas matplotlib torch torchvision torchaudio | grep -v 'already satisfied'
# %load_ext watermark
# %watermark -v -p watermark,numpy,pandas,matplotlib,torch

#
import math,random,os,sys,copy,time,glob,itertools,shutil,re, json
from scipy.stats import wilcoxon

#
import numpy as np

#
import torch, gc
torch.cuda.empty_cache()
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

import torch.nn as nn
import torch.nn.functional as tf
from torch.utils.data import Dataset,DataLoader
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor, Lambda

import pandas as pd

from pathlib import Path
sys.path[0] = str(Path(sys.path[0]).parent)

#
from demofcns import *
from opts.asgm.torchlasgm import PID
from opts.elpf.fo import LPF
from opts.elpf.esfo import esLPF

# from .. import arcs
from arcs.resnet import ResNetC

# python3 -m torch.utils.collect_env
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Python implementation: CPython
# Python version       : 3.10.6
# IPython version      : 8.7.0
#
# watermark : 2.3.1
# numpy     : 1.23.1
# pandas    : 1.4.3
# matplotlib: 3.5.3
# torch     : 1.12.0+cu116

# %% [markdown]
# ##### Setup Configurations (Hyperparameters and so on)

# %%
# - is it being run remotely on OSU EECS server?
remotelyrun = 1 # 0 | 1

#----------------------
# Load setup config
#----------------------
with open('cfgs.json', 'r') as cfglist:
  cfgs = json.load(cfglist)
  
# setup
cfgs['storedir'] = "../expstore"

# - pick data-set
cfgs["dataset"] = "cifar10"
# - set max. batchsize for each epoch, training runs, training epochs, 
cfgs["batch-size"] = 128 # 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, ...
cfgs['runs'] = 10
cfgs["epochs"] = 30

# -pick computation device
devcnt = torch.cuda.device_count()

# - setup multiprocessing, human signature
# random seed for python libraries
cfgs["seed"] = 2023
cfgs["var_seed"] = 1
worker_seed = cfgs["seed"] % (2**32)
cfgs["num-workers"] = 0 #3
cfgs["human_signature"] = "oas" # for signing experiments ran.


if devcnt > 1:
  cfgs["device"] = torch.device('cuda') # "cuda:1"
  torch.cuda.set_device(1)
elif devcnt == 1:
  cfgs["device"] = torch.device('cuda')
else:
  cfgs["device"] = torch.device('cpu')
#
if remotelyrun:
  cfgs["remote"] = True
else:
  cfgs["remote"] = False

# %% [markdown]
# ##### (Generate) or Load the Dataset

# %%
#----------------------
# Download/Load Dataset
#----------------------
if not cfgs["remote"]:
  # same dir. as source-code
  data_folder = "../data"
else:
  # dalton's scratch on OSU's eecs server
  data_folder = "/scratch/data"


# CIFAR10
if cfgs["dataset"] == "cifar10":
    train_data = datasets.CIFAR10(
      root=data_folder+"/CIFAR10",
      train=True,
      download=True,
      transform=transforms.Compose([ToTensor(),        
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),]),
    )
    test_data = datasets.CIFAR10(
      root=data_folder+"/CIFAR10",
      train=False,
      download= True,
      transform=transforms.Compose([ToTensor(),  
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),])
    )
    indim = [3,32,32]
    class_num = 10
    channels = indim[0]
    val_data = None
    
# Tests 
trainloader = torch.utils.data.DataLoader(train_data, batch_size=cfgs['batch-size'],shuffle=True)
# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)
pass
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ##### Construct Model (Differentiable Function) with  necessary methods.

# %%
'''
Uses ResNetC
'''

class thisNN(nn.Module):
  def __init__(self,num_heads=1,in_feats=[3,32,32],out_feats=10,layers=6, loss_type="mce", outs_class=True, mdl_name="nnresnet") -> None:
    """
    __init__ _summary_

    _extended_summary_

    Args:
        num_heads (int, req): net. output head. Defaults to 1.
        in_feats (int, req): net. input dimension. Defaults to 1.
        out_feats (int, req): net. output dimension per head. Defaults to 1.
        loss_type (str, req): type of loss function Defaults to "mse". ("mse","mce" for multi-class cross-entropy, "bce" binary-class cross-entropy)
        outs_class (bool, req): does model return class indices. Defaults to False, implying it outputs real-valued probabilities. This is also true for loss_type="mse" regardless of user-choice.
    """
    super().__init__()
    self.num_heads = num_heads
    
    # define mdl. params.
    self.cnn = nn.ModuleList()
    for hid in range(num_heads): 
      self.cnn.append(
        ResNetC(in_chans=in_feats[0],stem_chans=64,layers=str(layers),botneck=False,num_classes=out_feats,num_heads=num_heads) 
      )
    self.relu = nn.ReLU()
    self.flatten = nn.Flatten()
    
    # prob.fcn at last output or network head layer
    if loss_type == "bce" or loss_type == "mse":
      self.out = torch.nn.Sigmoid()
    else:
      self.out = torch.nn.Softmax()
    
    self.loss_type = loss_type
    self.outs_class = outs_class
    
    # optimizer
    self.sgm = None
    
    # saved trained model
    self.chkpt = None
    
    
    self.devcnt = torch.cuda.device_count()
    self.device = None
    self.name = mdl_name
    
    if not(loss_type == "mse" or loss_type =="mce" or loss_type == "bce"):
      raise ValueError(f"loss_type='{loss_type}' is not defined for this class")
    if (loss_type == "mse"):
      self.outs_class = False    
    
@clsmethod(thisNN)
def forward(self:thisNN, x):
  # pre-process
  logits = []
  for hid in range(self.num_heads):
    resnet = self.cnn[hid]
    y = resnet(x)  
    logits.append(y)
    
  return logits # List [Tensor]

@clsmethod(thisNN)
def outhead(self:thisNN, x):
  probs = []
  for hid in range(self.num_heads):
    y = self.out(x[hid])
    probs.append(y)  
  return probs # List [Tensor]

# Add necessary functions to train model
add_to_thisnn(thisNN,worker_seed,setseed,cseedwk)

# Use saved mdl as
# mdl <-- load model function
# prediction = mdl.infer(input)

# %% [markdown]
# ##### Run the Network Modeling (Training)

# %%
# Test.

torch.manual_seed(2023)
devcnt = torch.cuda.device_count()

cfgs['mdl_name_dir'] = "nndemo7f_cifar10_resnet6"
isclassifier = True
cfgs["ss_init"] = 1e-3 # default 1e-3
cfgs["eps_ss"] = 1 # default 5e-1
cfgs["weight_decay"] = 1e-5 # default 1e-5
mdl = thisNN(mdl_name=cfgs['mdl_name_dir'])
if devcnt > 0:
    mdl.cuda()
cfgs['pathstr'] = str(mdl.name)+str(cfgs["batch-size"])+"_"+cfgs["dataset"]+"_"+str(cfgs["runs"])+"_"+str(cfgs["epochs"])

mdl.runs(train_data, test_data, cfgs=cfgs, eval_name="Test")
# Out:
# Seed: 2023
# **************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 1],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# **************************************************************************************************************************************************
#
# calc.: 0.000136, pvec2norm: 42.282299, gvec2norm: 9.312165
# ss_calc: 0.001264
# ss_used: 0.001264
# 1: Elapsed Train time: 1.21-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 1.5579, Accuracy: 44.00% ] || Test: [ Avg Loss: 1.3565, Accuracy: 52.13% ]
# Elapsed Inf. time: 0.07-mins.
#
# 2: Elapsed Train time: 1.22-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 1.1527, Accuracy: 59.01% ] || Test: [ Avg Loss: 1.1376, Accuracy: 60.49% ]
# Elapsed Inf. time: 0.07-mins.
#
# 3: Elapsed Train time: 1.08-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.9859, Accuracy: 65.04% ] || Test: [ Avg Loss: 1.0994, Accuracy: 61.53% ]
# Elapsed Inf. time: 0.07-mins.
#
# 4: Elapsed Train time: 0.96-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.8859, Accuracy: 68.96% ] || Test: [ Avg Loss: 0.9524, Accuracy: 66.31% ]
# Elapsed Inf. time: 0.07-mins.
#
# 5: Elapsed Train time: 1.01-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.
mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3531, Accuracy: 87.87% ] || Test: [ Avg Loss: 0.4632, Accuracy: 84.78% ]
# Elapsed Inf. time: 0.07-mins.
#
# 25: Elapsed Train time: 1.29-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3430, Accuracy: 88.19% ] || Test: [ Avg Loss: 0.4655, Accuracy: 84.68% ]
# Elapsed Inf. time: 0.07-mins.
#
# 26: Elapsed Train time: 1.21-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3338, Accuracy: 88.60% ] || Test: [ Avg Loss: 0.4674, Accuracy: 84.68% ]
# Elapsed Inf. time: 0.07-mins.
#
# 27: Elapsed Train time: 1.29-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3291, Accuracy: 88.51% ] || Test: [ Avg Loss: 0.4623, Accuracy: 84.70% ]
# Elapsed Inf. time: 0.07-mins.
#
# 28: Elapsed Train time: 1.25-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3237, Accuracy: 88.86% ] || Test: [ Avg Loss: 0.4553, Accuracy: 85.15% ]
# Elapsed Inf. time: 0.07-mins.
#
# 29: Elapsed Train time: 1.27-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3166, Accuracy: 88.98% ] || Test: [ Avg Loss: 0.4754, Accuracy: 84.45% ]
# Elapsed Inf. time: 0.07-mins.
#
# 30: Elapsed Train time: 1.30-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3124, Accuracy: 89.06% ] || Test: [ Avg Loss: 0.4885, Accuracy: 84.31% ]
# Elapsed Inf. time: 0.07-mins.
#
# *********************************************************************************
# Done! Run: 9 : [Best Test @ epoch 28] || [ Avg loss: 0.455324, Accuracy: 85.15% ]
# *********************************************************************************
#
# **************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 1],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# **************************************************************************************************************************************************
#
# calc.: 0.000136, pvec2norm: 42.489346, gvec2norm: 13.216495
# ss_calc: 0.001803
# ss_used: 0.001803
# 1: Elapsed Train time: 1.25-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 1.5638, Accuracy: 44.07% ] || Test: [ Avg Loss: 1.4373, Accuracy: 49.52% ]
# Elapsed Inf. time: 0.07-mins.
#
# 2: Elapsed Train time: 1.26-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 1.1677, Accuracy: 58.45% ] || Test: [ Avg Loss: 1.2195, Accuracy: 57.41% ]
# Elapsed Inf. time: 0.07-mins.
#
# 3: Elapsed Train time: 1.29-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.9800, Accuracy: 65.33% ] || Test: [ Avg Loss: 1.0399, Accuracy: 64.71% ]
# Elapsed Inf. time: 0.07-mins.
#
# 4: Elapsed Train time: 1.30-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.8648, Accuracy: 69.72% ] || Test: [ Avg Loss: 0.9055, Accuracy: 68.60% ]
# Elapsed Inf. time: 0.07-mins.
#
# 5: Elapsed Train time: 1.22-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.7808, Accuracy: 72.74% ] || Test: [ Avg Loss: 0.7769, Accuracy: 73.25% ]
# Elapsed Inf. time: 0.07-mins.
#
# 6: Elapsed Train time: 1.26-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.7155, Accuracy: 75.08% ] || Test: [ Avg Loss: 0.7570, Accuracy: 74.22% ]
# Elapsed Inf. time: 0.07-mins.
#
# 7: Elapsed Train time: 1.03-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6636, Accuracy: 76.97% ] || Test: [ Avg Loss: 0.8109, Accuracy: 71.96% ]
# Elapsed Inf. time: 0.07-mins.
#
# 8: Elapsed Train time: 0.95-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6229, Accuracy: 78.51% ] || Test: [ Avg Loss: 0.6901, Accuracy: 76.31% ]
# Elapsed Inf. time: 0.07-mins.
#
# 9: Elapsed Train time: 1.31-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5880, Accuracy: 79.79% ] || Test: [ Avg Loss: 0.7220, Accuracy: 76.65% ]
# Elapsed Inf. time: 0.07-mins.
#
# 10: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5564, Accuracy: 80.86% ] || Test: [ Avg Loss: 0.6306, Accuracy: 78.21% ]
# Elapsed Inf. time: 0.07-mins.
#
# 11: Elapsed Train time: 1.02-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5254, Accuracy: 81.96% ] || Test: [ Avg Loss: 0.6451, Accuracy: 78.37% ]
# Elapsed Inf. time: 0.07-mins.
#
# 12: Elapsed Train time: 0.97-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5123, Accuracy: 82.52% ] || Test: [ Avg Loss: 0.6094, Accuracy: 79.61% ]
# Elapsed Inf. time: 0.07-mins.
#
# 13: Elapsed Train time: 1.26-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4876, Accuracy: 83.38% ] || Test: [ Avg Loss: 0.5424, Accuracy: 81.73% ]
# Elapsed Inf. time: 0.07-mins.
#
# 14: Elapsed Train time: 1.15-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4668, Accuracy: 84.01% ] || Test: [ Avg Loss: 0.5536, Accuracy: 81.43% ]
# Elapsed Inf. time: 0.07-mins.
#
# 15: Elapsed Train time: 1.22-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4504, Accuracy: 84.50% ] || Test: [ Avg Loss: 0.5249, Accuracy: 81.88% ]
# Elapsed Inf. time: 0.07-mins.
#
# 16: Elapsed Train time: 1.27-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4431, Accuracy: 84.66% ] || Test: [ Avg Loss: 0.5556, Accuracy: 81.97% ]
# Elapsed Inf. time: 0.07-mins.
#
# 17: Elapsed Train time: 1.23-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4267, Accuracy: 85.25% ] || Test: [ Avg Loss: 0.5433, Accuracy: 82.01% ]
# Elapsed Inf. time: 0.07-mins.
#
# 18: Elapsed Train time: 1.31-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4104, Accuracy: 85.99% ] || Test: [ Avg Loss: 0.5315, Accuracy: 82.64% ]
# Elapsed Inf. time: 0.07-mins.
#
# 19: Elapsed Train time: 1.29-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4011, Accuracy: 86.19% ] || Test: [ Avg Loss: 0.5240, Accuracy: 82.27% ]
# Elapsed Inf. time: 0.07-mins.
#
# 20: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3887, Accuracy: 86.56% ] || Test: [ Avg Loss: 0.5085, Accuracy: 83.20% ]
# Elapsed Inf. time: 0.07-mins.
#
# 21: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3820, Accuracy: 86.81% ] || Test: [ Avg Loss: 0.5034, Accuracy: 83.50% ]
# Elapsed Inf. time: 0.07-mins.
#
# 22: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3719, Accuracy: 87.26% ] || Test: [ Avg Loss: 0.5434, Accuracy: 81.94% ]
# Elapsed Inf. time: 0.07-mins.
#
# 23: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3665, Accuracy: 87.53% ] || Test: [ Avg Loss: 0.4719, Accuracy: 84.10% ]
# Elapsed Inf. time: 0.07-mins.
#
# 24: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3522, Accuracy: 87.78% ] || Test: [ Avg Loss: 0.5058, Accuracy: 83.17% ]
# Elapsed Inf. time: 0.07-mins.
#
# 25: Elapsed Train time: 1.39-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3425, Accuracy: 88.16% ] || Test: [ Avg Loss: 0.5039, Accuracy: 83.22% ]
# Elapsed Inf. time: 0.07-mins.
#
# 26: Elapsed Train time: 1.39-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3387, Accuracy: 88.39% ] || Test: [ Avg Loss: 0.5376, Accuracy: 82.90% ]
# Elapsed Inf. time: 0.07-mins.
#
# 27: Elapsed Train time: 1.40-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3376, Accuracy: 88.29% ] || Test: [ Avg Loss: 0.4694, Accuracy: 84.44% ]
# Elapsed Inf. time: 0.07-mins.
#
# 28: Elapsed Train time: 1.29-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3277, Accuracy: 88.78% ] || Test: [ Avg Loss: 0.4793, Accuracy: 84.02% ]
# Elapsed Inf. time: 0.07-mins.
#
# 29: Elapsed Train time: 1.30-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3166, Accuracy: 88.97% ] || Test: [ Avg Loss: 0.4750, Accuracy: 84.28% ]
# Elapsed Inf. time: 0.07-mins.
#
# 30: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3112, Accuracy: 89.31% ] || Test: [ Avg Loss: 0.4475, Accuracy: 84.72% ]
# Elapsed Inf. time: 0.07-mins.
#
# **********************************************************************************
# Done! Run: 10 : [Best Test @ epoch 30] || [ Avg loss: 0.447544, Accuracy: 84.72% ]
# **********************************************************************************
#
# *********************************************
# Average Prediction Difference = 0.15%
# Effective Test Accuracy = 85.05%, pval=0.0000
# *********************************************

# %%
# Plots
plotter_v1(cfgs,run_idx=1)
