# %%
#!/scratch/nnenv/bin/python3

# %pip install watermark numpy pandas matplotlib torch torchvision torchaudio | grep -v 'already satisfied'
# %load_ext watermark
# %watermark -v -p watermark,numpy,pandas,matplotlib,torch

#
import math,random,os,sys,copy,time,glob,itertools,shutil,re, json
from scipy.stats import wilcoxon

#
import numpy as np

#
import torch, gc
torch.cuda.empty_cache()
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

import torch.nn as nn
import torch.nn.functional as tf
from torch.utils.data import Dataset,DataLoader
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor, Lambda

import pandas as pd

from pathlib import Path
sys.path[0] = str(Path(sys.path[0]).parent)

#
from demofcns import *
from opts.asgm.torchlasgm import PID
from opts.elpf.fo import LPF
from opts.elpf.esfo import esLPF

# from .. import arcs
from arcs.resnet import ResNetC

# python3 -m torch.utils.collect_env
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Python implementation: CPython
# Python version       : 3.10.6
# IPython version      : 8.7.0
#
# watermark : 2.3.1
# numpy     : 1.23.1
# pandas    : 1.4.3
# matplotlib: 3.5.3
# torch     : 1.12.0+cu116

# %% [markdown]
# ##### Setup Configurations (Hyperparameters and so on)

# %%
# - is it being run remotely on OSU EECS server?
remotelyrun = 1 # 0 | 1

#----------------------
# Load setup config
#----------------------
with open('cfgs.json', 'r') as cfglist:
  cfgs = json.load(cfglist)
  
# setup
cfgs['storedir'] = "../expstore"

# - pick data-set
cfgs["dataset"] = "cifar10"
# - set max. batchsize for each epoch, training runs, training epochs, 
cfgs["batch-size"] = 128 # 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, ...
cfgs['runs'] = 10
cfgs["epochs"] = 30

# -pick computation device
devcnt = torch.cuda.device_count()

# - setup multiprocessing, human signature
# random seed for python libraries
cfgs["seed"] = 2023
cfgs["var_seed"] = 1
worker_seed = cfgs["seed"] % (2**32)
cfgs["num-workers"] = 0 #3
cfgs["human_signature"] = "oas" # for signing experiments ran.


if devcnt > 1:
  cfgs["device"] = torch.device('cuda') # "cuda:1"
  torch.cuda.set_device(1)
elif devcnt == 1:
  cfgs["device"] = torch.device('cuda')
else:
  cfgs["device"] = torch.device('cpu')
#
if remotelyrun:
  cfgs["remote"] = True
else:
  cfgs["remote"] = False

# %% [markdown]
# ##### (Generate) or Load the Dataset

# %%
#----------------------
# Download/Load Dataset
#----------------------
if not cfgs["remote"]:
  # same dir. as source-code
  data_folder = "../data"
else:
  # dalton's scratch on OSU's eecs server
  data_folder = "/scratch/data"


# CIFAR10
if cfgs["dataset"] == "cifar10":
    train_data = datasets.CIFAR10(
      root=data_folder+"/CIFAR10",
      train=True,
      download=True,
      transform=transforms.Compose([ToTensor(),        
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),]),
    )
    test_data = datasets.CIFAR10(
      root=data_folder+"/CIFAR10",
      train=False,
      download= True,
      transform=transforms.Compose([ToTensor(),  
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),])
    )
    indim = [3,32,32]
    class_num = 10
    channels = indim[0]
    val_data = None
    
# Tests 
trainloader = torch.utils.data.DataLoader(train_data, batch_size=cfgs['batch-size'],shuffle=True)
# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)
pass
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ##### Construct Model (Differentiable Function) with  necessary methods.

# %%
'''
Uses ResNetC
'''

class thisNN(nn.Module):
  def __init__(self,num_heads=1,in_feats=[3,32,32],out_feats=10,layers=6, loss_type="mce", outs_class=True, mdl_name="nnresnet") -> None:
    """
    __init__ _summary_

    _extended_summary_

    Args:
        num_heads (int, req): net. output head. Defaults to 1.
        in_feats (int, req): net. input dimension. Defaults to 1.
        out_feats (int, req): net. output dimension per head. Defaults to 1.
        loss_type (str, req): type of loss function Defaults to "mse". ("mse","mce" for multi-class cross-entropy, "bce" binary-class cross-entropy)
        outs_class (bool, req): does model return class indices. Defaults to False, implying it outputs real-valued probabilities. This is also true for loss_type="mse" regardless of user-choice.
    """
    super().__init__()
    self.num_heads = num_heads
    
    # define mdl. params.
    self.cnn = nn.ModuleList()
    for hid in range(num_heads): 
      self.cnn.append(
        ResNetC(in_chans=in_feats[0],stem_chans=64,layers=str(layers),botneck=False,num_classes=out_feats,num_heads=num_heads) 
      )
    self.relu = nn.ReLU()
    self.flatten = nn.Flatten()
    
    # prob.fcn at last output or network head layer
    if loss_type == "bce" or loss_type == "mse":
      self.out = torch.nn.Sigmoid()
    else:
      self.out = torch.nn.Softmax()
    
    self.loss_type = loss_type
    self.outs_class = outs_class
    
    # optimizer
    self.sgm = None
    
    # saved trained model
    self.chkpt = None
    
    
    self.devcnt = torch.cuda.device_count()
    self.device = None
    self.name = mdl_name
    
    if not(loss_type == "mse" or loss_type =="mce" or loss_type == "bce"):
      raise ValueError(f"loss_type='{loss_type}' is not defined for this class")
    if (loss_type == "mse"):
      self.outs_class = False    
    
@clsmethod(thisNN)
def forward(self:thisNN, x):
  # pre-process
  logits = []
  for hid in range(self.num_heads):
    resnet = self.cnn[hid]
    y = resnet(x)  
    logits.append(y)
    
  return logits # List [Tensor]

@clsmethod(thisNN)
def outhead(self:thisNN, x):
  probs = []
  for hid in range(self.num_heads):
    y = self.out(x[hid])
    probs.append(y)  
  return probs # List [Tensor]

# Add necessary functions to train model
add_to_thisnn(thisNN,worker_seed,setseed,cseedwk)

# Use saved mdl as
# mdl <-- load model function
# prediction = mdl.infer(input)

# %% [markdown]
# ##### Run the Network Modeling (Training)

# %%
# Test.

torch.manual_seed(2023)
devcnt = torch.cuda.device_count()

cfgs['mdl_name_dir'] = "nndemo7_cifar10_resnet6"
isclassifier = True
cfgs["ss_init"] = 1e-3 # default 1e-3
cfgs["eps_ss"] = 5e-1 # default 5e-1
cfgs["weight_decay"] = 1e-5 # default 1e-5
mdl = thisNN(mdl_name=cfgs['mdl_name_dir'])
if devcnt > 0:
    mdl.cuda()
cfgs['pathstr'] = str(mdl.name)+str(cfgs["batch-size"])+"_"+cfgs["dataset"]+"_"+str(cfgs["runs"])+"_"+str(cfgs["epochs"])

mdl.runs(train_data, test_data, cfgs=cfgs, eval_name="Test")
# Out:
# Seed: 2023
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9982],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# calc.: 0.000136, pvec2norm: 42.282299, gvec2norm: 9.312165
# ss_calc: 0.001264
# ss_used: 0.001264
# 1: Elapsed Train time: 1.32-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 1.5482, Accuracy: 44.36% ] || Test: [ Avg Loss: 1.2972, Accuracy: 53.61% ]
# Elapsed Inf. time: 0.07-mins.
#
# 2: Elapsed Train time: 1.39-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 1.1752, Accuracy: 58.05% ] || Test: [ Avg Loss: 1.2059, Accuracy: 57.98% ]
# Elapsed Inf. time: 0.07-mins.
#
# 3: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 1.0118, Accuracy: 64.12% ] || Test: [ Avg Loss: 1.0525, Accuracy: 62.89% ]
# Elapsed Inf. time: 0.07-mins.
#
# 4: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.9195, Accuracy: 67.79% ] || Test: [ Avg Loss: 0.9142, Accuracy: 67.94% ]
# Elapsed Inf. time: 0.07-mins.
#
# 5: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.8440, Accuracy: 70.52% ] || Test: [ Avg Loss: 0.8406, Accuracy: 70.00% ]
# Elapsed Inf. time: 0.07-mins.
#
# 6: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.7799, Accuracy: 72.94% ] || Test: [ Avg Loss: 0.7947, Accuracy: 72.25% ]
# Elapsed Inf. time: 0.07-mins.
#
# 7: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.7302, Accuracy: 74.54% ] || Test: [ Avg Loss: 0.7623, Accuracy: 73.96% ]
# Elapsed Inf. time: 0.07-mins.
#
# 8: Elapsed Train time: 1.33-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6818, Accuracy: 76.33% ] || Test: [ Avg Loss: 0.7259, Accuracy: 75.00% ]
# Elapsed Inf. time: 0.07-mins.
#
# 9: Elapsed Train time: 1.30-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6474, Accuracy: 77.59% ] || Test: [ Avg Loss: 0.7039, Accuracy: 76.55% ]
# Elapsed Inf. time: 0.07-mins.
#
# 10: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6189, Accuracy: 78.62% ] || Test: [ Avg Loss: 0.6393, Accuracy: 78.05% ]
# Elapsed Inf. time: 0.07-mins.
#
# 11: Elapsed Train time: 1.32-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5897, Accuracy: 79.67% ] || Test: [ Avg Loss: 0.6610, Accuracy: 77.54% ]
# Elapsed Inf. time: 0.07-mins.
#
# 12: Elapsed Train time: 1.30-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5632, Accuracy: 80.69% ] || Test: [ Avg Loss: 0.6717, Accuracy: 77.48% ]
# Elapsed Inf. time: 0.07-mins.
#
# 13: Elapsed Train time: 1.30-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5432, Accuracy: 81.25% ] || Test: [ Avg Loss: 0.6450, Accuracy: 77.74% ]
# Elapsed Inf. time: 0.07-mins.
#
# 14: Elapsed Train time: 1.34-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5250, Accuracy: 81.96% ] || Test: [ Avg Loss: 0.6112, Accuracy: 79.09% ]
# Elapsed Inf. time: 0.07-mins.
#
# 15: Elapsed Train time: 1.30-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5082, Accuracy: 82.47% ] || Test: [ Avg Loss: 0.5664, Accuracy: 80.73% ]
# Elapsed Inf. time: 0.07-mins.
#
# 16: Elapsed Train time: 1.29-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4907, Accuracy: 83.11% ] || Test: [ Avg Loss: 0.5257, Accuracy: 82.07% ]
# Elapsed Inf. time: 0.07-mins.
#
# 17: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4773, Accuracy: 83.60% ] || Test: [ Avg Loss: 0.5113, Accuracy: 82.81% ]
# Elapsed Inf. time: 0.07-mins.
#
# 18: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4613, Accuracy: 84.22% ] || Test: [ Avg Loss: 0.5673, Accuracy: 80.43% ]
# Elapsed Inf. time: 0.07-mins.
#
# 19: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4491, Accuracy: 84.68% ] || Test: [ Avg Loss: 0.5292, Accuracy: 82.58% ]
# Elapsed Inf. time: 0.07-mins.
#
# 20: Elapsed Train time: 1.30-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4430, Accuracy: 84.84% ] || Test: [ Avg Loss: 0.5028, Accuracy: 83.13% ]
# Elapsed Inf. time: 0.07-mins.
#
# 21: Elapsed Train time: 1.32-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4224, Accuracy: 85.67% ] || Test: [ Avg Loss: 0.5427, Accuracy: 81.64% ]
# Elapsed Inf. time: 0.07-mins.
#
# 22: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4180, Accuracy: 85.52% ] || Test: [ Avg Loss: 0.4887, Accuracy: 83.48% ]
# Elapsed Inf. time: 0.07-mins.
#
# 23: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4041, Accuracy: 86.22% ] || Test: [ Avg Loss: 0.5245, Accuracy: 82.11% ]
# Elapsed Inf. time: 0.07-mins.
#
# 24: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3969, Accuracy: 86.27% ] || Test: [ Avg Loss: 0.4815, Accuracy: 83.97% ]
# Elapsed Inf. time: 0.07-mins.
#
# 25: Elapsed Train time: 1.32-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3871, Accuracy: 86.79% ] || Test: [ Avg Loss: 0.4553, Accuracy: 84.41% ]
# Elapsed Inf. time: 0.07-mins.
#
# 26: Elapsed Train time: 1.33-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3792, Accuracy: 87.02% ] || Test: [ Avg Loss: 0.4607, Accuracy: 84.22% ]
# Elapsed Inf. time: 0.07-mins.
#
# 27: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3730, Accuracy: 87.26% ] || Test: [ Avg Loss: 0.4986, Accuracy: 83.35% ]
# Elapsed Inf. time: 0.07-mins.
#
# 28: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3660, Accuracy: 87.42% ] || Test: [ Avg Loss: 0.4558, Accuracy: 84.87% ]
# Elapsed Inf. time: 0.07-mins.
#
# 29: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3579, Accuracy: 87.83% ] || Test: [ Avg Loss: 0.4387, Accuracy: 85.44% ]
# Elapsed Inf. time: 0.07-mins.
#
# 30: Elapsed Train time: 1.30-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3502, Accuracy: 87.96% ] || Test: [ Avg Loss: 0.4465, Accuracy: 84.94% ]
# Elapsed Inf. time: 0.07-mins.
#
# *********************************************************************************
# Done! Run: 1 : [Best Test @ epoch 29] || [ Avg loss: 0.438715, Accuracy: 85.44% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9982],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# calc.: 0.000135, pvec2norm: 42.162495, gvec2norm: 12.026475
# ss_calc: 0.001628
# ss_used: 0.001628
# 1: Elapsed Train time: 0.99-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 1.5736, Accuracy: 44.09% ] || Test: [ Avg Loss: 1.3131, Accuracy: 52.24% ]
# Elapsed Inf. time: 0.06-mins.
#
# 2: Elapsed Train time: 0.96-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 1.1832, Accuracy: 57.99% ] || Test: [ Avg Loss: 1.0971, Accuracy: 61.01% ]
# Elapsed Inf. time: 0.06-mins.
#
# 3: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 1.0132, Accuracy: 64.20% ] || Test: [ Avg Loss: 0.9763, Accuracy: 65.05% ]
# Elapsed Inf. time: 0.07-mins.
#
# 4: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.9049, Accuracy: 68.30% ] || Test: [ Avg Loss: 0.8680, Accuracy: 69.64% ]
# Elapsed Inf. time: 0.07-mins.
#
# 5: Elapsed Train time: 1.34-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.8212, Accuracy: 71.38% ] || Test: [ Avg Loss: 0.8419, Accuracy: 70.29% ]
# Elapsed Inf. time: 0.07-mins.
#
# 6: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.7532, Accuracy: 73.81% ] || Test: [ Avg Loss: 0.8300, Accuracy: 71.10% ]
# Elapsed Inf. time: 0.07-mins.
#
# 7: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6966, Accuracy: 75.87% ] || Test: [ Avg Loss: 0.7063, Accuracy: 75.81% ]
# Elapsed Inf. time: 0.07-mins.
#
# 8: Elapsed Train time: 1.39-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6530, Accuracy: 77.54% ] || Test: [ Avg Loss: 0.6701, Accuracy: 77.35% ]
# Elapsed Inf. time: 0.07-mins.
#
# 9: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6169, Accuracy: 78.65% ] || Test: [ Avg Loss: 0.7040, Accuracy: 75.33% ]
# Elapsed Inf. time: 0.07-mins.
#
# 10: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5875, Accuracy: 79.77% ] || Test: [ Avg Loss: 0.6119, Accuracy: 79.22% ]
# Elapsed Inf. time: 0.07-mins.
#
# 11: Elapsed Train time: 1.39-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5626, Accuracy: 80.61% ] || Test: [ Avg Loss: 0.5831, Accuracy: 79.56% ]
# Elapsed Inf. time: 0.07-mins.
#
# 12: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5385, Accuracy: 81.53% ] || Test: [ Avg Loss: 0.5622, Accuracy: 80.37% ]
# Elapsed Inf. time: 0.07-mins.
#
# 13: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5197, Accuracy: 82.10% ] || Test: [ Avg Loss: 0.5502, Accuracy: 81.06% ]
# Elapsed Inf. time: 0.07-mins.
#
# 14: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4980, Accuracy: 82.95% ] || Test: [ Avg Loss: 0.5250, Accuracy: 81.75% ]
# Elapsed Inf. time: 0.07-mins.
#
# 15: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4824, Accuracy: 83.50% ] || Test: [ Avg Loss: 0.5229, Accuracy: 82.43% ]
# Elapsed Inf. time: 0.07-mins.
#
# 16: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4702, Accuracy: 83.88% ] || Test: [ Avg Loss: 0.5450, Accuracy: 81.57% ]
# Elapsed Inf. time: 0.07-mins.
#
# 17: Elapsed Train time: 1.34-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4547, Accuracy: 84.22% ] || Test: [ Avg Loss: 0.4842, Accuracy: 83.58% ]
# Elapsed Inf. time: 0.07-mins.
#
# 18: Elapsed Train time: 1.33-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4424, Accuracy: 84.97% ] || Test: [ Avg Loss: 0.5078, Accuracy: 82.87% ]
# Elapsed Inf. time: 0.07-mins.
#
# 19: Elapsed Train time: 1.32-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4308, Accuracy: 85.14% ] || Test: [ Avg Loss: 0.4709, Accuracy: 84.03% ]
# Elapsed Inf. time: 0.07-mins.
#
# 20: Elapsed Train time: 1.29-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4163, Accuracy: 85.73% ] || Test: [ Avg Loss: 0.4736, Accuracy: 84.16% ]
# Elapsed Inf. time: 0.07-mins.
#
# 21: Elapsed Train time: 1.32-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4035, Accuracy: 86.14% ] || Test: [ Avg Loss: 0.5002, Accuracy: 83.23% ]
# Elapsed Inf. time: 0.07-mins.
#
# 22: Elapsed Train time: 1.27-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3929, Accuracy: 86.55% ] || Test: [ Avg Loss: 0.5847, Accuracy: 81.03% ]
# Elapsed Inf. time: 0.07-mins.
#
# 23: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3871, Accuracy: 86.64% ] || Test: [ Avg Loss: 0.4530, Accuracy: 84.95% ]
# Elapsed Inf. time: 0.07-mins.
#
# 24: Elapsed Train time: 1.30-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3779, Accuracy: 87.01% ] || Test: [ Avg Loss: 0.4931, Accuracy: 83.52% ]
# Elapsed Inf. time: 0.07-mins.
#
# 25: Elapsed Train time: 1.30-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3712, Accuracy: 87.15% ] || Test: [ Avg Loss: 0.4618, Accuracy: 84.56% ]
# Elapsed Inf. time: 0.07-mins.
#
# 26: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3604, Accuracy: 87.60% ] || Test: [ Avg Loss: 0.4530, Accuracy: 84.77% ]
# Elapsed Inf. time: 0.07-mins.
#
# 27: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3511, Accuracy: 87.93% ] || Test: [ Avg Loss: 0.4401, Accuracy: 85.30% ]
# Elapsed Inf. time: 0.07-mins.
#
# 28: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3449, Accuracy: 88.05% ] || Test: [ Avg Loss: 0.4530, Accuracy: 84.99% ]
# Elapsed Inf. time: 0.07-mins.
#
# 29: Elapsed Train time: 1.33-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3357, Accuracy: 88.47% ] || Test: [ Avg Loss: 0.4635, Accuracy: 84.79% ]
# Elapsed Inf. time: 0.07-mins.
#
# 30: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3310, Accuracy: 88.46% ] || Test: [ Avg Loss: 0.4324, Accuracy: 85.76% ]
# Elapsed Inf. time: 0.07-mins.
#
# *********************************************************************************
# Done! Run: 2 : [Best Test @ epoch 30] || [ Avg loss: 0.432399, Accuracy: 85.76% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9982],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# calc.: 0.000136, pvec2norm: 42.254745, gvec2norm: 13.200025
# ss_calc: 0.001791
# ss_used: 0.001791
# 1: Elapsed Train time: 1.29-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 1.5604, Accuracy: 44.20% ] || Test: [ Avg Loss: 1.2983, Accuracy: 52.86% ]
# Elapsed Inf. time: 0.07-mins.
#
# 2: Elapsed Train time: 1.32-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 1.1705, Accuracy: 58.32% ] || Test: [ Avg Loss: 1.1708, Accuracy: 60.01% ]
# Elapsed Inf. time: 0.07-mins.
#
# 3: Elapsed Train time: 1.34-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 1.0039, Accuracy: 64.54% ] || Test: [ Avg Loss: 0.9115, Accuracy: 68.00% ]
# Elapsed Inf. time: 0.07-mins.
#
# 4: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.8909, Accuracy: 68.75% ] || Test: [ Avg Loss: 0.8772, Accuracy: 68.41% ]
# Elapsed Inf. time: 0.07-mins.
#
# 5: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.8082, Accuracy: 71.54% ] || Test: [ Avg Loss: 0.7977, Accuracy: 71.62% ]
# Elapsed Inf. time: 0.07-mins.
#
# 6: Elapsed Train time: 1.32-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.7417, Accuracy: 74.24% ] || Test: [ Avg Loss: 0.7799, Accuracy: 73.09% ]
# Elapsed Inf. time: 0.07-mins.
#
# 7: Elapsed Train time: 1.33-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6905, Accuracy: 75.86% ] || Test: [ Avg Loss: 0.7006, Accuracy: 76.34% ]
# Elapsed Inf. time: 0.07-mins.
#
# 8: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6460, Accuracy: 77.61% ] || Test: [ Avg Loss: 0.7348, Accuracy: 74.80% ]
# Elapsed Inf. time: 0.07-mins.
#
# 9: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6129, Accuracy: 78.73% ] || Test: [ Avg Loss: 0.6345, Accuracy: 77.93% ]
# Elapsed Inf. time: 0.07-mins.
#
# 10: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5806, Accuracy: 79.88% ] || Test: [ Avg Loss: 0.5997, Accuracy: 80.02% ]
# Elapsed Inf. time: 0.07-mins.
#
# 11: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5531, Accuracy: 80.98% ] || Test: [ Avg Loss: 0.5776, Accuracy: 80.21% ]
# Elapsed Inf. time: 0.07-mins.
#
# 12: Elapsed Train time: 1.33-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5302, Accuracy: 81.72% ] || Test: [ Avg Loss: 0.5561, Accuracy: 81.07% ]
# Elapsed Inf. time: 0.07-mins.
#
# 13: Elapsed Train time: 1.29-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5077, Accuracy: 82.50% ] || Test: [ Avg Loss: 0.5417, Accuracy: 81.95% ]
# Elapsed Inf. time: 0.07-mins.
#
# 14: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4933, Accuracy: 83.03% ] || Test: [ Avg Loss: 0.5307, Accuracy: 81.82% ]
# Elapsed Inf. time: 0.07-mins.
#
# 15: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4708, Accuracy: 83.91% ] || Test: [ Avg Loss: 0.5443, Accuracy: 81.74% ]
# Elapsed Inf. time: 0.07-mins.
#
# 16: Elapsed Train time: 1.31-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4563, Accuracy: 84.22% ] || Test: [ Avg Loss: 0.5738, Accuracy: 81.24% ]
# Elapsed Inf. time: 0.07-mins.
#
# 17: Elapsed Train time: 1.34-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4490, Accuracy: 84.69% ] || Test: [ Avg Loss: 0.4619, Accuracy: 84.43% ]
# Elapsed Inf. time: 0.07-mins.
#
# 18: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4326, Accuracy: 85.13% ] || Test: [ Avg Loss: 0.4817, Accuracy: 83.53% ]
# Elapsed Inf. time: 0.07-mins.
#
# 19: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4220, Accuracy: 85.52% ] || Test: [ Avg Loss: 0.4888, Accuracy: 83.66% ]
# Elapsed Inf. time: 0.07-mins.
#
# 20: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4119, Accuracy: 85.81% ] || Test: [ Avg Loss: 0.4636, Accuracy: 84.07% ]
# Elapsed Inf. time: 0.07-mins.
#
# 21: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3970, Accuracy: 86.27% ] || Test: [ Avg Loss: 0.4568, Accuracy: 84.63% ]
# Elapsed Inf. time: 0.07-mins.
#
# 22: Elapsed Train time: 1.30-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3898, Accuracy: 86.52% ] || Test: [ Avg Loss: 0.4518, Accuracy: 84.69% ]
# Elapsed Inf. time: 0.07-mins.
#
# 23: Elapsed Train time: 1.30-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3812, Accuracy: 86.81% ] || Test: [ Avg Loss: 0.4679, Accuracy: 84.40% ]
# Elapsed Inf. time: 0.07-mins.
#
# 24: Elapsed Train time: 1.32-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3714, Accuracy: 87.25% ] || Test: [ Avg Loss: 0.4433, Accuracy: 85.23% ]
# Elapsed Inf. time: 0.07-mins.
#
# 25: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3660, Accuracy: 87.49% ] || Test: [ Avg Loss: 0.4742, Accuracy: 84.38% ]
# Elapsed Inf. time: 0.07-mins.
#
# 26: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3506, Accuracy: 88.00% ] || Test: [ Avg Loss: 0.4269, Accuracy: 85.55% ]
# Elapsed Inf. time: 0.07-mins.
#
# 27: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3509, Accuracy: 87.98% ] || Test: [ Avg Loss: 0.4853, Accuracy: 83.71% ]
# Elapsed Inf. time: 0.07-mins.
#
# 28: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3407, Accuracy: 88.22% ] || Test: [ Avg Loss: 0.4294, Accuracy: 85.45% ]
# Elapsed Inf. time: 0.07-mins.
#
# 29: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3298, Accuracy: 88.53% ] || Test: [ Avg Loss: 0.4838, Accuracy: 83.95% ]
# Elapsed Inf. time: 0.07-mins.
#
# 30: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3244, Accuracy: 88.84% ] || Test: [ Avg Loss: 0.4328, Accuracy: 86.00% ]
# Elapsed Inf. time: 0.07-mins.
#
# *********************************************************************************
# Done! Run: 3 : [Best Test @ epoch 30] || [ Avg loss: 0.432801, Accuracy: 86.00% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9982],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# calc.: 0.000136, pvec2norm: 42.461296, gvec2norm: 14.672884
# ss_calc: 0.002000
# ss_used: 0.002000
# 1: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 1.5675, Accuracy: 43.84% ] || Test: [ Avg Loss: 1.3973, Accuracy: 51.42% ]
# Elapsed Inf. time: 0.07-mins.
#
# 2: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 1.1703, Accuracy: 58.18% ] || Test: [ Avg Loss: 1.0917, Accuracy: 60.63% ]
# Elapsed Inf. time: 0.07-mins.
#
# 3: Elapsed Train time: 1.33-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.9964, Accuracy: 64.74% ] || Test: [ Avg Loss: 1.0142, Accuracy: 64.58% ]
# Elapsed Inf. time: 0.07-mins.
#
# 4: Elapsed Train time: 1.30-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.8804, Accuracy: 69.00% ] || Test: [ Avg Loss: 0.8536, Accuracy: 70.41% ]
# Elapsed Inf. time: 0.07-mins.
#
# 5: Elapsed Train time: 1.18-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.7977, Accuracy: 72.05% ] || Test: [ Avg Loss: 0.7418, Accuracy: 74.11% ]
# Elapsed Inf. time: 0.07-mins.
#
# 6: Elapsed Train time: 1.19-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.7355, Accuracy: 74.37% ] || Test: [ Avg Loss: 0.6910, Accuracy: 75.93% ]
# Elapsed Inf. time: 0.07-mins.
#
# 7: Elapsed Train time: 1.04-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6798, Accuracy: 76.48% ] || Test: [ Avg Loss: 0.6699, Accuracy: 76.96% ]
# Elapsed Inf. time: 0.07-mins.
#
# 8: Elapsed Train time: 1.00-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6413, Accuracy: 77.86% ] || Test: [ Avg Loss: 0.6724, Accuracy: 77.02% ]
# Elapsed Inf. time: 0.07-mins.
#
# 9: Elapsed Train time: 1.04-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6014, Accuracy: 79.19% ] || Test: [ Avg Loss: 0.5951, Accuracy: 79.83% ]
# Elapsed Inf. time: 0.07-mins.
#
# 10: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5692, Accuracy: 80.47% ] || Test: [ Avg Loss: 0.5831, Accuracy: 79.62% ]
# Elapsed Inf. time: 0.07-mins.
#
# 11: Elapsed Train time: 1.39-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5431, Accuracy: 81.12% ] || Test: [ Avg Loss: 0.5899, Accuracy: 80.07% ]
# Elapsed Inf. time: 0.07-mins.
#
# 12: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5208, Accuracy: 82.01% ] || Test: [ Avg Loss: 0.5979, Accuracy: 79.12% ]
# Elapsed Inf. time: 0.07-mins.
#
# 13: Elapsed Train time: 1.34-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5013, Accuracy: 82.67% ] || Test: [ Avg Loss: 0.5614, Accuracy: 80.71% ]
# Elapsed Inf. time: 0.07-mins.
#
# 14: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4859, Accuracy: 83.25% ] || Test: [ Avg Loss: 0.5379, Accuracy: 81.91% ]
# Elapsed Inf. time: 0.07-mins.
#
# 15: Elapsed Train time: 1.34-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4654, Accuracy: 83.93% ] || Test: [ Avg Loss: 0.5053, Accuracy: 82.90% ]
# Elapsed Inf. time: 0.07-mins.
#
# 16: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4547, Accuracy: 84.31% ] || Test: [ Avg Loss: 0.5134, Accuracy: 82.75% ]
# Elapsed Inf. time: 0.07-mins.
#
# 17: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4383, Accuracy: 84.91% ] || Test: [ Avg Loss: 0.4990, Accuracy: 82.95% ]
# Elapsed Inf. time: 0.07-mins.
#
# 18: Elapsed Train time: 1.34-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4286, Accuracy: 85.17% ] || Test: [ Avg Loss: 0.4922, Accuracy: 83.52% ]
# Elapsed Inf. time: 0.07-mins.
#
# 19: Elapsed Train time: 1.32-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4097, Accuracy: 85.80% ] || Test: [ Avg Loss: 0.4710, Accuracy: 84.23% ]
# Elapsed Inf. time: 0.07-mins.
#
# 20: Elapsed Train time: 1.32-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4020, Accuracy: 86.14% ] || Test: [ Avg Loss: 0.4823, Accuracy: 84.05% ]
# Elapsed Inf. time: 0.07-mins.
#
# 21: Elapsed Train time: 1.34-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3939, Accuracy: 86.46% ] || Test: [ Avg Loss: 0.4728, Accuracy: 84.15% ]
# Elapsed Inf. time: 0.07-mins.
#
# 22: Elapsed Train time: 1.39-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3815, Accuracy: 86.81% ] || Test: [ Avg Loss: 0.4723, Accuracy: 84.76% ]
# Elapsed Inf. time: 0.07-mins.
#
# 23: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3726, Accuracy: 87.01% ] || Test: [ Avg Loss: 0.4620, Accuracy: 84.71% ]
# Elapsed Inf. time: 0.07-mins.
#
# 24: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3662, Accuracy: 87.40% ] || Test: [ Avg Loss: 0.4681, Accuracy: 84.56% ]
# Elapsed Inf. time: 0.07-mins.
#
# 25: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3551, Accuracy: 87.64% ] || Test: [ Avg Loss: 0.4437, Accuracy: 85.23% ]
# Elapsed Inf. time: 0.07-mins.
#
# 26: Elapsed Train time: 1.32-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3469, Accuracy: 87.92% ] || Test: [ Avg Loss: 0.4583, Accuracy: 85.13% ]
# Elapsed Inf. time: 0.07-mins.
#
# 27: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3387, Accuracy: 88.20% ] || Test: [ Avg Loss: 0.4588, Accuracy: 84.88% ]
# Elapsed Inf. time: 0.07-mins.
#
# 28: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3316, Accuracy: 88.53% ] || Test: [ Avg Loss: 0.4283, Accuracy: 85.92% ]
# Elapsed Inf. time: 0.07-mins.
#
# 29: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3250, Accuracy: 88.84% ] || Test: [ Avg Loss: 0.4612, Accuracy: 84.93% ]
# Elapsed Inf. time: 0.07-mins.
#
# 30: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3205, Accuracy: 88.85% ] || Test: [ Avg Loss: 0.4599, Accuracy: 85.10% ]
# Elapsed Inf. time: 0.07-mins.
#
# *********************************************************************************
# Done! Run: 4 : [Best Test @ epoch 28] || [ Avg loss: 0.428316, Accuracy: 85.92% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9982],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# calc.: 0.000135, pvec2norm: 42.187302, gvec2norm: 11.644622
# ss_calc: 0.001577
# ss_used: 0.001577
# 1: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 1.5297, Accuracy: 45.32% ] || Test: [ Avg Loss: 1.3307, Accuracy: 52.17% ]
# Elapsed Inf. time: 0.07-mins.
#
# 2: Elapsed Train time: 1.30-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 1.1364, Accuracy: 59.67% ] || Test: [ Avg Loss: 1.1400, Accuracy: 60.07% ]
# Elapsed Inf. time: 0.07-mins.
#
# 3: Elapsed Train time: 1.34-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.9767, Accuracy: 65.52% ] || Test: [ Avg Loss: 0.9598, Accuracy: 66.26% ]
# Elapsed Inf. time: 0.07-mins.
#
# 4: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.8703, Accuracy: 69.49% ] || Test: [ Avg Loss: 0.8696, Accuracy: 70.19% ]
# Elapsed Inf. time: 0.07-mins.
#
# 5: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.7916, Accuracy: 72.32% ] || Test: [ Avg Loss: 0.8185, Accuracy: 71.53% ]
# Elapsed Inf. time: 0.07-mins.
#
# 6: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.7310, Accuracy: 74.70% ] || Test: [ Avg Loss: 0.7946, Accuracy: 72.69% ]
# Elapsed Inf. time: 0.07-mins.
#
# 7: Elapsed Train time: 1.31-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6844, Accuracy: 76.39% ] || Test: [ Avg Loss: 0.7199, Accuracy: 75.12% ]
# Elapsed Inf. time: 0.07-mins.
#
# 8: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6496, Accuracy: 77.53% ] || Test: [ Avg Loss: 0.7085, Accuracy: 76.01% ]
# Elapsed Inf. time: 0.07-mins.
#
# 9: Elapsed Train time: 1.33-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6053, Accuracy: 79.15% ] || Test: [ Avg Loss: 0.6641, Accuracy: 77.02% ]
# Elapsed Inf. time: 0.07-mins.
#
# 10: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5794, Accuracy: 80.05% ] || Test: [ Avg Loss: 0.5866, Accuracy: 79.98% ]
# Elapsed Inf. time: 0.07-mins.
#
# 11: Elapsed Train time: 1.34-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5497, Accuracy: 80.96% ] || Test: [ Avg Loss: 0.5721, Accuracy: 80.10% ]
# Elapsed Inf. time: 0.07-mins.
#
# 12: Elapsed Train time: 1.33-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5282, Accuracy: 81.74% ] || Test: [ Avg Loss: 0.5535, Accuracy: 80.99% ]
# Elapsed Inf. time: 0.07-mins.
#
# 13: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5115, Accuracy: 82.51% ] || Test: [ Avg Loss: 0.5386, Accuracy: 81.44% ]
# Elapsed Inf. time: 0.07-mins.
#
# 14: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4876, Accuracy: 83.31% ] || Test: [ Avg Loss: 0.5760, Accuracy: 80.24% ]
# Elapsed Inf. time: 0.07-mins.
#
# 15: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4782, Accuracy: 83.62% ] || Test: [ Avg Loss: 0.5395, Accuracy: 81.55% ]
# Elapsed Inf. time: 0.07-mins.
#
# 16: Elapsed Train time: 1.39-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4645, Accuracy: 84.17% ] || Test: [ Avg Loss: 0.5349, Accuracy: 81.51% ]
# Elapsed Inf. time: 0.07-mins.
#
# 17: Elapsed Train time: 1.07-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4517, Accuracy: 84.54% ] || Test: [ Avg Loss: 0.4956, Accuracy: 82.87% ]
# Elapsed Inf. time: 0.07-mins.
#
# 18: Elapsed Train time: 0.99-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4335, Accuracy: 85.04% ] || Test: [ Avg Loss: 0.4775, Accuracy: 83.65% ]
# Elapsed Inf. time: 0.06-mins.
#
# 19: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4209, Accuracy: 85.41% ] || Test: [ Avg Loss: 0.4844, Accuracy: 83.62% ]
# Elapsed Inf. time: 0.07-mins.
#
# 20: Elapsed Train time: 1.34-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4104, Accuracy: 85.90% ] || Test: [ Avg Loss: 0.4910, Accuracy: 83.59% ]
# Elapsed Inf. time: 0.07-mins.
#
# 21: Elapsed Train time: 1.33-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4016, Accuracy: 86.07% ] || Test: [ Avg Loss: 0.4879, Accuracy: 83.46% ]
# Elapsed Inf. time: 0.07-mins.
#
# 22: Elapsed Train time: 1.34-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3956, Accuracy: 86.42% ] || Test: [ Avg Loss: 0.4518, Accuracy: 84.84% ]
# Elapsed Inf. time: 0.07-mins.
#
# 23: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3800, Accuracy: 86.96% ] || Test: [ Avg Loss: 0.4782, Accuracy: 84.31% ]
# Elapsed Inf. time: 0.07-mins.
#
# 24: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3746, Accuracy: 87.11% ] || Test: [ Avg Loss: 0.4694, Accuracy: 84.38% ]
# Elapsed Inf. time: 0.07-mins.
#
# 25: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3694, Accuracy: 87.38% ] || Test: [ Avg Loss: 0.4405, Accuracy: 85.25% ]
# Elapsed Inf. time: 0.07-mins.
#
# 26: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3563, Accuracy: 87.74% ] || Test: [ Avg Loss: 0.4858, Accuracy: 84.02% ]
# Elapsed Inf. time: 0.07-mins.
#
# 27: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3478, Accuracy: 88.15% ] || Test: [ Avg Loss: 0.4512, Accuracy: 85.31% ]
# Elapsed Inf. time: 0.07-mins.
#
# 28: Elapsed Train time: 1.30-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3452, Accuracy: 88.00% ] || Test: [ Avg Loss: 0.4521, Accuracy: 84.63% ]
# Elapsed Inf. time: 0.07-mins.
#
# 29: Elapsed Train time: 0.97-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3353, Accuracy: 88.49% ] || Test: [ Avg Loss: 0.4314, Accuracy: 85.48% ]
# Elapsed Inf. time: 0.07-mins.
#
# 30: Elapsed Train time: 1.04-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3302, Accuracy: 88.78% ] || Test: [ Avg Loss: 0.4157, Accuracy: 85.80% ]
# Elapsed Inf. time: 0.07-mins.
#
# *********************************************************************************
# Done! Run: 5 : [Best Test @ epoch 30] || [ Avg loss: 0.415729, Accuracy: 85.80% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9982],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# calc.: 0.000136, pvec2norm: 42.261230, gvec2norm: 11.966516
# ss_calc: 0.001624
# ss_used: 0.001624
# 1: Elapsed Train time: 1.04-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 1.5059, Accuracy: 46.53% ] || Test: [ Avg Loss: 1.3081, Accuracy: 54.37% ]
# Elapsed Inf. time: 0.07-mins.
#
# 2: Elapsed Train time: 1.04-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 1.1281, Accuracy: 59.57% ] || Test: [ Avg Loss: 1.0622, Accuracy: 62.34% ]
# Elapsed Inf. time: 0.07-mins.
#
# 3: Elapsed Train time: 1.04-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.9659, Accuracy: 66.24% ] || Test: [ Avg Loss: 0.9926, Accuracy: 65.66% ]
# Elapsed Inf. time: 0.07-mins.
#
# 4: Elapsed Train time: 0.96-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.8607, Accuracy: 69.64% ] || Test: [ Avg Loss: 0.8444, Accuracy: 70.93% ]
# Elapsed Inf. time: 0.07-mins.
#
# 5: Elapsed Train time: 1.17-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.7820, Accuracy: 72.64% ] || Test: [ Avg Loss: 0.8210, Accuracy: 71.47% ]
# Elapsed Inf. time: 0.07-mins.
#
# 6: Elapsed Train time: 1.39-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.7234, Accuracy: 74.90% ] || Test: [ Avg Loss: 0.7370, Accuracy: 74.96% ]
# Elapsed Inf. time: 0.07-mins.
#
# 7: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6766, Accuracy: 76.46% ] || Test: [ Avg Loss: 0.6635, Accuracy: 76.96% ]
# Elapsed Inf. time: 0.07-mins.
#
# 8: Elapsed Train time: 1.39-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6419, Accuracy: 77.83% ] || Test: [ Avg Loss: 0.7145, Accuracy: 75.59% ]
# Elapsed Inf. time: 0.07-mins.
#
# 9: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6069, Accuracy: 78.92% ] || Test: [ Avg Loss: 0.6460, Accuracy: 78.12% ]
# Elapsed Inf. time: 0.07-mins.
#
# 10: Elapsed Train time: 1.16-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5801, Accuracy: 79.87% ] || Test: [ Avg Loss: 0.6075, Accuracy: 78.98% ]
# Elapsed Inf. time: 0.07-mins.
#
# 11: Elapsed Train time: 1.11-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5526, Accuracy: 81.04% ] || Test: [ Avg Loss: 0.6186, Accuracy: 78.18% ]
# Elapsed Inf. time: 0.07-mins.
#
# 12: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5293, Accuracy: 81.82% ] || Test: [ Avg Loss: 0.5473, Accuracy: 81.77% ]
# Elapsed Inf. time: 0.07-mins.
#
# 13: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5034, Accuracy: 82.69% ] || Test: [ Avg Loss: 0.6004, Accuracy: 79.73% ]
# Elapsed Inf. time: 0.07-mins.
#
# 14: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4892, Accuracy: 82.93% ] || Test: [ Avg Loss: 0.5372, Accuracy: 81.81% ]
# Elapsed Inf. time: 0.07-mins.
#
# 15: Elapsed Train time: 1.11-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4761, Accuracy: 83.64% ] || Test: [ Avg Loss: 0.5173, Accuracy: 82.45% ]
# Elapsed Inf. time: 0.07-mins.
#
# 16: Elapsed Train time: 0.99-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4579, Accuracy: 84.22% ] || Test: [ Avg Loss: 0.5134, Accuracy: 82.45% ]
# Elapsed Inf. time: 0.07-mins.
#
# 17: Elapsed Train time: 1.30-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4442, Accuracy: 84.72% ] || Test: [ Avg Loss: 0.4967, Accuracy: 83.08% ]
# Elapsed Inf. time: 0.07-mins.
#
# 18: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4359, Accuracy: 85.04% ] || Test: [ Avg Loss: 0.5003, Accuracy: 83.36% ]
# Elapsed Inf. time: 0.07-mins.
#
# 19: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4224, Accuracy: 85.55% ] || Test: [ Avg Loss: 0.5018, Accuracy: 83.06% ]
# Elapsed Inf. time: 0.07-mins.
#
# 20: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4057, Accuracy: 86.08% ] || Test: [ Avg Loss: 0.4942, Accuracy: 83.46% ]
# Elapsed Inf. time: 0.07-mins.
#
# 21: Elapsed Train time: 1.39-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3998, Accuracy: 86.30% ] || Test: [ Avg Loss: 0.4955, Accuracy: 83.85% ]
# Elapsed Inf. time: 0.07-mins.
#
# 22: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3842, Accuracy: 86.74% ] || Test: [ Avg Loss: 0.4986, Accuracy: 83.45% ]
# Elapsed Inf. time: 0.07-mins.
#
# 23: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3799, Accuracy: 87.03% ] || Test: [ Avg Loss: 0.4679, Accuracy: 84.16% ]
# Elapsed Inf. time: 0.07-mins.
#
# 24: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3724, Accuracy: 87.14% ] || Test: [ Avg Loss: 0.4630, Accuracy: 84.51% ]
# Elapsed Inf. time: 0.07-mins.
#
# 25: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3608, Accuracy: 87.49% ] || Test: [ Avg Loss: 0.4446, Accuracy: 85.07% ]
# Elapsed Inf. time: 0.07-mins.
#
# 26: Elapsed Train time: 1.32-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3548, Accuracy: 87.71% ] || Test: [ Avg Loss: 0.4505, Accuracy: 84.94% ]
# Elapsed Inf. time: 0.07-mins.
#
# 27: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3530, Accuracy: 87.82% ] || Test: [ Avg Loss: 0.4671, Accuracy: 84.29% ]
# Elapsed Inf. time: 0.07-mins.
#
# 28: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3416, Accuracy: 88.27% ] || Test: [ Avg Loss: 0.4417, Accuracy: 85.05% ]
# Elapsed Inf. time: 0.07-mins.
#
# 29: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3327, Accuracy: 88.69% ] || Test: [ Avg Loss: 0.4862, Accuracy: 83.90% ]
# Elapsed Inf. time: 0.07-mins.
#
# 30: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3281, Accuracy: 88.69% ] || Test: [ Avg Loss: 0.4389, Accuracy: 85.05% ]
# Elapsed Inf. time: 0.07-mins.
#
# *********************************************************************************
# Done! Run: 6 : [Best Test @ epoch 25] || [ Avg loss: 0.444585, Accuracy: 85.07% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9982],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# calc.: 0.000136, pvec2norm: 42.464172, gvec2norm: 12.234230
# ss_calc: 0.001668
# ss_used: 0.001668
# 1: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 1.5574, Accuracy: 44.30% ] || Test: [ Avg Loss: 1.4271, Accuracy: 50.41% ]
# Elapsed Inf. time: 0.07-mins.
#
# 2: Elapsed Train time: 1.32-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 1.1791, Accuracy: 58.09% ] || Test: [ Avg Loss: 1.0925, Accuracy: 61.48% ]
# Elapsed Inf. time: 0.07-mins.
#
# 3: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 1.0025, Accuracy: 64.55% ] || Test: [ Avg Loss: 0.9077, Accuracy: 67.81% ]
# Elapsed Inf. time: 0.07-mins.
#
# 4: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.8886, Accuracy: 68.64% ] || Test: [ Avg Loss: 0.8870, Accuracy: 68.86% ]
# Elapsed Inf. time: 0.07-mins.
#
# 5: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.8113, Accuracy: 71.61% ] || Test: [ Avg Loss: 0.8550, Accuracy: 70.65% ]
# Elapsed Inf. time: 0.07-mins.
#
# 6: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.7465, Accuracy: 74.03% ] || Test: [ Avg Loss: 0.7476, Accuracy: 74.79% ]
# Elapsed Inf. time: 0.07-mins.
#
# 7: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6944, Accuracy: 75.87% ] || Test: [ Avg Loss: 0.7001, Accuracy: 76.19% ]
# Elapsed Inf. time: 0.07-mins.
#
# 8: Elapsed Train time: 1.31-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6561, Accuracy: 77.25% ] || Test: [ Avg Loss: 0.7180, Accuracy: 75.18% ]
# Elapsed Inf. time: 0.07-mins.
#
# 9: Elapsed Train time: 1.34-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6161, Accuracy: 78.81% ] || Test: [ Avg Loss: 0.7001, Accuracy: 76.56% ]
# Elapsed Inf. time: 0.07-mins.
#
# 10: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5945, Accuracy: 79.56% ] || Test: [ Avg Loss: 0.6111, Accuracy: 78.56% ]
# Elapsed Inf. time: 0.07-mins.
#
# 11: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5628, Accuracy: 80.49% ] || Test: [ Avg Loss: 0.6282, Accuracy: 78.61% ]
# Elapsed Inf. time: 0.07-mins.
#
# 12: Elapsed Train time: 1.34-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5383, Accuracy: 81.44% ] || Test: [ Avg Loss: 0.5905, Accuracy: 80.27% ]
# Elapsed Inf. time: 0.07-mins.
#
# 13: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5256, Accuracy: 81.88% ] || Test: [ Avg Loss: 0.5643, Accuracy: 81.33% ]
# Elapsed Inf. time: 0.07-mins.
#
# 14: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5003, Accuracy: 82.87% ] || Test: [ Avg Loss: 0.5065, Accuracy: 82.62% ]
# Elapsed Inf. time: 0.07-mins.
#
# 15: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4864, Accuracy: 83.27% ] || Test: [ Avg Loss: 0.5650, Accuracy: 81.45% ]
# Elapsed Inf. time: 0.07-mins.
#
# 16: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4675, Accuracy: 84.07% ] || Test: [ Avg Loss: 0.5714, Accuracy: 80.69% ]
# Elapsed Inf. time: 0.07-mins.
#
# 17: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4541, Accuracy: 84.28% ] || Test: [ Avg Loss: 0.5094, Accuracy: 82.33% ]
# Elapsed Inf. time: 0.07-mins.
#
# 18: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4465, Accuracy: 84.51% ] || Test: [ Avg Loss: 0.5192, Accuracy: 82.40% ]
# Elapsed Inf. time: 0.07-mins.
#
# 19: Elapsed Train time: 1.25-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4343, Accuracy: 85.03% ] || Test: [ Avg Loss: 0.5635, Accuracy: 81.69% ]
# Elapsed Inf. time: 0.07-mins.
#
# 20: Elapsed Train time: 0.97-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4200, Accuracy: 85.59% ] || Test: [ Avg Loss: 0.4653, Accuracy: 84.10% ]
# Elapsed Inf. time: 0.07-mins.
#
# 21: Elapsed Train time: 0.97-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4122, Accuracy: 85.88% ] || Test: [ Avg Loss: 0.4458, Accuracy: 84.85% ]
# Elapsed Inf. time: 0.07-mins.
#
# 22: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3947, Accuracy: 86.46% ] || Test: [ Avg Loss: 0.5110, Accuracy: 83.06% ]
# Elapsed Inf. time: 0.07-mins.
#
# 23: Elapsed Train time: 1.28-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3968, Accuracy: 86.38% ] || Test: [ Avg Loss: 0.4801, Accuracy: 83.85% ]
# Elapsed Inf. time: 0.07-mins.
#
# 24: Elapsed Train time: 0.97-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3810, Accuracy: 86.93% ] || Test: [ Avg Loss: 0.4380, Accuracy: 85.59% ]
# Elapsed Inf. time: 0.07-mins.
#
# 25: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3771, Accuracy: 87.00% ] || Test: [ Avg Loss: 0.4635, Accuracy: 84.61% ]
# Elapsed Inf. time: 0.07-mins.
#
# 26: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3670, Accuracy: 87.43% ] || Test: [ Avg Loss: 0.4415, Accuracy: 85.44% ]
# Elapsed Inf. time: 0.07-mins.
#
# 27: Elapsed Train time: 1.31-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3557, Accuracy: 87.59% ] || Test: [ Avg Loss: 0.4484, Accuracy: 84.73% ]
# Elapsed Inf. time: 0.07-mins.
#
# 28: Elapsed Train time: 1.31-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3556, Accuracy: 87.61% ] || Test: [ Avg Loss: 0.4230, Accuracy: 85.98% ]
# Elapsed Inf. time: 0.07-mins.
#
# 29: Elapsed Train time: 1.31-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3449, Accuracy: 88.07% ] || Test: [ Avg Loss: 0.4666, Accuracy: 84.43% ]
# Elapsed Inf. time: 0.07-mins.
#
# 30: Elapsed Train time: 1.30-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3339, Accuracy: 88.43% ] || Test: [ Avg Loss: 0.4210, Accuracy: 86.00% ]
# Elapsed Inf. time: 0.07-mins.
#
# ...
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3884, Accuracy: 86.62% ] || Test: [ Avg Loss: 0.5078, Accuracy: 83.51% ]
# Elapsed Inf. time: 0.07-mins.
#
# 23: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3823, Accuracy: 86.97% ] || Test: [ Avg Loss: 0.4736, Accuracy: 83.94% ]
# Elapsed Inf. time: 0.07-mins.
#
# 24: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3725, Accuracy: 87.13% ] || Test: [ Avg Loss: 0.4554, Accuracy: 84.57% ]
# Elapsed Inf. time: 0.07-mins.
#
# 25: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3623, Accuracy: 87.44% ] || Test: [ Avg Loss: 0.4638, Accuracy: 84.83% ]
# Elapsed Inf. time: 0.07-mins.
#
# 26: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3559, Accuracy: 87.65% ] || Test: [ Avg Loss: 0.4358, Accuracy: 85.48% ]
# Elapsed Inf. time: 0.07-mins.
#
# 27: Elapsed Train time: 1.28-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3495, Accuracy: 88.08% ] || Test: [ Avg Loss: 0.4293, Accuracy: 85.76% ]
# Elapsed Inf. time: 0.07-mins.
#
# 28: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3407, Accuracy: 88.26% ] || Test: [ Avg Loss: 0.4307, Accuracy: 85.42% ]
# Elapsed Inf. time: 0.07-mins.
#
# 29: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3355, Accuracy: 88.34% ] || Test: [ Avg Loss: 0.4330, Accuracy: 85.72% ]
# Elapsed Inf. time: 0.07-mins.
#
# 30: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3288, Accuracy: 88.70% ] || Test: [ Avg Loss: 0.4290, Accuracy: 85.96% ]
# Elapsed Inf. time: 0.07-mins.
#
# *********************************************************************************
# Done! Run: 8 : [Best Test @ epoch 30] || [ Avg loss: 0.429002, Accuracy: 85.96% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9982],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# calc.: 0.000136, pvec2norm: 42.312893, gvec2norm: 14.652908
# ss_calc: 0.001990
# ss_used: 0.001990
# 1: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 1.5925, Accuracy: 43.72% ] || Test: [ Avg Loss: 1.3012, Accuracy: 53.02% ]
# Elapsed Inf. time: 0.07-mins.
#
# 2: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 1.1662, Accuracy: 58.36% ] || Test: [ Avg Loss: 1.0985, Accuracy: 61.37% ]
# Elapsed Inf. time: 0.07-mins.
#
# 3: Elapsed Train time: 1.31-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.9864, Accuracy: 65.24% ] || Test: [ Avg Loss: 0.9625, Accuracy: 65.90% ]
# Elapsed Inf. time: 0.07-mins.
#
# 4: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.8751, Accuracy: 69.43% ] || Test: [ Avg Loss: 0.8814, Accuracy: 69.49% ]
# Elapsed Inf. time: 0.07-mins.
#
# 5: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.7888, Accuracy: 72.43% ] || Test: [ Avg Loss: 0.8295, Accuracy: 72.02% ]
# Elapsed Inf. time: 0.07-mins.
#
# 6: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.7304, Accuracy: 74.66% ] || Test: [ Avg Loss: 0.8224, Accuracy: 71.36% ]
# Elapsed Inf. time: 0.07-mins.
#
# 7: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6795, Accuracy: 76.57% ] || Test: [ Avg Loss: 0.6672, Accuracy: 76.44% ]
# Elapsed Inf. time: 0.07-mins.
#
# 8: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6328, Accuracy: 78.16% ] || Test: [ Avg Loss: 0.6710, Accuracy: 76.85% ]
# Elapsed Inf. time: 0.07-mins.
#
# 9: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5941, Accuracy: 79.66% ] || Test: [ Avg Loss: 0.6394, Accuracy: 78.29% ]
# Elapsed Inf. time: 0.07-mins.
#
# 10: Elapsed Train time: 1.39-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5740, Accuracy: 80.16% ] || Test: [ Avg Loss: 0.5925, Accuracy: 79.81% ]
# Elapsed Inf. time: 0.07-mins.
#
# 11: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5445, Accuracy: 81.27% ] || Test: [ Avg Loss: 0.5666, Accuracy: 80.60% ]
# Elapsed Inf. time: 0.07-mins.
#
# 12: Elapsed Train time: 1.33-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5196, Accuracy: 82.29% ] || Test: [ Avg Loss: 0.5644, Accuracy: 80.66% ]
# Elapsed Inf. time: 0.07-mins.
#
# 13: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5006, Accuracy: 82.87% ] || Test: [ Avg Loss: 0.5281, Accuracy: 82.03% ]
# Elapsed Inf. time: 0.07-mins.
#
# 14: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4832, Accuracy: 83.30% ] || Test: [ Avg Loss: 0.5083, Accuracy: 82.56% ]
# Elapsed Inf. time: 0.07-mins.
#
# 15: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4729, Accuracy: 83.76% ] || Test: [ Avg Loss: 0.5118, Accuracy: 82.66% ]
# Elapsed Inf. time: 0.07-mins.
#
# 16: Elapsed Train time: 1.34-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4507, Accuracy: 84.40% ] || Test: [ Avg Loss: 0.5209, Accuracy: 82.23% ]
# Elapsed Inf. time: 0.07-mins.
#
# 17: Elapsed Train time: 1.30-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4424, Accuracy: 84.69% ] || Test: [ Avg Loss: 0.4832, Accuracy: 83.71% ]
# Elapsed Inf. time: 0.07-mins.
#
# 18: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4252, Accuracy: 85.34% ] || Test: [ Avg Loss: 0.4978, Accuracy: 83.16% ]
# Elapsed Inf. time: 0.07-mins.
#
# 19: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4180, Accuracy: 85.71% ] || Test: [ Avg Loss: 0.4682, Accuracy: 84.45% ]
# Elapsed Inf. time: 0.07-mins.
#
# 20: Elapsed Train time: 1.32-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4061, Accuracy: 85.93% ] || Test: [ Avg Loss: 0.4781, Accuracy: 83.99% ]
# Elapsed Inf. time: 0.07-mins.
#
# 21: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3967, Accuracy: 86.31% ] || Test: [ Avg Loss: 0.4582, Accuracy: 84.47% ]
# Elapsed Inf. time: 0.07-mins.
#
# 22: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3808, Accuracy: 86.96% ] || Test: [ Avg Loss: 0.4623, Accuracy: 84.62% ]
# Elapsed Inf. time: 0.07-mins.
#
# 23: Elapsed Train time: 1.32-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3760, Accuracy: 86.88% ] || Test: [ Avg Loss: 0.5007, Accuracy: 83.63% ]
# Elapsed Inf. time: 0.07-mins.
#
# 24: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3720, Accuracy: 87.15% ] || Test: [ Avg Loss: 0.4480, Accuracy: 85.36% ]
# Elapsed Inf. time: 0.07-mins.
#
# 25: Elapsed Train time: 1.34-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3567, Accuracy: 87.68% ] || Test: [ Avg Loss: 0.4638, Accuracy: 84.56% ]
# Elapsed Inf. time: 0.07-mins.
#
# 26: Elapsed Train time: 1.32-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3510, Accuracy: 87.89% ] || Test: [ Avg Loss: 0.4538, Accuracy: 85.01% ]
# Elapsed Inf. time: 0.07-mins.
#
# 27: Elapsed Train time: 1.33-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3460, Accuracy: 88.05% ] || Test: [ Avg Loss: 0.4315, Accuracy: 85.60% ]
# Elapsed Inf. time: 0.07-mins.
#
# 28: Elapsed Train time: 1.33-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3382, Accuracy: 88.29% ] || Test: [ Avg Loss: 0.4285, Accuracy: 85.51% ]
# Elapsed Inf. time: 0.07-mins.
#
# 29: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3274, Accuracy: 88.83% ] || Test: [ Avg Loss: 0.4353, Accuracy: 85.72% ]
# Elapsed Inf. time: 0.07-mins.
#
# 30: Elapsed Train time: 1.35-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3268, Accuracy: 88.82% ] || Test: [ Avg Loss: 0.4294, Accuracy: 85.95% ]
# Elapsed Inf. time: 0.07-mins.
#
# *********************************************************************************
# Done! Run: 9 : [Best Test @ epoch 30] || [ Avg loss: 0.429448, Accuracy: 85.95% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9982],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# calc.: 0.000136, pvec2norm: 42.489346, gvec2norm: 13.216495
# ss_calc: 0.001803
# ss_used: 0.001803
# 1: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 1.5463, Accuracy: 44.57% ] || Test: [ Avg Loss: 1.3552, Accuracy: 52.09% ]
# Elapsed Inf. time: 0.07-mins.
#
# 2: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 1.1769, Accuracy: 58.18% ] || Test: [ Avg Loss: 1.2102, Accuracy: 58.12% ]
# Elapsed Inf. time: 0.07-mins.
#
# 3: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.9986, Accuracy: 64.53% ] || Test: [ Avg Loss: 1.0671, Accuracy: 64.86% ]
# Elapsed Inf. time: 0.07-mins.
#
# 4: Elapsed Train time: 1.33-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.8855, Accuracy: 68.92% ] || Test: [ Avg Loss: 0.8441, Accuracy: 70.61% ]
# Elapsed Inf. time: 0.07-mins.
#
# 5: Elapsed Train time: 1.31-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.8025, Accuracy: 71.95% ] || Test: [ Avg Loss: 0.7989, Accuracy: 71.84% ]
# Elapsed Inf. time: 0.07-mins.
#
# 6: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.7413, Accuracy: 74.11% ] || Test: [ Avg Loss: 0.7269, Accuracy: 74.68% ]
# Elapsed Inf. time: 0.07-mins.
#
# 7: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6882, Accuracy: 76.01% ] || Test: [ Avg Loss: 0.8034, Accuracy: 72.20% ]
# Elapsed Inf. time: 0.07-mins.
#
# 8: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6484, Accuracy: 77.51% ] || Test: [ Avg Loss: 0.6508, Accuracy: 77.84% ]
# Elapsed Inf. time: 0.07-mins.
#
# 9: Elapsed Train time: 1.33-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.6133, Accuracy: 78.86% ] || Test: [ Avg Loss: 0.7054, Accuracy: 76.67% ]
# Elapsed Inf. time: 0.07-mins.
#
# 10: Elapsed Train time: 1.32-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5838, Accuracy: 79.97% ] || Test: [ Avg Loss: 0.5805, Accuracy: 79.99% ]
# Elapsed Inf. time: 0.07-mins.
#
# 11: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5564, Accuracy: 80.71% ] || Test: [ Avg Loss: 0.5800, Accuracy: 80.37% ]
# Elapsed Inf. time: 0.07-mins.
#
# 12: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5327, Accuracy: 81.74% ] || Test: [ Avg Loss: 0.5579, Accuracy: 80.99% ]
# Elapsed Inf. time: 0.07-mins.
#
# 13: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.5135, Accuracy: 82.20% ] || Test: [ Avg Loss: 0.5450, Accuracy: 81.77% ]
# Elapsed Inf. time: 0.07-mins.
#
# 14: Elapsed Train time: 1.19-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4966, Accuracy: 83.09% ] || Test: [ Avg Loss: 0.5546, Accuracy: 81.29% ]
# Elapsed Inf. time: 0.07-mins.
#
# 15: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4807, Accuracy: 83.57% ] || Test: [ Avg Loss: 0.5146, Accuracy: 82.45% ]
# Elapsed Inf. time: 0.07-mins.
#
# 16: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4642, Accuracy: 84.03% ] || Test: [ Avg Loss: 0.5213, Accuracy: 82.69% ]
# Elapsed Inf. time: 0.07-mins.
#
# 17: Elapsed Train time: 1.30-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4517, Accuracy: 84.50% ] || Test: [ Avg Loss: 0.4908, Accuracy: 83.57% ]
# Elapsed Inf. time: 0.07-mins.
#
# 18: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4377, Accuracy: 85.04% ] || Test: [ Avg Loss: 0.4901, Accuracy: 83.48% ]
# Elapsed Inf. time: 0.07-mins.
#
# 19: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4264, Accuracy: 85.38% ] || Test: [ Avg Loss: 0.4944, Accuracy: 83.13% ]
# Elapsed Inf. time: 0.07-mins.
#
# 20: Elapsed Train time: 1.38-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4153, Accuracy: 85.75% ] || Test: [ Avg Loss: 0.4553, Accuracy: 84.56% ]
# Elapsed Inf. time: 0.07-mins.
#
# 21: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.4073, Accuracy: 86.09% ] || Test: [ Avg Loss: 0.4645, Accuracy: 84.37% ]
# Elapsed Inf. time: 0.07-mins.
#
# 22: Elapsed Train time: 1.30-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3967, Accuracy: 86.46% ] || Test: [ Avg Loss: 0.4533, Accuracy: 84.14% ]
# Elapsed Inf. time: 0.07-mins.
#
# 23: Elapsed Train time: 1.30-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3857, Accuracy: 86.77% ] || Test: [ Avg Loss: 0.4386, Accuracy: 85.14% ]
# Elapsed Inf. time: 0.07-mins.
#
# 24: Elapsed Train time: 0.98-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3774, Accuracy: 86.98% ] || Test: [ Avg Loss: 0.4487, Accuracy: 84.47% ]
# Elapsed Inf. time: 0.07-mins.
#
# 25: Elapsed Train time: 0.97-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3678, Accuracy: 87.36% ] || Test: [ Avg Loss: 0.4806, Accuracy: 83.70% ]
# Elapsed Inf. time: 0.07-mins.
#
# 26: Elapsed Train time: 1.21-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3610, Accuracy: 87.70% ] || Test: [ Avg Loss: 0.4543, Accuracy: 85.13% ]
# Elapsed Inf. time: 0.07-mins.
#
# 27: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3509, Accuracy: 88.03% ] || Test: [ Avg Loss: 0.4413, Accuracy: 85.05% ]
# Elapsed Inf. time: 0.07-mins.
#
# 28: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3500, Accuracy: 87.94% ] || Test: [ Avg Loss: 0.4453, Accuracy: 85.17% ]
# Elapsed Inf. time: 0.07-mins.
#
# 29: Elapsed Train time: 1.36-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3320, Accuracy: 88.70% ] || Test: [ Avg Loss: 0.4366, Accuracy: 85.47% ]
# Elapsed Inf. time: 0.07-mins.
#
# 30: Elapsed Train time: 1.37-mins.
# Batches/Steps/Iterations per Epoch:   391
# Train:	[ Avg Loss: 0.3311, Accuracy: 88.61% ] || Test: [ Avg Loss: 0.4362, Accuracy: 85.33% ]
# Elapsed Inf. time: 0.07-mins.
#
# **********************************************************************************
# Done! Run: 10 : [Best Test @ epoch 29] || [ Avg loss: 0.436618, Accuracy: 85.47% ]
# **********************************************************************************
#
# *********************************************
# Average Prediction Difference = 0.13%
# Effective Test Accuracy = 85.61%, pval=0.0000
# *********************************************

# %%
# Plots
plotter_v1(cfgs,run_idx=1)
