# %% [markdown]
# ##### Load Required Libraries

# %%
# !pip install watermark numpy scipy pandas matplotlib torch torchvision torchaudio --yes

# %load_ext watermark
# %watermark -v -p watermark,numpy,pandas,matplotlib,torch

#
import math,random,os,copy,time,glob,itertools,shutil,re, json
from scipy.stats import wilcoxon

#
import numpy as np

#
import torch
import torch.nn as nn
import torch.nn.functional as tf
from torch.utils.data import Dataset,DataLoader
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor, Lambda

#
import pandas as pd


#
from demofcns import *
from opts.asgm.torchlasgm import PID
from opts.elpf.fo import LPF
from opts.elpf.esfo import esLPF

worker_seed = 2023
def setseed(inc=0):
    # for redundancy
    # set seed for technical reproducibility
    myseed = worker_seed + inc
    random.seed(myseed)
    np.random.seed(myseed)
    np.random.default_rng(myseed)
    torch.manual_seed(myseed)    
    
    # torch.use_deterministic_algorithms(True)
    if torch.cuda.device_count() > 0:
      torch.cuda.manual_seed_all(myseed)
      torch.cuda.manual_seed(myseed)
      # torch.backends.cudnn.enabled = True
      # torch.backends.cuda.matmul.allow_tf32 = False
      # torch.backends.cudnn.benchmark = False
      # torch.backends.cudnn.deterministic = False
      # torch.backends.cudnn.allow_tf32 = True



class cseed_worker():
  def __init__(self,inc=0):
    self.inc = inc
    
  def seed_worker(self,workerid):
    np.random.seed(worker_seed+self.inc)
    random.seed(worker_seed+self.inc)

cseedwk = cseed_worker()

# python3 -m torch.utils.collect_env
# Out:
# Python implementation: CPython
# Python version       : 3.10.6
# IPython version      : 8.4.0
#
# watermark : 2.3.1
# numpy     : 1.23.2
# pandas    : 1.4.3
# matplotlib: 3.5.3
# torch     : 1.12.1+cu116

# %% [markdown]
# ##### Setup Configurations (Hyperparameters and so on)

# %%
# - is it being run remotely on OSU EECS server?
remotelyrun = 0 # 0 | 1

#----------------------
# Load setup config
#----------------------
with open('cfgs.json', 'r') as cfglist:
  cfgs = json.load(cfglist)
  
# setup
cfgs['storedir'] = "expstore"

# - pick data-set
cfgs["dataset"] = "atoy"
# - set std. batchsize for each epoch, runs, epochs, multiprocessing, human
cfgs["batch-size"] = 128 # 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, ...
cfgs['runs'] = 10
cfgs["epochs"] = 10

# -pick computation device
devcnt = torch.cuda.device_count()

# random seed for python libraries
cfgs["seed"] = 2023
cfgs["var_seed"] = 1
worker_seed = cfgs["seed"] % (2**32)
cfgs["num-workers"] = 0 #3
cfgs["human_signature"] = "oas" # for signing experiments ran.

if devcnt > 1:
  cfgs["device"] = torch.device('cuda') # "cuda:1"
  torch.cuda.set_device(1)
elif devcnt == 1:
  cfgs["device"] = torch.device('cuda')
else:
  cfgs["device"] = torch.device('cpu')
#
if remotelyrun:
  cfgs["remote"] = True
else:
  cfgs["remote"] = False

# %% [markdown]
# ##### (Generate) or Load the Dataset

# %%
#----------------------
# Download/Load Dataset
#----------------------
if not cfgs["remote"]:
  # same dir. as source-code
  data_folder = "data"
else:
  # dalton's scratch on OSU's eecs server
  data_folder = "/scratch/data"


# aToy
class aToy(Dataset):
    def __init__(self, data, split="", transform=None, target_transform=None):
      if split=="train": 
        self.data = data['train']
      elif split=="val" or split=="test":
        self.data = data['dev']
      #
      self.transform = transform
      self.target_transform = target_transform
      
      self.input = self.data['in']      
      self.labels = self.data['out']
        
            
    def __len__(self):
      return self.labels.shape[0]
    
    def __getitem__(self, idx):
        
      x = self.input[idx,:]
      y = self.labels[idx,]

      # transforms ...
      if self.transform:
        x = self.transform(x)
      if self.target_transform:
        y = self.target_transform(y)
          
        
      return x,y
    
def aToyGenerator(data_dir=f"{data_folder}/toydata_twofeatures_two_class.txt"):
  
  # Dataset with input: dim = 2 and ouput: class = binary, dim = 1 
  df = pd.read_csv(data_dir, sep="\t")
  # print(df.head())
  data_in = torch.tensor(df[["x1", "x2"]].values, dtype=torch.float)
  data_out = torch.tensor(df["label"].values, dtype=torch.int64)
  
  #
  torch.Generator().manual_seed(0)
  for i in range(10):
    data_in = torch.cat([data_in, data_in+torch.normal(0,0.1,size=(data_in.shape[0],1))])
    data_out = torch.cat([data_out,data_out])
    
  #
  intrain, inval = torch.utils.data.random_split(data_in, [int(0.6*data_in.shape[0]), int(0.4*data_in.shape[0])], generator=torch.Generator().manual_seed(0))
  # print(len(intrain.indices))
  
  atoy_data_train = {"in":data_in[intrain.indices,:], "out":data_out[intrain.indices,]}
  atoy_data_dev = {"in":data_in[inval.indices,:], "out":data_out[inval.indices,]}
  return {"train":atoy_data_train, "dev":atoy_data_dev}

if cfgs["dataset"] == "atoy":
  atoy_data = aToyGenerator()
  train_data = aToy(atoy_data,split="train")   
  test_data = aToy(atoy_data,split="test")

# %% [markdown]
# ##### Construct Model (Differentiable Function) with  necessary methods.

# %%
class thisNN(nn.Module):
  def __init__(self,num_heads=1,in_feats=1,out_feats=1, loss_type="mse", outs_class=False, mdl_name="nn1") -> None:
    """
    __init__ _summary_

    _extended_summary_

    Args:
        num_heads (int, req): net. output head. Defaults to 1.
        in_feats (int, req): net. input dimension. Defaults to 1.
        out_feats (int, req): net. output dimension per head. Defaults to 1.
        loss_type (str, req): type of loss function Defaults to "mse". ("mse","mce" for multi-class cross-entropy, "bce" binary-class cross-entropy)
        outs_class (bool, req): does model return class indices. Defaults to False, implying it outputs real-valued probabilities. This is also true for loss_type="mse" regardless of user-choice.
    """
    super().__init__()
    self.num_heads = num_heads
    
    # define mdl. params.
    self.linearfcn = nn.ModuleList()
    
    self.keylinear = nn.ModuleList()
    self.valuelinear = nn.ModuleList()
    self.multiheadattn  = nn.ModuleList()
    for _ in range(num_heads):
      self.keylinear.append(
        torch.nn.Linear(in_features=in_feats,out_features=in_feats, bias=True)
      )
      self.valuelinear.append(
        torch.nn.Linear(in_features=in_feats,out_features=in_feats, bias=True)
      )
      self.multiheadattn.append(
        torch.nn.MultiheadAttention(in_feats,1,batch_first=True,)
      )      
      self.linearfcn.append(
        torch.nn.Linear(in_features=in_feats,out_features=out_feats, bias=True)
      )

    self.relu = nn.ReLU()
    
    # prob.fcn at last output or network head layer
    if loss_type == "bce" or loss_type == "mse":
      self.out = torch.nn.Sigmoid()
    else:
      self.out = torch.nn.Softmax()
    
    self.loss_type = loss_type
    self.outs_class = outs_class
    
    # optimizer
    self.sgm = None
    
    # saved trained model
    self.chkpt = None
    
    
    self.devcnt = torch.cuda.device_count()
    self.device = None
    self.name = mdl_name
    
    if not(loss_type == "mse" or loss_type =="mce" or loss_type == "bce"):
      raise ValueError(f"loss_type='{loss_type}' is not defined for this class")
    if (loss_type == "mse"):
      self.outs_class = False    
    
@clsmethod(thisNN)
def forward(self:thisNN, x):
  # pre-process
  # x= x.unsqueeze(-1)
  # x = x.permute(0,2,1)
  logits = []
  for hid in range(self.num_heads):
    xq = x.unsqueeze(-1)
    xq = xq.permute(0,2,1)
    keylinear = self.keylinear[hid]
    valuelinear = self.valuelinear[hid]
    xk = xq + self.relu(keylinear(xq))
    xv = xq + self.relu(valuelinear(xq))
    
    multiheadattn = self.multiheadattn[hid]
    y,_ = multiheadattn(xq,xk,xv)
    y = y + self.relu(y)
    
    
    y = y.permute(0,2,1)
    y = y.squeeze(-1)
    linearfcn = self.linearfcn[hid]
    y = linearfcn(y)  
    logits.append(y)
    
  return logits # List [Tensor]

@clsmethod(thisNN)
def outhead(self:thisNN, x):
  probs = []
  for hid in range(self.num_heads):
    y = self.out(x[hid])
    probs.append(y)  
  return probs # List [Tensor]

# Add necessary functions to train model
add_to_thisnn(thisNN,worker_seed,setseed,cseedwk)

# %% [markdown]
# ##### Run the Network Modeling (Training)

# %%
# Test.

torch.manual_seed(2023)
devcnt = torch.cuda.device_count()

cfgs['mdl_name_dir'] = "nntoydata"
isclassifier = True
cfgs["ss_init"] = 1e-2
cfgs["eps_ss"] = 5e-1 # default 5e-1
cfgs["weight_decay"] = 1e-5 # default 1e-5
mdl = thisNN(num_heads=1,in_feats=2,out_feats=1,loss_type="bce",outs_class=isclassifier, mdl_name=cfgs['mdl_name_dir'])
if devcnt > 0:
    mdl.cuda()
cfgs['pathstr'] = str(mdl.name)+str(cfgs["batch-size"])+"_"+cfgs["dataset"]+"_"+str(cfgs["runs"])+"_"+str(cfgs["epochs"])

mdl.runs(train_data, test_data, cfgs=cfgs, eval_name="Test")
# Out:
# Seed: 2023
# ******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.01), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# ******************************************************************************************************************************************************
#
# ss0: 0.1174
# 1: Elapsed Train time: 0.08-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0471, Accuracy: 98.16% ] || Test: [ Avg Loss: 0.0089, Accuracy: 99.77% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0056, Accuracy: 99.86% ] || Test: [ Avg Loss: 0.0037, Accuracy: 99.85% ]
# Elapsed Inf. time: 0.01-mins.
#
# 3: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0034, Accuracy: 99.89% ] || Test: [ Avg Loss: 0.0027, Accuracy: 99.89% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0036, Accuracy: 99.89% ] || Test: [ Avg Loss: 0.0023, Accuracy: 99.91% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0037, Accuracy: 99.88% ] || Test: [ Avg Loss: 0.0023, Accuracy: 99.89% ]
# Elapsed Inf. time: 0.00-mins.
#
# 6: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0038, Accuracy: 99.89% ] || Test: [ Avg Loss: 0.0027, Accuracy: 99.93% ]
# Elapsed Inf. time: 0.00-mins.
#
# 7: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0040, Accuracy: 99.85% ] || Test: [ Avg Loss: 0.0067, Accuracy: 99.83% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0037, Accuracy: 99.90% ] || Test: [ Avg Loss: 0.0038, Accuracy: 99.88% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0075, Accuracy: 99.83% ] || Test: [ Avg Loss: 0.0037, Accuracy: 99.91% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0053, Accuracy: 99.81% ] || Test: [ Avg Loss: 0.0050, Accuracy: 99.87% ]
# Elapsed Inf. time: 0.01-mins.
#
# ********************************************************************************
# Done! Run: 1 : [Best Test @ epoch 6] || [ Avg loss: 0.002746, Accuracy: 99.93% ]
# ********************************************************************************
#
# ******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.01), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# ******************************************************************************************************************************************************
#
# ss0: 0.1552
# 1: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.3510, Accuracy: 92.00% ] || Test: [ Avg Loss: 0.0157, Accuracy: 99.54% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0130, Accuracy: 99.53% ] || Test: [ Avg Loss: 0.0087, Accuracy: 99.68% ]
# Elapsed Inf. time: 0.01-mins.
#
# 3: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0099, Accuracy: 99.65% ] || Test: [ Avg Loss: 0.0070, Accuracy: 99.73% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0079, Accuracy: 99.73% ] || Test: [ Avg Loss: 0.0060, Accuracy: 99.78% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0069, Accuracy: 99.76% ] || Test: [ Avg Loss: 0.0055, Accuracy: 99.80% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0264, Accuracy: 99.39% ] || Test: [ Avg Loss: 0.0104, Accuracy: 99.74% ]
# Elapsed Inf. time: 0.00-mins.
#
# 7: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0109, Accuracy: 99.76% ] || Test: [ Avg Loss: 0.0086, Accuracy: 99.73% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0096, Accuracy: 99.75% ] || Test: [ Avg Loss: 0.0059, Accuracy: 99.80% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0072, Accuracy: 99.76% ] || Test: [ Avg Loss: 0.0054, Accuracy: 99.80% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0070, Accuracy: 99.78% ] || Test: [ Avg Loss: 0.0050, Accuracy: 99.82% ]
# Elapsed Inf. time: 0.01-mins.
#
# *********************************************************************************
# Done! Run: 2 : [Best Test @ epoch 10] || [ Avg loss: 0.004989, Accuracy: 99.82% ]
# *********************************************************************************
#
# ******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.01), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# ******************************************************************************************************************************************************
#
# ss0: 0.1961
# 1: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.1662, Accuracy: 94.37% ] || Test: [ Avg Loss: 0.0092, Accuracy: 99.66% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0107, Accuracy: 99.58% ] || Test: [ Avg Loss: 0.0070, Accuracy: 99.76% ]
# Elapsed Inf. time: 0.01-mins.
#
# 3: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0096, Accuracy: 99.67% ] || Test: [ Avg Loss: 0.0070, Accuracy: 99.73% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.06-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0088, Accuracy: 99.72% ] || Test: [ Avg Loss: 0.0057, Accuracy: 99.80% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0087, Accuracy: 99.72% ] || Test: [ Avg Loss: 0.0059, Accuracy: 99.80% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0075, Accuracy: 99.76% ] || Test: [ Avg Loss: 0.0053, Accuracy: 99.82% ]
# Elapsed Inf. time: 0.01-mins.
#
# 7: Elapsed Train time: 0.06-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0088, Accuracy: 99.70% ] || Test: [ Avg Loss: 0.0056, Accuracy: 99.80% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0077, Accuracy: 99.75% ] || Test: [ Avg Loss: 0.0060, Accuracy: 99.78% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0075, Accuracy: 99.80% ] || Test: [ Avg Loss: 0.0070, Accuracy: 99.73% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0085, Accuracy: 99.75% ] || Test: [ Avg Loss: 0.0055, Accuracy: 99.76% ]
# Elapsed Inf. time: 0.01-mins.
#
# ********************************************************************************
# Done! Run: 3 : [Best Test @ epoch 6] || [ Avg loss: 0.005287, Accuracy: 99.82% ]
# ********************************************************************************
#
# ******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.01), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# ******************************************************************************************************************************************************
#
# ss0: 0.2375
# 1: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.1326, Accuracy: 95.60% ] || Test: [ Avg Loss: 0.0080, Accuracy: 99.69% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0085, Accuracy: 99.71% ] || Test: [ Avg Loss: 0.0066, Accuracy: 99.77% ]
# Elapsed Inf. time: 0.01-mins.
#
# 3: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0085, Accuracy: 99.71% ] || Test: [ Avg Loss: 0.0061, Accuracy: 99.76% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0100, Accuracy: 99.63% ] || Test: [ Avg Loss: 0.0078, Accuracy: 99.76% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0100, Accuracy: 99.70% ] || Test: [ Avg Loss: 0.0056, Accuracy: 99.80% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0077, Accuracy: 99.76% ] || Test: [ Avg Loss: 0.0080, Accuracy: 99.72% ]
# Elapsed Inf. time: 0.01-mins.
#
# 7: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0077, Accuracy: 99.75% ] || Test: [ Avg Loss: 0.0058, Accuracy: 99.74% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0090, Accuracy: 99.74% ] || Test: [ Avg Loss: 0.0052, Accuracy: 99.83% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0073, Accuracy: 99.77% ] || Test: [ Avg Loss: 0.0061, Accuracy: 99.78% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0083, Accuracy: 99.75% ] || Test: [ Avg Loss: 0.0055, Accuracy: 99.79% ]
# Elapsed Inf. time: 0.01-mins.
#
# ********************************************************************************
# Done! Run: 4 : [Best Test @ epoch 8] || [ Avg loss: 0.005206, Accuracy: 99.83% ]
# ********************************************************************************
#
# ******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.01), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# ******************************************************************************************************************************************************
#
# ss0: 0.2756
# 1: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.4012, Accuracy: 95.56% ] || Test: [ Avg Loss: 0.0083, Accuracy: 99.88% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0159, Accuracy: 99.85% ] || Test: [ Avg Loss: 0.0168, Accuracy: 99.69% ]
# Elapsed Inf. time: 0.01-mins.
#
# 3: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0140, Accuracy: 99.83% ] || Test: [ Avg Loss: 0.0034, Accuracy: 99.88% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0052, Accuracy: 99.88% ] || Test: [ Avg Loss: 0.0024, Accuracy: 99.93% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0043, Accuracy: 99.84% ] || Test: [ Avg Loss: 0.0027, Accuracy: 99.91% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0031, Accuracy: 99.89% ] || Test: [ Avg Loss: 0.0023, Accuracy: 99.90% ]
# Elapsed Inf. time: 0.01-mins.
#
# 7: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0051, Accuracy: 99.83% ] || Test: [ Avg Loss: 0.0022, Accuracy: 99.91% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0041, Accuracy: 99.86% ] || Test: [ Avg Loss: 0.0023, Accuracy: 99.91% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0033, Accuracy: 99.89% ] || Test: [ Avg Loss: 0.0024, Accuracy: 99.87% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0057, Accuracy: 99.76% ] || Test: [ Avg Loss: 0.0029, Accuracy: 99.89% ]
# Elapsed Inf. time: 0.01-mins.
#
# ********************************************************************************
# Done! Run: 5 : [Best Test @ epoch 4] || [ Avg loss: 0.002389, Accuracy: 99.93% ]
# ********************************************************************************
#
# ******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.01), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# ******************************************************************************************************************************************************
#
# ss0: 0.2277
# 1: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0158, Accuracy: 99.53% ] || Test: [ Avg Loss: 0.0052, Accuracy: 99.85% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0052, Accuracy: 99.84% ] || Test: [ Avg Loss: 0.0087, Accuracy: 99.82% ]
# Elapsed Inf. time: 0.01-mins.
#
# 3: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0045, Accuracy: 99.87% ] || Test: [ Avg Loss: 0.0107, Accuracy: 99.79% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0099, Accuracy: 99.76% ] || Test: [ Avg Loss: 0.0036, Accuracy: 99.89% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0059, Accuracy: 99.84% ] || Test: [ Avg Loss: 0.0027, Accuracy: 99.89% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0053, Accuracy: 99.84% ] || Test: [ Avg Loss: 0.0027, Accuracy: 99.93% ]
# Elapsed Inf. time: 0.01-mins.
#
# 7: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0071, Accuracy: 99.80% ] || Test: [ Avg Loss: 0.0038, Accuracy: 99.87% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.06-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0074, Accuracy: 99.72% ] || Test: [ Avg Loss: 0.0027, Accuracy: 99.94% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0038, Accuracy: 99.85% ] || Test: [ Avg Loss: 0.0027, Accuracy: 99.91% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0035, Accuracy: 99.90% ] || Test: [ Avg Loss: 0.0044, Accuracy: 99.90% ]
# Elapsed Inf. time: 0.00-mins.
#
# ********************************************************************************
# Done! Run: 6 : [Best Test @ epoch 8] || [ Avg loss: 0.002728, Accuracy: 99.94% ]
# ********************************************************************************
#
# ******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.01), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# ******************************************************************************************************************************************************
#
# ss0: 0.2412
# 1: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.2232, Accuracy: 96.75% ] || Test: [ Avg Loss: 0.0044, Accuracy: 99.88% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0032, Accuracy: 99.90% ] || Test: [ Avg Loss: 0.0024, Accuracy: 99.89% ]
# Elapsed Inf. time: 0.00-mins.
#
# 3: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0035, Accuracy: 99.90% ] || Test: [ Avg Loss: 0.0032, Accuracy: 99.89% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0030, Accuracy: 99.88% ] || Test: [ Avg Loss: 0.0023, Accuracy: 99.89% ]
# Elapsed Inf. time: 0.00-mins.
#
# 5: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0034, Accuracy: 99.89% ] || Test: [ Avg Loss: 0.0030, Accuracy: 99.89% ]
# Elapsed Inf. time: 0.00-mins.
#
# 6: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0045, Accuracy: 99.85% ] || Test: [ Avg Loss: 0.0037, Accuracy: 99.88% ]
# Elapsed Inf. time: 0.01-mins.
#
# 7: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0032, Accuracy: 99.89% ] || Test: [ Avg Loss: 0.0030, Accuracy: 99.88% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0043, Accuracy: 99.87% ] || Test: [ Avg Loss: 0.0023, Accuracy: 99.93% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0035, Accuracy: 99.85% ] || Test: [ Avg Loss: 0.0037, Accuracy: 99.89% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0036, Accuracy: 99.88% ] || Test: [ Avg Loss: 0.0040, Accuracy: 99.84% ]
# Elapsed Inf. time: 0.01-mins.
#
# ********************************************************************************
# Done! Run: 7 : [Best Test @ epoch 8] || [ Avg loss: 0.002298, Accuracy: 99.93% ]
# ********************************************************************************
#
# ******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.01), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# ******************************************************************************************************************************************************
#
# ss0: 0.2743
# 1: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.7880, Accuracy: 94.57% ] || Test: [ Avg Loss: 0.0062, Accuracy: 99.83% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0084, Accuracy: 99.76% ] || Test: [ Avg Loss: 0.0026, Accuracy: 99.93% ]
# Elapsed Inf. time: 0.01-mins.
#
# 3: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0078, Accuracy: 99.85% ] || Test: [ Avg Loss: 0.0041, Accuracy: 99.87% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0053, Accuracy: 99.85% ] || Test: [ Avg Loss: 0.0041, Accuracy: 99.88% ]
# Elapsed Inf. time: 0.00-mins.
#
# 5: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0042, Accuracy: 99.83% ] || Test: [ Avg Loss: 0.0031, Accuracy: 99.91% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0085, Accuracy: 99.74% ] || Test: [ Avg Loss: 0.0047, Accuracy: 99.90% ]
# Elapsed Inf. time: 0.01-mins.
#
# 7: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0064, Accuracy: 99.82% ] || Test: [ Avg Loss: 0.0028, Accuracy: 99.93% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0039, Accuracy: 99.85% ] || Test: [ Avg Loss: 0.0039, Accuracy: 99.88% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0041, Accuracy: 99.89% ] || Test: [ Avg Loss: 0.0024, Accuracy: 99.87% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0037, Accuracy: 99.89% ] || Test: [ Avg Loss: 0.0030, Accuracy: 99.87% ]
# Elapsed Inf. time: 0.01-mins.
#
# ********************************************************************************
# Done! Run: 8 : [Best Test @ epoch 2] || [ Avg loss: 0.002609, Accuracy: 99.93% ]
# ********************************************************************************
#
# ******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.01), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# ******************************************************************************************************************************************************
#
# ss0: 0.3086
# 1: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 1.4418, Accuracy: 86.55% ] || Test: [ Avg Loss: 0.2536, Accuracy: 94.85% ]
# Elapsed Inf. time: 0.00-mins.
#
# 2: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.2360, Accuracy: 95.00% ] || Test: [ Avg Loss: 0.2227, Accuracy: 94.92% ]
# Elapsed Inf. time: 0.00-mins.
#
# 3: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.1101, Accuracy: 97.39% ] || Test: [ Avg Loss: 0.0098, Accuracy: 99.85% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0061, Accuracy: 99.85% ] || Test: [ Avg Loss: 0.0037, Accuracy: 99.87% ]
# Elapsed Inf. time: 0.00-mins.
#
# 5: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0076, Accuracy: 99.73% ] || Test: [ Avg Loss: 0.0050, Accuracy: 99.82% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0072, Accuracy: 99.72% ] || Test: [ Avg Loss: 0.0032, Accuracy: 99.88% ]
# Elapsed Inf. time: 0.01-mins.
#
# 7: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0044, Accuracy: 99.89% ] || Test: [ Avg Loss: 0.0032, Accuracy: 99.88% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0041, Accuracy: 99.84% ] || Test: [ Avg Loss: 0.0021, Accuracy: 99.89% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0062, Accuracy: 99.80% ] || Test: [ Avg Loss: 0.0027, Accuracy: 99.89% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0042, Accuracy: 99.86% ] || Test: [ Avg Loss: 0.0029, Accuracy: 99.91% ]
# Elapsed Inf. time: 0.01-mins.
#
# *********************************************************************************
# Done! Run: 9 : [Best Test @ epoch 10] || [ Avg loss: 0.002921, Accuracy: 99.91% ]
# *********************************************************************************
#
# ******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.01), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# ******************************************************************************************************************************************************
#
# ss0: 0.3615
# 1: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.3513, Accuracy: 97.64% ] || Test: [ Avg Loss: 0.0131, Accuracy: 99.95% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0271, Accuracy: 99.89% ] || Test: [ Avg Loss: 0.0142, Accuracy: 99.94% ]
# Elapsed Inf. time: 0.01-mins.
#
# 3: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0219, Accuracy: 99.83% ] || Test: [ Avg Loss: 0.0059, Accuracy: 99.93% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0133, Accuracy: 99.87% ] || Test: [ Avg Loss: 0.0037, Accuracy: 99.88% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0051, Accuracy: 99.89% ] || Test: [ Avg Loss: 0.0044, Accuracy: 99.93% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0052, Accuracy: 99.91% ] || Test: [ Avg Loss: 0.0039, Accuracy: 99.91% ]
# Elapsed Inf. time: 0.01-mins.
#
# 7: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0110, Accuracy: 99.85% ] || Test: [ Avg Loss: 0.0036, Accuracy: 99.94% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.04-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0077, Accuracy: 99.83% ] || Test: [ Avg Loss: 0.0044, Accuracy: 99.84% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0060, Accuracy: 99.87% ] || Test: [ Avg Loss: 0.0031, Accuracy: 99.95% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0063, Accuracy: 99.89% ] || Test: [ Avg Loss: 0.0031, Accuracy: 99.90% ]
# Elapsed Inf. time: 0.01-mins.
#
# *********************************************************************************
# Done! Run: 10 : [Best Test @ epoch 1] || [ Avg loss: 0.013090, Accuracy: 99.95% ]
# *********************************************************************************
#
# ********************************************
# Average Prediction Difference = 0.00
# Effective Test Accuracy = 99.90, pval=0.0000
# ********************************************
# r:\Programs\Python\Python310\lib\site-packages\scipy\stats\_morestats.py:3255: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "

# %%
# Plots
plotter_v1(cfgs,run_idx=1)

# %% [markdown]
# Using the test (or development) dataset, the average prediction difference gives the average percent of the test (or development) dataset on which the trained network flips its decision.
#
# Subtracting the average prediction difference from the average test-accuracy,
# recallibrates the expected test-accuracy from the trained model, we call this the effective test-accuracy.
#
# Here, 10 statistical training runs leads to a combined 45 prediction comparisons, on which the prediction difference is computed.
