# %% [markdown]
# ##### Load Required Libraries

# %%
# !pip install watermark numpy pandas matplotlib torch torchvision torchaudio --yes

# %load_ext watermark
# %watermark -v -p watermark,numpy,pandas,matplotlib,torch

#
import math,random,os,copy,time,glob,itertools,shutil,re, json
from scipy.stats import wilcoxon

#
import numpy as np

#
import torch
import torch.nn as nn
import torch.nn.functional as tf
from torch.utils.data import Dataset,DataLoader
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor, Lambda

#
import matplotlib.pyplot as plt 
import matplotlib.ticker as ticker
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif", # serif
    "font.sans-serif": "Helvetica", # Times, Palatino, Computer Modern Roman
})
from mpl_toolkits import mplot3d
from mpl_toolkits import mplot3d
import matplotlib.animation as animation
from matplotlib import gridspec
from IPython.display import clear_output
from mpl_toolkits.mplot3d import proj3d
from matplotlib.patches import FancyArrowPatch
from matplotlib.text import Annotation
from mpl_toolkits.mplot3d.proj3d import proj_transform
#
import pandas as pd


#
from demofcns import *
from opts.asgm.torchlasgm import PID
from opts.elpf.fo import LPF
from opts.elpf.sfo import sLPF

worker_seed = 2023
def setseed(inc=0):
    # for redundancy
    # set seed for technical reproducibility
    myseed = worker_seed + inc
    random.seed(myseed)
    np.random.seed(myseed)
    np.random.default_rng(myseed)
    torch.manual_seed(myseed)    
    
    # torch.use_deterministic_algorithms(True)
    if torch.cuda.device_count() > 0:
      torch.cuda.manual_seed_all(myseed)
      torch.cuda.manual_seed(myseed)
      # torch.backends.cudnn.enabled = True
      # torch.backends.cuda.matmul.allow_tf32 = False
      # torch.backends.cudnn.benchmark = False
      # torch.backends.cudnn.deterministic = False
      # torch.backends.cudnn.allow_tf32 = True



class cseed_worker():
  def __init__(self,inc=0):
    self.inc = inc
    
  def seed_worker(self,workerid):
    np.random.seed(worker_seed+self.inc)
    random.seed(worker_seed+self.inc)

cseedwk = cseed_worker()

# python3 -m torch.utils.collect_env
# Out:
# Python implementation: CPython
# Python version       : 3.10.6
# IPython version      : 8.4.0
#
# watermark : 2.3.1
# numpy     : 1.23.2
# pandas    : 1.4.3
# matplotlib: 3.5.3
# torch     : 1.12.1+cu116

# %% [markdown]
# ##### Setup Configurations (Hyperparameters and so on)

# %%
# - is it being run remotely on OSU EECS server?
remotelyrun = 0 # 0 | 1

#----------------------
# Load setup config
#----------------------
with open('cfgs.json', 'r') as cfglist:
  cfgs = json.load(cfglist)
  
# setup
cfgs['storedir'] = "expstore"

# - pick data-set
cfgs["dataset"] = "atoy"
# - set std. batchsize for each epoch, runs, epochs, multiprocessing, human
cfgs["batch-size"] = 128 # 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, ...
cfgs['runs'] = 10
cfgs["epochs"] = 5

# -pick computation device
devcnt = torch.cuda.device_count()

# random seed for python libraries
cfgs["seed"] = 2023
cfgs["var_seed"] = 1
worker_seed = cfgs["seed"] % (2**32)
cfgs["num-workers"] = 0 #3
cfgs["human_signature"] = "oas" # for signing experiments ran.

if devcnt > 1:
  cfgs["device"] = torch.device('cuda') # "cuda:1"
  torch.cuda.set_device(1)
elif devcnt == 1:
  cfgs["device"] = torch.device('cuda')
else:
  cfgs["device"] = torch.device('cpu')
#
if remotelyrun:
  cfgs["remote"] = True
else:
  cfgs["remote"] = False

# %% [markdown]
# ##### Construct Model (Differentiable Function) with  necessary methods.

# %%
class thisNN(nn.Module):
  def __init__(self,num_heads=1,in_feats=1,out_feats=1, loss_type="mse", outs_class=False, mdl_name="nn1") -> None:
    """
    __init__ _summary_

    _extended_summary_

    Args:
        num_heads (int, req): net. output head. Defaults to 1.
        in_feats (int, req): net. input dimension. Defaults to 1.
        out_feats (int, req): net. output dimension per head. Defaults to 1.
        loss_type (str, req): type of loss function Defaults to "mse". ("mse","mce" for multi-class cross-entropy, "bce" binary-class cross-entropy)
        outs_class (bool, req): does model return class indices. Defaults to False, implying it outputs real-valued probabilities. This is also true for loss_type="mse" regardless of user-choice.
    """
    super().__init__()
    self.num_heads = num_heads
    
    # define mdl. params.
    self.linearfcn = nn.ModuleList()
    
    self.keylinear = nn.ModuleList()
    self.valuelinear = nn.ModuleList()
    self.multiheadattn  = nn.ModuleList()
    for _ in range(num_heads):
      self.keylinear.append(
        torch.nn.Linear(in_features=in_feats,out_features=in_feats, bias=True)
      )
      self.valuelinear.append(
        torch.nn.Linear(in_features=in_feats,out_features=in_feats, bias=True)
      )
      self.multiheadattn.append(
        torch.nn.MultiheadAttention(in_feats,1,batch_first=True,)
      )      
      self.linearfcn.append(
        torch.nn.Linear(in_features=in_feats,out_features=out_feats, bias=True)
      )

    self.relu = nn.ReLU()
    
    # prob.fcn at last output or network head layer
    if loss_type == "bce" or loss_type == "mse":
      self.out = torch.nn.Sigmoid()
    else:
      self.out = torch.nn.Softmax()
    
    self.loss_type = loss_type
    self.outs_class = outs_class
    
    # optimizer
    self.sgm = None
    
    # saved trained model
    self.chkpt = None
    
    
    self.devcnt = torch.cuda.device_count()
    self.device = None
    self.name = mdl_name
    
    if not(loss_type == "mse" or loss_type =="mce" or loss_type == "bce"):
      raise ValueError(f"loss_type='{loss_type}' is not defined for this class")
    if (loss_type == "mse"):
      self.outs_class = False    
    
@clsmethod(thisNN)
def forward(self:thisNN, x):
  # pre-process
  # x= x.unsqueeze(-1)
  # x = x.permute(0,2,1)
  logits = []
  for hid in range(self.num_heads):
    xq = x.unsqueeze(-1)
    xq = xq.permute(0,2,1)
    keylinear = self.keylinear[hid]
    valuelinear = self.valuelinear[hid]
    xk = xq + self.relu(keylinear(xq))
    xv = xq + self.relu(valuelinear(xq))
    
    multiheadattn = self.multiheadattn[hid]
    y,_ = multiheadattn(xq,xk,xv)
    y = y + self.relu(y)
    
    
    y = y.permute(0,2,1)
    y = y.squeeze(-1)
    linearfcn = self.linearfcn[hid]
    y = linearfcn(y)  
    logits.append(y)
    
  return logits # List [Tensor]

@clsmethod(thisNN)
def outhead(self:thisNN, x):
  probs = []
  for hid in range(self.num_heads):
    y = self.out(x[hid])
    probs.append(y)  
  return probs # List [Tensor]

# Add necessary functions to train model
add_to_thisnn(thisNN,worker_seed,setseed,cseedwk)

# %% [markdown]
# ##### (Generate) or Load the Dataset

# %%
#----------------------
# Download/Load Dataset
#----------------------
if not cfgs["remote"]:
  # same dir. as source-code
  data_folder = "data"
else:
  # dalton's scratch on OSU's eecs server
  data_folder = "/scratch/data"


# aToy
class aToy(Dataset):
    def __init__(self, data, split="", transform=None, target_transform=None):
      if split=="train": 
        self.data = data['train']
      elif split=="val" or split=="test":
        self.data = data['dev']
      #
      self.transform = transform
      self.target_transform = target_transform
      
      self.input = self.data['in']      
      self.labels = self.data['out']
        
            
    def __len__(self):
      return self.labels.shape[0]
    
    def __getitem__(self, idx):
        
      x = self.input[idx,:]
      y = self.labels[idx,]

      # transforms ...
      if self.transform:
        x = self.transform(x)
      if self.target_transform:
        y = self.target_transform(y)
          
        
      return x,y
    
def aToyGenerator(data_dir=f"{data_folder}/toydata_twofeatures_two_class.txt"):
  
  # Dataset with input: dim = 2 and ouput: class = binary, dim = 1 
  df = pd.read_csv(data_dir, sep="\t")
  # print(df.head())
  data_in = torch.tensor(df[["x1", "x2"]].values, dtype=torch.float)
  data_out = torch.tensor(df["label"].values, dtype=torch.int64)
  
  #
  torch.Generator().manual_seed(0)
  for i in range(10):
    data_in = torch.cat([data_in, data_in+torch.normal(0,0.1,size=(data_in.shape[0],1))])
    data_out = torch.cat([data_out,data_out])
    
  #
  intrain, inval = torch.utils.data.random_split(data_in, [int(0.6*data_in.shape[0]), int(0.4*data_in.shape[0])], generator=torch.Generator().manual_seed(0))
  # print(len(intrain.indices))
  
  atoy_data_train = {"in":data_in[intrain.indices,:], "out":data_out[intrain.indices,]}
  atoy_data_dev = {"in":data_in[inval.indices,:], "out":data_out[inval.indices,]}
  return {"train":atoy_data_train, "dev":atoy_data_dev}

if cfgs["dataset"] == "atoy":
  atoy_data = aToyGenerator()
  train_data = aToy(atoy_data,split="train")   
  test_data = aToy(atoy_data,split="test")

# %% [markdown]
# ##### Run the Network Modeling (Training)

# %%
# Test.

torch.manual_seed(2023)
devcnt = torch.cuda.device_count()

cfgs['mdl_name_dir'] = "nntoydata"
isclassifier = True
cfgs["ss_init"] = 1e-2
cfgs["eps_ss"] = 5e-1 # default 5e-1
cfgs["weight_decay"] = 1e-5 # default 1e-5
mdl = thisNN(num_heads=1,in_feats=2,out_feats=1,loss_type="bce",outs_class=isclassifier, mdl_name=cfgs['mdl_name_dir'])
if devcnt > 0:
    mdl.cuda()
cfgs['pathstr'] = str(mdl.name)+str(cfgs["batch-size"])+"_"+cfgs["dataset"]+"_"+str(cfgs["runs"])+"_"+str(cfgs["epochs"])

mdl.runs(train_data, test_data, cfgs=cfgs, eval_name="Test")
# Out:
# Seed: 2023
# ******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.01), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# ******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.05-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.1768, Accuracy: 94.03% ] || Test: [ Avg Loss: 0.1279, Accuracy: 94.95% ]
# Elapsed Inf. time: 0.00-mins.
#
# 2: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0615, Accuracy: 97.26% ] || Test: [ Avg Loss: 0.0167, Accuracy: 99.78% ]
# Elapsed Inf. time: 0.00-mins.
#
# 3: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0062, Accuracy: 99.91% ] || Test: [ Avg Loss: 0.0053, Accuracy: 99.85% ]
# Elapsed Inf. time: 0.00-mins.
#
# 4: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0030, Accuracy: 99.95% ] || Test: [ Avg Loss: 0.0041, Accuracy: 99.84% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0022, Accuracy: 99.95% ] || Test: [ Avg Loss: 0.0044, Accuracy: 99.84% ]
# Elapsed Inf. time: 0.00-mins.
#
# ********************************************************************************
# Done! Run: 1 : [Best Test @ epoch 3] || [ Avg loss: 0.005254, Accuracy: 99.85% ]
# ********************************************************************************
#
# ******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.01), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# ******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.2115, Accuracy: 94.98% ] || Test: [ Avg Loss: 0.0171, Accuracy: 99.82% ]
# Elapsed Inf. time: 0.00-mins.
#
# 2: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0108, Accuracy: 99.91% ] || Test: [ Avg Loss: 0.0090, Accuracy: 99.83% ]
# Elapsed Inf. time: 0.00-mins.
#
# 3: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0063, Accuracy: 99.93% ] || Test: [ Avg Loss: 0.0066, Accuracy: 99.83% ]
# Elapsed Inf. time: 0.00-mins.
#
# 4: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0046, Accuracy: 99.93% ] || Test: [ Avg Loss: 0.0055, Accuracy: 99.83% ]
# Elapsed Inf. time: 0.00-mins.
#
# 5: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0037, Accuracy: 99.93% ] || Test: [ Avg Loss: 0.0051, Accuracy: 99.84% ]
# Elapsed Inf. time: 0.00-mins.
#
# ********************************************************************************
# Done! Run: 2 : [Best Test @ epoch 5] || [ Avg loss: 0.005126, Accuracy: 99.84% ]
# ********************************************************************************
#
# ******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.01), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# ******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.8364, Accuracy: 62.26% ] || Test: [ Avg Loss: 0.5759, Accuracy: 86.13% ]
# Elapsed Inf. time: 0.00-mins.
#
# 2: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.3720, Accuracy: 90.93% ] || Test: [ Avg Loss: 0.2420, Accuracy: 94.95% ]
# Elapsed Inf. time: 0.00-mins.
#
# 3: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.1675, Accuracy: 94.61% ] || Test: [ Avg Loss: 0.1243, Accuracy: 94.19% ]
# Elapsed Inf. time: 0.00-mins.
#
# 4: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0839, Accuracy: 96.20% ] || Test: [ Avg Loss: 0.0600, Accuracy: 97.83% ]
# Elapsed Inf. time: 0.00-mins.
#
# 5: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0432, Accuracy: 98.72% ] || Test: [ Avg Loss: 0.0343, Accuracy: 99.12% ]
# Elapsed Inf. time: 0.00-mins.
#
# ********************************************************************************
# Done! Run: 3 : [Best Test @ epoch 5] || [ Avg loss: 0.034319, Accuracy: 99.12% ]
# ********************************************************************************
#
# ******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.01), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# ******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.9050, Accuracy: 66.38% ] || Test: [ Avg Loss: 0.1368, Accuracy: 97.44% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0587, Accuracy: 99.41% ] || Test: [ Avg Loss: 0.0242, Accuracy: 99.74% ]
# Elapsed Inf. time: 0.00-mins.
#
# 3: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0132, Accuracy: 99.87% ] || Test: [ Avg Loss: 0.0095, Accuracy: 99.83% ]
# Elapsed Inf. time: 0.00-mins.
#
# 4: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0066, Accuracy: 99.91% ] || Test: [ Avg Loss: 0.0066, Accuracy: 99.83% ]
# Elapsed Inf. time: 0.00-mins.
#
# 5: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0046, Accuracy: 99.93% ] || Test: [ Avg Loss: 0.0055, Accuracy: 99.83% ]
# Elapsed Inf. time: 0.01-mins.
#
# ********************************************************************************
# Done! Run: 4 : [Best Test @ epoch 3] || [ Avg loss: 0.009511, Accuracy: 99.83% ]
# ********************************************************************************
#
# ******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.01), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# ******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.4251, Accuracy: 87.52% ] || Test: [ Avg Loss: 0.1432, Accuracy: 94.95% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0895, Accuracy: 95.55% ] || Test: [ Avg Loss: 0.0556, Accuracy: 98.00% ]
# Elapsed Inf. time: 0.00-mins.
#
# 3: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0294, Accuracy: 99.43% ] || Test: [ Avg Loss: 0.0175, Accuracy: 99.78% ]
# Elapsed Inf. time: 0.00-mins.
#
# 4: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0115, Accuracy: 99.86% ] || Test: [ Avg Loss: 0.0090, Accuracy: 99.84% ]
# Elapsed Inf. time: 0.00-mins.
#
# 5: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0065, Accuracy: 99.94% ] || Test: [ Avg Loss: 0.0063, Accuracy: 99.83% ]
# Elapsed Inf. time: 0.00-mins.
#
# ********************************************************************************
# Done! Run: 5 : [Best Test @ epoch 4] || [ Avg loss: 0.009028, Accuracy: 99.84% ]
# ********************************************************************************
#
# ******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.01), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# ******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.4496, Accuracy: 87.16% ] || Test: [ Avg Loss: 0.0935, Accuracy: 94.95% ]
# Elapsed Inf. time: 0.00-mins.
#
# 2: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0428, Accuracy: 98.35% ] || Test: [ Avg Loss: 0.0210, Accuracy: 99.71% ]
# Elapsed Inf. time: 0.00-mins.
#
# 3: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0128, Accuracy: 99.80% ] || Test: [ Avg Loss: 0.0097, Accuracy: 99.80% ]
# Elapsed Inf. time: 0.00-mins.
#
# 4: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0069, Accuracy: 99.88% ] || Test: [ Avg Loss: 0.0065, Accuracy: 99.80% ]
# Elapsed Inf. time: 0.00-mins.
#
# 5: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0046, Accuracy: 99.89% ] || Test: [ Avg Loss: 0.0052, Accuracy: 99.83% ]
# Elapsed Inf. time: 0.00-mins.
#
# ********************************************************************************
# Done! Run: 6 : [Best Test @ epoch 5] || [ Avg loss: 0.005238, Accuracy: 99.83% ]
# ********************************************************************************
#
# ******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.01), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# ******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0074, Accuracy: 99.85% ] || Test: [ Avg Loss: 0.0040, Accuracy: 99.84% ]
# Elapsed Inf. time: 0.00-mins.
#
# 2: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0022, Accuracy: 99.94% ] || Test: [ Avg Loss: 0.0036, Accuracy: 99.85% ]
# Elapsed Inf. time: 0.00-mins.
#
# 3: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0017, Accuracy: 99.94% ] || Test: [ Avg Loss: 0.0040, Accuracy: 99.85% ]
# Elapsed Inf. time: 0.00-mins.
#
# 4: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0015, Accuracy: 99.95% ] || Test: [ Avg Loss: 0.0038, Accuracy: 99.83% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0021, Accuracy: 99.90% ] || Test: [ Avg Loss: 0.0038, Accuracy: 99.84% ]
# Elapsed Inf. time: 0.00-mins.
#
# ********************************************************************************
# Done! Run: 7 : [Best Test @ epoch 2] || [ Avg loss: 0.003583, Accuracy: 99.85% ]
# ********************************************************************************
#
# ******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.01), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# ******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0044, Accuracy: 99.85% ] || Test: [ Avg Loss: 0.0039, Accuracy: 99.85% ]
# Elapsed Inf. time: 0.00-mins.
#
# 2: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0012, Accuracy: 99.96% ] || Test: [ Avg Loss: 0.0034, Accuracy: 99.84% ]
# Elapsed Inf. time: 0.00-mins.
#
# 3: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0012, Accuracy: 99.96% ] || Test: [ Avg Loss: 0.0039, Accuracy: 99.84% ]
# Elapsed Inf. time: 0.00-mins.
#
# 4: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0010, Accuracy: 99.94% ] || Test: [ Avg Loss: 0.0057, Accuracy: 99.87% ]
# Elapsed Inf. time: 0.00-mins.
#
# 5: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0013, Accuracy: 99.93% ] || Test: [ Avg Loss: 0.0062, Accuracy: 99.85% ]
# Elapsed Inf. time: 0.00-mins.
#
# ********************************************************************************
# Done! Run: 8 : [Best Test @ epoch 4] || [ Avg loss: 0.005718, Accuracy: 99.87% ]
# ********************************************************************************
#
# ******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.01), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# ******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 4.1621, Accuracy: 12.50% ] || Test: [ Avg Loss: 0.9336, Accuracy: 10.63% ]
# Elapsed Inf. time: 0.00-mins.
#
# 2: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.6752, Accuracy: 62.04% ] || Test: [ Avg Loss: 0.5314, Accuracy: 91.00% ]
# Elapsed Inf. time: 0.00-mins.
#
# 3: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.3462, Accuracy: 96.26% ] || Test: [ Avg Loss: 0.1943, Accuracy: 98.96% ]
# Elapsed Inf. time: 0.00-mins.
#
# 4: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0754, Accuracy: 99.61% ] || Test: [ Avg Loss: 0.0377, Accuracy: 99.76% ]
# Elapsed Inf. time: 0.00-mins.
#
# 5: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.0248, Accuracy: 99.86% ] || Test: [ Avg Loss: 0.0190, Accuracy: 99.78% ]
# Elapsed Inf. time: 0.00-mins.
#
# ********************************************************************************
# Done! Run: 9 : [Best Test @ epoch 5] || [ Avg loss: 0.019008, Accuracy: 99.78% ]
# ********************************************************************************
#
# ******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.01), (ending := 0), step-size pole : 0.9928],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# ******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 3.2628, Accuracy: 80.44% ] || Test: [ Avg Loss: 1.3695, Accuracy: 89.53% ]
# Elapsed Inf. time: 0.01-mins.
#
# 2: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.7574, Accuracy: 90.29% ] || Test: [ Avg Loss: 0.5121, Accuracy: 89.45% ]
# Elapsed Inf. time: 0.00-mins.
#
# 3: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.3849, Accuracy: 90.30% ] || Test: [ Avg Loss: 0.3440, Accuracy: 89.53% ]
# Elapsed Inf. time: 0.00-mins.
#
# 4: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.3055, Accuracy: 91.15% ] || Test: [ Avg Loss: 0.2957, Accuracy: 92.64% ]
# Elapsed Inf. time: 0.00-mins.
#
# 5: Elapsed Train time: 0.03-mins.
# Batches/Steps/Iterations per Epoch:    96
# Train:	[ Avg Loss: 0.2641, Accuracy: 94.75% ] || Test: [ Avg Loss: 0.2494, Accuracy: 94.92% ]
# Elapsed Inf. time: 0.00-mins.
#
# *********************************************************************************
# Done! Run: 10 : [Best Test @ epoch 5] || [ Avg loss: 0.249379, Accuracy: 94.92% ]
# *********************************************************************************
#
# Effective Test Accuracy=99.26143934461805, pval=5.684341886080802e-14

# %%
# Plots

plotter_v1(cfgs,run_idx=1)
# Out:
# r:\ai535py\dlexps\opts\demofcns.py:671: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "." (-> marker='.'). The keyword argument will take precedence.
#   ax2.plot(dev_preds_per_run.values, '.', c=color,
