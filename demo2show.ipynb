# %% [markdown]
# ##### Load Required Libraries

# %%
# !pip install watermark numpy pandas matplotlib torch torchvision torchaudio --yes

# %load_ext watermark
# %watermark -v -p watermark,numpy,pandas,matplotlib,torch

#
import math,random,os,copy,time,glob,itertools,shutil,re, json
from scipy.stats import wilcoxon

#
import numpy as np

#
import torch
import torch.nn as nn
import torch.nn.functional as tf
from torch.utils.data import Dataset,DataLoader
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor, Lambda

#
import matplotlib.pyplot as plt 
import matplotlib.ticker as ticker
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif", # sans-serif
    "font.sans-serif": "Helvetica", # Times, Palatino, Computer Modern Roman
})
from mpl_toolkits import mplot3d

#
import pandas as pd


#
from demofcns import *
from opts.asgm.torchlasgm import PID
from opts.elpf.fo import LPF
from opts.elpf.sfo import sLPF

worker_seed = 2023
def setseed(inc=0):
    # for redundancy
    # set seed for technical reproducibility
    myseed = worker_seed + inc
    random.seed(myseed)
    np.random.seed(myseed)
    np.random.default_rng(myseed)
    torch.manual_seed(myseed)    
    
    # torch.use_deterministic_algorithms(True)
    if torch.cuda.device_count() > 0:
      torch.cuda.manual_seed_all(myseed)
      torch.cuda.manual_seed(myseed)
      # torch.backends.cudnn.enabled = True
      # torch.backends.cuda.matmul.allow_tf32 = False
      # torch.backends.cudnn.benchmark = False
      # torch.backends.cudnn.deterministic = False
      # torch.backends.cudnn.allow_tf32 = True



class cseed_worker():
  def __init__(self,inc=0):
    self.inc = inc
    
  def seed_worker(self,workerid):
    np.random.seed(worker_seed+self.inc)
    random.seed(worker_seed+self.inc)

cseedwk = cseed_worker()

# python3 -m torch.utils.collect_env
# Out:
# Python implementation: CPython
# Python version       : 3.10.6
# IPython version      : 8.4.0
#
# watermark : 2.3.1
# numpy     : 1.23.2
# pandas    : 1.4.3
# matplotlib: 3.5.3
# torch     : 1.12.1+cu116

# %% [markdown]
# ##### Setup Configurations (Hyperparameters and so on)

# %%
# - is it being run remotely on OSU EECS server?
remotelyrun = 0 # 0 | 1

#----------------------
# Load setup config
#----------------------
with open('cfgs.json', 'r') as cfglist:
  cfgs = json.load(cfglist)
  
# setup
cfgs['storedir'] = "expstore"

# - pick data-set
cfgs["dataset"] = "fmnist"
# - set std. batchsize for each epoch, runs, epochs, multiprocessing, human
cfgs["batch-size"] = 128 # 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, ...
cfgs['runs'] = 10
cfgs["epochs"] = 30

# -pick computation device
devcnt = torch.cuda.device_count()

# random seed for python libraries
cfgs["seed"] = 2023
cfgs["var_seed"] = 1
worker_seed = cfgs["seed"] % (2**32)
cfgs["num-workers"] = 0 #3
cfgs["human_signature"] = "oas" # for signing experiments ran.



if devcnt > 1:
  cfgs["device"] = torch.device('cuda') # "cuda:1"
  torch.cuda.set_device(1)
elif devcnt == 1:
  cfgs["device"] = torch.device('cuda')
else:
  cfgs["device"] = torch.device('cpu')
#
if remotelyrun:
  cfgs["remote"] = True
else:
  cfgs["remote"] = False

# %% [markdown]
# ##### Construct Model (Differentiable Function) with  necessary methods.

# %%
class thisNN(nn.Module):
  def __init__(self,num_heads=1,in_feats=1,out_feats=1, loss_type="mse", outs_class=False, mdl_name="nn1") -> None:
    """
    __init__ _summary_

    _extended_summary_

    Args:
        num_heads (int, req): net. output head. Defaults to 1.
        in_feats (int, req): net. input dimension. Defaults to 1.
        out_feats (int, req): net. output dimension per head. Defaults to 1.
        loss_type (str, req): type of loss function Defaults to "mse". ("mse","mce" for multi-class cross-entropy, "bce" binary-class cross-entropy)
        outs_class (bool, req): does model return class indices. Defaults to False, implying it outputs real-valued probabilities. This is also true for loss_type="mse" regardless of user-choice.
    """
    super().__init__()
    self.num_heads = num_heads
    
    # define mdl. params.
    self.linearfcn = nn.ModuleList()
    
    self.keylinear = nn.ModuleList()
    self.valuelinear = nn.ModuleList()
    self.multiheadattn  = nn.ModuleList()
    self.ma_norm  = nn.ModuleList()
    for _ in range(num_heads):
      self.keylinear.append(
        nn.Sequential(
          torch.nn.Linear(in_features=in_feats[0],out_features=in_feats[0], bias=False),
          torch.nn.LayerNorm(normalized_shape=in_feats[0])
          )
      )
      self.valuelinear.append(
        nn.Sequential(
          torch.nn.Linear(in_features=in_feats[0],out_features=in_feats[0], bias=False),
          torch.nn.LayerNorm(normalized_shape=in_feats[0])
          )
      )
      self.multiheadattn.append(
            torch.nn.MultiheadAttention(in_feats[0],1,batch_first=True,)
      )
      
      self.ma_norm.append(
        torch.nn.LayerNorm(normalized_shape=in_feats[0])
      )
            
      self.linearfcn.append(
        torch.nn.Linear(in_features=in_feats[0]*in_feats[1],out_features=out_feats, bias=True)
      )

    self.relu = nn.ReLU()
    self.flatten = nn.Flatten()
    
    # prob.fcn at last output or network head layer
    if loss_type == "bce" or loss_type == "mse":
      self.out = torch.nn.Sigmoid()
    else:
      self.out = torch.nn.Softmax()
    
    self.loss_type = loss_type
    self.outs_class = outs_class
    
    # optimizer
    self.sgm = None
    
    # saved trained model
    self.chkpt = None
    
    
    self.devcnt = torch.cuda.device_count()
    self.device = None
    self.name = mdl_name
    
    if not(loss_type == "mse" or loss_type =="mce" or loss_type == "bce"):
      raise ValueError(f"loss_type='{loss_type}' is not defined for this class")
    if (loss_type == "mse"):
      self.outs_class = False    
    
@clsmethod(thisNN)
def forward(self:thisNN, x):
  # pre-process
  x = x.squeeze() # N x 1 x 28 x 28 -> N x 28 x 28
  logits = []
  for hid in range(self.num_heads):
    # xq = x.permute(0,2,1)
    xq = x
    keylinear = self.keylinear[hid]
    valuelinear = self.valuelinear[hid]
    xk = xq + self.relu(keylinear(xq))
    xv = xq + self.relu(valuelinear(xq))
    
    multiheadattn = self.multiheadattn[hid]
    manorm = self.ma_norm[hid]
    y,_ = multiheadattn(xq,xk,xv)
    y = y + self.relu(manorm(y))
    
    
    # y = y.permute(0,2,1)
    y = self.flatten(y)
    linearfcn = self.linearfcn[hid]
    y = linearfcn(y)  
    logits.append(y)
    
  return logits # List [Tensor]

@clsmethod(thisNN)
def outhead(self:thisNN, x):
  probs = []
  for hid in range(self.num_heads):
    y = self.out(x[hid])
    probs.append(y)  
  return probs # List [Tensor]

# Add necessary functions to train model
add_to_thisnn(thisNN,worker_seed,setseed,cseedwk)

# Use saved mdl as
# mdl <-- load model function
# prediction = mdl.infer(input)

# %% [markdown]
# ##### (Generate) or Load the Dataset

# %%
#----------------------
# Download/Load Dataset
#----------------------
if not cfgs["remote"]:
  # same dir. as source-code
  data_folder = "data"
else:
  # dalton's scratch on OSU's eecs server
  data_folder = "/scratch/data"


# FMNIST
if cfgs["dataset"] == "fmnist":
  train_data = datasets.FashionMNIST(
    root=data_folder,
    train=True,
    download=True,
    transform=ToTensor(),
  )
  test_data = datasets.FashionMNIST(
    root=data_folder,
    train=False,
    download= True,
    transform=ToTensor()
  )
  indim = [28,28]
  class_num = 10
  channels = 1
  val_data = None
  
# Tests 
trainloader = torch.utils.data.DataLoader(train_data, batch_size=cfgs['batch-size'],shuffle=True)
# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)
pass

# %% [markdown]
# ##### Run the Network Modeling (Training)

# %%
# Test.

torch.manual_seed(2023)
devcnt = torch.cuda.device_count()

cfgs['mdl_name_dir'] = "nnfmnist"
isclassifier = True
cfgs["ss_init"] = 1e-3 # default 1e-3
cfgs["eps_ss"] = 5e-1 # default 5e-1
cfgs["weight_decay"] = 1e-5 # default 1e-5
mdl = thisNN(num_heads=1,in_feats=[28,28],out_feats=10,loss_type="mce",outs_class=isclassifier, mdl_name=cfgs['mdl_name_dir'])
if devcnt > 0:
    mdl.cuda()
cfgs['pathstr'] = str(mdl.name)+str(cfgs["batch-size"])+"_"+cfgs["dataset"]+"_"+str(cfgs["runs"])+"_"+str(cfgs["epochs"])

mdl.runs(train_data, test_data, cfgs=cfgs, eval_name="Test")
# Out:
# Seed: 2023
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9985],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.30-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 1.3236, Accuracy: 63.51% ] || Test: [ Avg Loss: 0.7567, Accuracy: 73.24% ]
# Elapsed Inf. time: 0.04-mins.
#
# 2: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.6569, Accuracy: 76.79% ] || Test: [ Avg Loss: 0.6145, Accuracy: 78.42% ]
# Elapsed Inf. time: 0.02-mins.
#
# 3: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5759, Accuracy: 79.77% ] || Test: [ Avg Loss: 0.5719, Accuracy: 79.82% ]
# Elapsed Inf. time: 0.02-mins.
#
# 4: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5361, Accuracy: 81.06% ] || Test: [ Avg Loss: 0.5413, Accuracy: 80.77% ]
# Elapsed Inf. time: 0.02-mins.
#
# 5: Elapsed Train time: 0.28-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5078, Accuracy: 82.02% ] || Test: [ Avg Loss: 0.5372, Accuracy: 81.43% ]
# Elapsed Inf. time: 0.02-mins.
#
# 6: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4915, Accuracy: 82.54% ] || Test: [ Avg Loss: 0.5170, Accuracy: 81.59% ]
# Elapsed Inf. time: 0.02-mins.
#
# 7: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4733, Accuracy: 83.31% ] || Test: [ Avg Loss: 0.4879, Accuracy: 82.49% ]
# Elapsed Inf. time: 0.02-mins.
#
# 8: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4647, Accuracy: 83.59% ] || Test: [ Avg Loss: 0.4789, Accuracy: 83.07% ]
# Elapsed Inf. time: 0.02-mins.
#
# 9: Elapsed Train time: 1.47-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4493, Accuracy: 84.08% ] || Test: [ Avg Loss: 0.4757, Accuracy: 83.41% ]
# Elapsed Inf. time: 0.06-mins.
#
# 10: Elapsed Train time: 0.65-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4437, Accuracy: 84.28% ] || Test: [ Avg Loss: 0.4639, Accuracy: 83.46% ]
# Elapsed Inf. time: 0.02-mins.
#
# 11: Elapsed Train time: 0.36-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4347, Accuracy: 84.63% ] || Test: [ Avg Loss: 0.4557, Accuracy: 83.81% ]
# Elapsed Inf. time: 0.02-mins.
#
# 12: Elapsed Train time: 0.36-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4292, Accuracy: 84.73% ] || Test: [ Avg Loss: 0.4614, Accuracy: 83.77% ]
# Elapsed Inf. time: 0.02-mins.
#
# 13: Elapsed Train time: 0.34-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4191, Accuracy: 85.05% ] || Test: [ Avg Loss: 0.4421, Accuracy: 84.36% ]
# Elapsed Inf. time: 0.02-mins.
#
# 14: Elapsed Train time: 0.33-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4099, Accuracy: 85.35% ] || Test: [ Avg Loss: 0.4564, Accuracy: 83.44% ]
# Elapsed Inf. time: 0.03-mins.
#
# 15: Elapsed Train time: 0.34-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4092, Accuracy: 85.48% ] || Test: [ Avg Loss: 0.4398, Accuracy: 84.47% ]
# Elapsed Inf. time: 0.02-mins.
#
# 16: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4024, Accuracy: 85.59% ] || Test: [ Avg Loss: 0.4310, Accuracy: 84.45% ]
# Elapsed Inf. time: 0.02-mins.
#
# 17: Elapsed Train time: 0.34-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3968, Accuracy: 85.88% ] || Test: [ Avg Loss: 0.4259, Accuracy: 85.03% ]
# Elapsed Inf. time: 0.02-mins.
#
# 18: Elapsed Train time: 0.34-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3941, Accuracy: 85.95% ] || Test: [ Avg Loss: 0.4358, Accuracy: 84.81% ]
# Elapsed Inf. time: 0.03-mins.
#
# 19: Elapsed Train time: 0.32-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3914, Accuracy: 85.99% ] || Test: [ Avg Loss: 0.4287, Accuracy: 84.76% ]
# Elapsed Inf. time: 0.02-mins.
#
# 20: Elapsed Train time: 0.34-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3873, Accuracy: 86.11% ] || Test: [ Avg Loss: 0.4241, Accuracy: 84.70% ]
# Elapsed Inf. time: 0.02-mins.
#
# 21: Elapsed Train time: 0.32-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3839, Accuracy: 86.34% ] || Test: [ Avg Loss: 0.4106, Accuracy: 85.60% ]
# Elapsed Inf. time: 0.03-mins.
#
# 22: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3788, Accuracy: 86.36% ] || Test: [ Avg Loss: 0.4166, Accuracy: 84.93% ]
# Elapsed Inf. time: 0.02-mins.
#
# 23: Elapsed Train time: 0.34-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3776, Accuracy: 86.49% ] || Test: [ Avg Loss: 0.4084, Accuracy: 85.35% ]
# Elapsed Inf. time: 0.02-mins.
#
# 24: Elapsed Train time: 0.34-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3708, Accuracy: 86.66% ] || Test: [ Avg Loss: 0.4062, Accuracy: 85.53% ]
# Elapsed Inf. time: 0.02-mins.
#
# 25: Elapsed Train time: 0.34-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3710, Accuracy: 86.67% ] || Test: [ Avg Loss: 0.4067, Accuracy: 85.74% ]
# Elapsed Inf. time: 0.02-mins.
#
# 26: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3680, Accuracy: 86.81% ] || Test: [ Avg Loss: 0.4065, Accuracy: 85.40% ]
# Elapsed Inf. time: 0.03-mins.
#
# 27: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3637, Accuracy: 86.83% ] || Test: [ Avg Loss: 0.3961, Accuracy: 85.94% ]
# Elapsed Inf. time: 0.02-mins.
#
# 28: Elapsed Train time: 0.34-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3644, Accuracy: 86.89% ] || Test: [ Avg Loss: 0.3942, Accuracy: 85.95% ]
# Elapsed Inf. time: 0.03-mins.
#
# 29: Elapsed Train time: 0.34-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3588, Accuracy: 87.08% ] || Test: [ Avg Loss: 0.3950, Accuracy: 85.91% ]
# Elapsed Inf. time: 0.02-mins.
#
# 30: Elapsed Train time: 0.33-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3582, Accuracy: 87.04% ] || Test: [ Avg Loss: 0.3888, Accuracy: 86.28% ]
# Elapsed Inf. time: 0.02-mins.
#
# *********************************************************************************
# Done! Run: 1 : [Best Test @ epoch 30] || [ Avg loss: 0.388837, Accuracy: 86.28% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9985],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.34-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 1.3739, Accuracy: 65.67% ] || Test: [ Avg Loss: 0.7283, Accuracy: 74.44% ]
# Elapsed Inf. time: 0.02-mins.
#
# 2: Elapsed Train time: 0.32-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.6510, Accuracy: 77.39% ] || Test: [ Avg Loss: 0.6399, Accuracy: 77.20% ]
# Elapsed Inf. time: 0.02-mins.
#
# 3: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5750, Accuracy: 79.86% ] || Test: [ Avg Loss: 0.5647, Accuracy: 80.53% ]
# Elapsed Inf. time: 0.02-mins.
#
# 4: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5370, Accuracy: 81.25% ] || Test: [ Avg Loss: 0.5223, Accuracy: 81.82% ]
# Elapsed Inf. time: 0.02-mins.
#
# 5: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5064, Accuracy: 82.23% ] || Test: [ Avg Loss: 0.5233, Accuracy: 81.28% ]
# Elapsed Inf. time: 0.02-mins.
#
# 6: Elapsed Train time: 0.28-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4887, Accuracy: 82.83% ] || Test: [ Avg Loss: 0.4928, Accuracy: 82.56% ]
# Elapsed Inf. time: 0.03-mins.
#
# 7: Elapsed Train time: 0.35-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4785, Accuracy: 83.14% ] || Test: [ Avg Loss: 0.4954, Accuracy: 82.25% ]
# Elapsed Inf. time: 0.03-mins.
#
# 8: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4618, Accuracy: 83.69% ] || Test: [ Avg Loss: 0.4792, Accuracy: 82.73% ]
# Elapsed Inf. time: 0.03-mins.
#
# 9: Elapsed Train time: 0.36-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4509, Accuracy: 84.04% ] || Test: [ Avg Loss: 0.4573, Accuracy: 83.83% ]
# Elapsed Inf. time: 0.03-mins.
#
# 10: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4419, Accuracy: 84.33% ] || Test: [ Avg Loss: 0.4783, Accuracy: 82.81% ]
# Elapsed Inf. time: 0.02-mins.
#
# 11: Elapsed Train time: 0.34-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4335, Accuracy: 84.57% ] || Test: [ Avg Loss: 0.4652, Accuracy: 83.52% ]
# Elapsed Inf. time: 0.03-mins.
#
# 12: Elapsed Train time: 0.34-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4268, Accuracy: 84.90% ] || Test: [ Avg Loss: 0.4445, Accuracy: 84.21% ]
# Elapsed Inf. time: 0.02-mins.
#
# 13: Elapsed Train time: 0.32-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4231, Accuracy: 84.99% ] || Test: [ Avg Loss: 0.4392, Accuracy: 84.47% ]
# Elapsed Inf. time: 0.02-mins.
#
# 14: Elapsed Train time: 0.34-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4135, Accuracy: 85.32% ] || Test: [ Avg Loss: 0.4353, Accuracy: 84.54% ]
# Elapsed Inf. time: 0.02-mins.
#
# 15: Elapsed Train time: 0.35-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4083, Accuracy: 85.40% ] || Test: [ Avg Loss: 0.4316, Accuracy: 84.80% ]
# Elapsed Inf. time: 0.02-mins.
#
# 16: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4040, Accuracy: 85.59% ] || Test: [ Avg Loss: 0.4367, Accuracy: 84.71% ]
# Elapsed Inf. time: 0.02-mins.
#
# 17: Elapsed Train time: 0.33-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4029, Accuracy: 85.62% ] || Test: [ Avg Loss: 0.4259, Accuracy: 85.02% ]
# Elapsed Inf. time: 0.03-mins.
#
# 18: Elapsed Train time: 0.33-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3962, Accuracy: 85.90% ] || Test: [ Avg Loss: 0.4306, Accuracy: 84.69% ]
# Elapsed Inf. time: 0.03-mins.
#
# 19: Elapsed Train time: 0.34-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3916, Accuracy: 85.92% ] || Test: [ Avg Loss: 0.4238, Accuracy: 85.00% ]
# Elapsed Inf. time: 0.02-mins.
#
# 20: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3872, Accuracy: 86.12% ] || Test: [ Avg Loss: 0.4267, Accuracy: 84.55% ]
# Elapsed Inf. time: 0.03-mins.
#
# 21: Elapsed Train time: 0.35-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3846, Accuracy: 86.07% ] || Test: [ Avg Loss: 0.4106, Accuracy: 85.22% ]
# Elapsed Inf. time: 0.02-mins.
#
# 22: Elapsed Train time: 0.35-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3822, Accuracy: 86.40% ] || Test: [ Avg Loss: 0.4139, Accuracy: 85.13% ]
# Elapsed Inf. time: 0.03-mins.
#
# 23: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3807, Accuracy: 86.25% ] || Test: [ Avg Loss: 0.4192, Accuracy: 84.97% ]
# Elapsed Inf. time: 0.03-mins.
#
# 24: Elapsed Train time: 0.35-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3751, Accuracy: 86.58% ] || Test: [ Avg Loss: 0.4150, Accuracy: 85.37% ]
# Elapsed Inf. time: 0.02-mins.
#
# 25: Elapsed Train time: 0.35-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3731, Accuracy: 86.59% ] || Test: [ Avg Loss: 0.4127, Accuracy: 85.26% ]
# Elapsed Inf. time: 0.02-mins.
#
# 26: Elapsed Train time: 0.33-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3713, Accuracy: 86.69% ] || Test: [ Avg Loss: 0.4064, Accuracy: 85.53% ]
# Elapsed Inf. time: 0.03-mins.
#
# 27: Elapsed Train time: 0.34-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3687, Accuracy: 86.70% ] || Test: [ Avg Loss: 0.4059, Accuracy: 85.56% ]
# Elapsed Inf. time: 0.02-mins.
#
# 28: Elapsed Train time: 0.34-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3654, Accuracy: 86.77% ] || Test: [ Avg Loss: 0.4102, Accuracy: 85.33% ]
# Elapsed Inf. time: 0.02-mins.
#
# 29: Elapsed Train time: 0.33-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3644, Accuracy: 86.85% ] || Test: [ Avg Loss: 0.4002, Accuracy: 85.95% ]
# Elapsed Inf. time: 0.02-mins.
#
# 30: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3617, Accuracy: 86.91% ] || Test: [ Avg Loss: 0.3955, Accuracy: 86.20% ]
# Elapsed Inf. time: 0.02-mins.
#
# *********************************************************************************
# Done! Run: 2 : [Best Test @ epoch 30] || [ Avg loss: 0.395522, Accuracy: 86.20% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9985],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 1.5161, Accuracy: 64.98% ] || Test: [ Avg Loss: 0.7446, Accuracy: 73.59% ]
# Elapsed Inf. time: 0.02-mins.
#
# 2: Elapsed Train time: 0.32-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.6570, Accuracy: 76.86% ] || Test: [ Avg Loss: 0.6317, Accuracy: 78.20% ]
# Elapsed Inf. time: 0.03-mins.
#
# 3: Elapsed Train time: 0.35-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5747, Accuracy: 79.83% ] || Test: [ Avg Loss: 0.5660, Accuracy: 80.44% ]
# Elapsed Inf. time: 0.03-mins.
#
# 4: Elapsed Train time: 0.35-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5339, Accuracy: 81.32% ] || Test: [ Avg Loss: 0.5392, Accuracy: 81.86% ]
# Elapsed Inf. time: 0.03-mins.
#
# 5: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5077, Accuracy: 82.13% ] || Test: [ Avg Loss: 0.5217, Accuracy: 81.75% ]
# Elapsed Inf. time: 0.03-mins.
#
# 6: Elapsed Train time: 0.36-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4894, Accuracy: 82.67% ] || Test: [ Avg Loss: 0.5130, Accuracy: 82.29% ]
# Elapsed Inf. time: 0.02-mins.
#
# 7: Elapsed Train time: 0.32-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4731, Accuracy: 83.31% ] || Test: [ Avg Loss: 0.4949, Accuracy: 83.08% ]
# Elapsed Inf. time: 0.03-mins.
#
# 8: Elapsed Train time: 0.36-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4605, Accuracy: 83.77% ] || Test: [ Avg Loss: 0.4911, Accuracy: 83.07% ]
# Elapsed Inf. time: 0.03-mins.
#
# 9: Elapsed Train time: 0.34-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4486, Accuracy: 84.09% ] || Test: [ Avg Loss: 0.4857, Accuracy: 83.10% ]
# Elapsed Inf. time: 0.02-mins.
#
# 10: Elapsed Train time: 0.35-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4426, Accuracy: 84.32% ] || Test: [ Avg Loss: 0.4712, Accuracy: 83.37% ]
# Elapsed Inf. time: 0.02-mins.
#
# 11: Elapsed Train time: 0.33-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4317, Accuracy: 84.64% ] || Test: [ Avg Loss: 0.4682, Accuracy: 83.90% ]
# Elapsed Inf. time: 0.02-mins.
#
# 12: Elapsed Train time: 0.35-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4233, Accuracy: 85.00% ] || Test: [ Avg Loss: 0.4559, Accuracy: 84.09% ]
# Elapsed Inf. time: 0.02-mins.
#
# 13: Elapsed Train time: 0.34-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4158, Accuracy: 85.19% ] || Test: [ Avg Loss: 0.4472, Accuracy: 84.44% ]
# Elapsed Inf. time: 0.03-mins.
#
# 14: Elapsed Train time: 0.34-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4115, Accuracy: 85.34% ] || Test: [ Avg Loss: 0.4531, Accuracy: 83.76% ]
# Elapsed Inf. time: 0.02-mins.
#
# 15: Elapsed Train time: 0.34-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4078, Accuracy: 85.38% ] || Test: [ Avg Loss: 0.4578, Accuracy: 84.18% ]
# Elapsed Inf. time: 0.03-mins.
#
# 16: Elapsed Train time: 0.34-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4013, Accuracy: 85.75% ] || Test: [ Avg Loss: 0.4544, Accuracy: 83.88% ]
# Elapsed Inf. time: 0.03-mins.
#
# 17: Elapsed Train time: 0.35-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3980, Accuracy: 85.70% ] || Test: [ Avg Loss: 0.4433, Accuracy: 84.56% ]
# Elapsed Inf. time: 0.02-mins.
#
# 18: Elapsed Train time: 0.36-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3932, Accuracy: 85.95% ] || Test: [ Avg Loss: 0.4309, Accuracy: 84.54% ]
# Elapsed Inf. time: 0.02-mins.
#
# 19: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3898, Accuracy: 86.09% ] || Test: [ Avg Loss: 0.4338, Accuracy: 84.69% ]
# Elapsed Inf. time: 0.03-mins.
#
# 20: Elapsed Train time: 0.39-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3867, Accuracy: 86.21% ] || Test: [ Avg Loss: 0.4242, Accuracy: 85.05% ]
# Elapsed Inf. time: 0.03-mins.
#
# 21: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3812, Accuracy: 86.32% ] || Test: [ Avg Loss: 0.4147, Accuracy: 85.45% ]
# Elapsed Inf. time: 0.02-mins.
#
# 22: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3770, Accuracy: 86.41% ] || Test: [ Avg Loss: 0.4248, Accuracy: 84.87% ]
# Elapsed Inf. time: 0.03-mins.
#
# 23: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3765, Accuracy: 86.43% ] || Test: [ Avg Loss: 0.4160, Accuracy: 85.48% ]
# Elapsed Inf. time: 0.03-mins.
#
# 24: Elapsed Train time: 0.36-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3736, Accuracy: 86.63% ] || Test: [ Avg Loss: 0.4160, Accuracy: 85.17% ]
# Elapsed Inf. time: 0.03-mins.
#
# 25: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3702, Accuracy: 86.61% ] || Test: [ Avg Loss: 0.4166, Accuracy: 84.96% ]
# Elapsed Inf. time: 0.02-mins.
#
# 26: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3669, Accuracy: 86.81% ] || Test: [ Avg Loss: 0.4236, Accuracy: 85.10% ]
# Elapsed Inf. time: 0.03-mins.
#
# 27: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3647, Accuracy: 86.89% ] || Test: [ Avg Loss: 0.4132, Accuracy: 85.35% ]
# Elapsed Inf. time: 0.02-mins.
#
# 28: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3640, Accuracy: 87.02% ] || Test: [ Avg Loss: 0.4203, Accuracy: 84.96% ]
# Elapsed Inf. time: 0.03-mins.
#
# 29: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3599, Accuracy: 86.94% ] || Test: [ Avg Loss: 0.4095, Accuracy: 85.43% ]
# Elapsed Inf. time: 0.03-mins.
#
# 30: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3587, Accuracy: 87.16% ] || Test: [ Avg Loss: 0.4034, Accuracy: 85.81% ]
# Elapsed Inf. time: 0.02-mins.
#
# *********************************************************************************
# Done! Run: 3 : [Best Test @ epoch 30] || [ Avg loss: 0.403436, Accuracy: 85.81% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9985],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.39-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 1.7944, Accuracy: 62.69% ] || Test: [ Avg Loss: 0.7589, Accuracy: 73.30% ]
# Elapsed Inf. time: 0.02-mins.
#
# 2: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.6822, Accuracy: 76.05% ] || Test: [ Avg Loss: 0.6383, Accuracy: 77.42% ]
# Elapsed Inf. time: 0.02-mins.
#
# 3: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5973, Accuracy: 79.02% ] || Test: [ Avg Loss: 0.6001, Accuracy: 79.07% ]
# Elapsed Inf. time: 0.03-mins.
#
# 4: Elapsed Train time: 0.39-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5528, Accuracy: 80.52% ] || Test: [ Avg Loss: 0.5799, Accuracy: 79.18% ]
# Elapsed Inf. time: 0.03-mins.
#
# 5: Elapsed Train time: 0.39-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5213, Accuracy: 81.49% ] || Test: [ Avg Loss: 0.5424, Accuracy: 81.19% ]
# Elapsed Inf. time: 0.03-mins.
#
# 6: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4950, Accuracy: 82.36% ] || Test: [ Avg Loss: 0.5295, Accuracy: 81.27% ]
# Elapsed Inf. time: 0.02-mins.
#
# 7: Elapsed Train time: 0.32-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4757, Accuracy: 82.89% ] || Test: [ Avg Loss: 0.5056, Accuracy: 82.15% ]
# Elapsed Inf. time: 0.02-mins.
#
# 8: Elapsed Train time: 0.33-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4622, Accuracy: 83.28% ] || Test: [ Avg Loss: 0.4846, Accuracy: 83.01% ]
# Elapsed Inf. time: 0.02-mins.
#
# 9: Elapsed Train time: 0.32-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4517, Accuracy: 83.59% ] || Test: [ Avg Loss: 0.4780, Accuracy: 82.99% ]
# Elapsed Inf. time: 0.02-mins.
#
# 10: Elapsed Train time: 0.36-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4429, Accuracy: 84.00% ] || Test: [ Avg Loss: 0.4749, Accuracy: 82.85% ]
# Elapsed Inf. time: 0.03-mins.
#
# 11: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4347, Accuracy: 84.31% ] || Test: [ Avg Loss: 0.4611, Accuracy: 83.43% ]
# Elapsed Inf. time: 0.03-mins.
#
# 12: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4240, Accuracy: 84.61% ] || Test: [ Avg Loss: 0.4577, Accuracy: 83.60% ]
# Elapsed Inf. time: 0.03-mins.
#
# 13: Elapsed Train time: 0.40-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4196, Accuracy: 84.76% ] || Test: [ Avg Loss: 0.4446, Accuracy: 84.05% ]
# Elapsed Inf. time: 0.03-mins.
#
# 14: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4122, Accuracy: 84.94% ] || Test: [ Avg Loss: 0.4498, Accuracy: 83.82% ]
# Elapsed Inf. time: 0.02-mins.
#
# 15: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4046, Accuracy: 85.38% ] || Test: [ Avg Loss: 0.4395, Accuracy: 84.15% ]
# Elapsed Inf. time: 0.02-mins.
#
# 16: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4050, Accuracy: 85.30% ] || Test: [ Avg Loss: 0.4504, Accuracy: 83.85% ]
# Elapsed Inf. time: 0.03-mins.
#
# 17: Elapsed Train time: 0.39-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3960, Accuracy: 85.66% ] || Test: [ Avg Loss: 0.4519, Accuracy: 83.28% ]
# Elapsed Inf. time: 0.02-mins.
#
# 18: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3906, Accuracy: 85.74% ] || Test: [ Avg Loss: 0.4340, Accuracy: 84.39% ]
# Elapsed Inf. time: 0.04-mins.
#
# 19: Elapsed Train time: 0.39-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3878, Accuracy: 85.95% ] || Test: [ Avg Loss: 0.4349, Accuracy: 84.27% ]
# Elapsed Inf. time: 0.03-mins.
#
# 20: Elapsed Train time: 0.39-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3877, Accuracy: 85.89% ] || Test: [ Avg Loss: 0.4209, Accuracy: 84.95% ]
# Elapsed Inf. time: 0.03-mins.
#
# 21: Elapsed Train time: 0.39-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3826, Accuracy: 86.08% ] || Test: [ Avg Loss: 0.4412, Accuracy: 84.57% ]
# Elapsed Inf. time: 0.03-mins.
#
# 22: Elapsed Train time: 0.39-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3771, Accuracy: 86.25% ] || Test: [ Avg Loss: 0.4167, Accuracy: 84.91% ]
# Elapsed Inf. time: 0.03-mins.
#
# 23: Elapsed Train time: 0.40-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3749, Accuracy: 86.37% ] || Test: [ Avg Loss: 0.4185, Accuracy: 85.15% ]
# Elapsed Inf. time: 0.03-mins.
#
# 24: Elapsed Train time: 0.40-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3746, Accuracy: 86.37% ] || Test: [ Avg Loss: 0.4262, Accuracy: 84.52% ]
# Elapsed Inf. time: 0.02-mins.
#
# 25: Elapsed Train time: 0.39-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3701, Accuracy: 86.53% ] || Test: [ Avg Loss: 0.4196, Accuracy: 85.01% ]
# Elapsed Inf. time: 0.02-mins.
#
# 26: Elapsed Train time: 0.41-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3693, Accuracy: 86.60% ] || Test: [ Avg Loss: 0.4139, Accuracy: 85.28% ]
# Elapsed Inf. time: 0.03-mins.
#
# 27: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3623, Accuracy: 86.81% ] || Test: [ Avg Loss: 0.4089, Accuracy: 85.00% ]
# Elapsed Inf. time: 0.03-mins.
#
# 28: Elapsed Train time: 0.35-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3649, Accuracy: 86.77% ] || Test: [ Avg Loss: 0.4081, Accuracy: 85.35% ]
# Elapsed Inf. time: 0.02-mins.
#
# 29: Elapsed Train time: 0.28-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3599, Accuracy: 86.82% ] || Test: [ Avg Loss: 0.4067, Accuracy: 85.25% ]
# Elapsed Inf. time: 0.02-mins.
#
# 30: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3592, Accuracy: 86.94% ] || Test: [ Avg Loss: 0.4017, Accuracy: 85.53% ]
# Elapsed Inf. time: 0.02-mins.
#
# *********************************************************************************
# Done! Run: 4 : [Best Test @ epoch 30] || [ Avg loss: 0.401696, Accuracy: 85.53% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9985],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 1.1771, Accuracy: 68.32% ] || Test: [ Avg Loss: 0.6912, Accuracy: 75.45% ]
# Elapsed Inf. time: 0.02-mins.
#
# 2: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.6174, Accuracy: 78.63% ] || Test: [ Avg Loss: 0.5782, Accuracy: 79.65% ]
# Elapsed Inf. time: 0.02-mins.
#
# 3: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5534, Accuracy: 80.72% ] || Test: [ Avg Loss: 0.5435, Accuracy: 81.29% ]
# Elapsed Inf. time: 0.02-mins.
#
# 4: Elapsed Train time: 0.26-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5137, Accuracy: 82.28% ] || Test: [ Avg Loss: 0.5103, Accuracy: 82.34% ]
# Elapsed Inf. time: 0.02-mins.
#
# 5: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4927, Accuracy: 82.88% ] || Test: [ Avg Loss: 0.4853, Accuracy: 83.15% ]
# Elapsed Inf. time: 0.02-mins.
#
# 6: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4750, Accuracy: 83.38% ] || Test: [ Avg Loss: 0.5010, Accuracy: 82.59% ]
# Elapsed Inf. time: 0.02-mins.
#
# 7: Elapsed Train time: 0.28-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4600, Accuracy: 83.91% ] || Test: [ Avg Loss: 0.4629, Accuracy: 83.87% ]
# Elapsed Inf. time: 0.02-mins.
#
# 8: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4458, Accuracy: 84.30% ] || Test: [ Avg Loss: 0.4641, Accuracy: 83.70% ]
# Elapsed Inf. time: 0.02-mins.
#
# 9: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4367, Accuracy: 84.61% ] || Test: [ Avg Loss: 0.4509, Accuracy: 84.51% ]
# Elapsed Inf. time: 0.02-mins.
#
# 10: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4308, Accuracy: 84.84% ] || Test: [ Avg Loss: 0.4707, Accuracy: 82.92% ]
# Elapsed Inf. time: 0.02-mins.
#
# 11: Elapsed Train time: 0.20-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4231, Accuracy: 85.19% ] || Test: [ Avg Loss: 0.4471, Accuracy: 84.18% ]
# Elapsed Inf. time: 0.01-mins.
#
# 12: Elapsed Train time: 0.20-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4191, Accuracy: 85.21% ] || Test: [ Avg Loss: 0.4385, Accuracy: 84.26% ]
# Elapsed Inf. time: 0.01-mins.
#
# 13: Elapsed Train time: 0.20-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4097, Accuracy: 85.48% ] || Test: [ Avg Loss: 0.4349, Accuracy: 84.52% ]
# Elapsed Inf. time: 0.01-mins.
#
# 14: Elapsed Train time: 0.21-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4045, Accuracy: 85.67% ] || Test: [ Avg Loss: 0.4456, Accuracy: 83.83% ]
# Elapsed Inf. time: 0.01-mins.
#
# 15: Elapsed Train time: 0.20-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4032, Accuracy: 85.55% ] || Test: [ Avg Loss: 0.4269, Accuracy: 84.52% ]
# Elapsed Inf. time: 0.01-mins.
#
# 16: Elapsed Train time: 0.21-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3977, Accuracy: 85.79% ] || Test: [ Avg Loss: 0.4259, Accuracy: 84.78% ]
# Elapsed Inf. time: 0.01-mins.
#
# 17: Elapsed Train time: 0.20-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3907, Accuracy: 86.03% ] || Test: [ Avg Loss: 0.4167, Accuracy: 85.31% ]
# Elapsed Inf. time: 0.01-mins.
#
# 18: Elapsed Train time: 0.19-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3880, Accuracy: 86.20% ] || Test: [ Avg Loss: 0.4239, Accuracy: 84.60% ]
# Elapsed Inf. time: 0.01-mins.
#
# 19: Elapsed Train time: 0.20-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3853, Accuracy: 86.20% ] || Test: [ Avg Loss: 0.4148, Accuracy: 85.47% ]
# Elapsed Inf. time: 0.01-mins.
#
# 20: Elapsed Train time: 0.20-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3797, Accuracy: 86.37% ] || Test: [ Avg Loss: 0.4184, Accuracy: 84.91% ]
# Elapsed Inf. time: 0.01-mins.
#
# 21: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3758, Accuracy: 86.50% ] || Test: [ Avg Loss: 0.4050, Accuracy: 85.48% ]
# Elapsed Inf. time: 0.02-mins.
#
# 22: Elapsed Train time: 0.28-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3731, Accuracy: 86.55% ] || Test: [ Avg Loss: 0.4029, Accuracy: 85.38% ]
# Elapsed Inf. time: 0.02-mins.
#
# 23: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3706, Accuracy: 86.67% ] || Test: [ Avg Loss: 0.4124, Accuracy: 85.26% ]
# Elapsed Inf. time: 0.02-mins.
#
# 24: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3680, Accuracy: 86.76% ] || Test: [ Avg Loss: 0.4103, Accuracy: 85.52% ]
# Elapsed Inf. time: 0.02-mins.
#
# 25: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3646, Accuracy: 86.89% ] || Test: [ Avg Loss: 0.4089, Accuracy: 85.16% ]
# Elapsed Inf. time: 0.02-mins.
#
# 26: Elapsed Train time: 0.24-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3616, Accuracy: 86.84% ] || Test: [ Avg Loss: 0.4131, Accuracy: 85.29% ]
# Elapsed Inf. time: 0.02-mins.
#
# 27: Elapsed Train time: 0.23-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3611, Accuracy: 87.01% ] || Test: [ Avg Loss: 0.3994, Accuracy: 85.81% ]
# Elapsed Inf. time: 0.02-mins.
#
# 28: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3596, Accuracy: 87.00% ] || Test: [ Avg Loss: 0.4205, Accuracy: 85.14% ]
# Elapsed Inf. time: 0.02-mins.
#
# 29: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3576, Accuracy: 87.12% ] || Test: [ Avg Loss: 0.4030, Accuracy: 85.56% ]
# Elapsed Inf. time: 0.02-mins.
#
# 30: Elapsed Train time: 0.24-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3526, Accuracy: 87.25% ] || Test: [ Avg Loss: 0.3950, Accuracy: 85.85% ]
# Elapsed Inf. time: 0.02-mins.
#
# *********************************************************************************
# Done! Run: 5 : [Best Test @ epoch 30] || [ Avg loss: 0.394995, Accuracy: 85.85% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9985],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.23-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 1.4936, Accuracy: 64.30% ] || Test: [ Avg Loss: 0.7429, Accuracy: 73.70% ]
# Elapsed Inf. time: 0.02-mins.
#
# 2: Elapsed Train time: 0.23-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.6672, Accuracy: 76.65% ] || Test: [ Avg Loss: 0.6272, Accuracy: 77.69% ]
# Elapsed Inf. time: 0.02-mins.
#
# 3: Elapsed Train time: 0.23-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5881, Accuracy: 79.25% ] || Test: [ Avg Loss: 0.5941, Accuracy: 78.54% ]
# Elapsed Inf. time: 0.01-mins.
#
# 4: Elapsed Train time: 0.22-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5442, Accuracy: 80.89% ] || Test: [ Avg Loss: 0.5503, Accuracy: 80.63% ]
# Elapsed Inf. time: 0.01-mins.
#
# 5: Elapsed Train time: 0.22-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5210, Accuracy: 81.58% ] || Test: [ Avg Loss: 0.5286, Accuracy: 80.99% ]
# Elapsed Inf. time: 0.01-mins.
#
# 6: Elapsed Train time: 0.22-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4983, Accuracy: 82.28% ] || Test: [ Avg Loss: 0.5088, Accuracy: 81.70% ]
# Elapsed Inf. time: 0.01-mins.
#
# 7: Elapsed Train time: 0.21-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4780, Accuracy: 83.15% ] || Test: [ Avg Loss: 0.5022, Accuracy: 82.69% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.22-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4738, Accuracy: 83.22% ] || Test: [ Avg Loss: 0.5022, Accuracy: 82.47% ]
# Elapsed Inf. time: 0.01-mins.
#
# 9: Elapsed Train time: 0.21-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4592, Accuracy: 83.62% ] || Test: [ Avg Loss: 0.4959, Accuracy: 82.39% ]
# Elapsed Inf. time: 0.01-mins.
#
# 10: Elapsed Train time: 0.21-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4516, Accuracy: 83.78% ] || Test: [ Avg Loss: 0.4770, Accuracy: 83.02% ]
# Elapsed Inf. time: 0.01-mins.
#
# 11: Elapsed Train time: 0.21-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4415, Accuracy: 84.17% ] || Test: [ Avg Loss: 0.4716, Accuracy: 83.60% ]
# Elapsed Inf. time: 0.02-mins.
#
# 12: Elapsed Train time: 0.21-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4361, Accuracy: 84.27% ] || Test: [ Avg Loss: 0.4727, Accuracy: 82.78% ]
# Elapsed Inf. time: 0.02-mins.
#
# 13: Elapsed Train time: 0.22-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4266, Accuracy: 84.68% ] || Test: [ Avg Loss: 0.4584, Accuracy: 83.77% ]
# Elapsed Inf. time: 0.01-mins.
#
# 14: Elapsed Train time: 0.22-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4208, Accuracy: 84.87% ] || Test: [ Avg Loss: 0.4552, Accuracy: 83.87% ]
# Elapsed Inf. time: 0.02-mins.
#
# 15: Elapsed Train time: 0.22-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4145, Accuracy: 84.86% ] || Test: [ Avg Loss: 0.4585, Accuracy: 83.50% ]
# Elapsed Inf. time: 0.01-mins.
#
# 16: Elapsed Train time: 0.22-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4131, Accuracy: 85.02% ] || Test: [ Avg Loss: 0.4430, Accuracy: 84.25% ]
# Elapsed Inf. time: 0.02-mins.
#
# 17: Elapsed Train time: 0.22-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4087, Accuracy: 85.23% ] || Test: [ Avg Loss: 0.4432, Accuracy: 84.30% ]
# Elapsed Inf. time: 0.01-mins.
#
# 18: Elapsed Train time: 0.22-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4013, Accuracy: 85.41% ] || Test: [ Avg Loss: 0.4323, Accuracy: 84.95% ]
# Elapsed Inf. time: 0.02-mins.
#
# 19: Elapsed Train time: 0.22-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3939, Accuracy: 85.68% ] || Test: [ Avg Loss: 0.4468, Accuracy: 84.48% ]
# Elapsed Inf. time: 0.01-mins.
#
# 20: Elapsed Train time: 0.22-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3919, Accuracy: 85.81% ] || Test: [ Avg Loss: 0.4415, Accuracy: 84.63% ]
# Elapsed Inf. time: 0.01-mins.
#
# 21: Elapsed Train time: 0.22-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3875, Accuracy: 86.00% ] || Test: [ Avg Loss: 0.4285, Accuracy: 84.77% ]
# Elapsed Inf. time: 0.02-mins.
#
# 22: Elapsed Train time: 0.22-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3844, Accuracy: 86.05% ] || Test: [ Avg Loss: 0.4228, Accuracy: 85.18% ]
# Elapsed Inf. time: 0.01-mins.
#
# 23: Elapsed Train time: 0.21-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3799, Accuracy: 86.13% ] || Test: [ Avg Loss: 0.4199, Accuracy: 85.20% ]
# Elapsed Inf. time: 0.01-mins.
#
# 24: Elapsed Train time: 0.22-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3786, Accuracy: 86.22% ] || Test: [ Avg Loss: 0.4188, Accuracy: 85.27% ]
# Elapsed Inf. time: 0.01-mins.
#
# 25: Elapsed Train time: 0.22-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3751, Accuracy: 86.42% ] || Test: [ Avg Loss: 0.4413, Accuracy: 84.80% ]
# Elapsed Inf. time: 0.02-mins.
#
# 26: Elapsed Train time: 0.21-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3709, Accuracy: 86.58% ] || Test: [ Avg Loss: 0.4136, Accuracy: 85.36% ]
# Elapsed Inf. time: 0.01-mins.
#
# 27: Elapsed Train time: 0.21-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3678, Accuracy: 86.78% ] || Test: [ Avg Loss: 0.4125, Accuracy: 85.57% ]
# Elapsed Inf. time: 0.02-mins.
#
# 28: Elapsed Train time: 0.23-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3669, Accuracy: 86.68% ] || Test: [ Avg Loss: 0.4219, Accuracy: 84.99% ]
# Elapsed Inf. time: 0.02-mins.
#
# 29: Elapsed Train time: 0.23-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3647, Accuracy: 86.79% ] || Test: [ Avg Loss: 0.4087, Accuracy: 85.58% ]
# Elapsed Inf. time: 0.02-mins.
#
# 30: Elapsed Train time: 0.23-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3599, Accuracy: 86.81% ] || Test: [ Avg Loss: 0.4055, Accuracy: 85.72% ]
# Elapsed Inf. time: 0.02-mins.
#
# *********************************************************************************
# Done! Run: 6 : [Best Test @ epoch 30] || [ Avg loss: 0.405533, Accuracy: 85.72% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9985],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.23-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 1.5787, Accuracy: 63.83% ] || Test: [ Avg Loss: 0.7302, Accuracy: 74.00% ]
# Elapsed Inf. time: 0.02-mins.
#
# 2: Elapsed Train time: 0.23-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.6379, Accuracy: 77.12% ] || Test: [ Avg Loss: 0.6011, Accuracy: 78.67% ]
# Elapsed Inf. time: 0.02-mins.
#
# 3: Elapsed Train time: 0.23-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5685, Accuracy: 79.64% ] || Test: [ Avg Loss: 0.5606, Accuracy: 80.31% ]
# Elapsed Inf. time: 0.02-mins.
#
# 4: Elapsed Train time: 0.23-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5332, Accuracy: 80.98% ] || Test: [ Avg Loss: 0.5450, Accuracy: 80.70% ]
# Elapsed Inf. time: 0.02-mins.
#
# 5: Elapsed Train time: 0.23-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5081, Accuracy: 81.86% ] || Test: [ Avg Loss: 0.5162, Accuracy: 81.55% ]
# Elapsed Inf. time: 0.02-mins.
#
# 6: Elapsed Train time: 0.22-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4867, Accuracy: 82.57% ] || Test: [ Avg Loss: 0.5014, Accuracy: 81.95% ]
# Elapsed Inf. time: 0.02-mins.
#
# 7: Elapsed Train time: 0.22-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4779, Accuracy: 82.96% ] || Test: [ Avg Loss: 0.5237, Accuracy: 81.32% ]
# Elapsed Inf. time: 0.01-mins.
#
# 8: Elapsed Train time: 0.22-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4636, Accuracy: 83.33% ] || Test: [ Avg Loss: 0.4774, Accuracy: 82.58% ]
# Elapsed Inf. time: 0.02-mins.
#
# 9: Elapsed Train time: 0.22-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4547, Accuracy: 83.59% ] || Test: [ Avg Loss: 0.4758, Accuracy: 82.94% ]
# Elapsed Inf. time: 0.02-mins.
#
# 10: Elapsed Train time: 0.22-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4440, Accuracy: 84.04% ] || Test: [ Avg Loss: 0.4665, Accuracy: 83.67% ]
# Elapsed Inf. time: 0.02-mins.
#
# 11: Elapsed Train time: 0.24-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4354, Accuracy: 84.25% ] || Test: [ Avg Loss: 0.4536, Accuracy: 84.01% ]
# Elapsed Inf. time: 0.02-mins.
#
# 12: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4291, Accuracy: 84.66% ] || Test: [ Avg Loss: 0.4576, Accuracy: 83.75% ]
# Elapsed Inf. time: 0.02-mins.
#
# 13: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4211, Accuracy: 84.82% ] || Test: [ Avg Loss: 0.4487, Accuracy: 84.17% ]
# Elapsed Inf. time: 0.02-mins.
#
# 14: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4160, Accuracy: 85.03% ] || Test: [ Avg Loss: 0.4476, Accuracy: 83.97% ]
# Elapsed Inf. time: 0.02-mins.
#
# 15: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4109, Accuracy: 85.20% ] || Test: [ Avg Loss: 0.4347, Accuracy: 84.31% ]
# Elapsed Inf. time: 0.02-mins.
#
# 16: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4028, Accuracy: 85.47% ] || Test: [ Avg Loss: 0.4313, Accuracy: 84.82% ]
# Elapsed Inf. time: 0.02-mins.
#
# 17: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4006, Accuracy: 85.65% ] || Test: [ Avg Loss: 0.4424, Accuracy: 83.94% ]
# Elapsed Inf. time: 0.02-mins.
#
# 18: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3942, Accuracy: 85.89% ] || Test: [ Avg Loss: 0.4404, Accuracy: 84.21% ]
# Elapsed Inf. time: 0.02-mins.
#
# 19: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3943, Accuracy: 85.74% ] || Test: [ Avg Loss: 0.4266, Accuracy: 84.77% ]
# Elapsed Inf. time: 0.02-mins.
#
# 20: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3867, Accuracy: 86.00% ] || Test: [ Avg Loss: 0.4182, Accuracy: 85.14% ]
# Elapsed Inf. time: 0.02-mins.
#
# 21: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3827, Accuracy: 86.11% ] || Test: [ Avg Loss: 0.4205, Accuracy: 85.27% ]
# Elapsed Inf. time: 0.02-mins.
#
# 22: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3811, Accuracy: 86.27% ] || Test: [ Avg Loss: 0.4101, Accuracy: 85.37% ]
# Elapsed Inf. time: 0.02-mins.
#
# 23: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3759, Accuracy: 86.43% ] || Test: [ Avg Loss: 0.4124, Accuracy: 85.27% ]
# Elapsed Inf. time: 0.02-mins.
#
# 24: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3761, Accuracy: 86.43% ] || Test: [ Avg Loss: 0.4070, Accuracy: 85.62% ]
# Elapsed Inf. time: 0.02-mins.
#
# 25: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3740, Accuracy: 86.53% ] || Test: [ Avg Loss: 0.4080, Accuracy: 85.33% ]
# Elapsed Inf. time: 0.02-mins.
#
# 26: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3695, Accuracy: 86.68% ] || Test: [ Avg Loss: 0.4038, Accuracy: 85.69% ]
# Elapsed Inf. time: 0.02-mins.
#
# 27: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3652, Accuracy: 86.79% ] || Test: [ Avg Loss: 0.3978, Accuracy: 85.78% ]
# Elapsed Inf. time: 0.02-mins.
#
# 28: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3663, Accuracy: 86.74% ] || Test: [ Avg Loss: 0.3941, Accuracy: 85.86% ]
# Elapsed Inf. time: 0.02-mins.
#
# 29: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3609, Accuracy: 86.94% ] || Test: [ Avg Loss: 0.4017, Accuracy: 85.70% ]
# Elapsed Inf. time: 0.02-mins.
#
# 30: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3575, Accuracy: 87.15% ] || Test: [ Avg Loss: 0.3983, Accuracy: 85.60% ]
# Elapsed Inf. time: 0.02-mins.
#
# *********************************************************************************
# Done! Run: 7 : [Best Test @ epoch 28] || [ Avg loss: 0.394145, Accuracy: 85.86% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9985],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.25-mins.
# ...
# Elapsed Inf. time: 0.02-mins.
#
# 21: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3681, Accuracy: 86.73% ] || Test: [ Avg Loss: 0.4086, Accuracy: 85.34% ]
# Elapsed Inf. time: 0.03-mins.
#
# 22: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3653, Accuracy: 86.80% ] || Test: [ Avg Loss: 0.4118, Accuracy: 85.37% ]
# Elapsed Inf. time: 0.02-mins.
#
# 23: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3632, Accuracy: 86.83% ] || Test: [ Avg Loss: 0.4145, Accuracy: 85.26% ]
# Elapsed Inf. time: 0.02-mins.
#
# 24: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3589, Accuracy: 86.92% ] || Test: [ Avg Loss: 0.4094, Accuracy: 85.39% ]
# Elapsed Inf. time: 0.02-mins.
#
# 25: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3551, Accuracy: 86.99% ] || Test: [ Avg Loss: 0.3973, Accuracy: 85.88% ]
# Elapsed Inf. time: 0.02-mins.
#
# 26: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3519, Accuracy: 87.34% ] || Test: [ Avg Loss: 0.3953, Accuracy: 85.94% ]
# Elapsed Inf. time: 0.02-mins.
#
# 27: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3501, Accuracy: 87.23% ] || Test: [ Avg Loss: 0.4004, Accuracy: 86.06% ]
# Elapsed Inf. time: 0.02-mins.
#
# 28: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3493, Accuracy: 87.27% ] || Test: [ Avg Loss: 0.4000, Accuracy: 85.87% ]
# Elapsed Inf. time: 0.03-mins.
#
# 29: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3443, Accuracy: 87.61% ] || Test: [ Avg Loss: 0.3985, Accuracy: 85.91% ]
# Elapsed Inf. time: 0.02-mins.
#
# 30: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3441, Accuracy: 87.57% ] || Test: [ Avg Loss: 0.3963, Accuracy: 85.80% ]
# Elapsed Inf. time: 0.02-mins.
#
# *********************************************************************************
# Done! Run: 8 : [Best Test @ epoch 27] || [ Avg loss: 0.400397, Accuracy: 86.06% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9985],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 1.1091, Accuracy: 66.32% ] || Test: [ Avg Loss: 0.7187, Accuracy: 75.14% ]
# Elapsed Inf. time: 0.02-mins.
#
# 2: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.6407, Accuracy: 77.14% ] || Test: [ Avg Loss: 0.6318, Accuracy: 75.94% ]
# Elapsed Inf. time: 0.02-mins.
#
# 3: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5632, Accuracy: 79.78% ] || Test: [ Avg Loss: 0.5721, Accuracy: 79.73% ]
# Elapsed Inf. time: 0.02-mins.
#
# 4: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5230, Accuracy: 81.35% ] || Test: [ Avg Loss: 0.5248, Accuracy: 80.81% ]
# Elapsed Inf. time: 0.02-mins.
#
# 5: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4998, Accuracy: 82.16% ] || Test: [ Avg Loss: 0.5006, Accuracy: 82.50% ]
# Elapsed Inf. time: 0.03-mins.
#
# 6: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4807, Accuracy: 82.85% ] || Test: [ Avg Loss: 0.4847, Accuracy: 82.94% ]
# Elapsed Inf. time: 0.02-mins.
#
# 7: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4663, Accuracy: 83.38% ] || Test: [ Avg Loss: 0.4704, Accuracy: 83.29% ]
# Elapsed Inf. time: 0.03-mins.
#
# 8: Elapsed Train time: 0.24-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4497, Accuracy: 84.01% ] || Test: [ Avg Loss: 0.4793, Accuracy: 82.87% ]
# Elapsed Inf. time: 0.02-mins.
#
# 9: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4453, Accuracy: 84.14% ] || Test: [ Avg Loss: 0.4627, Accuracy: 83.57% ]
# Elapsed Inf. time: 0.03-mins.
#
# 10: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4325, Accuracy: 84.50% ] || Test: [ Avg Loss: 0.4527, Accuracy: 84.11% ]
# Elapsed Inf. time: 0.02-mins.
#
# 11: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4230, Accuracy: 84.93% ] || Test: [ Avg Loss: 0.4624, Accuracy: 83.57% ]
# Elapsed Inf. time: 0.02-mins.
#
# 12: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4166, Accuracy: 85.16% ] || Test: [ Avg Loss: 0.4350, Accuracy: 84.51% ]
# Elapsed Inf. time: 0.03-mins.
#
# 13: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4087, Accuracy: 85.46% ] || Test: [ Avg Loss: 0.4298, Accuracy: 84.69% ]
# Elapsed Inf. time: 0.02-mins.
#
# 14: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4022, Accuracy: 85.70% ] || Test: [ Avg Loss: 0.4333, Accuracy: 84.70% ]
# Elapsed Inf. time: 0.02-mins.
#
# 15: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3956, Accuracy: 85.83% ] || Test: [ Avg Loss: 0.4190, Accuracy: 85.28% ]
# Elapsed Inf. time: 0.02-mins.
#
# 16: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3930, Accuracy: 86.03% ] || Test: [ Avg Loss: 0.4177, Accuracy: 85.21% ]
# Elapsed Inf. time: 0.02-mins.
#
# 17: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3862, Accuracy: 86.19% ] || Test: [ Avg Loss: 0.4213, Accuracy: 84.93% ]
# Elapsed Inf. time: 0.02-mins.
#
# 18: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3817, Accuracy: 86.39% ] || Test: [ Avg Loss: 0.4155, Accuracy: 85.33% ]
# Elapsed Inf. time: 0.02-mins.
#
# 19: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3797, Accuracy: 86.38% ] || Test: [ Avg Loss: 0.4126, Accuracy: 85.27% ]
# Elapsed Inf. time: 0.02-mins.
#
# 20: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3745, Accuracy: 86.57% ] || Test: [ Avg Loss: 0.4121, Accuracy: 85.21% ]
# Elapsed Inf. time: 0.02-mins.
#
# 21: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3725, Accuracy: 86.73% ] || Test: [ Avg Loss: 0.4041, Accuracy: 85.56% ]
# Elapsed Inf. time: 0.02-mins.
#
# 22: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3677, Accuracy: 86.83% ] || Test: [ Avg Loss: 0.4029, Accuracy: 85.61% ]
# Elapsed Inf. time: 0.02-mins.
#
# 23: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3642, Accuracy: 86.90% ] || Test: [ Avg Loss: 0.4125, Accuracy: 85.31% ]
# Elapsed Inf. time: 0.02-mins.
#
# 24: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3643, Accuracy: 86.94% ] || Test: [ Avg Loss: 0.4052, Accuracy: 85.65% ]
# Elapsed Inf. time: 0.02-mins.
#
# 25: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3611, Accuracy: 87.08% ] || Test: [ Avg Loss: 0.4036, Accuracy: 85.73% ]
# Elapsed Inf. time: 0.02-mins.
#
# 26: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3583, Accuracy: 87.08% ] || Test: [ Avg Loss: 0.4010, Accuracy: 85.79% ]
# Elapsed Inf. time: 0.02-mins.
#
# 27: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3552, Accuracy: 87.21% ] || Test: [ Avg Loss: 0.3984, Accuracy: 86.10% ]
# Elapsed Inf. time: 0.02-mins.
#
# 28: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3521, Accuracy: 87.30% ] || Test: [ Avg Loss: 0.4118, Accuracy: 85.23% ]
# Elapsed Inf. time: 0.02-mins.
#
# 29: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3502, Accuracy: 87.39% ] || Test: [ Avg Loss: 0.4064, Accuracy: 85.86% ]
# Elapsed Inf. time: 0.02-mins.
#
# 30: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3496, Accuracy: 87.42% ] || Test: [ Avg Loss: 0.3933, Accuracy: 85.93% ]
# Elapsed Inf. time: 0.02-mins.
#
# *********************************************************************************
# Done! Run: 9 : [Best Test @ epoch 27] || [ Avg loss: 0.398391, Accuracy: 86.10% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9985],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# 1: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 1.2208, Accuracy: 66.78% ] || Test: [ Avg Loss: 0.7216, Accuracy: 73.70% ]
# Elapsed Inf. time: 0.02-mins.
#
# 2: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.6371, Accuracy: 77.56% ] || Test: [ Avg Loss: 0.5979, Accuracy: 78.86% ]
# Elapsed Inf. time: 0.02-mins.
#
# 3: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5691, Accuracy: 79.72% ] || Test: [ Avg Loss: 0.5873, Accuracy: 79.24% ]
# Elapsed Inf. time: 0.02-mins.
#
# 4: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5258, Accuracy: 81.26% ] || Test: [ Avg Loss: 0.5422, Accuracy: 80.85% ]
# Elapsed Inf. time: 0.02-mins.
#
# 5: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5066, Accuracy: 81.92% ] || Test: [ Avg Loss: 0.5056, Accuracy: 82.22% ]
# Elapsed Inf. time: 0.02-mins.
#
# 6: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4874, Accuracy: 82.61% ] || Test: [ Avg Loss: 0.5029, Accuracy: 81.89% ]
# Elapsed Inf. time: 0.02-mins.
#
# 7: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4732, Accuracy: 83.09% ] || Test: [ Avg Loss: 0.4887, Accuracy: 82.83% ]
# Elapsed Inf. time: 0.02-mins.
#
# 8: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4648, Accuracy: 83.47% ] || Test: [ Avg Loss: 0.4746, Accuracy: 83.52% ]
# Elapsed Inf. time: 0.02-mins.
#
# 9: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4507, Accuracy: 83.97% ] || Test: [ Avg Loss: 0.4753, Accuracy: 83.47% ]
# Elapsed Inf. time: 0.02-mins.
#
# 10: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4422, Accuracy: 84.26% ] || Test: [ Avg Loss: 0.4765, Accuracy: 83.07% ]
# Elapsed Inf. time: 0.02-mins.
#
# 11: Elapsed Train time: 0.24-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4320, Accuracy: 84.52% ] || Test: [ Avg Loss: 0.4705, Accuracy: 83.61% ]
# Elapsed Inf. time: 0.02-mins.
#
# 12: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4271, Accuracy: 84.67% ] || Test: [ Avg Loss: 0.4521, Accuracy: 84.00% ]
# Elapsed Inf. time: 0.02-mins.
#
# 13: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4181, Accuracy: 84.85% ] || Test: [ Avg Loss: 0.4464, Accuracy: 84.30% ]
# Elapsed Inf. time: 0.02-mins.
#
# 14: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4152, Accuracy: 85.13% ] || Test: [ Avg Loss: 0.4432, Accuracy: 84.40% ]
# Elapsed Inf. time: 0.02-mins.
#
# 15: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4071, Accuracy: 85.34% ] || Test: [ Avg Loss: 0.4421, Accuracy: 84.39% ]
# Elapsed Inf. time: 0.02-mins.
#
# 16: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4052, Accuracy: 85.52% ] || Test: [ Avg Loss: 0.4514, Accuracy: 84.53% ]
# Elapsed Inf. time: 0.02-mins.
#
# 17: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3964, Accuracy: 85.69% ] || Test: [ Avg Loss: 0.4319, Accuracy: 84.86% ]
# Elapsed Inf. time: 0.02-mins.
#
# 18: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3929, Accuracy: 85.81% ] || Test: [ Avg Loss: 0.4280, Accuracy: 85.00% ]
# Elapsed Inf. time: 0.02-mins.
#
# 19: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3917, Accuracy: 85.84% ] || Test: [ Avg Loss: 0.4215, Accuracy: 84.95% ]
# Elapsed Inf. time: 0.02-mins.
#
# 20: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3866, Accuracy: 85.95% ] || Test: [ Avg Loss: 0.4282, Accuracy: 84.91% ]
# Elapsed Inf. time: 0.02-mins.
#
# 21: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3822, Accuracy: 86.24% ] || Test: [ Avg Loss: 0.4180, Accuracy: 85.32% ]
# Elapsed Inf. time: 0.02-mins.
#
# 22: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3773, Accuracy: 86.38% ] || Test: [ Avg Loss: 0.4276, Accuracy: 85.11% ]
# Elapsed Inf. time: 0.02-mins.
#
# 23: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3737, Accuracy: 86.56% ] || Test: [ Avg Loss: 0.4122, Accuracy: 85.52% ]
# Elapsed Inf. time: 0.02-mins.
#
# 24: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3729, Accuracy: 86.47% ] || Test: [ Avg Loss: 0.4168, Accuracy: 85.33% ]
# Elapsed Inf. time: 0.02-mins.
#
# 25: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3688, Accuracy: 86.67% ] || Test: [ Avg Loss: 0.4084, Accuracy: 85.64% ]
# Elapsed Inf. time: 0.02-mins.
#
# 26: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3662, Accuracy: 86.70% ] || Test: [ Avg Loss: 0.4205, Accuracy: 84.82% ]
# Elapsed Inf. time: 0.02-mins.
#
# 27: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3623, Accuracy: 86.96% ] || Test: [ Avg Loss: 0.4056, Accuracy: 85.83% ]
# Elapsed Inf. time: 0.02-mins.
#
# 28: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3634, Accuracy: 86.76% ] || Test: [ Avg Loss: 0.4101, Accuracy: 85.77% ]
# Elapsed Inf. time: 0.02-mins.
#
# 29: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3609, Accuracy: 86.91% ] || Test: [ Avg Loss: 0.4026, Accuracy: 85.67% ]
# Elapsed Inf. time: 0.02-mins.
#
# 30: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3556, Accuracy: 87.12% ] || Test: [ Avg Loss: 0.4041, Accuracy: 85.71% ]
# Elapsed Inf. time: 0.02-mins.
#
# **********************************************************************************
# Done! Run: 10 : [Best Test @ epoch 27] || [ Avg loss: 0.405640, Accuracy: 85.83% ]
# **********************************************************************************
#
# Effective Test Accuracy=85.82033333333334, pval=5.684341886080802e-14

# %%
# Plots

plotter_v1(cfgs,run_idx=1)
