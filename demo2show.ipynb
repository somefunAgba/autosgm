# %% [markdown]
# ##### Load Required Libraries

# %%
# !pip install watermark numpy pandas matplotlib torch torchvision torchaudio --yes

# %load_ext watermark
# %watermark -v -p watermark,numpy,pandas,matplotlib,torch

#
import math,random,os,copy,time,glob,itertools,shutil,re, json
from scipy.stats import wilcoxon

#
import numpy as np

#
import torch
import torch.nn as nn
import torch.nn.functional as tf
from torch.utils.data import Dataset,DataLoader
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor, Lambda

#
import pandas as pd


#
from demofcns import *
from opts.asgm.torchlasgm import PID
from opts.elpf.fo import LPF
from opts.elpf.esfo import esLPF

worker_seed = 2023
def setseed(inc=0):
    # for redundancy
    # set seed for technical reproducibility
    myseed = worker_seed + inc
    random.seed(myseed)
    np.random.seed(myseed)
    np.random.default_rng(myseed)
    torch.manual_seed(myseed)    
    
    # torch.use_deterministic_algorithms(True)
    if torch.cuda.device_count() > 0:
      torch.cuda.manual_seed_all(myseed)
      torch.cuda.manual_seed(myseed)
      # torch.backends.cudnn.enabled = True
      # torch.backends.cuda.matmul.allow_tf32 = False
      # torch.backends.cudnn.benchmark = False
      # torch.backends.cudnn.deterministic = False
      # torch.backends.cudnn.allow_tf32 = True



class cseed_worker():
  def __init__(self,inc=0):
    self.inc = inc
    
  def seed_worker(self,workerid):
    np.random.seed(worker_seed+self.inc)
    random.seed(worker_seed+self.inc)

cseedwk = cseed_worker()

# python3 -m torch.utils.collect_env
# Out:
# Python implementation: CPython
# Python version       : 3.10.6
# IPython version      : 8.4.0
#
# watermark : 2.3.1
# numpy     : 1.23.2
# pandas    : 1.4.3
# matplotlib: 3.5.3
# torch     : 1.12.1+cu116

# %% [markdown]
# ##### Setup Configurations (Hyperparameters and so on)

# %%
# - is it being run remotely on OSU EECS server?
remotelyrun = 0 # 0 | 1

#----------------------
# Load setup config
#----------------------
with open('cfgs.json', 'r') as cfglist:
  cfgs = json.load(cfglist)
  
# setup
cfgs['storedir'] = "expstore"

# - pick data-set
cfgs["dataset"] = "fmnist"
# - set std. batchsize for each epoch, runs, epochs, multiprocessing, human
cfgs["batch-size"] = 128 # 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, ...
cfgs['runs'] = 10
cfgs["epochs"] = 30

# -pick computation device
devcnt = torch.cuda.device_count()

# random seed for python libraries
cfgs["seed"] = 2023
cfgs["var_seed"] = 1
worker_seed = cfgs["seed"] % (2**32)
cfgs["num-workers"] = 0 #3
cfgs["human_signature"] = "oas" # for signing experiments ran.



if devcnt > 1:
  cfgs["device"] = torch.device('cuda') # "cuda:1"
  torch.cuda.set_device(1)
elif devcnt == 1:
  cfgs["device"] = torch.device('cuda')
else:
  cfgs["device"] = torch.device('cpu')
#
if remotelyrun:
  cfgs["remote"] = True
else:
  cfgs["remote"] = False

# %% [markdown]
# ##### (Generate) or Load the Dataset

# %%
#----------------------
# Download/Load Dataset
#----------------------
if not cfgs["remote"]:
  # same dir. as source-code
  data_folder = "data"
else:
  # dalton's scratch on OSU's eecs server
  data_folder = "/scratch/data"


# FMNIST
if cfgs["dataset"] == "fmnist":
  train_data = datasets.FashionMNIST(
    root=data_folder,
    train=True,
    download=True,
    transform=ToTensor(),
  )
  test_data = datasets.FashionMNIST(
    root=data_folder,
    train=False,
    download= True,
    transform=ToTensor()
  )
  indim = [28,28]
  class_num = 10
  channels = 1
  val_data = None
  
# Tests 
trainloader = torch.utils.data.DataLoader(train_data, batch_size=cfgs['batch-size'],shuffle=True)
# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)
pass

# %% [markdown]
# ##### Construct Model (Differentiable Function) with  necessary methods.

# %%
class thisNN(nn.Module):
  def __init__(self,num_heads=1,in_feats=1,out_feats=1, loss_type="mse", outs_class=False, mdl_name="nn1") -> None:
    """
    __init__ _summary_

    _extended_summary_

    Args:
        num_heads (int, req): net. output head. Defaults to 1.
        in_feats (int, req): net. input dimension. Defaults to 1.
        out_feats (int, req): net. output dimension per head. Defaults to 1.
        loss_type (str, req): type of loss function Defaults to "mse". ("mse","mce" for multi-class cross-entropy, "bce" binary-class cross-entropy)
        outs_class (bool, req): does model return class indices. Defaults to False, implying it outputs real-valued probabilities. This is also true for loss_type="mse" regardless of user-choice.
    """
    super().__init__()
    self.num_heads = num_heads
    
    # define mdl. params.
    self.linearfcn = nn.ModuleList()
    
    self.keylinear = nn.ModuleList()
    self.valuelinear = nn.ModuleList()
    self.multiheadattn  = nn.ModuleList()
    self.ma_norm  = nn.ModuleList()
    for _ in range(num_heads):
      self.keylinear.append(
        nn.Sequential(
          torch.nn.Linear(in_features=in_feats[0],out_features=in_feats[0], bias=False),
          torch.nn.LayerNorm(normalized_shape=in_feats[0])
          )
      )
      self.valuelinear.append(
        nn.Sequential(
          torch.nn.Linear(in_features=in_feats[0],out_features=in_feats[0], bias=False),
          torch.nn.LayerNorm(normalized_shape=in_feats[0])
          )
      )
      self.multiheadattn.append(
            torch.nn.MultiheadAttention(in_feats[0],1,batch_first=True,)
      )
      
      self.ma_norm.append(
        torch.nn.LayerNorm(normalized_shape=in_feats[0])
      )
            
      self.linearfcn.append(
        torch.nn.Linear(in_features=in_feats[0]*in_feats[1],out_features=out_feats, bias=True)
      )

    self.relu = nn.ReLU()
    self.flatten = nn.Flatten()
    
    # prob.fcn at last output or network head layer
    if loss_type == "bce" or loss_type == "mse":
      self.out = torch.nn.Sigmoid()
    else:
      self.out = torch.nn.Softmax()
    
    self.loss_type = loss_type
    self.outs_class = outs_class
    
    # optimizer
    self.sgm = None
    
    # saved trained model
    self.chkpt = None
    
    
    self.devcnt = torch.cuda.device_count()
    self.device = None
    self.name = mdl_name
    
    if not(loss_type == "mse" or loss_type =="mce" or loss_type == "bce"):
      raise ValueError(f"loss_type='{loss_type}' is not defined for this class")
    if (loss_type == "mse"):
      self.outs_class = False    
    
@clsmethod(thisNN)
def forward(self:thisNN, x):
  # pre-process
  x = x.squeeze() # N x 1 x 28 x 28 -> N x 28 x 28
  logits = []
  for hid in range(self.num_heads):
    # xq = x.permute(0,2,1)
    xq = x
    keylinear = self.keylinear[hid]
    valuelinear = self.valuelinear[hid]
    xk = xq + self.relu(keylinear(xq))
    xv = xq + self.relu(valuelinear(xq))
    
    multiheadattn = self.multiheadattn[hid]
    manorm = self.ma_norm[hid]
    y,_ = multiheadattn(xq,xk,xv)
    y = y + self.relu(manorm(y))
    
    
    # y = y.permute(0,2,1)
    y = self.flatten(y)
    linearfcn = self.linearfcn[hid]
    y = linearfcn(y)  
    logits.append(y)
    
  return logits # List [Tensor]

@clsmethod(thisNN)
def outhead(self:thisNN, x):
  probs = []
  for hid in range(self.num_heads):
    y = self.out(x[hid])
    probs.append(y)  
  return probs # List [Tensor]

# Add necessary functions to train model
add_to_thisnn(thisNN,worker_seed,setseed,cseedwk)

# Use saved mdl as
# mdl <-- load model function
# prediction = mdl.infer(input)

# %% [markdown]
# ##### Run the Network Modeling (Training)

# %%
# Test.

torch.manual_seed(2023)
devcnt = torch.cuda.device_count()

cfgs['mdl_name_dir'] = "nnfmnist"
isclassifier = True
cfgs["ss_init"] = 1e-3 # default 1e-3
cfgs["eps_ss"] = 5e-1 # default 5e-1
cfgs["weight_decay"] = 1e-5 # default 1e-5
mdl = thisNN(num_heads=1,in_feats=[28,28],out_feats=10,loss_type="mce",outs_class=isclassifier, mdl_name=cfgs['mdl_name_dir'])
if devcnt > 0:
    mdl.cuda()
cfgs['pathstr'] = str(mdl.name)+str(cfgs["batch-size"])+"_"+cfgs["dataset"]+"_"+str(cfgs["runs"])+"_"+str(cfgs["epochs"])

mdl.runs(train_data, test_data, cfgs=cfgs, eval_name="Test")
# Out:
# Seed: 2023
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9985],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# ss0: 0.0034
# 1: Elapsed Train time: 0.32-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 1.0879, Accuracy: 70.28% ] || Test: [ Avg Loss: 0.5914, Accuracy: 79.04% ]
# Elapsed Inf. time: 0.02-mins.
#
# 2: Elapsed Train time: 0.25-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5712, Accuracy: 80.02% ] || Test: [ Avg Loss: 0.5267, Accuracy: 81.29% ]
# Elapsed Inf. time: 0.01-mins.
#
# 3: Elapsed Train time: 0.27-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5067, Accuracy: 82.18% ] || Test: [ Avg Loss: 0.5011, Accuracy: 82.46% ]
# Elapsed Inf. time: 0.02-mins.
#
# 4: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4756, Accuracy: 83.20% ] || Test: [ Avg Loss: 0.4791, Accuracy: 82.67% ]
# Elapsed Inf. time: 0.02-mins.
#
# 5: Elapsed Train time: 0.30-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4476, Accuracy: 84.07% ] || Test: [ Avg Loss: 0.4563, Accuracy: 84.01% ]
# Elapsed Inf. time: 0.02-mins.
#
# 6: Elapsed Train time: 0.30-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4310, Accuracy: 84.58% ] || Test: [ Avg Loss: 0.4278, Accuracy: 84.43% ]
# Elapsed Inf. time: 0.02-mins.
#
# 7: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4177, Accuracy: 85.00% ] || Test: [ Avg Loss: 0.4173, Accuracy: 85.01% ]
# Elapsed Inf. time: 0.02-mins.
#
# 8: Elapsed Train time: 0.30-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4080, Accuracy: 85.41% ] || Test: [ Avg Loss: 0.4114, Accuracy: 85.03% ]
# Elapsed Inf. time: 0.02-mins.
#
# 9: Elapsed Train time: 0.30-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3923, Accuracy: 85.91% ] || Test: [ Avg Loss: 0.4212, Accuracy: 84.84% ]
# Elapsed Inf. time: 0.02-mins.
#
# 10: Elapsed Train time: 0.30-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3875, Accuracy: 86.05% ] || Test: [ Avg Loss: 0.4016, Accuracy: 85.63% ]
# Elapsed Inf. time: 0.02-mins.
#
# 11: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3825, Accuracy: 86.23% ] || Test: [ Avg Loss: 0.3910, Accuracy: 85.83% ]
# Elapsed Inf. time: 0.02-mins.
#
# 12: Elapsed Train time: 0.35-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3710, Accuracy: 86.53% ] || Test: [ Avg Loss: 0.3936, Accuracy: 85.88% ]
# Elapsed Inf. time: 0.02-mins.
#
# 13: Elapsed Train time: 0.39-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3723, Accuracy: 86.47% ] || Test: [ Avg Loss: 0.3940, Accuracy: 85.73% ]
# Elapsed Inf. time: 0.03-mins.
#
# 14: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3614, Accuracy: 86.79% ] || Test: [ Avg Loss: 0.3949, Accuracy: 85.29% ]
# Elapsed Inf. time: 0.02-mins.
#
# 15: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3629, Accuracy: 86.95% ] || Test: [ Avg Loss: 0.3841, Accuracy: 86.12% ]
# Elapsed Inf. time: 0.02-mins.
#
# 16: Elapsed Train time: 0.40-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3528, Accuracy: 87.16% ] || Test: [ Avg Loss: 0.3895, Accuracy: 86.03% ]
# Elapsed Inf. time: 0.02-mins.
#
# 17: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3487, Accuracy: 87.27% ] || Test: [ Avg Loss: 0.3767, Accuracy: 86.52% ]
# Elapsed Inf. time: 0.02-mins.
#
# 18: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3476, Accuracy: 87.42% ] || Test: [ Avg Loss: 0.3821, Accuracy: 86.32% ]
# Elapsed Inf. time: 0.03-mins.
#
# 19: Elapsed Train time: 0.39-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.
]
# Elapsed Inf. time: 0.02-mins.
#
# 25: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3309, Accuracy: 88.07% ] || Test: [ Avg Loss: 0.3927, Accuracy: 86.02% ]
# Elapsed Inf. time: 0.03-mins.
#
# 26: Elapsed Train time: 0.36-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3308, Accuracy: 87.98% ] || Test: [ Avg Loss: 0.3877, Accuracy: 86.09% ]
# Elapsed Inf. time: 0.02-mins.
#
# 27: Elapsed Train time: 0.35-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3299, Accuracy: 88.02% ] || Test: [ Avg Loss: 0.3827, Accuracy: 86.22% ]
# Elapsed Inf. time: 0.03-mins.
#
# 28: Elapsed Train time: 0.32-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3243, Accuracy: 88.16% ] || Test: [ Avg Loss: 0.3958, Accuracy: 85.69% ]
# Elapsed Inf. time: 0.02-mins.
#
# 29: Elapsed Train time: 0.32-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3237, Accuracy: 88.31% ] || Test: [ Avg Loss: 0.3913, Accuracy: 86.18% ]
# Elapsed Inf. time: 0.02-mins.
#
# 30: Elapsed Train time: 0.34-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3207, Accuracy: 88.19% ] || Test: [ Avg Loss: 0.3778, Accuracy: 86.64% ]
# Elapsed Inf. time: 0.02-mins.
#
# *********************************************************************************
# Done! Run: 9 : [Best Test @ epoch 30] || [ Avg loss: 0.377839, Accuracy: 86.64% ]
# *********************************************************************************
#
# *******************************************************************************************************************************************************
# aSGM info:
# [step-size or linear correlation value (starting := 0.001), (ending := 0), step-size pole : 0.9985],
# [LPF Poles [i,n,o] : 0.9, 0.999, 1e-05]
# *******************************************************************************************************************************************************
#
# ss0: 0.0037
# 1: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 1.1261, Accuracy: 72.59% ] || Test: [ Avg Loss: 0.6321, Accuracy: 77.91% ]
# Elapsed Inf. time: 0.02-mins.
#
# 2: Elapsed Train time: 0.34-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5784, Accuracy: 79.98% ] || Test: [ Avg Loss: 0.5472, Accuracy: 81.15% ]
# Elapsed Inf. time: 0.02-mins.
#
# 3: Elapsed Train time: 0.34-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.5209, Accuracy: 81.63% ] || Test: [ Avg Loss: 0.5089, Accuracy: 82.34% ]
# Elapsed Inf. time: 0.02-mins.
#
# 4: Elapsed Train time: 0.33-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4828, Accuracy: 82.79% ] || Test: [ Avg Loss: 0.4875, Accuracy: 82.82% ]
# Elapsed Inf. time: 0.02-mins.
#
# 5: Elapsed Train time: 0.36-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4624, Accuracy: 83.44% ] || Test: [ Avg Loss: 0.4721, Accuracy: 83.39% ]
# Elapsed Inf. time: 0.02-mins.
#
# 6: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4409, Accuracy: 84.23% ] || Test: [ Avg Loss: 0.4587, Accuracy: 83.52% ]
# Elapsed Inf. time: 0.02-mins.
#
# 7: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4318, Accuracy: 84.40% ] || Test: [ Avg Loss: 0.4506, Accuracy: 84.10% ]
# Elapsed Inf. time: 0.02-mins.
#
# 8: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4214, Accuracy: 84.91% ] || Test: [ Avg Loss: 0.4354, Accuracy: 84.62% ]
# Elapsed Inf. time: 0.03-mins.
#
# 9: Elapsed Train time: 0.40-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.4091, Accuracy: 85.21% ] || Test: [ Avg Loss: 0.4375, Accuracy: 84.31% ]
# Elapsed Inf. time: 0.03-mins.
#
# 10: Elapsed Train time: 0.39-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3970, Accuracy: 85.67% ] || Test: [ Avg Loss: 0.4478, Accuracy: 83.75% ]
# Elapsed Inf. time: 0.02-mins.
#
# 11: Elapsed Train time: 0.35-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3884, Accuracy: 85.90% ] || Test: [ Avg Loss: 0.4320, Accuracy: 84.85% ]
# Elapsed Inf. time: 0.02-mins.
#
# 12: Elapsed Train time: 0.35-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3853, Accuracy: 86.02% ] || Test: [ Avg Loss: 0.4206, Accuracy: 85.36% ]
# Elapsed Inf. time: 0.02-mins.
#
# 13: Elapsed Train time: 0.36-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3740, Accuracy: 86.31% ] || Test: [ Avg Loss: 0.4181, Accuracy: 85.67% ]
# Elapsed Inf. time: 0.02-mins.
#
# 14: Elapsed Train time: 0.33-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3763, Accuracy: 86.39% ] || Test: [ Avg Loss: 0.4092, Accuracy: 85.59% ]
# Elapsed Inf. time: 0.02-mins.
#
# 15: Elapsed Train time: 0.37-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3642, Accuracy: 86.69% ] || Test: [ Avg Loss: 0.4181, Accuracy: 85.34% ]
# Elapsed Inf. time: 0.02-mins.
#
# 16: Elapsed Train time: 0.38-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3649, Accuracy: 86.84% ] || Test: [ Avg Loss: 0.4014, Accuracy: 85.82% ]
# Elapsed Inf. time: 0.02-mins.
#
# 17: Elapsed Train time: 0.33-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3590, Accuracy: 86.99% ] || Test: [ Avg Loss: 0.4045, Accuracy: 85.67% ]
# Elapsed Inf. time: 0.02-mins.
#
# 18: Elapsed Train time: 0.32-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3549, Accuracy: 87.11% ] || Test: [ Avg Loss: 0.3988, Accuracy: 85.81% ]
# Elapsed Inf. time: 0.02-mins.
#
# 19: Elapsed Train time: 0.32-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3511, Accuracy: 87.27% ] || Test: [ Avg Loss: 0.3952, Accuracy: 86.22% ]
# Elapsed Inf. time: 0.02-mins.
#
# 20: Elapsed Train time: 0.33-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3488, Accuracy: 87.22% ] || Test: [ Avg Loss: 0.3928, Accuracy: 86.09% ]
# Elapsed Inf. time: 0.02-mins.
#
# 21: Elapsed Train time: 0.32-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3477, Accuracy: 87.31% ] || Test: [ Avg Loss: 0.3873, Accuracy: 86.52% ]
# Elapsed Inf. time: 0.02-mins.
#
# 22: Elapsed Train time: 0.33-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3416, Accuracy: 87.47% ] || Test: [ Avg Loss: 0.4013, Accuracy: 85.56% ]
# Elapsed Inf. time: 0.02-mins.
#
# 23: Elapsed Train time: 0.32-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3367, Accuracy: 87.67% ] || Test: [ Avg Loss: 0.3904, Accuracy: 85.98% ]
# Elapsed Inf. time: 0.02-mins.
#
# 24: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3366, Accuracy: 87.59% ] || Test: [ Avg Loss: 0.3869, Accuracy: 86.30% ]
# Elapsed Inf. time: 0.02-mins.
#
# 25: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3347, Accuracy: 87.84% ] || Test: [ Avg Loss: 0.3921, Accuracy: 86.40% ]
# Elapsed Inf. time: 0.02-mins.
#
# 26: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3318, Accuracy: 87.78% ] || Test: [ Avg Loss: 0.4033, Accuracy: 85.35% ]
# Elapsed Inf. time: 0.02-mins.
#
# 27: Elapsed Train time: 0.31-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3310, Accuracy: 87.89% ] || Test: [ Avg Loss: 0.3955, Accuracy: 86.08% ]
# Elapsed Inf. time: 0.02-mins.
#
# 28: Elapsed Train time: 0.32-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3272, Accuracy: 88.01% ] || Test: [ Avg Loss: 0.3847, Accuracy: 86.47% ]
# Elapsed Inf. time: 0.02-mins.
#
# 29: Elapsed Train time: 0.29-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3260, Accuracy: 87.97% ] || Test: [ Avg Loss: 0.3882, Accuracy: 86.13% ]
# Elapsed Inf. time: 0.02-mins.
#
# 30: Elapsed Train time: 0.39-mins.
# Batches/Steps/Iterations per Epoch:   469
# Train:	[ Avg Loss: 0.3247, Accuracy: 88.05% ] || Test: [ Avg Loss: 0.3837, Accuracy: 86.33% ]
# Elapsed Inf. time: 0.02-mins.
#
# **********************************************************************************
# Done! Run: 10 : [Best Test @ epoch 21] || [ Avg loss: 0.387291, Accuracy: 86.52% ]
# **********************************************************************************
#
# ********************************************
# Average Prediction Difference = 0.10
# Effective Test Accuracy = 86.69, pval=0.0000
# ********************************************

# %%
# Plots

plotter_v1(cfgs,run_idx=1)
